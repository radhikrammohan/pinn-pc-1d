# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_norm import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# MPS is available
# Using device: mps
# MPS is available
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(25)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 1.0

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_max = props['k_l']
rho_max = props['rho_s']
cp_max = props['cp_l']
alpha_max = k_max / (rho_max * cp_max)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# The number of points in the initial condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+25002=25002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=100)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=10000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=10000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=10000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=10000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=100 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=10000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=10000 )  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=10000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=10000) # random sampler for bc right residuals

train_loader = DataLoader(inp_dataset, batch_size=256, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=256, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=256, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=256, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=256, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=256, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=256, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=256, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=256, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=256, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 8#  best yet is 8
output_size=1

learning_rate = 0.001 # 0.001
hidden_layers = 4  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =1000
epochs_2 = 10
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 2.7104e+00,| Test-Loss 2.5404e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5494e+00,| pde-loss 3.8164e-02,| initc-loss 1.2165e+00,|bc_loss 1.4557e+00|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9049e+00,| pde-loss-test 5.6139e-02,| initc-loss-test 1.1567e+00,|bc_loss-test 1.3556e+00|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 1.5556e+00,| Test-Loss 1.4884e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4041e-01,| pde-loss 1.1562e-02,| initc-loss 7.6300e-01,|bc_loss 7.8105e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5902e+00,| pde-loss-test 2.2787e-02,| initc-loss-test 7.3068e-01,|bc_loss-test 7.4632e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 9.4494e-01,| Test-Loss 8.8552e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9278e-01,| pde-loss 6.4247e-03,| initc-loss 4.8134e-01,|bc_loss 4.5718e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.2953e-01,| pde-loss-test 1.4920e-02,| initc-loss-test 4.4819e-01,|bc_loss-test 4.2986e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 3.4310e-01,| Test-Loss 2.8356e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7240e-01,| pde-loss 1.0500e-02,| initc-loss 1.5782e-01,|bc_loss 1.7478e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9199e-01,| pde-loss-test 2.0584e-02,| initc-loss-test 1.2158e-01,|bc_loss-test 1.5169e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 7.5317e-02,| Test-Loss 7.5222e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0345e-02,| pde-loss 7.1523e-03,| initc-loss 1.9713e-02,|bc_loss 4.8451e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0490e-02,| pde-loss-test 1.6296e-02,| initc-loss-test 1.5361e-02,|bc_loss-test 5.1713e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 8.2984e-02,| Test-Loss 7.8930e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9570e-02,| pde-loss 3.2495e-03,| initc-loss 1.9866e-02,|bc_loss 5.9868e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8909e-02,| pde-loss-test 5.9314e-03,| initc-loss-test 1.6883e-02,|bc_loss-test 5.9081e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 4.5558e-02,| Test-Loss 4.3273e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0748e-02,| pde-loss 1.5621e-03,| initc-loss 1.7335e-02,|bc_loss 2.6661e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.7344e-02,| pde-loss-test 3.4899e-03,| initc-loss-test 1.6788e-02,|bc_loss-test 2.4741e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 4.2538e-02,| Test-Loss 4.4568e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3502e-03,| pde-loss 1.4798e-03,| initc-loss 2.5478e-02,|bc_loss 1.5580e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1353e-02,| pde-loss-test 2.6812e-03,| initc-loss-test 2.7709e-02,|bc_loss-test 1.5519e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 3.4677e-02,| Test-Loss 3.4737e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4570e-03,| pde-loss 1.1189e-03,| initc-loss 1.6633e-02,|bc_loss 1.6925e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1266e-02,| pde-loss-test 2.3272e-03,| initc-loss-test 1.6552e-02,|bc_loss-test 1.7021e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 2.8594e-02,| Test-Loss 3.2944e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5396e-03,| pde-loss 1.2773e-03,| initc-loss 8.9809e-03,|bc_loss 1.8336e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9817e-02,| pde-loss-test 2.2357e-03,| initc-loss-test 1.0393e-02,|bc_loss-test 2.1433e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 2.6638e-02,| Test-Loss 2.8497e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6653e-03,| pde-loss 1.3693e-03,| initc-loss 1.0341e-02,|bc_loss 1.4928e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7001e-02,| pde-loss-test 2.6244e-03,| initc-loss-test 9.8524e-03,|bc_loss-test 1.7333e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 2.3491e-02,| Test-Loss 2.1617e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2829e-03,| pde-loss 1.2594e-03,| initc-loss 9.8819e-03,|bc_loss 1.2350e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.4317e-03,| pde-loss-test 2.6750e-03,| initc-loss-test 8.0931e-03,|bc_loss-test 1.2187e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 2.0749e-02,| Test-Loss 2.0009e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.0261e-03,| pde-loss 1.5465e-03,| initc-loss 8.0388e-03,|bc_loss 1.1163e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.1354e-03,| pde-loss-test 3.2511e-03,| initc-loss-test 7.5807e-03,|bc_loss-test 1.0803e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 1.8207e-02,| Test-Loss 1.8192e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.0578e-03,| pde-loss 1.3968e-03,| initc-loss 6.4328e-03,|bc_loss 1.0378e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.6447e-03,| pde-loss-test 3.0481e-03,| initc-loss-test 6.8639e-03,|bc_loss-test 9.8039e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 1.5925e-02,| Test-Loss 1.6653e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1268e-03,| pde-loss 1.7115e-03,| initc-loss 5.5123e-03,|bc_loss 8.7017e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1820e-03,| pde-loss-test 3.8276e-03,| initc-loss-test 6.3088e-03,|bc_loss-test 8.4307e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 1.5254e-02,| Test-Loss 1.5681e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2081e-03,| pde-loss 1.9034e-03,| initc-loss 5.6203e-03,|bc_loss 7.7300e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9305e-03,| pde-loss-test 3.7437e-03,| initc-loss-test 4.9737e-03,|bc_loss-test 8.8356e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 1.3302e-02,| Test-Loss 1.5022e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0527e-03,| pde-loss 1.9146e-03,| initc-loss 4.8209e-03,|bc_loss 6.5662e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.4270e-03,| pde-loss-test 4.1866e-03,| initc-loss-test 4.7302e-03,|bc_loss-test 8.1983e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 1.1862e-02,| Test-Loss 1.1815e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0776e-03,| pde-loss 2.4159e-03,| initc-loss 3.7755e-03,|bc_loss 5.6708e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.6770e-03,| pde-loss-test 4.5911e-03,| initc-loss-test 4.0427e-03,|bc_loss-test 5.4767e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 1.1449e-02,| Test-Loss 1.1360e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6401e-03,| pde-loss 2.8681e-03,| initc-loss 3.4598e-03,|bc_loss 5.1210e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.4268e-03,| pde-loss-test 5.1981e-03,| initc-loss-test 4.0524e-03,|bc_loss-test 4.7086e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 9.9076e-03,| Test-Loss 1.2769e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5881e-03,| pde-loss 2.2749e-03,| initc-loss 3.1779e-03,|bc_loss 4.4549e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4689e-03,| pde-loss-test 5.2253e-03,| initc-loss-test 3.0016e-03,|bc_loss-test 7.1545e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 1.0239e-02,| Test-Loss 9.7185e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1624e-03,| pde-loss 2.9454e-03,| initc-loss 3.4805e-03,|bc_loss 3.8131e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6818e-03,| pde-loss-test 5.5497e-03,| initc-loss-test 2.9150e-03,|bc_loss-test 4.0287e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 9.0583e-03,| Test-Loss 9.1989e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1773e-03,| pde-loss 2.9070e-03,| initc-loss 2.6207e-03,|bc_loss 3.5307e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8864e-03,| pde-loss-test 6.0478e-03,| initc-loss-test 2.5883e-03,|bc_loss-test 3.5866e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 9.1633e-03,| Test-Loss 1.0962e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2362e-03,| pde-loss 3.2182e-03,| initc-loss 2.7774e-03,|bc_loss 3.1676e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3303e-03,| pde-loss-test 6.5546e-03,| initc-loss-test 2.5965e-03,|bc_loss-test 5.0880e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 8.6461e-03,| Test-Loss 8.2141e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.1262e-04,| pde-loss 2.7457e-03,| initc-loss 2.7775e-03,|bc_loss 3.1229e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9601e-03,| pde-loss-test 5.6350e-03,| initc-loss-test 2.4961e-03,|bc_loss-test 2.9005e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 7.9704e-03,| Test-Loss 7.8883e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0361e-03,| pde-loss 2.9472e-03,| initc-loss 2.2973e-03,|bc_loss 2.7260e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6721e-03,| pde-loss-test 5.5670e-03,| initc-loss-test 2.3373e-03,|bc_loss-test 2.7675e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 7.9773e-03,| Test-Loss 7.8457e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0228e-03,| pde-loss 2.7367e-03,| initc-loss 2.3600e-03,|bc_loss 2.8805e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7975e-03,| pde-loss-test 6.5625e-03,| initc-loss-test 2.0102e-03,|bc_loss-test 2.5543e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 7.8773e-03,| Test-Loss 7.5107e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1540e-04,| pde-loss 3.0451e-03,| initc-loss 2.2428e-03,|bc_loss 2.5894e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0229e-03,| pde-loss-test 6.3847e-03,| initc-loss-test 1.8724e-03,|bc_loss-test 2.4459e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 7.5295e-03,| Test-Loss 7.8890e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3320e-04,| pde-loss 2.8724e-03,| initc-loss 2.0846e-03,|bc_loss 2.5725e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6291e-03,| pde-loss-test 7.1576e-03,| initc-loss-test 1.8710e-03,|bc_loss-test 2.4392e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 7.3192e-03,| Test-Loss 7.0773e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5007e-04,| pde-loss 2.8524e-03,| initc-loss 2.0438e-03,|bc_loss 2.4230e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4444e-03,| pde-loss-test 6.0556e-03,| initc-loss-test 1.7849e-03,|bc_loss-test 2.2646e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 7.5940e-03,| Test-Loss 7.4215e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8090e-04,| pde-loss 3.2267e-03,| initc-loss 1.9892e-03,|bc_loss 2.3781e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2473e-03,| pde-loss-test 6.2576e-03,| initc-loss-test 1.8906e-03,|bc_loss-test 2.4020e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 7.2721e-03,| Test-Loss 7.0691e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3664e-04,| pde-loss 3.1345e-03,| initc-loss 1.7992e-03,|bc_loss 2.3384e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4815e-03,| pde-loss-test 5.8915e-03,| initc-loss-test 1.8244e-03,|bc_loss-test 2.2991e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 7.2211e-03,| Test-Loss 6.8168e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5579e-04,| pde-loss 3.1482e-03,| initc-loss 1.8674e-03,|bc_loss 2.2055e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4619e-03,| pde-loss-test 5.5840e-03,| initc-loss-test 1.9113e-03,|bc_loss-test 2.1135e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 7.0246e-03,| Test-Loss 7.0308e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8386e-04,| pde-loss 2.6641e-03,| initc-loss 1.6834e-03,|bc_loss 2.6771e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5163e-03,| pde-loss-test 5.7957e-03,| initc-loss-test 1.8800e-03,|bc_loss-test 2.2530e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 6.9133e-03,| Test-Loss 6.7283e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8369e-04,| pde-loss 3.1265e-03,| initc-loss 1.6584e-03,|bc_loss 2.1284e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0068e-03,| pde-loss-test 6.1914e-03,| initc-loss-test 1.5987e-03,|bc_loss-test 2.0340e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 6.6446e-03,| Test-Loss 6.7672e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8565e-04,| pde-loss 2.7910e-03,| initc-loss 1.6870e-03,|bc_loss 2.1666e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3514e-03,| pde-loss-test 6.1744e-03,| initc-loss-test 1.7121e-03,|bc_loss-test 1.9680e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 6.6592e-03,| Test-Loss 6.7035e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7641e-04,| pde-loss 2.8506e-03,| initc-loss 1.6074e-03,|bc_loss 2.2012e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.5628e-04,| pde-loss-test 5.9800e-03,| initc-loss-test 1.5667e-03,|bc_loss-test 2.1468e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 6.4943e-03,| Test-Loss 6.3640e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5101e-04,| pde-loss 2.8359e-03,| initc-loss 1.7058e-03,|bc_loss 1.9526e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1015e-03,| pde-loss-test 5.1057e-03,| initc-loss-test 1.6308e-03,|bc_loss-test 2.1803e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 6.2551e-03,| Test-Loss 9.0885e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9970e-04,| pde-loss 2.6533e-03,| initc-loss 1.5819e-03,|bc_loss 2.0200e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1833e-03,| pde-loss-test 6.0613e-03,| initc-loss-test 1.6235e-03,|bc_loss-test 4.4343e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 6.8511e-03,| Test-Loss 8.6326e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5006e-04,| pde-loss 3.0276e-03,| initc-loss 1.5398e-03,|bc_loss 2.2837e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4468e-03,| pde-loss-test 6.7694e-03,| initc-loss-test 1.3470e-03,|bc_loss-test 3.9008e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 6.6324e-03,| Test-Loss 6.5022e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1893e-04,| pde-loss 2.9254e-03,| initc-loss 1.6603e-03,|bc_loss 2.0467e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0052e-03,| pde-loss-test 5.9799e-03,| initc-loss-test 1.5753e-03,|bc_loss-test 1.9369e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 6.2606e-03,| Test-Loss 8.5706e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4737e-04,| pde-loss 2.5338e-03,| initc-loss 1.6388e-03,|bc_loss 2.0881e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2683e-03,| pde-loss-test 5.8166e-03,| initc-loss-test 1.5154e-03,|bc_loss-test 4.1469e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 6.1355e-03,| Test-Loss 6.3014e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4609e-04,| pde-loss 2.6365e-03,| initc-loss 1.5179e-03,|bc_loss 1.9811e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1540e-03,| pde-loss-test 6.1498e-03,| initc-loss-test 1.3672e-03,|bc_loss-test 1.8593e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 6.6943e-03,| Test-Loss 6.2290e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4688e-04,| pde-loss 2.8575e-03,| initc-loss 1.7073e-03,|bc_loss 2.1295e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6269e-04,| pde-loss-test 5.8680e-03,| initc-loss-test 1.4371e-03,|bc_loss-test 1.8579e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 6.0277e-03,| Test-Loss 8.0903e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6071e-04,| pde-loss 2.4457e-03,| initc-loss 1.5138e-03,|bc_loss 2.0682e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3223e-03,| pde-loss-test 5.0310e-03,| initc-loss-test 1.4919e-03,|bc_loss-test 4.0830e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 6.3400e-03,| Test-Loss 6.0363e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9058e-04,| pde-loss 2.8515e-03,| initc-loss 1.5050e-03,|bc_loss 1.9835e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0935e-03,| pde-loss-test 4.6325e-03,| initc-loss-test 1.6084e-03,|bc_loss-test 2.1117e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 6.0206e-03,| Test-Loss 6.1942e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4737e-04,| pde-loss 2.2993e-03,| initc-loss 1.5142e-03,|bc_loss 2.2070e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.4111e-04,| pde-loss-test 5.4394e-03,| initc-loss-test 1.4136e-03,|bc_loss-test 2.0609e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 5.9823e-03,| Test-Loss 7.8572e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1827e-04,| pde-loss 2.6077e-03,| initc-loss 1.4563e-03,|bc_loss 1.9183e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.4070e-04,| pde-loss-test 4.6806e-03,| initc-loss-test 1.4659e-03,|bc_loss-test 4.0510e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 6.4439e-03,| Test-Loss 5.9638e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6999e-04,| pde-loss 2.7922e-03,| initc-loss 1.4147e-03,|bc_loss 2.2369e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.8523e-04,| pde-loss-test 4.9679e-03,| initc-loss-test 1.3710e-03,|bc_loss-test 2.1088e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 5.9476e-03,| Test-Loss 6.0519e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9401e-04,| pde-loss 2.4129e-03,| initc-loss 1.5274e-03,|bc_loss 2.0074e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0274e-03,| pde-loss-test 4.9719e-03,| initc-loss-test 1.5607e-03,|bc_loss-test 2.0052e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 5.3134e-03,| Test-Loss 6.0636e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.8893e-04,| pde-loss 1.9865e-03,| initc-loss 1.4087e-03,|bc_loss 1.9183e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6486e-04,| pde-loss-test 4.8828e-03,| initc-loss-test 1.5110e-03,|bc_loss-test 2.1112e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 5.7156e-03,| Test-Loss 5.8185e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1451e-04,| pde-loss 2.1864e-03,| initc-loss 1.3366e-03,|bc_loss 2.1926e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9649e-04,| pde-loss-test 4.5793e-03,| initc-loss-test 1.3504e-03,|bc_loss-test 2.1784e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 5.7812e-03,| Test-Loss 5.8023e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.7166e-04,| pde-loss 2.2699e-03,| initc-loss 1.5096e-03,|bc_loss 2.0017e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3009e-03,| pde-loss-test 5.0128e-03,| initc-loss-test 1.3778e-03,|bc_loss-test 1.9181e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 5.8923e-03,| Test-Loss 5.4000e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3527e-04,| pde-loss 2.4232e-03,| initc-loss 1.5166e-03,|bc_loss 1.9526e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1374e-03,| pde-loss-test 4.3330e-03,| initc-loss-test 1.4285e-03,|bc_loss-test 1.8051e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 5.2976e-03,| Test-Loss 5.8590e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5211e-04,| pde-loss 1.8399e-03,| initc-loss 1.4731e-03,|bc_loss 1.9846e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1820e-04,| pde-loss-test 4.7526e-03,| initc-loss-test 1.4560e-03,|bc_loss-test 2.0267e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 5.3542e-03,| Test-Loss 6.0646e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.0226e-04,| pde-loss 2.1205e-03,| initc-loss 1.4119e-03,|bc_loss 1.8218e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.2569e-04,| pde-loss-test 5.2305e-03,| initc-loss-test 1.3716e-03,|bc_loss-test 2.0778e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 5.9044e-03,| Test-Loss 6.2005e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1632e-04,| pde-loss 2.5065e-03,| initc-loss 1.4123e-03,|bc_loss 1.9856e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3395e-04,| pde-loss-test 5.3591e-03,| initc-loss-test 1.3915e-03,|bc_loss-test 2.1295e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 6.0940e-03,| Test-Loss 5.5103e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9485e-04,| pde-loss 2.6971e-03,| initc-loss 1.4086e-03,|bc_loss 1.9883e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5674e-03,| pde-loss-test 4.4565e-03,| initc-loss-test 1.4206e-03,|bc_loss-test 1.8614e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 5.4851e-03,| Test-Loss 6.0495e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3949e-04,| pde-loss 2.3187e-03,| initc-loss 1.2792e-03,|bc_loss 1.8872e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4216e-04,| pde-loss-test 5.2750e-03,| initc-loss-test 1.3761e-03,|bc_loss-test 2.0359e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 5.2308e-03,| Test-Loss 5.3367e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3642e-04,| pde-loss 1.9894e-03,| initc-loss 1.4383e-03,|bc_loss 1.8031e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.9884e-04,| pde-loss-test 4.2301e-03,| initc-loss-test 1.3821e-03,|bc_loss-test 1.8395e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 5.5805e-03,| Test-Loss 5.7745e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5505e-04,| pde-loss 2.3996e-03,| initc-loss 1.3332e-03,|bc_loss 1.8477e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1037e-03,| pde-loss-test 4.4609e-03,| initc-loss-test 1.3915e-03,|bc_loss-test 2.1526e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 5.8227e-03,| Test-Loss 5.6649e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9893e-04,| pde-loss 2.5143e-03,| initc-loss 1.4768e-03,|bc_loss 1.8316e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.9245e-04,| pde-loss-test 4.6000e-03,| initc-loss-test 1.3953e-03,|bc_loss-test 1.9696e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 5.5478e-03,| Test-Loss 5.5869e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.3490e-04,| pde-loss 2.2829e-03,| initc-loss 1.4424e-03,|bc_loss 1.8226e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2956e-04,| pde-loss-test 4.7050e-03,| initc-loss-test 1.3478e-03,|bc_loss-test 1.8866e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 5.7620e-03,| Test-Loss 5.5439e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7033e-04,| pde-loss 2.3930e-03,| initc-loss 1.4819e-03,|bc_loss 1.8871e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2235e-03,| pde-loss-test 4.7189e-03,| initc-loss-test 1.3543e-03,|bc_loss-test 1.8301e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 6.1014e-03,| Test-Loss 6.0471e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5300e-04,| pde-loss 2.6899e-03,| initc-loss 1.4327e-03,|bc_loss 1.9788e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0333e-03,| pde-loss-test 5.3330e-03,| initc-loss-test 1.4284e-03,|bc_loss-test 1.9521e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 5.9817e-03,| Test-Loss 7.8350e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2634e-04,| pde-loss 2.2610e-03,| initc-loss 1.5350e-03,|bc_loss 2.1857e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.5922e-04,| pde-loss-test 4.7260e-03,| initc-loss-test 1.3318e-03,|bc_loss-test 4.1402e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 5.5057e-03,| Test-Loss 5.2706e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7947e-04,| pde-loss 2.0894e-03,| initc-loss 1.4659e-03,|bc_loss 1.9504e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3488e-04,| pde-loss-test 4.2382e-03,| initc-loss-test 1.4747e-03,|bc_loss-test 1.6768e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 5.6315e-03,| Test-Loss 5.4267e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1289e-04,| pde-loss 2.1947e-03,| initc-loss 1.4606e-03,|bc_loss 1.9762e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1665e-03,| pde-loss-test 4.7625e-03,| initc-loss-test 1.3763e-03,|bc_loss-test 1.6691e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 5.2955e-03,| Test-Loss 5.5108e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4008e-04,| pde-loss 2.1480e-03,| initc-loss 1.2301e-03,|bc_loss 1.9174e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6781e-04,| pde-loss-test 4.8847e-03,| initc-loss-test 1.2734e-03,|bc_loss-test 1.7951e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 5.1981e-03,| Test-Loss 5.4566e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3599e-04,| pde-loss 1.8267e-03,| initc-loss 1.3336e-03,|bc_loss 2.0378e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2327e-03,| pde-loss-test 4.3451e-03,| initc-loss-test 1.3552e-03,|bc_loss-test 1.9289e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 5.4386e-03,| Test-Loss 5.4739e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7409e-04,| pde-loss 2.2172e-03,| initc-loss 1.3173e-03,|bc_loss 1.9041e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4117e-03,| pde-loss-test 4.5438e-03,| initc-loss-test 1.2815e-03,|bc_loss-test 1.9205e-03|
# ...
# | Data-loss-test 1.0041e-03,| pde-loss-test 4.3427e-03,| initc-loss-test 1.2996e-03,|bc_loss-test 1.8939e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 781,            | Training-Loss 5.5336e-03,| Test-Loss 5.2818e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.7532e-04,| pde-loss 2.4141e-03,| initc-loss 1.3056e-03,|bc_loss 1.8139e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2206e-03,| pde-loss-test 4.5447e-03,| initc-loss-test 1.2525e-03,|bc_loss-test 1.7569e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 791,            | Training-Loss 5.3771e-03,| Test-Loss 5.3702e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.0759e-04,| pde-loss 2.1603e-03,| initc-loss 1.2626e-03,|bc_loss 1.9542e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.9938e-04,| pde-loss-test 4.4451e-03,| initc-loss-test 1.3365e-03,|bc_loss-test 1.8112e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 801,            | Training-Loss 5.5571e-03,| Test-Loss 4.9351e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.2965e-04,| pde-loss 2.3579e-03,| initc-loss 1.3140e-03,|bc_loss 1.8852e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6352e-04,| pde-loss-test 3.9806e-03,| initc-loss-test 1.2499e-03,|bc_loss-test 1.6950e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 811,            | Training-Loss 5.3870e-03,| Test-Loss 5.3936e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1159e-04,| pde-loss 1.9705e-03,| initc-loss 1.3637e-03,|bc_loss 2.0528e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.5115e-04,| pde-loss-test 4.3291e-03,| initc-loss-test 1.3465e-03,|bc_loss-test 1.8826e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 821,            | Training-Loss 5.2753e-03,| Test-Loss 5.1945e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9459e-04,| pde-loss 2.1515e-03,| initc-loss 1.3042e-03,|bc_loss 1.8196e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0424e-03,| pde-loss-test 4.4543e-03,| initc-loss-test 1.2617e-03,|bc_loss-test 1.7057e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 831,            | Training-Loss 5.4341e-03,| Test-Loss 5.1434e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4857e-04,| pde-loss 2.2298e-03,| initc-loss 1.4264e-03,|bc_loss 1.7779e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0097e-03,| pde-loss-test 4.5882e-03,| initc-loss-test 1.3133e-03,|bc_loss-test 1.5360e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 841,            | Training-Loss 5.4175e-03,| Test-Loss 5.2320e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1397e-04,| pde-loss 2.2640e-03,| initc-loss 1.3442e-03,|bc_loss 1.8093e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6402e-04,| pde-loss-test 4.2688e-03,| initc-loss-test 1.3251e-03,|bc_loss-test 1.7725e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 851,            | Training-Loss 5.7849e-03,| Test-Loss 5.2625e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.1439e-04,| pde-loss 2.6706e-03,| initc-loss 1.3081e-03,|bc_loss 1.8062e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3648e-03,| pde-loss-test 4.3547e-03,| initc-loss-test 1.2073e-03,|bc_loss-test 1.8779e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 861,            | Training-Loss 5.4551e-03,| Test-Loss 5.2780e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.7760e-04,| pde-loss 2.3487e-03,| initc-loss 1.3032e-03,|bc_loss 1.8032e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.3250e-04,| pde-loss-test 4.1509e-03,| initc-loss-test 1.2661e-03,|bc_loss-test 1.9365e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 871,            | Training-Loss 5.2493e-03,| Test-Loss 5.6274e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3119e-04,| pde-loss 2.1928e-03,| initc-loss 1.2512e-03,|bc_loss 1.8053e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0119e-03,| pde-loss-test 5.2906e-03,| initc-loss-test 1.2557e-03,|bc_loss-test 1.7265e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 881,            | Training-Loss 4.8846e-03,| Test-Loss 5.1301e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8690e-04,| pde-loss 1.9679e-03,| initc-loss 1.2839e-03,|bc_loss 1.6329e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2064e-03,| pde-loss-test 4.3649e-03,| initc-loss-test 1.2953e-03,|bc_loss-test 1.6523e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 891,            | Training-Loss 5.0087e-03,| Test-Loss 5.1187e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5774e-04,| pde-loss 1.9630e-03,| initc-loss 1.3243e-03,|bc_loss 1.7214e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1983e-03,| pde-loss-test 4.4971e-03,| initc-loss-test 1.2082e-03,|bc_loss-test 1.6619e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 901,            | Training-Loss 5.0115e-03,| Test-Loss 5.2609e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1536e-04,| pde-loss 2.0215e-03,| initc-loss 1.3291e-03,|bc_loss 1.6608e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2610e-03,| pde-loss-test 4.2941e-03,| initc-loss-test 1.3352e-03,|bc_loss-test 1.7787e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 911,            | Training-Loss 5.1703e-03,| Test-Loss 5.1319e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7885e-04,| pde-loss 2.2435e-03,| initc-loss 1.2982e-03,|bc_loss 1.6285e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3191e-03,| pde-loss-test 4.2660e-03,| initc-loss-test 1.2908e-03,|bc_loss-test 1.7081e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 921,            | Training-Loss 5.1208e-03,| Test-Loss 5.4609e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6664e-04,| pde-loss 2.0806e-03,| initc-loss 1.2515e-03,|bc_loss 1.7887e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1028e-03,| pde-loss-test 4.3902e-03,| initc-loss-test 1.2360e-03,|bc_loss-test 2.0297e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 931,            | Training-Loss 5.6480e-03,| Test-Loss 7.0118e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5374e-04,| pde-loss 2.5068e-03,| initc-loss 1.2043e-03,|bc_loss 1.9369e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0038e-03,| pde-loss-test 3.9348e-03,| initc-loss-test 1.2400e-03,|bc_loss-test 3.8044e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 941,            | Training-Loss 5.3595e-03,| Test-Loss 7.0223e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6541e-04,| pde-loss 2.2628e-03,| initc-loss 1.3156e-03,|bc_loss 1.7811e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.0833e-04,| pde-loss-test 3.8851e-03,| initc-loss-test 1.3586e-03,|bc_loss-test 3.7211e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 951,            | Training-Loss 5.3590e-03,| Test-Loss 4.8341e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5509e-04,| pde-loss 2.3306e-03,| initc-loss 1.3079e-03,|bc_loss 1.7204e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.7718e-04,| pde-loss-test 4.2816e-03,| initc-loss-test 1.2211e-03,|bc_loss-test 1.4722e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 961,            | Training-Loss 4.9153e-03,| Test-Loss 5.0288e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1040e-04,| pde-loss 1.9535e-03,| initc-loss 1.1671e-03,|bc_loss 1.7947e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3270e-03,| pde-loss-test 4.4376e-03,| initc-loss-test 1.1569e-03,|bc_loss-test 1.6532e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 971,            | Training-Loss 4.5615e-03,| Test-Loss 4.6669e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9710e-04,| pde-loss 1.7428e-03,| initc-loss 1.2371e-03,|bc_loss 1.5816e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1846e-03,| pde-loss-test 3.7547e-03,| initc-loss-test 1.2762e-03,|bc_loss-test 1.5134e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 981,            | Training-Loss 5.0956e-03,| Test-Loss 4.6104e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8591e-04,| pde-loss 2.1377e-03,| initc-loss 1.1883e-03,|bc_loss 1.7696e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2208e-03,| pde-loss-test 3.8782e-03,| initc-loss-test 1.2470e-03,|bc_loss-test 1.4244e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 991,            | Training-Loss 4.7932e-03,| Test-Loss 4.7554e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7237e-04,| pde-loss 2.0836e-03,| initc-loss 1.1048e-03,|bc_loss 1.6048e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2966e-03,| pde-loss-test 3.8366e-03,| initc-loss-test 1.2132e-03,|bc_loss-test 1.6239e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1000,            | Training-Loss 4.7752e-03,| Test-Loss 5.0615e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5833e-04,| pde-loss 1.8821e-03,| initc-loss 1.1999e-03,|bc_loss 1.6933e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6922e-04,| pde-loss-test 4.5594e-03,| initc-loss-test 1.1819e-03,|bc_loss-test 1.5999e-03|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,919.0,298.0) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[873.1366 ]
#  [878.1317 ]
#  [882.587  ]
#  ...
#  [829.05646]
#  [829.0729 ]
#  [829.0914 ]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings_2.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.0004511760724698042
# 1.0

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[873.1366 ]
#  [873.2155 ]
#  [873.2945 ]
#  ...
#  [840.6609 ]
#  [840.65656]
#  [840.65216]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

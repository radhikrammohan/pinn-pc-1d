# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools

from ht_simNy import sim1d



from pyDOE2 import fullfact
from pyDOE2 import fracfact

import statsmodels.api as sm

from statsmodels.formula.api import ols
from scipy.stats import ttest_ind
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### <center>Pareto analysis</center>

# %% [markdown]
# <p style="font-size:12px; font-family:'Times New Roman', sans-serif; line-height:1.6;">
#
# In this section sensitivity study of the soldification is performed with respect to different material properties and  initial/boundary conditions. The soldification time is the variable under study and it is calcualted based on solution of 1D heat transfer and phase change equation.
#
#
#
# Here the parameters/factors are as follows:-
#
# 1. Density for material in liquid state $\rho_l$.<br>
# 2. Density for material in solid state $\rho_s$.<br>
# 3. Latent Heat of Fusion <br>
# 4. Specific heat of material in liquid state $C_{pl}$ <br>
# 5. Specific heat of material in solid state $C_{ps}$ <br>
# 6. Thermal Conductivity of material in liquid state $k_l$<br>
# 7. Thermal Conductivity of material in solid state $k_s$ <br>
#
#
# Boundary conditions:-
# 8. Surrounding Temperature <br>
#
# Initial Conditions:-
#
# 9. Initial_temperature <br>
#
#
# </p>

# %% [markdown]
# The number of runs are large so a fractional factorial design is adopted.

# %% [markdown]
# ## Fractional Factorial Design

# %%
#Create a fractional factorial design

from pyDOE2 import fracfact

num_levels = 2
levels = [0, 1]
num_vars = 11
design2 = fracfact('a b c d e f ab ac ad ae af bc')
L_level = 0.99
R_level = 1.01
perc_change = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.3, 0.03, 0.60, 0.30,0.30]


factor_levels = {
    'rho_l': [2386.2, 2533.8], #A
    'rho_s': [2628.7, 2791.3], #B
    'k_l': [100.88,107.12],    #C
    'k_s': [93.31, 99.08],      #D
    'cp_l': [1207.94, 1282.65], #E
    'cp_s': [934.11, 991.89],  #F
    'Surr_temp': [285.0,298.0], #G
    'L_fusion': [377330.0, 400670.0], #H
    'temp_init': [901.0, 925.0], # J
    'heat_transfer_coefficient_left': [10.0, 15.0], #K
    'heat_transfer_coefficient_right': [11.0, 15.0], #L
    'Length': [10.0e-3, 20.0e-3],      #M
}


factor_names = list(factor_levels.keys())
# print (313.0 *(1+perc_change[6]))
# Create a DataFrame from the fractional factorial design
doe_df_sol_time_fracfact = pd.DataFrame(design2, columns=factor_names)

for factor, levels in factor_levels.items():
    doe_df_sol_time_fracfact[factor] = doe_df_sol_time_fracfact[factor].map({-1: levels[0], 1: levels[1]})

    
print(doe_df_sol_time_fracfact.shape)
# Out:
# (64, 12)

# %%
FracFact_doe_sol_time = doe_df_sol_time_fracfact.copy()

FracFact_doe_sol_time['Lowest_Niyama'] = [0.0] * FracFact_doe_sol_time.shape[0] # Data frame inclduing the response variable

print(FracFact_doe_sol_time.shape)

# %%
for i in range(FracFact_doe_sol_time.shape[0]):
    input_values = FracFact_doe_sol_time.iloc[i,:-1].values
    if input_values.size > 0:
        k = sim1d(*input_values)
        FracFact_doe_sol_time.at[i, 'Lowest_Niyama'] = k

# %% [markdown]
# ### Histogram of the Total Solidifcation time is plotted

# %%
plt.hist(FracFact_doe_sol_time['Lowest_Niyama'], bins=10, alpha=0.5, color='b')
plt.title('Lowest Niyama')
plt.xlabel('Dimensionless Niyama Number')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Regression model is developed

# %%
# Create the formula for the ANOVA
formula = 'Lowest_Niyama ~ C(rho_l) + C(rho_s) + C(k_l) + C(k_s) + \
           C(cp_l) + C(cp_s) + C(Surr_temp) + C(L_fusion) \
         + C(temp_init)+ C(heat_transfer_coefficient_left) + C(heat_transfer_coefficient_right)+ C(Length) \
         + C(rho_l):C(k_s) + C(rho_s):C(cp_l) + C(k_l):C(cp_s) + C(Surr_temp):C(L_fusion) + \
              C(temp_init):C(heat_transfer_coefficient_right) + C(heat_transfer_coefficient_left):C(Length)'

# Fit the model
model = sm.OLS.from_formula(formula, data=FracFact_doe_sol_time).fit()
print(model.summary())

# %% [markdown]
# ### Plot of Residuals

# %%
residuals_ols = model.resid
FracFact_doe_sol_time['Residuals'] =residuals_ols
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model.fittedvalues, residuals_ols)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Fitted Values')
plt.xlabel('Seconds')
plt.ylabel('Residuals')
plt.show()


# print (f"This is followed by the histogram of the residuals")
# plt.hist(residuals_ols, bins=10, alpha=0.5, color='b')
# plt.title('Residuals Histogram')
# plt.xlabel('Seconds')
# plt.ylabel('Frequency')
# plt.show()

# %% [markdown]
# ### Normality of Residuals check

# %%
from scipy.stats import shapiro

# Shapiro-Wilk Test
stat, p_value = shapiro(residuals_ols)
print('Shapiro-Wilk Test Statistic:', stat)
print('p-value:', p_value)

if p_value > 0.05:
    print('The residuals are normally distributed (fail to reject H0).')
else:
    print('The residuals are not normally distributed (reject H0).')

# %%
from statsmodels.formula.api import ols
# Create the formula for the ANOVA

formula = 'Lowest_Niyama ~ C(rho_l) + C(rho_s) + C(k_l) + C(k_s) + \
           C(cp_l) + C(cp_s) + C(Surr_temp) + C(L_fusion) \
         + C(temp_init)+ C(heat_transfer_coefficient_left) + C(heat_transfer_coefficient_right)+ C(Length) \
         + C(rho_l):C(k_s) + C(rho_s):C(cp_l) + C(k_l):C(cp_s) + C(Surr_temp):C(L_fusion) + \
              C(temp_init):C(heat_transfer_coefficient_right) + C(heat_transfer_coefficient_left):C(Length)'

# Fit the model
model_anova = ols(formula, data=FracFact_doe_sol_time).fit()

# Perform ANOVA
anova_results = sm.stats.anova_lm(model_anova, typ=2)

# Display the ANOVA results
print(anova_results)
print(model.summary())

# %% [markdown]
# ### ANOVA Results

# %%
from scipy.stats import f
# Create a DataFrame from the ANOVA results
anova_results_df = anova_results.reset_index()

# Sort by the F-statistic or sum of squares for visualization
anova_results_df = anova_results_df.sort_values(by='F', ascending=False)

dfn = anova_results_df['df'][0]
dfd = model.df_resid

alpha = 0.05
f_critical = f.ppf(1-alpha, dfn, dfd)
print(f'Critical F-value: {f_critical}')

# Plot the Pareto chart
plt.figure(figsize=(10, 6))
plt.bar(anova_results_df['index'], anova_results_df['F'], color='b')
plt.axhline(f_critical, color='r', linestyle='--',linewidth=2)
plt.xlabel('Factors')
plt.ylabel('F-statistic')
plt.title('Pareto Chart of ANOVA F-statistics')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Main effects and Interactions Terms Analysis

# %%
mean_response = {}

for factor in factor_names:
    mean_response[factor] = FracFact_doe_sol_time.groupby(factor)['Lowest_Niyama'].mean()

plt.figure(figsize=(25, 10))

for i, factor in enumerate(factor_names):
    plt.subplot(2, 6, i+1)
    plt.plot(mean_response[factor], marker='o', color='b')
    plt.title(f'Mean Response vs. {factor}')
    plt.xlabel(factor)
    plt.ylabel('Lowest_Niyama')

plt.tight_layout()
plt.show()

# %%
# # Function to plot interaction effects
# def plot_interaction(df, factor1, factor2, response):
#     levels1 = sorted(df[factor1].unique())
#     levels2 = sorted(df[factor2].unique())
    
#     mean_responses = df.groupby([factor1, factor2])[response].mean().unstack()
    
#     plt.figure()
#     for level2 in levels2:
        
#         plt.plot(levels1, mean_responses[level2], marker='o', label=f'{factor2}={level2}')
#     plt.xlabel(factor1)
#     plt.ylabel(f'Mean {response}')
#     plt.title(f'Interaction Effect of {factor1} and {factor2}')
#     plt.legend()
#     plt.show()

# # Plot interaction effects for each pair of factors
# plt.figure(figsize=(10, 6))

# for i in range(len(factor_names)):
    
#     for j in range(i+1, len(factor_names)):
        
#         plot_interaction(FracFact_doe_sol_time, factor_names[i], factor_names[j], 'total_sol_time')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# The interaction was observed among rho_l and cp_s , rho_s and cp_s , cp_l and cp_s  & cp_s and temp_init.

# %% [markdown]
# ## Center points check

# %%
num_center_points = 1

center_point = {factor: np.mean(levels) for factor,levels in factor_levels.items()}

center_pt_df = pd.DataFrame([center_point] * num_center_points, columns=factor_names)

doe_center_pt = pd.concat([doe_df_sol_time_fracfact, center_pt_df], ignore_index=True)
print(doe_center_pt.shape)
# Out:
# (65, 12)

# %% [markdown]
# ### Factorial design

# %%
Fractional_Factorial_doe_center_pt = doe_center_pt.copy()

Fractional_Factorial_doe_center_pt['Lowest_Niyama'] = [0.0] * Fractional_Factorial_doe_center_pt.shape[0]

print(Fractional_Factorial_doe_center_pt.shape)
# Out:
# (65, 13)

# %%
for i in range(Fractional_Factorial_doe_center_pt.shape[0]):
    input_values = Fractional_Factorial_doe_center_pt.iloc[i,:-1].values
    k= sim1d(*input_values)
    Fractional_Factorial_doe_center_pt.at[i, 'Lowest_Niyama'] = k
# Out:
# Lowest Niyama:6.22, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.57, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:2.71, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.53, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:3.17, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.64, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:4.81, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.13, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:5.96, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.8, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:2.6, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.45, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:3.04, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.52, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:4.61, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.29, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.01, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:7.89, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.44, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.02, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.01, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.41, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:4.44, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.01, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:7.25, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.6, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.24, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:4.83, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:934.11, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:4.19, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.01, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.06, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.87, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:2.2, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.38, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:4.44, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.01, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:0.29, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.01
# Lowest Niyama:1.23, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# Lowest Niyama:2.45, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:11.0,length:0.02
# Lowest Niyama:0.01, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1207.94, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.17, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:10.01, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.38, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:3.38, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.59, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:5.56, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:6.53, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:93.31, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.3, rho_l:2386.2, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:9.59, rho_l:2533.8, rho_s:2628.7, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:0.32, rho_l:2386.2, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:3.24, rho_l:2533.8, rho_s:2791.3, k_l:100.88, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.51, rho_l:2386.2, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.01
# Lowest Niyama:5.33, rho_l:2533.8, rho_s:2628.7, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.01
# Lowest Niyama:0.0, rho_l:2386.2, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:285.0, L_fusion:377330.0, temp_init:901.0,htc_l:10.0,htc_r:11.0,length:0.02
# Lowest Niyama:6.26, rho_l:2533.8, rho_s:2791.3, k_l:107.12, k_s:99.08, cp_l:1282.65, cp_s:991.89, t_surr:298.0, L_fusion:400670.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# Lowest Niyama:1.11, rho_l:2460.0, rho_s:2710.0, k_l:104.0, k_s:96.195, cp_l:1245.295, cp_s:963.0, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:13.0,length:0.015

# %% [markdown]
# CSV file generator

# %% [markdown]
# ### Plot

# %%
counts = range(1,len(Fractional_Factorial_doe_center_pt)+1)

plt.scatter(counts,Fractional_Factorial_doe_center_pt['Lowest_Niyama'], alpha=0.5, color='b')
plt.title('Lowest Niyama')
plt.xlabel('Index')
plt.ylabel('Lowest Niyama')
plt.show()

# %% [markdown]
# ### Regression Model

# %%
formula5 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model5 = sm.OLS.from_formula(formula5, data=Fractional_Factorial_doe_center_pt.iloc[:-1]).fit()
print(model5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     9.717
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           1.84e-09
# Time:                        10:36:33   Log-Likelihood:                -115.11
# No. Observations:                  64   AIC:                             256.2
# Df Residuals:                      51   BIC:                             284.3
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                         -14.2373     25.612     -0.556      0.581     -65.656      37.182
# rho_l                               0.0065      0.003      2.344      0.023       0.001       0.012
# rho_s                              -0.0052      0.003     -2.046      0.046      -0.010   -9.79e-05
# k_l                                -0.0669      0.066     -1.019      0.313      -0.199       0.065
# k_s                                -0.0062      0.071     -0.088      0.930      -0.149       0.136
# cp_l                                0.0105      0.005      1.918      0.061      -0.000       0.022
# cp_s                                0.0028      0.007      0.390      0.698      -0.011       0.017
# Surr_temp                          -0.0292      0.031     -0.926      0.359      -0.092       0.034
# L_fusion                        -1.004e-06   1.75e-05     -0.057      0.955   -3.62e-05    3.42e-05
# temp_init                          -0.0009      0.017     -0.051      0.959      -0.035       0.033
# heat_transfer_coefficient_left      0.6871      0.082      8.391      0.000       0.523       0.851
# heat_transfer_coefficient_right     0.3415      0.102      3.336      0.002       0.136       0.547
# Length                            181.4063     40.940      4.431      0.000      99.217     263.596
# ==============================================================================
# Omnibus:                        2.549   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.280   Jarque-Bera (JB):                2.480
# Skew:                          -0.456   Prob(JB):                        0.289
# Kurtosis:                       2.688   Cond. No.                     7.79e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.79e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model5.predict(Fractional_Factorial_doe_center_pt.iloc[-1])
print(f'Predicted value of the response variable: {y_pred.values[0]}')
error = Fractional_Factorial_doe_center_pt.iloc[-1]['Lowest_Niyama'] - y_pred.values[0]
print(f'Prediction error: {error}')

# Perform a t-test to determine if the prediction error is significantly different from zero
# Extract the residuals from the model
residuals = model5.resid

# Calculate the mean and standard error of the residuals
mean_residuals = np.mean(residuals)
std_error = np.std(residuals, ddof=1) / np.sqrt(len(residuals))

# Perform t-test on the prediction error
t_statistic = (error - mean_residuals) / std_error
df = len(residuals) - 1  # Degrees of freedom
p_value = 2 * (1 - stats.t.cdf(np.abs(t_statistic), df))

print(f't-statistic: {t_statistic}')
print(f'p-value: {p_value}')

# Interpretation of the t-test result
if p_value < 0.05:
    print("The prediction error is significantly different from zero (reject null hypothesis).")
else:
    print("The prediction error is not significantly different from zero (fail to reject null hypothesis).")
# Out:
# Predicted value of the response variable: 2.054843749998666
# Prediction error: -0.9448437499986657
# t-statistic: -5.130163612341615
# p-value: 2.990034398742125e-06
# The prediction error is significantly different from zero (reject null hypothesis).

# %%
residual5 = model5.resid
Fractional_Factorial_doe_center_pt['Residuals'] =residual5
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model5.fittedvalues, residual5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Model Output')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# #### Anova

# %%
from statsmodels.formula.api import ols

formula7 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model7 = ols(formula7, data=Fractional_Factorial_doe_center_pt).fit()

anova_results7 = sm.stats.anova_lm(model7, typ=2)

print(anova_results7)
# Out:
#                                      sum_sq    df          F        PR(>F)
# rho_l                             14.736002   1.0   5.567018  2.209179e-02
# rho_s                             11.230877   1.0   4.242840  4.443777e-02
# k_l                                2.784727   1.0   1.052024  3.097893e-01
# k_s                                0.020664   1.0   0.007807  9.299342e-01
# cp_l                               9.867452   1.0   3.727760  5.897583e-02
# cp_s                               0.408002   1.0   0.154136  6.962183e-01
# Surr_temp                          2.299014   1.0   0.868530  3.556697e-01
# L_fusion                           0.008789   1.0   0.003320  9.542701e-01
# temp_init                          0.007014   1.0   0.002650  9.591433e-01
# heat_transfer_coefficient_left   188.821952   1.0  71.333817  2.529358e-11
# heat_transfer_coefficient_right   29.852564   1.0  11.277806  1.473819e-03
# Length                            52.653164   1.0  19.891496  4.408817e-05
# Residual                         137.644975  52.0        NaN           NaN

# %% [markdown]
# #### Main effects with center points

# %%
mean_response_center = {}

for factor in factor_names:
    mean_response_center[factor] = Fractional_Factorial_doe_center_pt.groupby(factor)['Lowest_Niyama'].mean()

# print(mean_response_center)
plt.figure(figsize=(25, 10))

for i, factor in enumerate(factor_names):
    plt.subplot(2, 8, i+1)

    mean_responses = mean_response_center[factor]


    center_point = mean_responses.iloc[-2]
    center_point_index = mean_responses.index[-2]
    # print(center_point_index,center)
    non_center_points_low = mean_responses.iloc[0]
    non_center_points_low_index = mean_responses.index[0]
    non_center_points_high = mean_responses.iloc[-1]
    non_center_points_high_index = mean_responses.index[-1]

    plt.plot([non_center_points_low_index,non_center_points_high_index], [non_center_points_low,non_center_points_high],marker='o', color='b')
    
    # Plotting the center points
    center_points = mean_response_center[factor]
    plt.scatter([center_point_index], [center_point], color='r', label='Center Points')
    
    # # Plot all individual data points for the factor
    # all_data_points = Fractional_Factorial_doe_center_pt.groupby(factor)['Lowest_Niyama']
    # for key, group in all_data_points:
    #     plt.scatter([key]*len(group), group, alpha=0.3, color='gray')

    plt.title(f'Mean Response vs. {factor}')
    plt.xlabel(factor)
    plt.ylabel('Lowest_Niyama')

plt.tight_layout()
plt.show()

# %%
formula8 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length + rho_l*rho_s + rho_l:rho_s + rho_l:heat_transfer_coefficient_left + rho_l:heat_transfer_coefficient_right + rho_l:Length + rho_s:heat_transfer_coefficient_left + rho_s:heat_transfer_coefficient_right + rho_s:Length + heat_transfer_coefficient_left:heat_transfer_coefficient_right + heat_transfer_coefficient_left:Length + heat_transfer_coefficient_right:Length'

# %%
model8 = ols(formula8, data=Fractional_Factorial_doe_center_pt).fit()
print(model8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     62.39
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           2.80e-26
# Time:                        12:12:01   Log-Likelihood:                -49.991
# No. Observations:                  65   AIC:                             138.0
# Df Residuals:                      46   BIC:                             179.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                      -9.211e-06   2.82e-06     -3.264      0.002   -1.49e-05   -3.53e-06
# rho_l                                                             -0.0284      0.009     -3.113      0.003      -0.047      -0.010
# rho_s                                                              0.0183      0.010      1.833      0.073      -0.002       0.038
# k_l                                                                0.0401      0.036      1.123      0.267      -0.032       0.112
# k_s                                                               -0.0062      0.027     -0.232      0.818      -0.060       0.048
# cp_l                                                               0.0061      0.003      2.061      0.045       0.000       0.012
# cp_s                                                               0.0035      0.004      0.917      0.364      -0.004       0.011
# Surr_temp                                                         -0.0345      0.012     -2.984      0.005      -0.058      -0.011
# L_fusion                                                       -1.004e-06   6.65e-06     -0.151      0.881   -1.44e-05    1.24e-05
# temp_init                                                         -0.0009      0.006     -0.135      0.893      -0.014       0.012
# heat_transfer_coefficient_left                                 -5.788e-06   5.51e-05     -0.105      0.917      -0.000       0.000
# heat_transfer_coefficient_right                                 4.573e-06   5.81e-05      0.079      0.938      -0.000       0.000
# Length                                                            -0.0003   7.38e-05     -4.132      0.000      -0.000      -0.000
# rho_l:rho_s                                                     5.799e-06   1.67e-06      3.478      0.001    2.44e-06    9.16e-06
# rho_l:heat_transfer_coefficient_left                               0.0009      0.000      2.064      0.045     2.2e-05       0.002
# rho_l:heat_transfer_coefficient_right                             -0.0001      0.001     -0.274      0.785      -0.001       0.001
# rho_l:Length                                                       0.6661      0.210      3.168      0.003       0.243       1.089
# rho_s:heat_transfer_coefficient_left                              -0.0017      0.000     -4.509      0.000      -0.002      -0.001
# rho_s:heat_transfer_coefficient_right                             -0.0003      0.000     -0.622      0.537      -0.001       0.001
# rho_s:Length                                                      -0.8208      0.197     -4.174      0.000      -1.217      -0.425
# heat_transfer_coefficient_left:heat_transfer_coefficient_right     0.1467      0.016      9.452      0.000       0.115       0.178
# heat_transfer_coefficient_left:Length                             84.0375      6.207     13.540      0.000      71.544      96.531
# heat_transfer_coefficient_right:Length                           -21.7969      7.758     -2.810      0.007     -37.413      -6.180
# ==============================================================================
# Omnibus:                        1.996   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.476
# Skew:                          -0.364   Prob(JB):                        0.478
# Kurtosis:                       3.126   Cond. No.                     3.59e+24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.26e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.api as sm
import pandas as pd
import itertools

# Define the list of variables
variables = ['rho_l', 'rho_s', 'k_l', 'k_s', 'cp_l', 'cp_s', 'Surr_temp', 'L_fusion', 'temp_init', 'heat_transfer_coefficient_left', 'heat_transfer_coefficient_right', 'Length']

# Generate interaction terms
combinations = list(itertools.combinations(variables, 2))
interaction_terms = ['{}*{}'.format(a, b) for a, b in combinations]

# Generate quadratic (axial) terms
quadratic_terms = ['np.power({}, 2)'.format(var) for var in variables]

# Base formula with main effects
base_formula = 'Lowest_Niyama ~ ' + ' + '.join(variables)

# Combine all terms into the final formula
all_terms = variables + interaction_terms + quadratic_terms
final_formula = 'Lowest_Niyama ~ ' + ' + '.join(all_terms)

# Print the final formula
print("Final Formula for Statsmodels:")
print(final_formula)

# Assuming Fractional_Factorial_doe_center_pt is your DataFrame with the necessary data
# Fit the model using all but the last row of the DataFrame
model9 = sm.OLS.from_formula(final_formula, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model9.summary())
# Out:
# Final Formula for Statsmodels:
# Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + cp_l + cp_s + Surr_temp + L_fusion + temp_init + heat_transfer_coefficient_left + heat_transfer_coefficient_right + Length + rho_l*rho_s + rho_l*k_l + rho_l*k_s + rho_l*cp_l + rho_l*cp_s + rho_l*Surr_temp + rho_l*L_fusion + rho_l*temp_init + rho_l*heat_transfer_coefficient_left + rho_l*heat_transfer_coefficient_right + rho_l*Length + rho_s*k_l + rho_s*k_s + rho_s*cp_l + rho_s*cp_s + rho_s*Surr_temp + rho_s*L_fusion + rho_s*temp_init + rho_s*heat_transfer_coefficient_left + rho_s*heat_transfer_coefficient_right + rho_s*Length + k_l*k_s + k_l*cp_l + k_l*cp_s + k_l*Surr_temp + k_l*L_fusion + k_l*temp_init + k_l*heat_transfer_coefficient_left + k_l*heat_transfer_coefficient_right + k_l*Length + k_s*cp_l + k_s*cp_s + k_s*Surr_temp + k_s*L_fusion + k_s*temp_init + k_s*heat_transfer_coefficient_left + k_s*heat_transfer_coefficient_right + k_s*Length + cp_l*cp_s + cp_l*Surr_temp + cp_l*L_fusion + cp_l*temp_init + cp_l*heat_transfer_coefficient_left + cp_l*heat_transfer_coefficient_right + cp_l*Length + cp_s*Surr_temp + cp_s*L_fusion + cp_s*temp_init + cp_s*heat_transfer_coefficient_left + cp_s*heat_transfer_coefficient_right + cp_s*Length + Surr_temp*L_fusion + Surr_temp*temp_init + Surr_temp*heat_transfer_coefficient_left + Surr_temp*heat_transfer_coefficient_right + Surr_temp*Length + L_fusion*temp_init + L_fusion*heat_transfer_coefficient_left + L_fusion*heat_transfer_coefficient_right + L_fusion*Length + temp_init*heat_transfer_coefficient_left + temp_init*heat_transfer_coefficient_right + temp_init*Length + heat_transfer_coefficient_left*heat_transfer_coefficient_right + heat_transfer_coefficient_left*Length + heat_transfer_coefficient_right*Length + np.power(rho_l, 2) + np.power(rho_s, 2) + np.power(k_l, 2) + np.power(k_s, 2) + np.power(cp_l, 2) + np.power(cp_s, 2) + np.power(Surr_temp, 2) + np.power(L_fusion, 2) + np.power(temp_init, 2) + np.power(heat_transfer_coefficient_left, 2) + np.power(heat_transfer_coefficient_right, 2) + np.power(Length, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     75.65
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           4.28e-19
# Time:                        12:51:57   Log-Likelihood:                -1.9125
# No. Observations:                  65   AIC:                             81.83
# Df Residuals:                      26   BIC:                             166.6
# Df Model:                          38
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                         -0.0462      0.006     -7.770      0.000      -0.058      -0.034
# rho_l                                                              0.0008      0.000      7.335      0.000       0.001       0.001
# rho_s                                                             -0.0002   9.09e-06    -16.826      0.000      -0.000      -0.000
# k_l                                                            -5.811e-06   2.04e-05     -0.285      0.778   -4.77e-05    3.61e-05
# k_s                                                               -0.0001    2.2e-05     -6.322      0.000      -0.000   -9.39e-05
# cp_l                                                             2.77e-05   2.13e-06     12.986      0.000    2.33e-05    3.21e-05
# cp_s                                                            2.494e-05   2.03e-06     12.261      0.000    2.08e-05    2.91e-05
# Surr_temp                                                      -1.041e-05   1.53e-06     -6.798      0.000   -1.36e-05   -7.26e-06
# L_fusion                                                       -6.078e-05   7.28e-05     -0.835      0.411      -0.000    8.88e-05
# temp_init                                                      -1.874e-06    2.7e-07     -6.931      0.000   -2.43e-06   -1.32e-06
# heat_transfer_coefficient_left                                 -3.988e-06   4.86e-07     -8.197      0.000   -4.99e-06   -2.99e-06
# heat_transfer_coefficient_right                                 2.445e-06   4.56e-07      5.359      0.000    1.51e-06    3.38e-06
# Length                                                         -2.912e-06   1.38e-07    -21.093      0.000    -3.2e-06   -2.63e-06
# rho_l:rho_s                                                        0.0002      0.000      1.373      0.181   -9.57e-05       0.000
# rho_l:k_l                                                      -2.667e-07   1.12e-06     -0.239      0.813   -2.56e-06    2.03e-06
# rho_l:k_s                                                       4.684e-05      0.000      0.144      0.887      -0.001       0.001
# rho_l:cp_l                                                      6.306e-05   4.72e-05      1.337      0.193   -3.39e-05       0.000
# rho_l:cp_s                                                        -0.0002   5.98e-05     -3.465      0.002      -0.000   -8.42e-05
# rho_l:Surr_temp                                                    0.0006      0.001      1.235      0.228      -0.000       0.002
# rho_l:L_fusion                                                 -2.798e-06   1.13e-06     -2.468      0.020   -5.13e-06   -4.68e-07
# rho_l:temp_init                                                 1.595e-05   7.51e-05      0.212      0.834      -0.000       0.000
# rho_l:heat_transfer_coefficient_left                               0.0003      0.000      2.428      0.022    4.85e-05       0.001
# rho_l:heat_transfer_coefficient_right                           -6.52e-05      0.000     -0.399      0.693      -0.000       0.000
# rho_l:Length                                                   -1.583e-05   1.31e-05     -1.209      0.237   -4.27e-05    1.11e-05
# rho_s:k_l                                                         -0.0003      0.000     -1.221      0.233      -0.001       0.000
# rho_s:k_s                                                      -4.955e-05      0.000     -0.272      0.788      -0.000       0.000
# rho_s:cp_l                                                     -3.371e-05   1.62e-05     -2.079      0.048    -6.7e-05   -3.81e-07
# rho_s:cp_s                                                     -5.194e-05    2.1e-05     -2.477      0.020    -9.5e-05   -8.84e-06
# rho_s:Surr_temp                                                    0.0007      0.001      1.218      0.234      -0.000       0.002
# rho_s:L_fusion                                                  2.585e-07   5.19e-08      4.979      0.000    1.52e-07    3.65e-07
# rho_s:temp_init                                                 1.943e-05   5.05e-05      0.385      0.703   -8.43e-05       0.000
# rho_s:heat_transfer_coefficient_left                              -0.0007      0.000     -4.713      0.000      -0.001      -0.000
# rho_s:heat_transfer_coefficient_right                             -0.0003      0.000     -1.831      0.079      -0.001    3.42e-05
# rho_s:Length                                                   -1.745e-05   1.44e-05     -1.210      0.237   -4.71e-05    1.22e-05
# k_l:k_s                                                         2.085e-06    1.4e-05      0.149      0.883   -2.67e-05    3.08e-05
# k_l:cp_l                                                          -0.0002   8.33e-05     -2.428      0.022      -0.000    -3.1e-05
# k_l:cp_s                                                        3.253e-05      0.000      0.321      0.751      -0.000       0.000
# k_l:Surr_temp                                                   2.683e-05   2.15e-05      1.249      0.223   -1.73e-05     7.1e-05
# k_l:L_fusion                                                    4.679e-06   2.86e-06      1.635      0.114    -1.2e-06    1.06e-05
# k_l:temp_init                                                  -7.508e-06   5.83e-05     -0.129      0.899      -0.000       0.000
# k_l:heat_transfer_coefficient_left                              1.362e-05   5.56e-06      2.448      0.021    2.18e-06    2.51e-05
# k_l:heat_transfer_coefficient_right                            -2.182e-06      7e-06     -0.311      0.758   -1.66e-05    1.22e-05
# k_l:Length                                                     -6.697e-07   5.54e-07     -1.210      0.237   -1.81e-06    4.68e-07
# k_s:cp_l                                                          -0.0002      0.000     -0.571      0.573      -0.001       0.001
# k_s:cp_s                                                         8.52e-05      0.001      0.157      0.877      -0.001       0.001
# k_s:Surr_temp                                                   3.081e-05   4.65e-05      0.663      0.513   -6.48e-05       0.000
# k_s:L_fusion                                                    5.606e-07   1.43e-06      0.392      0.698   -2.38e-06     3.5e-06
# k_s:temp_init                                                   1.735e-05      0.000      0.144      0.886      -0.000       0.000
# k_s:heat_transfer_coefficient_left                              1.197e-05   6.32e-06      1.895      0.069   -1.01e-06     2.5e-05
# k_s:heat_transfer_coefficient_right                            -2.678e-06   7.73e-06     -0.346      0.732   -1.86e-05    1.32e-05
# k_s:Length                                                        -1.2674      3.414     -0.371      0.714      -8.286       5.751
# cp_l:cp_s                                                          0.0007   4.56e-05     14.888      0.000       0.001       0.001
# cp_l:Surr_temp                                                    -0.0009      0.000     -5.218      0.000      -0.001      -0.001
# cp_l:L_fusion                                                  -5.425e-07   1.13e-07     -4.802      0.000   -7.75e-07    -3.1e-07
# cp_l:temp_init                                                 -6.607e-05      0.000     -0.602      0.553      -0.000       0.000
# cp_l:heat_transfer_coefficient_left                                0.0002   6.58e-05      2.426      0.023    2.44e-05       0.000
# cp_l:heat_transfer_coefficient_right                               0.0006      0.000      1.754      0.091      -0.000       0.001
# cp_l:Length                                                        1.3477      0.264      5.111      0.000       0.806       1.890
# cp_s:Surr_temp                                                 -1.596e-05      0.000     -0.078      0.939      -0.000       0.000
# cp_s:L_fusion                                                   3.713e-07   1.46e-07      2.541      0.017     7.1e-08    6.72e-07
# cp_s:temp_init                                                 -8.965e-05      0.000     -0.631      0.533      -0.000       0.000
# cp_s:heat_transfer_coefficient_left                                0.0007      0.000      2.138      0.042     2.8e-05       0.001
# cp_s:heat_transfer_coefficient_right                           -2.636e-05   6.38e-05     -0.413      0.683      -0.000       0.000
# cp_s:Length                                                       -0.9162      0.341     -2.687      0.012      -1.617      -0.215
# Surr_temp:L_fusion                                             -6.951e-06   8.33e-06     -0.834      0.412   -2.41e-05    1.02e-05
# Surr_temp:temp_init                                                0.0002      0.000      0.933      0.359      -0.000       0.001
# Surr_temp:heat_transfer_coefficient_left                        4.108e-05   1.68e-05      2.438      0.022    6.45e-06    7.57e-05
# Surr_temp:heat_transfer_coefficient_right                      -3.433e-06   2.05e-05     -0.167      0.868   -4.56e-05    3.87e-05
# Surr_temp:Length                                               -1.873e-06   1.55e-06     -1.210      0.237   -5.06e-06    1.31e-06
# L_fusion:temp_init                                                  3e-08   3.52e-07      0.085      0.933   -6.93e-07    7.53e-07
# L_fusion:heat_transfer_coefficient_left                        -1.532e-06   1.45e-06     -1.054      0.302   -4.52e-06    1.46e-06
# L_fusion:heat_transfer_coefficient_right                        2.827e-06   1.82e-06      1.554      0.132   -9.12e-07    6.57e-06
# L_fusion:Length                                                   -0.0025      0.002     -1.210      0.237      -0.007       0.002
# temp_init:heat_transfer_coefficient_left                        4.456e-05      0.000      0.310      0.759      -0.000       0.000
# temp_init:heat_transfer_coefficient_right                      -2.911e-06      0.000     -0.016      0.987      -0.000       0.000
# temp_init:Length                                                  -0.1797      0.821     -0.219      0.828      -1.867       1.508
# heat_transfer_coefficient_left:heat_transfer_coefficient_right   5.07e-06   1.37e-06      3.694      0.001    2.25e-06    7.89e-06
# heat_transfer_coefficient_left:Length                             84.0375      3.940     21.329      0.000      75.938      92.137
# heat_transfer_coefficient_right:Length                           -21.7969      4.925     -4.426      0.000     -31.921     -11.673
# np.power(rho_l, 2)                                              9.782e-05   5.35e-05      1.829      0.079   -1.21e-05       0.000
# np.power(rho_s, 2)                                                -0.0001    8.8e-05     -1.374      0.181      -0.000       6e-05
# np.power(k_l, 2)                                                1.811e-07   9.48e-08      1.911      0.067   -1.37e-08    3.76e-07
# np.power(k_s, 2)                                                3.712e-06   2.55e-05      0.146      0.885   -4.87e-05    5.61e-05
# np.power(cp_l, 2)                                              -6.563e-05   3.94e-05     -1.664      0.108      -0.000    1.54e-05
# np.power(cp_s, 2)                                                 -0.0001   4.43e-05     -3.019      0.006      -0.000   -4.26e-05
# np.power(Surr_temp, 2)                                             0.0001      0.000      1.233      0.229   -9.88e-05       0.000
# np.power(L_fusion, 2)                                           1.033e-08   6.08e-09      1.698      0.101   -2.17e-09    2.28e-08
# np.power(temp_init, 2)                                          3.616e-06   5.65e-05      0.064      0.949      -0.000       0.000
# np.power(heat_transfer_coefficient_left, 2)                      3.29e-06   1.31e-06      2.517      0.018    6.03e-07    5.98e-06
# np.power(heat_transfer_coefficient_right, 2)                   -6.372e-07   1.72e-06     -0.370      0.714   -4.18e-06     2.9e-06
# np.power(Length, 2)                                            -1.928e-10    1.6e-10     -1.206      0.239   -5.21e-10    1.36e-10
# ==============================================================================
# Omnibus:                        0.865   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.649   Jarque-Bera (JB):                0.550
# Skew:                           0.224   Prob(JB):                        0.759
# Kurtosis:                       3.054   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large,  1e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula11 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s \
             + cp_l + cp_s + Surr_temp + L_fusion + temp_init + \
            heat_transfer_coefficient_left + heat_transfer_coefficient_right + Length + \
            rho_l*rho_s + rho_l*k_l + rho_l*cp_l + rho_l*cp_s + rho_l*Surr_temp + rho_l*L_fusion + rho_l*heat_transfer_coefficient_left + \
             + rho_l*Length + rho_s*k_l + rho_s*cp_l + \
            rho_s*cp_s + rho_s*Surr_temp + rho_s*L_fusion  + rho_s*heat_transfer_coefficient_left + \
            rho_s*heat_transfer_coefficient_right + rho_s*Length + k_l*cp_l  + k_l*Surr_temp + k_l*L_fusion +\
             + k_l*heat_transfer_coefficient_left  + k_l*Length + k_s*cp_l  + \
            k_s*Surr_temp + k_s*heat_transfer_coefficient_left +  \
            cp_l*cp_s + cp_l*Surr_temp + cp_l*L_fusion + cp_l*temp_init + cp_l*heat_transfer_coefficient_left + \
            cp_l*Length +  cp_s*L_fusion + cp_s*temp_init + cp_s*heat_transfer_coefficient_left + cp_s*heat_transfer_coefficient_right + \
            cp_s*Length + Surr_temp*L_fusion + Surr_temp*temp_init + Surr_temp*heat_transfer_coefficient_left +  \
            Surr_temp*Length + L_fusion*heat_transfer_coefficient_left + L_fusion*heat_transfer_coefficient_right + L_fusion*Length + \
            + heat_transfer_coefficient_left*heat_transfer_coefficient_right + \
            heat_transfer_coefficient_left*Length + heat_transfer_coefficient_right*Length + np.power(rho_l, 2) + np.power(rho_s, 2) + np.power(k_l, 2) + np.power(cp_l, 2) + np.power(cp_s, 2) + \
                np.power(Surr_temp, 2) + np.power(L_fusion, 2) + np.power(heat_transfer_coefficient_left, 2) + np.power(Length, 2)'

# %%
model10 = sm.OLS.from_formula(formula11, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model10.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     102.5
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           6.05e-24
# Time:                        15:38:12   Log-Likelihood:                -2.3544
# No. Observations:                  65   AIC:                             72.71
# Df Residuals:                      31   BIC:                             146.6
# Df Model:                          33
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          0.0427      0.009      5.002      0.000       0.025       0.060
# rho_l                                                              0.0002   4.36e-05      4.307      0.000    9.88e-05       0.000
# rho_s                                                            -5.9e-05   2.11e-05     -2.800      0.009      -0.000    -1.6e-05
# k_l                                                               -0.0002   9.32e-06    -23.509      0.000      -0.000      -0.000
# k_s                                                                0.0495      0.643      0.077      0.939      -1.262       1.361
# cp_l                                                            4.442e-05   6.37e-06      6.975      0.000    3.14e-05    5.74e-05
# cp_s                                                           -3.961e-06   2.57e-06     -1.539      0.134   -9.21e-06    1.29e-06
# Surr_temp                                                       5.267e-06   7.94e-07      6.636      0.000    3.65e-06    6.89e-06
# L_fusion                                                          -0.0001      0.001     -0.139      0.890      -0.002       0.002
# temp_init                                                          0.0312      0.400      0.078      0.938      -0.785       0.848
# heat_transfer_coefficient_left                                 -3.934e-06   5.04e-07     -7.800      0.000   -4.96e-06   -2.91e-06
# heat_transfer_coefficient_right                                 8.482e-07    9.9e-07      0.857      0.398   -1.17e-06    2.87e-06
# Length                                                          -1.44e-06   1.55e-07     -9.292      0.000   -1.76e-06   -1.12e-06
# rho_l:rho_s                                                        0.0002      0.000      1.420      0.166      -0.000       0.001
# rho_l:k_l                                                       5.396e-06   1.04e-06      5.190      0.000    3.28e-06    7.52e-06
# rho_l:cp_l                                                       4.41e-05      0.000      0.347      0.731      -0.000       0.000
# rho_l:cp_s                                                     -4.057e-05      0.000     -0.127      0.900      -0.001       0.001
# rho_l:Surr_temp                                                    0.0008      0.000      3.301      0.002       0.000       0.001
# rho_l:L_fusion                                                 -3.499e-06   1.12e-06     -3.132      0.004   -5.78e-06   -1.22e-06
# rho_l:heat_transfer_coefficient_left                               0.0003      0.000      0.969      0.340      -0.000       0.001
# rho_l:Length                                                   -1.983e-05   6.09e-06     -3.257      0.003   -3.22e-05   -7.41e-06
# rho_s:k_l                                                         -0.0004      0.000     -3.265      0.003      -0.001      -0.000
# rho_s:cp_l                                                     -3.374e-05    1.5e-05     -2.256      0.031   -6.42e-05   -3.24e-06
# rho_s:cp_s                                                     -5.196e-05   1.93e-05     -2.687      0.011   -9.14e-05   -1.25e-05
# rho_s:Surr_temp                                                    0.0008      0.000      3.269      0.003       0.000       0.001
# rho_s:L_fusion                                                  2.583e-07   4.79e-08      5.397      0.000    1.61e-07    3.56e-07
# rho_s:heat_transfer_coefficient_left                              -0.0007      0.000     -2.635      0.013      -0.001      -0.000
# rho_s:heat_transfer_coefficient_right                             -0.0003      0.000     -1.063      0.296      -0.001       0.000
# rho_s:Length                                                   -2.186e-05   6.71e-06     -3.258      0.003   -3.55e-05   -8.17e-06
# k_l:cp_l                                                          -0.0002      0.000     -0.948      0.350      -0.001       0.000
# k_l:Surr_temp                                                   3.355e-05   1.01e-05      3.328      0.002     1.3e-05    5.41e-05
# k_l:L_fusion                                                    5.848e-06   1.62e-06      3.609      0.001    2.54e-06    9.15e-06
# k_l:heat_transfer_coefficient_left                              1.483e-05   1.56e-05      0.951      0.349    -1.7e-05    4.66e-05
# k_l:Length                                                     -8.387e-07   2.57e-07     -3.258      0.003   -1.36e-06   -3.14e-07
# k_s:cp_l                                                          -0.0002      0.000     -0.540      0.593      -0.001       0.001
# k_s:Surr_temp                                                      0.0010      0.002      0.430      0.670      -0.004       0.006
# k_s:heat_transfer_coefficient_left                                -0.0061      0.022     -0.282      0.780      -0.050       0.038
# cp_l:cp_s                                                          0.0007   4.21e-05     16.146      0.000       0.001       0.001
# cp_l:Surr_temp                                                    -0.0009      0.000     -3.569      0.001      -0.001      -0.000
# cp_l:L_fusion                                                  -5.426e-07   1.04e-07     -5.208      0.000   -7.55e-07    -3.3e-07
# cp_l:temp_init                                                  3.185e-05      0.000      0.094      0.926      -0.001       0.001
# cp_l:heat_transfer_coefficient_left                                0.0002      0.000      0.971      0.339      -0.000       0.001
# cp_l:Length                                                        1.3477      0.243      5.543      0.000       0.852       1.844
# cp_s:L_fusion                                                   3.712e-07   1.35e-07      2.756      0.010    9.65e-08    6.46e-07
# cp_s:temp_init                                                 -8.969e-05      0.000     -0.685      0.499      -0.000       0.000
# cp_s:heat_transfer_coefficient_left                                0.0013      0.001      2.123      0.042    5.24e-05       0.003
# cp_s:heat_transfer_coefficient_right                               0.0004      0.001      0.500      0.621      -0.001       0.002
# cp_s:Length                                                       -0.9162      0.314     -2.914      0.007      -1.557      -0.275
# Surr_temp:L_fusion                                             -9.323e-06   3.95e-06     -2.363      0.025   -1.74e-05   -1.28e-06
# Surr_temp:temp_init                                             5.008e-05      0.001      0.086      0.932      -0.001       0.001
# Surr_temp:heat_transfer_coefficient_left                        4.527e-05   4.35e-05      1.040      0.306   -4.35e-05       0.000
# Surr_temp:Length                                               -2.346e-06    7.2e-07     -3.258      0.003   -3.81e-06   -8.78e-07
# L_fusion:heat_transfer_coefficient_left                        -1.459e-06   1.58e-06     -0.921      0.364   -4.69e-06    1.77e-06
# L_fusion:heat_transfer_coefficient_right                        2.952e-06   1.95e-06      1.517      0.139   -1.02e-06    6.92e-06
# L_fusion:Length                                                   -0.0031      0.001     -3.257      0.003      -0.005      -0.001
# heat_transfer_coefficient_left:heat_transfer_coefficient_right  1.123e-05   1.13e-05      0.993      0.329   -1.18e-05    3.43e-05
# heat_transfer_coefficient_left:Length                             84.0375      3.633     23.131      0.000      76.628      91.447
# heat_transfer_coefficient_right:Length                           -21.7969      4.541     -4.800      0.000     -31.059     -12.535
# np.power(rho_l, 2)                                              9.072e-05   5.12e-05      1.772      0.086   -1.37e-05       0.000
# np.power(rho_s, 2)                                                -0.0001   8.42e-05     -1.779      0.085      -0.000    2.19e-05
# np.power(k_l, 2)                                                 1.62e-07   9.16e-08      1.769      0.087   -2.48e-08    3.49e-07
# np.power(cp_l, 2)                                              -8.155e-05      0.000     -0.372      0.713      -0.001       0.000
# np.power(cp_s, 2)                                                 -0.0003      0.000     -0.840      0.407      -0.001       0.000
# np.power(Surr_temp, 2)                                             0.0002   5.64e-05      3.294      0.002    7.07e-05       0.000
# np.power(L_fusion, 2)                                            1.35e-08   4.66e-09      2.896      0.007    3.99e-09     2.3e-08
# np.power(heat_transfer_coefficient_left, 2)                     3.599e-06   3.36e-06      1.072      0.292   -3.25e-06    1.04e-05
# np.power(Length, 2)                                            -2.415e-10   7.44e-11     -3.246      0.003   -3.93e-10   -8.97e-11
# ==============================================================================
# Omnibus:                        0.509   Durbin-Watson:                   1.436
# Prob(Omnibus):                  0.775   Jarque-Bera (JB):                0.235
# Skew:                           0.144   Prob(JB):                        0.889
# Kurtosis:                       3.063   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large,  1e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula12 = 'Lowest_Niyama ~  cp_s + heat_transfer_coefficient_right + \
            rho_l*rho_s +rho_l*cp_s + rho_l*L_fusion + rho_l*heat_transfer_coefficient_left + \
             +  rho_s*cp_l + rho_s*cp_s + rho_s*Surr_temp + rho_s*L_fusion   \
            + cp_l*cp_s + cp_l*Surr_temp + cp_l*L_fusion +  cp_l*Length +  \
            cp_s*L_fusion +  cp_s*heat_transfer_coefficient_left  + cp_s*Length +  L_fusion*Length + \
            heat_transfer_coefficient_left*Length + heat_transfer_coefficient_right*Length + np.power(rho_l, 2) \
                '

# %%
model11 = sm.OLS.from_formula(formula12, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model11.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     157.1
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           5.89e-33
# Time:                        16:06:26   Log-Likelihood:                -9.2090
# No. Observations:                  65   AIC:                             66.42
# Df Residuals:                      41   BIC:                             118.6
# Df Model:                          23
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                              -2.403e-06   3.05e-05     -0.079      0.938   -6.41e-05    5.92e-05
# cp_s                                      -0.3354      0.047     -7.179      0.000      -0.430      -0.241
# heat_transfer_coefficient_right            0.8914      0.069     12.883      0.000       0.752       1.031
# rho_l                                     -0.1358      0.165     -0.824      0.415      -0.469       0.197
# rho_s                                      0.1490      0.131      1.133      0.264      -0.117       0.415
# rho_l:rho_s                               -0.0002   5.64e-05     -2.690      0.010      -0.000   -3.78e-05
# rho_l:cp_s                                -0.0002   3.46e-05     -6.053      0.000      -0.000      -0.000
# L_fusion                                   0.0003      0.000      1.050      0.300      -0.000       0.001
# rho_l:L_fusion                         -2.422e-07   5.09e-08     -4.754      0.000   -3.45e-07   -1.39e-07
# heat_transfer_coefficient_left             0.0005      0.001      0.861      0.394      -0.001       0.002
# rho_l:heat_transfer_coefficient_left      -0.0008      0.000     -3.164      0.003      -0.001      -0.000
# cp_l                                       0.0614      0.086      0.714      0.479      -0.112       0.235
# rho_s:cp_l                             -3.349e-05   1.44e-05     -2.318      0.026   -6.27e-05   -4.31e-06
# rho_s:cp_s                             -5.196e-05   1.87e-05     -2.781      0.008   -8.97e-05   -1.42e-05
# Surr_temp                                 -0.0164      0.020     -0.829      0.412      -0.056       0.024
# rho_s:Surr_temp                            0.0007   8.74e-05      8.245      0.000       0.001       0.001
# rho_s:L_fusion                          2.591e-07   4.62e-08      5.601      0.000    1.66e-07    3.52e-07
# cp_l:cp_s                                  0.0007   4.07e-05     16.711      0.000       0.001       0.001
# cp_l:Surr_temp                            -0.0014      0.000     -7.973      0.000      -0.002      -0.001
# cp_l:L_fusion                          -5.423e-07   1.01e-07     -5.388      0.000   -7.46e-07   -3.39e-07
# Length                                  3.168e-07   4.11e-07      0.770      0.446   -5.14e-07    1.15e-06
# cp_l:Length                                1.3477      0.235      5.737      0.000       0.873       1.822
# cp_s:L_fusion                           3.712e-07    1.3e-07      2.852      0.007    1.08e-07    6.34e-07
# cp_s:heat_transfer_coefficient_left        0.0013      0.001      2.197      0.034       0.000       0.003
# cp_s:Length                               -0.9162      0.304     -3.016      0.004      -1.530      -0.303
# L_fusion:Length                           -0.0036      0.001     -3.290      0.002      -0.006      -0.001
# heat_transfer_coefficient_left:Length     84.0375      3.510     23.940      0.000      76.948      91.127
# heat_transfer_coefficient_right:Length   -21.7969      4.388     -4.967      0.000     -30.659     -12.935
# np.power(rho_l, 2)                         0.0002    6.5e-05      2.671      0.011    4.23e-05       0.000
# ==============================================================================
# Omnibus:                        0.030   Durbin-Watson:                   1.515
# Prob(Omnibus):                  0.985   Jarque-Bera (JB):                0.163
# Skew:                           0.042   Prob(JB):                        0.922
# Kurtosis:                       2.770   Cond. No.                     1.90e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.32e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
anova_results7 = sm.stats.anova_lm(model11, typ=2)

print(anova_results7)
# Out:
#                                            sum_sq    df           F  \
# cp_s                                     0.342065   1.0    2.775844
# heat_transfer_coefficient_right         28.613047   1.0  232.193526
# rho_l                                    0.876773   1.0    7.114970
# rho_s                                   11.222023   1.0   91.066186
# rho_l:rho_s                              0.891456   1.0    7.234120
# rho_l:cp_s                               4.514874   1.0   36.637987
# L_fusion                                 0.008789   1.0    0.071323
# rho_l:L_fusion                           2.784727   1.0   22.597925
# heat_transfer_coefficient_left           0.685944   1.0    5.566406
# rho_l:heat_transfer_coefficient_left     1.233668   1.0   10.011158
# cp_l                                     9.023117   1.0   73.222168
# rho_s:cp_l                               0.662189   1.0    5.373633
# rho_s:cp_s                               0.953064   1.0    7.734070
# Surr_temp                                1.024820   1.0    8.316370
# rho_s:Surr_temp                          8.377982   1.0   67.986927
# rho_s:L_fusion                           3.866139   1.0   31.373536
# cp_l:cp_s                               34.412889   1.0  279.258969
# cp_l:Surr_temp                           7.833002   1.0   63.564438
# cp_l:L_fusion                            3.576827   1.0   29.025779
# Length                                   0.005542   1.0    0.044971
# cp_l:Length                              4.055189   1.0   32.907668
# cp_s:L_fusion                            1.002502   1.0    8.135253
# cp_s:heat_transfer_coefficient_left      0.594827   1.0    4.826989
# cp_s:Length                              1.120952   1.0    9.096469
# L_fusion:Length                          1.333475   1.0   10.821089
# heat_transfer_coefficient_left:Length   70.623014   1.0  573.102423
# heat_transfer_coefficient_right:Length   3.040664   1.0   24.674845
# np.power(rho_l, 2)                       0.878995   1.0    7.133006
# Residual                                 5.052402  41.0         NaN
#
#                                               PR(>F)
# cp_s                                    1.033196e-01
# heat_transfer_coefficient_right         1.741285e-18
# rho_l                                   1.089464e-02
# rho_s                                   5.688772e-12
# rho_l:rho_s                             1.029785e-02
# rho_l:cp_s                              3.637827e-07
# L_fusion                                7.907592e-01
# rho_l:L_fusion                          2.467775e-05
# heat_transfer_coefficient_left          2.315267e-02
# rho_l:heat_transfer_coefficient_left    2.929621e-03
# cp_l                                    1.153851e-10
# rho_s:cp_l                              2.550968e-02
# rho_s:cp_s                              8.149006e-03
# Surr_temp                               6.232947e-03
# rho_s:Surr_temp                         3.057512e-10
# rho_s:L_fusion                          1.594899e-06
# cp_l:cp_s                               6.614069e-20
# cp_l:Surr_temp                          7.234101e-10
# cp_l:L_fusion                           3.199816e-06
# Length                                  8.331088e-01
# cp_l:Length                             1.024979e-06
# cp_s:L_fusion                           6.771456e-03
# cp_s:heat_transfer_coefficient_left     3.372571e-02
# cp_s:Length                             4.383714e-03
# L_fusion:Length                         2.066936e-03
# heat_transfer_coefficient_left:Length   1.024041e-25
# heat_transfer_coefficient_right:Length  1.245656e-05
# np.power(rho_l, 2)                      1.080198e-02
# Residual                                         NaN

# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_norm import *

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(25)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 1.0

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_max = props['k_l']
rho_max = props['rho_s']
cp_max = props['cp_l']
alpha_max = k_max / (rho_max * cp_max)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# The number of points in the initial condition is 25000
# scaling not initiated
# The number of points in the left boundary condition is 25000
# The number of points in the right boundary condition is 25000
# scaling not initiated
# The number of points in the left boundary condition is 25000
# The number of points in the right boundary condition is 25000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+25002=25002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=100)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=10000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=10000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=10000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=10000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=100 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=10000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=10000 )  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=10000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=10000) # random sampler for bc right residuals

train_loader = DataLoader(inp_dataset, batch_size=256, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=256, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=256, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=256, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=256, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=256, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=256, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=256, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=256, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=256, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 3# 64
output_size=1

learning_rate = 0.001 # 0.001
hidden_layers = 3


# epochs_1 = props['epochs'] # 1000
epochs_1 =15000
epochs_2 = 10
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 1.5247e+00,| Test-Loss 1.5255e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3865e-01,| pde-loss 1.6876e-01,| initc-loss 4.8010e-01,|bc_loss 8.7586e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8425e+00,| pde-loss-test 3.5050e-01,| initc-loss-test 4.8826e-01,|bc_loss-test 8.6196e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 1.1633e+00,| Test-Loss 1.1530e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4751e-01,| pde-loss 9.5308e-02,| initc-loss 4.3357e-01,|bc_loss 6.3443e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2921e+00,| pde-loss-test 1.9308e-01,| initc-loss-test 4.2491e-01,|bc_loss-test 6.3154e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 8.8254e-01,| Test-Loss 8.3190e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9099e-01,| pde-loss 5.0884e-02,| initc-loss 3.7037e-01,|bc_loss 4.6129e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0125e+00,| pde-loss-test 9.8553e-02,| initc-loss-test 3.5362e-01,|bc_loss-test 4.2900e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 6.3822e-01,| Test-Loss 6.1198e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2988e-01,| pde-loss 3.0214e-02,| initc-loss 3.0684e-01,|bc_loss 3.0117e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8669e-01,| pde-loss-test 5.5334e-02,| initc-loss-test 2.9736e-01,|bc_loss-test 2.8695e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 4.5754e-01,| Test-Loss 4.3675e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1290e-01,| pde-loss 1.6924e-02,| initc-loss 2.4577e-01,|bc_loss 1.9485e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.8591e-01,| pde-loss-test 2.9588e-02,| initc-loss-test 2.3878e-01,|bc_loss-test 1.8317e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 3.1739e-01,| Test-Loss 3.0698e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2520e-01,| pde-loss 1.1478e-02,| initc-loss 1.8866e-01,|bc_loss 1.1724e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3113e-01,| pde-loss-test 2.2843e-02,| initc-loss-test 1.8174e-01,|bc_loss-test 1.1382e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 2.1862e-01,| Test-Loss 2.0640e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3583e-02,| pde-loss 1.0800e-02,| initc-loss 1.4021e-01,|bc_loss 6.7607e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3910e-01,| pde-loss-test 2.0134e-02,| initc-loss-test 1.3202e-01,|bc_loss-test 6.4309e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 1.4241e-01,| Test-Loss 1.4008e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4044e-02,| pde-loss 1.1038e-02,| initc-loss 9.3183e-02,|bc_loss 3.8193e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2851e-02,| pde-loss-test 2.0853e-02,| initc-loss-test 9.3261e-02,|bc_loss-test 3.6392e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 9.9634e-02,| Test-Loss 9.6569e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9206e-02,| pde-loss 1.1324e-02,| initc-loss 6.4922e-02,|bc_loss 2.3387e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1977e-02,| pde-loss-test 2.0521e-02,| initc-loss-test 6.2913e-02,|bc_loss-test 2.3396e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 7.1985e-02,| Test-Loss 7.0290e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.2865e-03,| pde-loss 1.1166e-02,| initc-loss 4.1509e-02,|bc_loss 1.9310e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8961e-02,| pde-loss-test 2.0814e-02,| initc-loss-test 4.2919e-02,|bc_loss-test 1.6964e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 5.5790e-02,| Test-Loss 5.5922e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7047e-03,| pde-loss 9.7149e-03,| initc-loss 2.8139e-02,|bc_loss 1.7936e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2910e-02,| pde-loss-test 1.9168e-02,| initc-loss-test 2.8657e-02,|bc_loss-test 1.7681e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 4.9200e-02,| Test-Loss 4.9633e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.0513e-03,| pde-loss 9.9472e-03,| initc-loss 2.0765e-02,|bc_loss 1.8487e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6780e-02,| pde-loss-test 1.6648e-02,| initc-loss-test 2.1772e-02,|bc_loss-test 1.9536e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 4.7706e-02,| Test-Loss 4.4912e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1728e-03,| pde-loss 8.8312e-03,| initc-loss 1.5883e-02,|bc_loss 2.2991e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4796e-02,| pde-loss-test 1.9893e-02,| initc-loss-test 1.4547e-02,|bc_loss-test 2.0419e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 4.3141e-02,| Test-Loss 4.5986e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5653e-03,| pde-loss 8.0139e-03,| initc-loss 1.1891e-02,|bc_loss 2.3236e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7017e-02,| pde-loss-test 2.0553e-02,| initc-loss-test 1.3592e-02,|bc_loss-test 2.2118e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 4.4036e-02,| Test-Loss 4.3825e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3758e-03,| pde-loss 9.8465e-03,| initc-loss 1.1409e-02,|bc_loss 2.2780e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3927e-02,| pde-loss-test 1.5552e-02,| initc-loss-test 1.2034e-02,|bc_loss-test 2.4015e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 4.1960e-02,| Test-Loss 4.0865e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3364e-03,| pde-loss 6.8011e-03,| initc-loss 1.0752e-02,|bc_loss 2.4407e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9840e-02,| pde-loss-test 1.5143e-02,| initc-loss-test 1.0940e-02,|bc_loss-test 2.2354e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 4.0130e-02,| Test-Loss 4.0141e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0317e-02,| pde-loss 7.1813e-03,| initc-loss 1.0799e-02,|bc_loss 2.2150e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5396e-02,| pde-loss-test 1.5253e-02,| initc-loss-test 1.1160e-02,|bc_loss-test 2.1355e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 4.0012e-02,| Test-Loss 4.2122e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4644e-03,| pde-loss 7.1766e-03,| initc-loss 1.0861e-02,|bc_loss 2.1975e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5989e-02,| pde-loss-test 1.7558e-02,| initc-loss-test 1.1038e-02,|bc_loss-test 2.2305e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 3.8360e-02,| Test-Loss 3.8882e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2452e-03,| pde-loss 7.4422e-03,| initc-loss 9.9996e-03,|bc_loss 2.0918e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0427e-02,| pde-loss-test 1.4081e-02,| initc-loss-test 1.1051e-02,|bc_loss-test 2.0791e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 3.5716e-02,| Test-Loss 3.7167e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5606e-03,| pde-loss 6.5369e-03,| initc-loss 9.9314e-03,|bc_loss 1.9248e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6838e-02,| pde-loss-test 1.2811e-02,| initc-loss-test 1.0216e-02,|bc_loss-test 2.0545e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 3.7080e-02,| Test-Loss 3.7611e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.3186e-03,| pde-loss 7.1711e-03,| initc-loss 1.0543e-02,|bc_loss 1.9366e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8044e-02,| pde-loss-test 1.5147e-02,| initc-loss-test 9.6958e-03,|bc_loss-test 2.0341e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 3.7044e-02,| Test-Loss 3.6278e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5978e-03,| pde-loss 6.3628e-03,| initc-loss 1.0171e-02,|bc_loss 2.0511e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7978e-02,| pde-loss-test 1.2472e-02,| initc-loss-test 1.0145e-02,|bc_loss-test 1.9897e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 3.6874e-02,| Test-Loss 3.7113e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.7875e-03,| pde-loss 6.2406e-03,| initc-loss 1.0302e-02,|bc_loss 2.0331e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6864e-02,| pde-loss-test 1.3180e-02,| initc-loss-test 1.0868e-02,|bc_loss-test 1.9656e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 3.3910e-02,| Test-Loss 3.6151e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7007e-03,| pde-loss 5.6836e-03,| initc-loss 9.9364e-03,|bc_loss 1.8290e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5071e-02,| pde-loss-test 1.2150e-02,| initc-loss-test 1.0358e-02,|bc_loss-test 1.9717e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 3.4378e-02,| Test-Loss 3.3733e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3659e-03,| pde-loss 5.7823e-03,| initc-loss 9.6169e-03,|bc_loss 1.8979e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2024e-02,| pde-loss-test 1.3131e-02,| initc-loss-test 9.3968e-03,|bc_loss-test 1.7771e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 3.3224e-02,| Test-Loss 3.3332e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4417e-03,| pde-loss 5.6307e-03,| initc-loss 9.9123e-03,|bc_loss 1.7681e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2568e-02,| pde-loss-test 1.1775e-02,| initc-loss-test 9.3776e-03,|bc_loss-test 1.8067e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 3.3526e-02,| Test-Loss 3.1952e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.6671e-03,| pde-loss 5.2847e-03,| initc-loss 9.7888e-03,|bc_loss 1.8453e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3445e-02,| pde-loss-test 1.0850e-02,| initc-loss-test 9.4540e-03,|bc_loss-test 1.7073e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 3.0554e-02,| Test-Loss 3.1874e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.0036e-03,| pde-loss 5.1685e-03,| initc-loss 9.3550e-03,|bc_loss 1.6031e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0366e-02,| pde-loss-test 1.1693e-02,| initc-loss-test 9.1477e-03,|bc_loss-test 1.6880e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 2.9684e-02,| Test-Loss 3.0065e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9208e-03,| pde-loss 5.0124e-03,| initc-loss 7.7738e-03,|bc_loss 1.6898e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1334e-02,| pde-loss-test 9.0803e-03,| initc-loss-test 8.6021e-03,|bc_loss-test 1.6923e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 3.0344e-02,| Test-Loss 2.9823e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9338e-03,| pde-loss 5.3136e-03,| initc-loss 8.8140e-03,|bc_loss 1.6216e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5958e-02,| pde-loss-test 1.0799e-02,| initc-loss-test 8.1786e-03,|bc_loss-test 1.6245e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 2.9053e-02,| Test-Loss 2.9047e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1804e-03,| pde-loss 4.7293e-03,| initc-loss 7.9348e-03,|bc_loss 1.6389e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1062e-02,| pde-loss-test 8.9046e-03,| initc-loss-test 9.0303e-03,|bc_loss-test 1.5564e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 3.0758e-02,| Test-Loss 2.8592e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.5726e-03,| pde-loss 4.6114e-03,| initc-loss 8.3699e-03,|bc_loss 1.7777e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3890e-02,| pde-loss-test 8.6367e-03,| initc-loss-test 8.6866e-03,|bc_loss-test 1.5587e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 2.7942e-02,| Test-Loss 2.7338e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7950e-03,| pde-loss 4.6467e-03,| initc-loss 8.5440e-03,|bc_loss 1.4751e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0855e-02,| pde-loss-test 9.9020e-03,| initc-loss-test 7.8073e-03,|bc_loss-test 1.4579e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 2.5826e-02,| Test-Loss 2.7610e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.2475e-03,| pde-loss 4.3903e-03,| initc-loss 7.2456e-03,|bc_loss 1.4190e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6311e-02,| pde-loss-test 7.3838e-03,| initc-loss-test 8.7468e-03,|bc_loss-test 1.5171e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 2.6636e-02,| Test-Loss 2.6621e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.2836e-03,| pde-loss 4.3945e-03,| initc-loss 7.6896e-03,|bc_loss 1.4551e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2115e-02,| pde-loss-test 7.6683e-03,| initc-loss-test 8.3196e-03,|bc_loss-test 1.4467e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 2.4215e-02,| Test-Loss 2.5284e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1824e-03,| pde-loss 4.1648e-03,| initc-loss 6.9742e-03,|bc_loss 1.3076e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.7573e-03,| pde-loss-test 6.6745e-03,| initc-loss-test 8.3723e-03,|bc_loss-test 1.3575e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 2.4359e-02,| Test-Loss 2.7093e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.2361e-03,| pde-loss 3.9103e-03,| initc-loss 6.3869e-03,|bc_loss 1.4062e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.9018e-03,| pde-loss-test 7.3180e-03,| initc-loss-test 8.6682e-03,|bc_loss-test 1.4766e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 2.4954e-02,| Test-Loss 2.4356e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.6223e-03,| pde-loss 3.9354e-03,| initc-loss 7.4676e-03,|bc_loss 1.3551e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2108e-03,| pde-loss-test 7.3179e-03,| initc-loss-test 7.6329e-03,|bc_loss-test 1.3064e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 2.3977e-02,| Test-Loss 2.4687e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.0881e-03,| pde-loss 3.4719e-03,| initc-loss 7.5148e-03,|bc_loss 1.2990e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.4562e-03,| pde-loss-test 6.5620e-03,| initc-loss-test 7.7891e-03,|bc_loss-test 1.3617e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 2.3595e-02,| Test-Loss 2.2116e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4285e-03,| pde-loss 3.6359e-03,| initc-loss 7.6247e-03,|bc_loss 1.2334e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1019e-02,| pde-loss-test 6.2446e-03,| initc-loss-test 6.2346e-03,|bc_loss-test 1.2759e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 2.3189e-02,| Test-Loss 2.1667e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1632e-03,| pde-loss 3.3599e-03,| initc-loss 7.0536e-03,|bc_loss 1.2775e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0589e-02,| pde-loss-test 5.7682e-03,| initc-loss-test 6.2956e-03,|bc_loss-test 1.2488e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 2.2449e-02,| Test-Loss 2.2573e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.2122e-03,| pde-loss 3.0374e-03,| initc-loss 6.7615e-03,|bc_loss 1.2650e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1262e-02,| pde-loss-test 6.5793e-03,| initc-loss-test 7.2128e-03,|bc_loss-test 1.2070e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 2.1679e-02,| Test-Loss 2.2246e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5881e-03,| pde-loss 3.6889e-03,| initc-loss 6.1404e-03,|bc_loss 1.1850e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0334e-02,| pde-loss-test 6.2104e-03,| initc-loss-test 7.1457e-03,|bc_loss-test 1.1996e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 2.1070e-02,| Test-Loss 2.1895e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.2415e-03,| pde-loss 3.0951e-03,| initc-loss 6.4525e-03,|bc_loss 1.1523e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8036e-03,| pde-loss-test 6.6042e-03,| initc-loss-test 6.7763e-03,|bc_loss-test 1.1816e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 2.0578e-02,| Test-Loss 2.1209e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5931e-03,| pde-loss 3.0476e-03,| initc-loss 5.7623e-03,|bc_loss 1.1768e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9091e-03,| pde-loss-test 5.9785e-03,| initc-loss-test 7.6002e-03,|bc_loss-test 1.0619e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 2.0549e-02,| Test-Loss 2.0031e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6162e-03,| pde-loss 3.1549e-03,| initc-loss 6.7408e-03,|bc_loss 1.0654e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0681e-03,| pde-loss-test 5.9575e-03,| initc-loss-test 5.6832e-03,|bc_loss-test 1.1369e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 1.9735e-02,| Test-Loss 1.9966e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6767e-03,| pde-loss 2.7964e-03,| initc-loss 5.8855e-03,|bc_loss 1.1053e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0764e-03,| pde-loss-test 5.9497e-03,| initc-loss-test 6.1778e-03,|bc_loss-test 1.0814e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 1.9325e-02,| Test-Loss 1.9128e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5375e-03,| pde-loss 2.7540e-03,| initc-loss 5.9686e-03,|bc_loss 1.0603e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6999e-03,| pde-loss-test 5.4272e-03,| initc-loss-test 6.2018e-03,|bc_loss-test 1.0213e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 1.8564e-02,| Test-Loss 1.9876e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6266e-03,| pde-loss 2.8968e-03,| initc-loss 5.4014e-03,|bc_loss 1.0266e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.5527e-03,| pde-loss-test 5.0687e-03,| initc-loss-test 6.3923e-03,|bc_loss-test 1.0950e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 1.9299e-02,| Test-Loss 1.9331e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6425e-03,| pde-loss 2.7654e-03,| initc-loss 5.7857e-03,|bc_loss 1.0748e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8725e-03,| pde-loss-test 5.5978e-03,| initc-loss-test 5.8154e-03,|bc_loss-test 1.0717e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 1.8759e-02,| Test-Loss 1.9302e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4991e-03,| pde-loss 2.5660e-03,| initc-loss 5.7373e-03,|bc_loss 1.0455e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.3203e-03,| pde-loss-test 5.7185e-03,| initc-loss-test 5.9796e-03,|bc_loss-test 1.0464e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 1.7866e-02,| Test-Loss 1.8936e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4061e-03,| pde-loss 2.6261e-03,| initc-loss 6.3935e-03,|bc_loss 8.8468e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.3079e-03,| pde-loss-test 4.4928e-03,| initc-loss-test 5.9649e-03,|bc_loss-test 1.0724e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 1.7817e-02,| Test-Loss 1.7942e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.2389e-03,| pde-loss 2.4206e-03,| initc-loss 5.5725e-03,|bc_loss 9.8236e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0898e-03,| pde-loss-test 5.2409e-03,| initc-loss-test 5.5651e-03,|bc_loss-test 9.7559e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 1.7104e-02,| Test-Loss 1.7347e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1791e-03,| pde-loss 2.3353e-03,| initc-loss 5.9452e-03,|bc_loss 8.8231e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9076e-03,| pde-loss-test 4.3422e-03,| initc-loss-test 5.7737e-03,|bc_loss-test 9.4026e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 1.7299e-02,| Test-Loss 1.6699e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4363e-03,| pde-loss 2.5539e-03,| initc-loss 5.5831e-03,|bc_loss 9.1621e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9318e-03,| pde-loss-test 4.6824e-03,| initc-loss-test 5.3943e-03,|bc_loss-test 8.9633e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 1.6049e-02,| Test-Loss 1.6292e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.0619e-03,| pde-loss 2.3716e-03,| initc-loss 4.5269e-03,|bc_loss 9.1504e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1535e-03,| pde-loss-test 4.0355e-03,| initc-loss-test 5.5599e-03,|bc_loss-test 8.7140e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 1.6635e-02,| Test-Loss 1.6819e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0980e-03,| pde-loss 2.6101e-03,| initc-loss 5.3085e-03,|bc_loss 8.7162e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2969e-03,| pde-loss-test 4.8102e-03,| initc-loss-test 5.2161e-03,|bc_loss-test 9.1975e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 1.5935e-02,| Test-Loss 1.5923e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0287e-03,| pde-loss 2.2206e-03,| initc-loss 4.9585e-03,|bc_loss 8.7555e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.4902e-03,| pde-loss-test 3.6615e-03,| initc-loss-test 5.2658e-03,|bc_loss-test 8.8262e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 1.5885e-02,| Test-Loss 1.6578e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5271e-03,| pde-loss 2.2022e-03,| initc-loss 5.2908e-03,|bc_loss 8.3923e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1770e-03,| pde-loss-test 4.7250e-03,| initc-loss-test 5.8127e-03,|bc_loss-test 8.4028e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 1.8722e-02,| Test-Loss 1.5934e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9800e-03,| pde-loss 2.2146e-03,| initc-loss 5.3082e-03,|bc_loss 1.1199e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7556e-03,| pde-loss-test 4.5482e-03,| initc-loss-test 4.7842e-03,|bc_loss-test 8.8754e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 1.5367e-02,| Test-Loss 1.5288e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.5033e-03,| pde-loss 1.9780e-03,| initc-loss 5.1903e-03,|bc_loss 8.1984e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.6736e-03,| pde-loss-test 4.3046e-03,| initc-loss-test 5.2710e-03,|bc_loss-test 7.8645e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 1.4993e-02,| Test-Loss 1.5019e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4962e-03,| pde-loss 2.0162e-03,| initc-loss 4.7601e-03,|bc_loss 8.2167e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2686e-03,| pde-loss-test 4.3680e-03,| initc-loss-test 4.7735e-03,|bc_loss-test 8.0614e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 1.4903e-02,| Test-Loss 1.4122e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5430e-03,| pde-loss 2.5007e-03,| initc-loss 4.5907e-03,|bc_loss 7.8116e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.4835e-03,| pde-loss-test 4.4796e-03,| initc-loss-test 4.2905e-03,|bc_loss-test 7.5922e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 1.4501e-02,| Test-Loss 1.3772e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.7632e-03,| pde-loss 2.1179e-03,| initc-loss 4.6630e-03,|bc_loss 7.7203e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.4825e-03,| pde-loss-test 4.2514e-03,| initc-loss-test 4.1467e-03,|bc_loss-test 7.4999e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 1.4385e-02,| Test-Loss 1.5121e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.2407e-03,| pde-loss 2.3091e-03,| initc-loss 4.6527e-03,|bc_loss 7.4227e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1271e-03,| pde-loss-test 4.4683e-03,| initc-loss-test 5.1026e-03,|bc_loss-test 7.7845e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 1.3709e-02,| Test-Loss 1.3579e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6541e-03,| pde-loss 1.7490e-03,| initc-loss 4.3295e-03,|bc_loss 7.6306e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1729e-03,| pde-loss-test 3.9609e-03,| initc-loss-test 4.5959e-03,|bc_loss-test 7.0021e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 1.4192e-02,| Test-Loss 1.4132e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3625e-03,| pde-loss 2.0429e-03,| initc-loss 4.6224e-03,|bc_loss 7.5264e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.5062e-03,| pde-loss-test 4.1407e-03,| initc-loss-test 4.7133e-03,|bc_loss-test 7.3487e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 1.4467e-02,| Test-Loss 1.3089e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1072e-03,| pde-loss 2.1086e-03,| initc-loss 4.8939e-03,|bc_loss 7.4650e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.9020e-03,| pde-loss-test 4.2704e-03,| initc-loss-test 3.6839e-03,|bc_loss-test 7.2698e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 1.3334e-02,| Test-Loss 1.2575e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5628e-03,| pde-loss 1.9377e-03,| initc-loss 4.2461e-03,|bc_loss 7.1497e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.8003e-03,| pde-loss-test 3.6662e-03,| initc-loss-test 4.3197e-03,|bc_loss-test 6.4223e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 1.5582e-02,| Test-Loss 1.3175e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0644e-03,| pde-loss 2.0058e-03,| initc-loss 5.0300e-03,|bc_loss 8.5459e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9999e-03,| pde-loss-test 4.0549e-03,| initc-loss-test 4.1220e-03,|bc_loss-test 7.0258e-03|
# ...
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14781,            | Training-Loss 1.1420e-03,| Test-Loss 9.4281e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6255e-02,| pde-loss 7.9442e-05,| initc-loss 7.5944e-04,|bc_loss 3.0313e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9415e-02,| pde-loss-test 2.7762e-04,| initc-loss-test 5.2396e-04,|bc_loss-test 2.8004e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14791,            | Training-Loss 1.1169e-03,| Test-Loss 8.4386e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6010e-02,| pde-loss 8.6188e-05,| initc-loss 8.4478e-04,|bc_loss 1.8589e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3571e-02,| pde-loss-test 1.1274e-04,| initc-loss-test 5.1843e-04,|bc_loss-test 2.6907e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14801,            | Training-Loss 1.1119e-03,| Test-Loss 1.0812e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6484e-02,| pde-loss 8.5269e-05,| initc-loss 7.7941e-04,|bc_loss 2.4719e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.5339e-02,| pde-loss-test 2.6543e-04,| initc-loss-test 6.7460e-04,|bc_loss-test 2.7388e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14811,            | Training-Loss 1.1297e-03,| Test-Loss 1.1005e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6836e-02,| pde-loss 8.7636e-05,| initc-loss 7.6009e-04,|bc_loss 2.8199e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.5116e-02,| pde-loss-test 1.9223e-04,| initc-loss-test 7.4378e-04,|bc_loss-test 2.6062e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14821,            | Training-Loss 1.1211e-03,| Test-Loss 1.1399e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6187e-02,| pde-loss 8.7146e-05,| initc-loss 7.5728e-04,|bc_loss 2.7670e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9836e-02,| pde-loss-test 2.3750e-04,| initc-loss-test 7.3913e-04,|bc_loss-test 2.8197e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14831,            | Training-Loss 3.4722e-03,| Test-Loss 1.0895e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6011e-02,| pde-loss 8.7078e-05,| initc-loss 8.7704e-04,|bc_loss 2.5081e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0593e-02,| pde-loss-test 1.7839e-04,| initc-loss-test 6.7439e-04,|bc_loss-test 3.2589e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14841,            | Training-Loss 3.2182e-03,| Test-Loss 1.0409e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3214e-02,| pde-loss 1.4940e-04,| initc-loss 6.5174e-04,|bc_loss 2.4171e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1202e-02,| pde-loss-test 2.9792e-04,| initc-loss-test 6.5768e-04,|bc_loss-test 2.3430e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14851,            | Training-Loss 1.1835e-03,| Test-Loss 9.8913e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7885e-02,| pde-loss 8.5318e-05,| initc-loss 9.0110e-04,|bc_loss 1.9712e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2623e-02,| pde-loss-test 1.6417e-04,| initc-loss-test 6.3116e-04,|bc_loss-test 2.7589e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14861,            | Training-Loss 1.0609e-03,| Test-Loss 1.1897e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6609e-02,| pde-loss 7.5307e-05,| initc-loss 6.6538e-04,|bc_loss 3.2021e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4053e-02,| pde-loss-test 2.3214e-04,| initc-loss-test 7.0336e-04,|bc_loss-test 3.7022e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14871,            | Training-Loss 1.0064e-03,| Test-Loss 1.1659e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5549e-02,| pde-loss 8.5055e-05,| initc-loss 6.9067e-04,|bc_loss 2.3064e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9927e-02,| pde-loss-test 1.8816e-04,| initc-loss-test 8.2946e-04,|bc_loss-test 2.4240e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14881,            | Training-Loss 1.2409e-03,| Test-Loss 9.9421e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4638e-02,| pde-loss 6.2990e-05,| initc-loss 9.3599e-04,|bc_loss 2.4188e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4557e-02,| pde-loss-test 1.8463e-04,| initc-loss-test 6.1443e-04,|bc_loss-test 2.8747e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14891,            | Training-Loss 1.1953e-03,| Test-Loss 1.0352e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5139e-02,| pde-loss 1.0280e-04,| initc-loss 7.7345e-04,|bc_loss 3.1909e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1507e-02,| pde-loss-test 1.9427e-04,| initc-loss-test 6.1655e-04,|bc_loss-test 3.2150e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14901,            | Training-Loss 1.0213e-03,| Test-Loss 1.2298e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5841e-02,| pde-loss 1.0564e-04,| initc-loss 5.9907e-04,|bc_loss 3.1658e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9840e-02,| pde-loss-test 1.9840e-04,| initc-loss-test 8.8138e-04,|bc_loss-test 2.4920e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14911,            | Training-Loss 8.7803e-04,| Test-Loss 1.1281e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4340e-02,| pde-loss 6.1393e-05,| initc-loss 5.9711e-04,|bc_loss 2.1953e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2621e-02,| pde-loss-test 1.6041e-04,| initc-loss-test 8.2799e-04,|bc_loss-test 2.1990e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14921,            | Training-Loss 1.0612e-03,| Test-Loss 1.1306e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5477e-02,| pde-loss 1.0765e-04,| initc-loss 7.2035e-04,|bc_loss 2.3323e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2903e-02,| pde-loss-test 2.4163e-04,| initc-loss-test 7.4895e-04,|bc_loss-test 2.6088e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14931,            | Training-Loss 1.1460e-03,| Test-Loss 9.6519e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6239e-02,| pde-loss 1.1579e-04,| initc-loss 7.9866e-04,|bc_loss 2.3155e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2205e-02,| pde-loss-test 2.0124e-04,| initc-loss-test 6.5204e-04,|bc_loss-test 2.1253e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14941,            | Training-Loss 8.7706e-04,| Test-Loss 1.0470e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5926e-02,| pde-loss 7.6478e-05,| initc-loss 5.6567e-04,|bc_loss 2.3491e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4260e-02,| pde-loss-test 2.0035e-04,| initc-loss-test 7.0329e-04,|bc_loss-test 2.4358e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14951,            | Training-Loss 9.9469e-04,| Test-Loss 1.0059e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6178e-02,| pde-loss 8.5860e-05,| initc-loss 6.9251e-04,|bc_loss 2.1632e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1455e-02,| pde-loss-test 9.6110e-05,| initc-loss-test 7.2138e-04,|bc_loss-test 2.3651e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14961,            | Training-Loss 9.9223e-04,| Test-Loss 1.0775e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7360e-02,| pde-loss 6.8347e-05,| initc-loss 6.1741e-04,|bc_loss 3.0647e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3551e-02,| pde-loss-test 1.2930e-04,| initc-loss-test 7.7096e-04,|bc_loss-test 2.4189e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14971,            | Training-Loss 1.1486e-03,| Test-Loss 1.0081e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5462e-02,| pde-loss 1.3003e-04,| initc-loss 8.1354e-04,|bc_loss 2.0502e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0429e-02,| pde-loss-test 1.2311e-04,| initc-loss-test 6.9247e-04,|bc_loss-test 2.5407e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14981,            | Training-Loss 8.9518e-04,| Test-Loss 1.1045e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5759e-02,| pde-loss 8.7983e-05,| initc-loss 5.6160e-04,|bc_loss 2.4560e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3162e-02,| pde-loss-test 3.2546e-04,| initc-loss-test 7.3617e-04,|bc_loss-test 2.0556e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 14991,            | Training-Loss 1.0864e-03,| Test-Loss 8.3166e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7363e-02,| pde-loss 1.0204e-04,| initc-loss 7.0841e-04,|bc_loss 2.7591e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4875e-02,| pde-loss-test 1.7437e-04,| initc-loss-test 4.7990e-04,|bc_loss-test 2.6458e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 15000,            | Training-Loss 7.6775e-04,| Test-Loss 1.0558e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6077e-02,| pde-loss 6.7426e-05,| initc-loss 4.5521e-04,|bc_loss 2.4511e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0196e-02,| pde-loss-test 1.4294e-04,| initc-loss-test 7.7208e-04,|bc_loss-test 2.1229e-04|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,919.0,298.0) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[840.74927]
#  [874.3741 ]
#  [897.95465]
#  ...
#  [847.0196 ]
#  [830.6044 ]
#  [812.2068 ]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

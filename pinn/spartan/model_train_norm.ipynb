# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_norm import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# MPS is available
# Using device: mps
# MPS is available
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(25)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 1.0

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_max = props['k_l']
rho_max = props['rho_s']
cp_max = props['cp_l']
alpha_max = k_max / (rho_max * cp_max)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# The number of points in the initial condition is 40000
# scaling not initiated
# The number of points in the left boundary condition is 40000
# The number of points in the right boundary condition is 40000
# scaling not initiated
# The number of points in the left boundary condition is 40000
# The number of points in the right boundary condition is 40000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+25002=25002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 25000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+12502=12502.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data_new2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=100)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=10000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=10000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=10000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=10000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=100 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=10000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=10000 )  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=10000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=10000) # random sampler for bc right residuals

train_loader = DataLoader(inp_dataset, batch_size=256, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=256, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=256, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=256, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=256, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=256, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=256, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=256, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=256, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=256, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 8#  best yet is 8
output_size=1

learning_rate = 0.001 # 0.001
hidden_layers = 4  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =1000
epochs_2 = 100
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate,line_search_fn ='strong_wolfe')

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 3.4311e+00,| Test-Loss 3.3968e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0718e+00,| pde-loss 1.3686e-01,| initc-loss 1.3806e+00,|bc_loss 1.9136e+00|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.9435e+00,| pde-loss-test 3.1541e-01,| initc-loss-test 1.3543e+00,|bc_loss-test 1.8848e+00|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 2.7964e+00,| Test-Loss 2.7168e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6532e+00,| pde-loss 1.1736e-01,| initc-loss 1.1443e+00,|bc_loss 1.5348e+00|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2350e+00,| pde-loss-test 2.7323e-01,| initc-loss-test 1.0800e+00,|bc_loss-test 1.5002e+00|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 2.2038e+00,| Test-Loss 2.1348e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2363e+00,| pde-loss 7.3978e-02,| initc-loss 9.3316e-01,|bc_loss 1.1966e+00|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.4338e+00,| pde-loss-test 1.6463e-01,| initc-loss-test 9.0190e-01,|bc_loss-test 1.1506e+00|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 1.6852e+00,| Test-Loss 1.6436e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3747e-01,| pde-loss 5.3454e-02,| initc-loss 7.4857e-01,|bc_loss 8.8320e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8368e+00,| pde-loss-test 9.4046e-02,| initc-loss-test 7.4209e-01,|bc_loss-test 8.5451e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 1.2583e+00,| Test-Loss 1.2178e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6145e-01,| pde-loss 2.7113e-02,| initc-loss 6.1463e-01,|bc_loss 6.1658e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2670e+00,| pde-loss-test 5.0208e-02,| initc-loss-test 6.0155e-01,|bc_loss-test 5.9119e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 8.8821e-01,| Test-Loss 8.5082e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3831e-01,| pde-loss 1.0128e-02,| initc-loss 4.8292e-01,|bc_loss 3.9516e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2979e-01,| pde-loss-test 1.5285e-02,| initc-loss-test 4.6670e-01,|bc_loss-test 3.7648e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 5.9440e-01,| Test-Loss 5.7159e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.5825e-01,| pde-loss 1.8372e-03,| initc-loss 3.6123e-01,|bc_loss 2.3134e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.9945e-01,| pde-loss-test 3.1912e-03,| initc-loss-test 3.5168e-01,|bc_loss-test 2.1832e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 3.7670e-01,| Test-Loss 3.6197e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4141e-01,| pde-loss 3.3879e-04,| initc-loss 2.5624e-01,|bc_loss 1.2013e-01|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6221e-01,| pde-loss-test 7.9831e-04,| initc-loss-test 2.4929e-01,|bc_loss-test 1.1228e-01|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 2.2440e-01,| Test-Loss 2.1622e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9800e-02,| pde-loss 1.4328e-03,| initc-loss 1.6953e-01,|bc_loss 5.3433e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2806e-01,| pde-loss-test 3.4032e-03,| initc-loss-test 1.6555e-01,|bc_loss-test 4.8969e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 1.3001e-01,| Test-Loss 1.2274e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0837e-02,| pde-loss 2.5036e-03,| initc-loss 1.0803e-01,|bc_loss 1.9475e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.0931e-02,| pde-loss-test 4.9455e-03,| initc-loss-test 1.0254e-01,|bc_loss-test 1.7734e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 7.1964e-02,| Test-Loss 6.8586e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.8524e-03,| pde-loss 2.1052e-03,| initc-loss 6.4644e-02,|bc_loss 5.2155e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8776e-02,| pde-loss-test 5.5385e-03,| initc-loss-test 6.1399e-02,|bc_loss-test 4.4174e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 4.0936e-02,| Test-Loss 3.9139e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9333e-03,| pde-loss 2.2408e-03,| initc-loss 3.7892e-02,|bc_loss 8.0315e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.0869e-03,| pde-loss-test 5.7327e-03,| initc-loss-test 3.5579e-02,|bc_loss-test 6.9323e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 2.4586e-02,| Test-Loss 2.3384e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7317e-04,| pde-loss 1.8971e-03,| initc-loss 2.2137e-02,|bc_loss 5.5278e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2121e-03,| pde-loss-test 3.6003e-03,| initc-loss-test 2.0881e-02,|bc_loss-test 7.0332e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 1.6269e-02,| Test-Loss 1.5714e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3853e-04,| pde-loss 1.6336e-03,| initc-loss 1.3139e-02,|bc_loss 1.4960e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0843e-03,| pde-loss-test 3.3079e-03,| initc-loss-test 1.2535e-02,|bc_loss-test 1.5246e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 1.2323e-02,| Test-Loss 1.1886e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.0868e-04,| pde-loss 1.6410e-03,| initc-loss 8.4616e-03,|bc_loss 2.2208e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3026e-03,| pde-loss-test 3.0077e-03,| initc-loss-test 8.0207e-03,|bc_loss-test 2.3620e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 1.0322e-02,| Test-Loss 9.8740e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5156e-04,| pde-loss 1.8029e-03,| initc-loss 5.7591e-03,|bc_loss 2.7595e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.5836e-04,| pde-loss-test 3.1699e-03,| initc-loss-test 5.5638e-03,|bc_loss-test 2.7252e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 9.2562e-03,| Test-Loss 9.2194e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.0329e-04,| pde-loss 2.0968e-03,| initc-loss 4.2641e-03,|bc_loss 2.8953e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4081e-03,| pde-loss-test 4.4296e-03,| initc-loss-test 4.1234e-03,|bc_loss-test 2.8812e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 8.7956e-03,| Test-Loss 8.7388e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8730e-04,| pde-loss 2.4375e-03,| initc-loss 3.4099e-03,|bc_loss 2.9481e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.1143e-03,| pde-loss-test 4.7204e-03,| initc-loss-test 3.2818e-03,|bc_loss-test 3.0969e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 8.2266e-03,| Test-Loss 1.0772e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0810e-04,| pde-loss 2.5337e-03,| initc-loss 2.8742e-03,|bc_loss 2.8188e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4068e-03,| pde-loss-test 5.2789e-03,| initc-loss-test 2.7828e-03,|bc_loss-test 5.3502e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 8.9007e-03,| Test-Loss 7.9691e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3061e-04,| pde-loss 3.0465e-03,| initc-loss 2.5979e-03,|bc_loss 3.2563e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4092e-03,| pde-loss-test 5.1221e-03,| initc-loss-test 2.5336e-03,|bc_loss-test 2.8745e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 8.3305e-03,| Test-Loss 8.2657e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0320e-03,| pde-loss 2.8339e-03,| initc-loss 2.3811e-03,|bc_loss 3.1155e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3519e-03,| pde-loss-test 5.5166e-03,| initc-loss-test 2.3866e-03,|bc_loss-test 3.1208e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 8.2739e-03,| Test-Loss 8.4264e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8880e-04,| pde-loss 2.9529e-03,| initc-loss 2.2331e-03,|bc_loss 3.0879e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3947e-03,| pde-loss-test 5.6705e-03,| initc-loss-test 2.2522e-03,|bc_loss-test 3.3389e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 8.4374e-03,| Test-Loss 8.2863e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.6257e-04,| pde-loss 3.1823e-03,| initc-loss 2.2283e-03,|bc_loss 3.0268e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5583e-03,| pde-loss-test 6.0712e-03,| initc-loss-test 2.1558e-03,|bc_loss-test 3.0949e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 8.3446e-03,| Test-Loss 8.2775e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.7060e-04,| pde-loss 3.3471e-03,| initc-loss 2.1389e-03,|bc_loss 2.8585e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7264e-03,| pde-loss-test 6.4383e-03,| initc-loss-test 2.1369e-03,|bc_loss-test 2.9214e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 8.0690e-03,| Test-Loss 8.1113e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.1427e-04,| pde-loss 2.8244e-03,| initc-loss 2.1108e-03,|bc_loss 3.1338e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5890e-03,| pde-loss-test 6.1630e-03,| initc-loss-test 2.1232e-03,|bc_loss-test 2.9066e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 8.3178e-03,| Test-Loss 7.8872e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0685e-03,| pde-loss 3.0973e-03,| initc-loss 2.1321e-03,|bc_loss 3.0883e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5286e-03,| pde-loss-test 5.7938e-03,| initc-loss-test 2.1160e-03,|bc_loss-test 2.8743e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 8.1430e-03,| Test-Loss 8.1388e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.0233e-04,| pde-loss 3.0042e-03,| initc-loss 2.0851e-03,|bc_loss 3.0537e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6369e-03,| pde-loss-test 5.7241e-03,| initc-loss-test 2.1483e-03,|bc_loss-test 3.1284e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 8.1766e-03,| Test-Loss 7.9544e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.4454e-04,| pde-loss 3.0445e-03,| initc-loss 2.1160e-03,|bc_loss 3.0161e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4266e-03,| pde-loss-test 5.8704e-03,| initc-loss-test 2.1112e-03,|bc_loss-test 2.9080e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 8.3245e-03,| Test-Loss 7.9710e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.0114e-04,| pde-loss 3.2058e-03,| initc-loss 2.0949e-03,|bc_loss 3.0238e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7460e-03,| pde-loss-test 5.8197e-03,| initc-loss-test 2.1326e-03,|bc_loss-test 2.9285e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 8.0296e-03,| Test-Loss 7.9783e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.3533e-04,| pde-loss 3.1271e-03,| initc-loss 2.1196e-03,|bc_loss 2.7829e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5347e-03,| pde-loss-test 5.6647e-03,| initc-loss-test 2.1249e-03,|bc_loss-test 3.0210e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 8.0099e-03,| Test-Loss 8.5782e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.2585e-04,| pde-loss 2.8429e-03,| initc-loss 2.1272e-03,|bc_loss 3.0398e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2686e-03,| pde-loss-test 6.1647e-03,| initc-loss-test 2.1492e-03,|bc_loss-test 3.3467e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 7.9924e-03,| Test-Loss 8.2788e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7257e-04,| pde-loss 2.8868e-03,| initc-loss 2.1590e-03,|bc_loss 2.9467e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9457e-03,| pde-loss-test 5.3371e-03,| initc-loss-test 2.1946e-03,|bc_loss-test 3.4156e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 1.0528e-02,| Test-Loss 8.5251e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6751e-04,| pde-loss 3.0056e-03,| initc-loss 2.1611e-03,|bc_loss 5.3611e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5678e-03,| pde-loss-test 6.0318e-03,| initc-loss-test 2.1694e-03,|bc_loss-test 3.3398e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 8.2801e-03,| Test-Loss 8.2614e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0334e-03,| pde-loss 2.9293e-03,| initc-loss 2.1227e-03,|bc_loss 3.2281e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6356e-03,| pde-loss-test 5.9753e-03,| initc-loss-test 2.1671e-03,|bc_loss-test 3.1067e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 8.2392e-03,| Test-Loss 8.3649e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.3735e-04,| pde-loss 3.0973e-03,| initc-loss 2.1946e-03,|bc_loss 2.9474e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5029e-03,| pde-loss-test 6.1954e-03,| initc-loss-test 2.1249e-03,|bc_loss-test 3.1422e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 7.8310e-03,| Test-Loss 8.4398e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9502e-04,| pde-loss 2.6415e-03,| initc-loss 2.1722e-03,|bc_loss 3.0174e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5025e-03,| pde-loss-test 6.0516e-03,| initc-loss-test 2.1479e-03,|bc_loss-test 3.2662e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 7.8399e-03,| Test-Loss 7.6759e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4837e-04,| pde-loss 2.6572e-03,| initc-loss 2.1613e-03,|bc_loss 3.0214e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7766e-03,| pde-loss-test 4.9463e-03,| initc-loss-test 2.1687e-03,|bc_loss-test 3.0340e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 8.2656e-03,| Test-Loss 1.2944e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4545e-04,| pde-loss 2.7592e-03,| initc-loss 2.1318e-03,|bc_loss 3.3745e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5292e-03,| pde-loss-test 5.8062e-03,| initc-loss-test 2.1739e-03,|bc_loss-test 7.8667e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 8.2106e-03,| Test-Loss 7.8005e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.2612e-04,| pde-loss 2.9909e-03,| initc-loss 2.1186e-03,|bc_loss 3.1011e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8467e-03,| pde-loss-test 5.8205e-03,| initc-loss-test 2.1349e-03,|bc_loss-test 2.7553e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 7.8467e-03,| Test-Loss 8.2757e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8148e-04,| pde-loss 3.1199e-03,| initc-loss 2.1175e-03,|bc_loss 2.6093e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5178e-03,| pde-loss-test 5.8466e-03,| initc-loss-test 2.1102e-03,|bc_loss-test 3.2422e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 8.1262e-03,| Test-Loss 7.9496e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.2164e-04,| pde-loss 2.9277e-03,| initc-loss 2.0963e-03,|bc_loss 3.1021e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9047e-03,| pde-loss-test 6.0169e-03,| initc-loss-test 2.0981e-03,|bc_loss-test 2.8430e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 7.9379e-03,| Test-Loss 7.9213e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.8504e-04,| pde-loss 2.7483e-03,| initc-loss 2.1348e-03,|bc_loss 3.0548e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7265e-03,| pde-loss-test 5.2038e-03,| initc-loss-test 2.1503e-03,|bc_loss-test 3.1691e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 7.8058e-03,| Test-Loss 1.0007e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2319e-03,| pde-loss 2.7440e-03,| initc-loss 2.1328e-03,|bc_loss 2.9290e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5770e-03,| pde-loss-test 5.3348e-03,| initc-loss-test 2.1516e-03,|bc_loss-test 5.1883e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 7.6735e-03,| Test-Loss 7.8322e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5803e-04,| pde-loss 2.6422e-03,| initc-loss 2.1758e-03,|bc_loss 2.8555e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9375e-03,| pde-loss-test 5.1426e-03,| initc-loss-test 2.1851e-03,|bc_loss-test 3.0757e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 7.9052e-03,| Test-Loss 1.0842e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.8132e-04,| pde-loss 2.6932e-03,| initc-loss 2.1262e-03,|bc_loss 3.0858e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.5292e-03,| pde-loss-test 6.1372e-03,| initc-loss-test 2.1798e-03,|bc_loss-test 5.5937e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 7.9479e-03,| Test-Loss 7.8509e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1710e-04,| pde-loss 2.7776e-03,| initc-loss 2.1347e-03,|bc_loss 3.0355e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3817e-03,| pde-loss-test 5.4325e-03,| initc-loss-test 2.1621e-03,|bc_loss-test 2.9726e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 7.7750e-03,| Test-Loss 7.6218e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.1528e-04,| pde-loss 2.6897e-03,| initc-loss 2.1424e-03,|bc_loss 2.9429e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7922e-03,| pde-loss-test 5.1765e-03,| initc-loss-test 2.1450e-03,|bc_loss-test 2.8886e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 7.8903e-03,| Test-Loss 7.5898e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9941e-04,| pde-loss 2.6878e-03,| initc-loss 2.1453e-03,|bc_loss 3.0572e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5596e-03,| pde-loss-test 5.8230e-03,| initc-loss-test 2.1250e-03,|bc_loss-test 2.5533e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 7.9769e-03,| Test-Loss 7.8729e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0401e-03,| pde-loss 2.9109e-03,| initc-loss 2.1326e-03,|bc_loss 2.9334e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4509e-03,| pde-loss-test 5.5204e-03,| initc-loss-test 2.1399e-03,|bc_loss-test 2.9728e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 7.8925e-03,| Test-Loss 7.9148e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.3919e-04,| pde-loss 2.8558e-03,| initc-loss 2.1274e-03,|bc_loss 2.9093e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6075e-03,| pde-loss-test 5.7297e-03,| initc-loss-test 2.1548e-03,|bc_loss-test 2.8952e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 7.7398e-03,| Test-Loss 8.0729e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.5704e-04,| pde-loss 2.7278e-03,| initc-loss 2.1462e-03,|bc_loss 2.8659e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0951e-03,| pde-loss-test 5.5544e-03,| initc-loss-test 2.1522e-03,|bc_loss-test 3.1435e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 7.6546e-03,| Test-Loss 8.2607e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.9956e-04,| pde-loss 2.5194e-03,| initc-loss 2.1291e-03,|bc_loss 3.0061e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8647e-03,| pde-loss-test 5.5128e-03,| initc-loss-test 2.1539e-03,|bc_loss-test 3.3504e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 7.4244e-03,| Test-Loss 8.0935e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8014e-04,| pde-loss 2.3705e-03,| initc-loss 2.1491e-03,|bc_loss 2.9049e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5661e-03,| pde-loss-test 5.5642e-03,| initc-loss-test 2.1667e-03,|bc_loss-test 3.1447e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 8.0427e-03,| Test-Loss 7.7333e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7351e-04,| pde-loss 2.9417e-03,| initc-loss 2.1209e-03,|bc_loss 2.9801e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.2797e-03,| pde-loss-test 5.2681e-03,| initc-loss-test 2.1158e-03,|bc_loss-test 2.9835e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 7.9721e-03,| Test-Loss 7.8495e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9935e-04,| pde-loss 2.6631e-03,| initc-loss 2.1653e-03,|bc_loss 3.1437e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0593e-03,| pde-loss-test 5.1846e-03,| initc-loss-test 2.1407e-03,|bc_loss-test 3.1164e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 7.9379e-03,| Test-Loss 7.6370e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.0756e-04,| pde-loss 2.8945e-03,| initc-loss 2.1802e-03,|bc_loss 2.8632e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4255e-03,| pde-loss-test 5.2686e-03,| initc-loss-test 2.1577e-03,|bc_loss-test 2.8450e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 7.9367e-03,| Test-Loss 1.0257e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.4934e-04,| pde-loss 2.6669e-03,| initc-loss 2.1646e-03,|bc_loss 3.1051e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8148e-03,| pde-loss-test 5.6285e-03,| initc-loss-test 2.1300e-03,|bc_loss-test 5.3130e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 7.6088e-03,| Test-Loss 1.0260e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8864e-04,| pde-loss 2.4908e-03,| initc-loss 2.1790e-03,|bc_loss 2.9390e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5001e-03,| pde-loss-test 5.4637e-03,| initc-loss-test 2.1486e-03,|bc_loss-test 5.3795e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 8.0893e-03,| Test-Loss 8.1422e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1632e-04,| pde-loss 2.7891e-03,| initc-loss 2.1347e-03,|bc_loss 3.1654e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4353e-03,| pde-loss-test 5.5388e-03,| initc-loss-test 2.1317e-03,|bc_loss-test 3.2412e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 7.7150e-03,| Test-Loss 8.4215e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.3308e-04,| pde-loss 2.7806e-03,| initc-loss 2.1157e-03,|bc_loss 2.8186e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2151e-03,| pde-loss-test 5.9092e-03,| initc-loss-test 2.1405e-03,|bc_loss-test 3.3264e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 7.3085e-03,| Test-Loss 1.0078e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4023e-04,| pde-loss 2.4376e-03,| initc-loss 2.1072e-03,|bc_loss 2.7637e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4563e-03,| pde-loss-test 5.5470e-03,| initc-loss-test 2.1158e-03,|bc_loss-test 5.1889e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 9.7401e-03,| Test-Loss 7.6923e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3816e-04,| pde-loss 2.5465e-03,| initc-loss 2.1052e-03,|bc_loss 5.0883e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4933e-03,| pde-loss-test 5.4759e-03,| initc-loss-test 2.1131e-03,|bc_loss-test 2.8411e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 7.7294e-03,| Test-Loss 8.1236e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1149e-04,| pde-loss 2.6000e-03,| initc-loss 2.1324e-03,|bc_loss 2.9970e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5250e-03,| pde-loss-test 5.2638e-03,| initc-loss-test 2.1290e-03,|bc_loss-test 3.3627e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 7.8145e-03,| Test-Loss 7.5960e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7168e-04,| pde-loss 2.7986e-03,| initc-loss 2.1857e-03,|bc_loss 2.8303e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2518e-03,| pde-loss-test 5.1447e-03,| initc-loss-test 2.1455e-03,|bc_loss-test 2.8781e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 7.8952e-03,| Test-Loss 7.9543e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5901e-04,| pde-loss 2.8752e-03,| initc-loss 2.1697e-03,|bc_loss 2.8504e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0042e-03,| pde-loss-test 5.8731e-03,| initc-loss-test 2.1605e-03,|bc_loss-test 2.8573e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 7.4550e-03,| Test-Loss 7.5777e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9465e-04,| pde-loss 2.3855e-03,| initc-loss 2.1589e-03,|bc_loss 2.9106e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9674e-03,| pde-loss-test 5.2055e-03,| initc-loss-test 2.1478e-03,|bc_loss-test 2.8271e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 8.2664e-03,| Test-Loss 7.5531e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0787e-04,| pde-loss 2.7021e-03,| initc-loss 2.1974e-03,|bc_loss 3.3669e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5175e-03,| pde-loss-test 4.7300e-03,| initc-loss-test 2.1502e-03,|bc_loss-test 3.0379e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 7.9060e-03,| Test-Loss 1.2327e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.6769e-04,| pde-loss 2.6044e-03,| initc-loss 2.1806e-03,|bc_loss 3.1210e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8474e-03,| pde-loss-test 4.8819e-03,| initc-loss-test 2.1139e-03,|bc_loss-test 7.7724e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 8.0262e-03,| Test-Loss 7.7271e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3580e-04,| pde-loss 2.7756e-03,| initc-loss 2.1603e-03,|bc_loss 3.0902e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7206e-03,| pde-loss-test 5.0234e-03,| initc-loss-test 2.1263e-03,|bc_loss-test 3.0891e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 7.4310e-03,| Test-Loss 7.6945e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1912e-04,| pde-loss 2.3141e-03,| initc-loss 2.1573e-03,|bc_loss 2.9596e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2063e-03,| pde-loss-test 4.9062e-03,| initc-loss-test 2.1496e-03,|bc_loss-test 3.0919e-03|
# ...
# | Data-loss-test 2.0934e-03,| pde-loss-test 4.8981e-03,| initc-loss-test 2.1158e-03,|bc_loss-test 3.1300e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 781,            | Training-Loss 7.3567e-03,| Test-Loss 7.4240e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.4271e-04,| pde-loss 2.4009e-03,| initc-loss 2.1025e-03,|bc_loss 2.8533e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3478e-03,| pde-loss-test 5.2919e-03,| initc-loss-test 2.0624e-03,|bc_loss-test 2.7157e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 791,            | Training-Loss 7.4296e-03,| Test-Loss 7.3426e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5922e-04,| pde-loss 2.4381e-03,| initc-loss 2.1022e-03,|bc_loss 2.8893e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5846e-03,| pde-loss-test 4.7967e-03,| initc-loss-test 2.1212e-03,|bc_loss-test 2.8231e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 801,            | Training-Loss 7.5844e-03,| Test-Loss 7.2750e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8989e-04,| pde-loss 2.3964e-03,| initc-loss 2.1445e-03,|bc_loss 3.0435e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5141e-03,| pde-loss-test 4.5359e-03,| initc-loss-test 2.0972e-03,|bc_loss-test 2.9099e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 811,            | Training-Loss 7.7069e-03,| Test-Loss 7.4417e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5761e-04,| pde-loss 2.4842e-03,| initc-loss 2.1061e-03,|bc_loss 3.1166e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5496e-03,| pde-loss-test 4.8731e-03,| initc-loss-test 2.0979e-03,|bc_loss-test 2.9072e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 821,            | Training-Loss 7.8514e-03,| Test-Loss 7.6688e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.5993e-04,| pde-loss 2.5876e-03,| initc-loss 2.1500e-03,|bc_loss 3.1138e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5499e-03,| pde-loss-test 5.1633e-03,| initc-loss-test 2.1122e-03,|bc_loss-test 2.9750e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 831,            | Training-Loss 7.3289e-03,| Test-Loss 7.6534e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7917e-04,| pde-loss 2.3404e-03,| initc-loss 2.1272e-03,|bc_loss 2.8614e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6806e-03,| pde-loss-test 5.0069e-03,| initc-loss-test 2.1651e-03,|bc_loss-test 2.9848e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 841,            | Training-Loss 7.2935e-03,| Test-Loss 7.4107e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4738e-04,| pde-loss 2.4026e-03,| initc-loss 2.1681e-03,|bc_loss 2.7227e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6399e-03,| pde-loss-test 4.8628e-03,| initc-loss-test 2.1203e-03,|bc_loss-test 2.8590e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 851,            | Training-Loss 7.6268e-03,| Test-Loss 7.7339e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.6484e-04,| pde-loss 2.3617e-03,| initc-loss 2.1314e-03,|bc_loss 3.1337e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0801e-03,| pde-loss-test 5.4862e-03,| initc-loss-test 2.1497e-03,|bc_loss-test 2.8411e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 861,            | Training-Loss 7.4442e-03,| Test-Loss 7.7482e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.1867e-04,| pde-loss 2.2545e-03,| initc-loss 2.1069e-03,|bc_loss 3.0828e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4146e-03,| pde-loss-test 5.0110e-03,| initc-loss-test 2.1218e-03,|bc_loss-test 3.1209e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 871,            | Training-Loss 7.3853e-03,| Test-Loss 7.3836e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8437e-04,| pde-loss 2.5997e-03,| initc-loss 2.1210e-03,|bc_loss 2.6647e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3930e-03,| pde-loss-test 4.7268e-03,| initc-loss-test 2.0889e-03,|bc_loss-test 2.9313e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 881,            | Training-Loss 7.3938e-03,| Test-Loss 7.5868e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.4087e-04,| pde-loss 2.2056e-03,| initc-loss 2.1119e-03,|bc_loss 3.0764e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7128e-03,| pde-loss-test 4.3974e-03,| initc-loss-test 2.1684e-03,|bc_loss-test 3.2198e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 891,            | Training-Loss 7.4879e-03,| Test-Loss 7.4396e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4893e-04,| pde-loss 2.6452e-03,| initc-loss 2.1220e-03,|bc_loss 2.7207e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6752e-03,| pde-loss-test 4.9515e-03,| initc-loss-test 2.1255e-03,|bc_loss-test 2.8384e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 901,            | Training-Loss 7.3161e-03,| Test-Loss 7.2502e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5679e-04,| pde-loss 2.4058e-03,| initc-loss 2.1090e-03,|bc_loss 2.8012e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5169e-03,| pde-loss-test 4.6699e-03,| initc-loss-test 2.1420e-03,|bc_loss-test 2.7732e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 911,            | Training-Loss 7.5433e-03,| Test-Loss 7.2302e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.6606e-04,| pde-loss 2.4166e-03,| initc-loss 2.0652e-03,|bc_loss 3.0614e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4596e-03,| pde-loss-test 4.7999e-03,| initc-loss-test 2.1158e-03,|bc_loss-test 2.7145e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 921,            | Training-Loss 7.6677e-03,| Test-Loss 7.6660e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.7108e-04,| pde-loss 2.5354e-03,| initc-loss 2.1281e-03,|bc_loss 3.0042e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5428e-03,| pde-loss-test 4.9319e-03,| initc-loss-test 2.1218e-03,|bc_loss-test 3.0783e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 931,            | Training-Loss 7.2605e-03,| Test-Loss 6.9350e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0738e-04,| pde-loss 2.3416e-03,| initc-loss 2.1523e-03,|bc_loss 2.7666e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1664e-03,| pde-loss-test 4.2455e-03,| initc-loss-test 2.1098e-03,|bc_loss-test 2.7025e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 941,            | Training-Loss 7.4667e-03,| Test-Loss 7.2738e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9920e-04,| pde-loss 2.5964e-03,| initc-loss 2.0917e-03,|bc_loss 2.7786e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1784e-03,| pde-loss-test 4.4850e-03,| initc-loss-test 2.1044e-03,|bc_loss-test 2.9269e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 951,            | Training-Loss 7.1814e-03,| Test-Loss 7.6291e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2345e-04,| pde-loss 2.2441e-03,| initc-loss 2.1057e-03,|bc_loss 2.8316e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5333e-03,| pde-loss-test 4.6663e-03,| initc-loss-test 2.1342e-03,|bc_loss-test 3.1617e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 961,            | Training-Loss 7.3915e-03,| Test-Loss 7.2728e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9881e-04,| pde-loss 2.3898e-03,| initc-loss 2.0901e-03,|bc_loss 2.9116e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7229e-03,| pde-loss-test 4.5939e-03,| initc-loss-test 2.1541e-03,|bc_loss-test 2.8217e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 971,            | Training-Loss 7.4607e-03,| Test-Loss 7.3330e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.9977e-04,| pde-loss 2.4966e-03,| initc-loss 2.1507e-03,|bc_loss 2.8135e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8536e-03,| pde-loss-test 4.4559e-03,| initc-loss-test 2.1584e-03,|bc_loss-test 2.9467e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 981,            | Training-Loss 7.0690e-03,| Test-Loss 7.5537e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.6064e-04,| pde-loss 2.4509e-03,| initc-loss 2.0578e-03,|bc_loss 2.5603e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5095e-03,| pde-loss-test 4.8036e-03,| initc-loss-test 2.1296e-03,|bc_loss-test 3.0223e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 991,            | Training-Loss 7.1966e-03,| Test-Loss 7.0443e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.2217e-04,| pde-loss 2.1926e-03,| initc-loss 2.0694e-03,|bc_loss 2.9347e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4774e-03,| pde-loss-test 4.2542e-03,| initc-loss-test 2.0799e-03,|bc_loss-test 2.8372e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1000,            | Training-Loss 7.3268e-03,| Test-Loss 7.1628e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.6120e-04,| pde-loss 2.3675e-03,| initc-loss 2.0983e-03,|bc_loss 2.8610e-03|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5310e-03,| pde-loss-test 4.1632e-03,| initc-loss-test 2.1183e-03,|bc_loss-test 2.9629e-03|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_data = loss_train['data-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_data, label='Data Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,919.0,298.0) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[883.2113 ]
#  [884.26306]
#  [885.24866]
#  ...
#  [833.5996 ]
#  [833.69415]
#  [833.78186]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings_2.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.0004511760724698042
# 1.0

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[883.2113 ]
#  [883.22766]
#  [883.2439 ]
#  ...
#  [804.6974 ]
#  [804.6998 ]
#  [804.7023 ]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc_icc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_norm import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(32)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
# plot the intial temperature field
plt.figure(figsize=(8, 6))
plt.plot( tempfield[0, :], label='Initial Temperature Field')
plt.title('Initial Temperature Field')
plt.xlabel('Position (x)')
plt.ylabel('Temperature')
plt.legend()
plt.grid()

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 0.9999180924377908

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_l = props['k_l']
k_s = props['k_s']
rho_l = props['rho_l']
rho_s = props['rho_s']
cp_l = props['cp_l']
cp_s = props['cp_s']
alpha_l = k_l / (rho_l * cp_l)
alpha_s = k_s / (rho_s * cp_s)

alpha_max = max(alpha_l, alpha_s)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# The number of points in the initial condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+20002=20002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+10002=10002.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+10002=10002.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data_new2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=1000)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=1000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=1000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=1000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=1000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=1000 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=1000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=1000)  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=1000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=1000) # random sampler for bc right residuals

train_loader = DataLoader(inp_dataset, batch_size=256, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=256, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=256, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=256, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=256, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=256, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=256, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=256, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=256, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=256, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 45#  best yet is 8
output_size=1

learning_rate = 0.002 # 0.001
hidden_layers = 3  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =1000
epochs_2 = 100
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate,line_search_fn ='strong_wolfe')

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 7.1611e-01,| Test-Loss 3.7477e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1615e-02,| pde-loss 1.1169e-01,| initc-loss 3.8866e-02,|bc_loss 3.3800e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.5913e-02,| pde-loss-test 6.6489e-02,| initc-loss-test 2.4734e-02,|bc_loss-test 3.2934e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 9.2409e-03,| Test-Loss 7.8408e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0400e-04,| pde-loss 1.4255e-03,| initc-loss 1.1903e-03,|bc_loss 6.7298e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0027e-04,| pde-loss-test 5.0159e-04,| initc-loss-test 1.0954e-03,|bc_loss-test 7.2358e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 5.0844e-03,| Test-Loss 4.9476e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.7725e-05,| pde-loss 8.0569e-04,| initc-loss 8.5036e-04,|bc_loss 2.9394e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3411e-04,| pde-loss-test 3.4455e-04,| initc-loss-test 7.4724e-04,|bc_loss-test 2.7642e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 4.5770e-03,| Test-Loss 4.5597e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1649e-05,| pde-loss 6.6838e-04,| initc-loss 6.8149e-04,|bc_loss 2.5881e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1669e-04,| pde-loss-test 3.3492e-04,| initc-loss-test 7.3576e-04,|bc_loss-test 2.9686e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 4.4763e-03,| Test-Loss 4.3808e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.6752e-05,| pde-loss 5.5524e-04,| initc-loss 6.1775e-04,|bc_loss 3.2492e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4055e-04,| pde-loss-test 2.5951e-04,| initc-loss-test 6.6855e-04,|bc_loss-test 2.5735e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 4.2264e-03,| Test-Loss 4.2046e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3871e-05,| pde-loss 5.6793e-04,| initc-loss 6.6147e-04,|bc_loss 2.9923e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5340e-04,| pde-loss-test 2.3788e-04,| initc-loss-test 6.5362e-04,|bc_loss-test 2.6500e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 4.0296e-03,| Test-Loss 3.8441e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9492e-05,| pde-loss 4.5657e-04,| initc-loss 6.5951e-04,|bc_loss 2.7586e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0950e-04,| pde-loss-test 2.5562e-04,| initc-loss-test 6.1604e-04,|bc_loss-test 2.2930e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 3.8613e-03,| Test-Loss 3.7057e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.5169e-05,| pde-loss 3.9266e-04,| initc-loss 6.2660e-04,|bc_loss 2.6686e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3179e-04,| pde-loss-test 2.1501e-04,| initc-loss-test 5.4686e-04,|bc_loss-test 2.6831e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 3.4174e-03,| Test-Loss 3.4606e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9674e-05,| pde-loss 4.1572e-04,| initc-loss 4.7739e-04,|bc_loss 2.1690e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9023e-04,| pde-loss-test 2.0191e-04,| initc-loss-test 4.7511e-04,|bc_loss-test 2.6714e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 3.0989e-03,| Test-Loss 2.9491e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.2647e-05,| pde-loss 3.4056e-04,| initc-loss 4.9819e-04,|bc_loss 2.2061e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8354e-04,| pde-loss-test 1.4108e-04,| initc-loss-test 4.3647e-04,|bc_loss-test 2.1850e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 2.5571e-03,| Test-Loss 2.5113e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3402e-05,| pde-loss 2.7424e-04,| initc-loss 4.2414e-04,|bc_loss 1.4509e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.1464e-05,| pde-loss-test 1.7175e-04,| initc-loss-test 4.0752e-04,|bc_loss-test 1.4101e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 2.4170e-03,| Test-Loss 4.6194e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9559e-05,| pde-loss 6.7347e-04,| initc-loss 3.1231e-04,|bc_loss 9.6657e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4355e-04,| pde-loss-test 1.7731e-03,| initc-loss-test 3.0913e-04,|bc_loss-test 1.3962e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 2.1953e-03,| Test-Loss 2.1667e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7982e-05,| pde-loss 3.6471e-04,| initc-loss 3.7057e-04,|bc_loss 1.1646e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5938e-04,| pde-loss-test 1.0286e-04,| initc-loss-test 3.2842e-04,|bc_loss-test 1.2934e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 2.8747e-03,| Test-Loss 4.4845e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5014e-05,| pde-loss 1.1090e-03,| initc-loss 3.1388e-04,|bc_loss 1.1215e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4100e-04,| pde-loss-test 1.2442e-03,| initc-loss-test 3.0822e-04,|bc_loss-test 1.2162e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 2.3367e-03,| Test-Loss 2.0180e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5645e-05,| pde-loss 5.2157e-04,| initc-loss 3.2977e-04,|bc_loss 1.2577e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0985e-05,| pde-loss-test 1.0091e-04,| initc-loss-test 3.5419e-04,|bc_loss-test 9.3599e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 2.8541e-03,| Test-Loss 2.3811e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.6476e-05,| pde-loss 1.0738e-03,| initc-loss 3.4740e-04,|bc_loss 8.7407e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1276e-05,| pde-loss-test 4.3851e-04,| initc-loss-test 3.4947e-04,|bc_loss-test 1.0443e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 2.1205e-03,| Test-Loss 2.0207e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9973e-05,| pde-loss 3.3806e-04,| initc-loss 3.7862e-04,|bc_loss 1.0928e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1262e-05,| pde-loss-test 1.0165e-04,| initc-loss-test 3.6352e-04,|bc_loss-test 8.9431e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 2.6741e-03,| Test-Loss 3.1698e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9475e-05,| pde-loss 9.2680e-04,| initc-loss 3.3358e-04,|bc_loss 1.0581e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.7589e-05,| pde-loss-test 8.8315e-04,| initc-loss-test 3.1460e-04,|bc_loss-test 1.0510e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 2.1267e-03,| Test-Loss 1.9811e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.5129e-05,| pde-loss 3.0714e-04,| initc-loss 3.6250e-04,|bc_loss 9.5314e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2932e-05,| pde-loss-test 1.6506e-04,| initc-loss-test 3.4331e-04,|bc_loss-test 9.1304e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 2.9865e-03,| Test-Loss 1.8660e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9766e-05,| pde-loss 1.2735e-03,| initc-loss 3.3734e-04,|bc_loss 9.4403e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.2931e-05,| pde-loss-test 1.1566e-04,| initc-loss-test 3.3754e-04,|bc_loss-test 7.9686e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 1.9424e-03,| Test-Loss 2.0810e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.3761e-05,| pde-loss 2.4387e-04,| initc-loss 3.2822e-04,|bc_loss 1.0272e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.8524e-05,| pde-loss-test 1.3397e-04,| initc-loss-test 3.6480e-04,|bc_loss-test 7.4564e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 2.4000e-03,| Test-Loss 2.5511e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4842e-05,| pde-loss 7.3810e-04,| initc-loss 3.0293e-04,|bc_loss 9.5962e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4448e-05,| pde-loss-test 3.6327e-04,| initc-loss-test 3.4597e-04,|bc_loss-test 1.1166e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 2.5143e-03,| Test-Loss 6.2061e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9434e-05,| pde-loss 7.8635e-04,| initc-loss 3.1889e-04,|bc_loss 1.1294e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8586e-04,| pde-loss-test 1.8565e-03,| initc-loss-test 2.8243e-04,|bc_loss-test 1.9679e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 3.1534e-03,| Test-Loss 2.0049e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.2383e-05,| pde-loss 1.5250e-03,| initc-loss 3.1261e-04,|bc_loss 1.0180e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.9625e-05,| pde-loss-test 1.0494e-04,| initc-loss-test 2.9472e-04,|bc_loss-test 1.0059e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 2.5581e-03,| Test-Loss 2.2268e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.0805e-05,| pde-loss 3.8778e-04,| initc-loss 3.8130e-04,|bc_loss 1.2239e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.0083e-05,| pde-loss-test 1.6924e-04,| initc-loss-test 3.5840e-04,|bc_loss-test 1.0265e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 2.4231e-03,| Test-Loss 3.1750e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3170e-05,| pde-loss 6.7645e-04,| initc-loss 3.8899e-04,|bc_loss 8.1371e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4626e-04,| pde-loss-test 3.0046e-04,| initc-loss-test 3.3399e-04,|bc_loss-test 1.3307e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 2.3008e-03,| Test-Loss 1.9485e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9305e-05,| pde-loss 5.4906e-04,| initc-loss 3.8258e-04,|bc_loss 7.6227e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8481e-05,| pde-loss-test 1.0882e-04,| initc-loss-test 3.6077e-04,|bc_loss-test 8.4670e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 3.2161e-03,| Test-Loss 6.4051e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2062e-05,| pde-loss 1.3915e-03,| initc-loss 3.4621e-04,|bc_loss 9.8122e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0947e-04,| pde-loss-test 2.4227e-03,| initc-loss-test 3.0153e-04,|bc_loss-test 2.2825e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 3.0275e-03,| Test-Loss 2.6380e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8489e-05,| pde-loss 1.3618e-03,| initc-loss 3.3188e-04,|bc_loss 9.3360e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5601e-05,| pde-loss-test 5.4817e-04,| initc-loss-test 3.2455e-04,|bc_loss-test 8.5636e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 3.2078e-03,| Test-Loss 2.0941e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8222e-05,| pde-loss 1.5780e-03,| initc-loss 2.9307e-04,|bc_loss 1.1589e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6994e-05,| pde-loss-test 1.4307e-04,| initc-loss-test 3.4514e-04,|bc_loss-test 9.4996e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 2.2230e-03,| Test-Loss 2.0519e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4928e-05,| pde-loss 5.7625e-04,| initc-loss 3.2539e-04,|bc_loss 1.0943e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2088e-05,| pde-loss-test 1.6001e-04,| initc-loss-test 3.0874e-04,|bc_loss-test 8.4638e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 2.5427e-03,| Test-Loss 2.2210e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9952e-05,| pde-loss 7.0524e-04,| initc-loss 3.2938e-04,|bc_loss 1.0058e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.3581e-05,| pde-loss-test 1.2542e-04,| initc-loss-test 3.3372e-04,|bc_loss-test 1.0394e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 2.1783e-03,| Test-Loss 1.9384e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9892e-05,| pde-loss 4.2841e-04,| initc-loss 3.4074e-04,|bc_loss 7.9501e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2928e-05,| pde-loss-test 9.3986e-05,| initc-loss-test 3.5937e-04,|bc_loss-test 7.3941e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 3.4876e-03,| Test-Loss 2.5356e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7422e-05,| pde-loss 1.7497e-03,| initc-loss 3.4223e-04,|bc_loss 1.1732e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.5710e-05,| pde-loss-test 5.2113e-04,| initc-loss-test 3.0905e-04,|bc_loss-test 1.0660e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 2.6036e-03,| Test-Loss 1.9141e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.6916e-05,| pde-loss 9.8377e-04,| initc-loss 3.0003e-04,|bc_loss 9.0500e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4245e-05,| pde-loss-test 2.1238e-04,| initc-loss-test 3.0419e-04,|bc_loss-test 6.8776e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 2.2880e-03,| Test-Loss 2.1089e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5444e-05,| pde-loss 3.8068e-04,| initc-loss 4.5198e-04,|bc_loss 4.9573e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.8288e-05,| pde-loss-test 1.4518e-04,| initc-loss-test 3.4807e-04,|bc_loss-test 9.8014e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 3.9977e-03,| Test-Loss 4.7961e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0916e-05,| pde-loss 2.0712e-03,| initc-loss 3.0585e-04,|bc_loss 1.7628e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3216e-04,| pde-loss-test 8.5825e-04,| initc-loss-test 2.8094e-04,|bc_loss-test 2.2421e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 4.9032e-03,| Test-Loss 5.1256e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1786e-04,| pde-loss 6.4171e-04,| initc-loss 5.4608e-04,|bc_loss 5.5698e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5860e-04,| pde-loss-test 1.9628e-04,| initc-loss-test 6.2200e-04,|bc_loss-test 6.0831e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 4.1209e-03,| Test-Loss 3.9897e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4646e-05,| pde-loss 4.2317e-04,| initc-loss 6.6589e-04,|bc_loss 2.2671e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1856e-04,| pde-loss-test 2.1635e-04,| initc-loss-test 6.8700e-04,|bc_loss-test 2.2391e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 3.3408e-03,| Test-Loss 3.3471e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2139e-05,| pde-loss 4.0024e-04,| initc-loss 4.8955e-04,|bc_loss 2.2233e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0700e-04,| pde-loss-test 1.6861e-04,| initc-loss-test 5.4634e-04,|bc_loss-test 1.9917e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 2.4808e-03,| Test-Loss 2.4778e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8912e-05,| pde-loss 3.0083e-04,| initc-loss 3.9128e-04,|bc_loss 1.1537e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5730e-04,| pde-loss-test 2.8233e-04,| initc-loss-test 3.0604e-04,|bc_loss-test 1.6153e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 2.6324e-03,| Test-Loss 1.9988e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1419e-05,| pde-loss 8.3542e-04,| initc-loss 3.3540e-04,|bc_loss 9.9715e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1592e-04,| pde-loss-test 6.5800e-05,| initc-loss-test 3.6884e-04,|bc_loss-test 1.2159e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 3.0661e-03,| Test-Loss 3.3192e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7151e-05,| pde-loss 1.1912e-03,| initc-loss 3.1810e-04,|bc_loss 1.5674e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2170e-04,| pde-loss-test 6.7323e-04,| initc-loss-test 2.9498e-04,|bc_loss-test 1.3580e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 2.2397e-03,| Test-Loss 2.0620e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1146e-05,| pde-loss 5.4372e-04,| initc-loss 3.0606e-04,|bc_loss 8.3827e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0691e-05,| pde-loss-test 2.2417e-04,| initc-loss-test 3.1139e-04,|bc_loss-test 7.8866e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 2.2791e-03,| Test-Loss 2.0388e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.3030e-05,| pde-loss 5.9450e-04,| initc-loss 3.3044e-04,|bc_loss 1.5353e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.7786e-05,| pde-loss-test 2.2088e-04,| initc-loss-test 3.5407e-04,|bc_loss-test 7.0446e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 2.9501e-03,| Test-Loss 1.9467e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4272e-05,| pde-loss 1.2281e-03,| initc-loss 3.2426e-04,|bc_loss 1.6448e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5062e-05,| pde-loss-test 9.9954e-05,| initc-loss-test 3.7065e-04,|bc_loss-test 7.5471e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 2.2573e-03,| Test-Loss 2.0642e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6077e-05,| pde-loss 4.4701e-04,| initc-loss 3.3530e-04,|bc_loss 1.1640e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.0088e-05,| pde-loss-test 1.1891e-04,| initc-loss-test 3.5388e-04,|bc_loss-test 8.3169e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 2.5336e-03,| Test-Loss 6.3969e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2066e-05,| pde-loss 7.4963e-04,| initc-loss 3.1496e-04,|bc_loss 9.2700e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3073e-04,| pde-loss-test 1.9548e-03,| initc-loss-test 3.0582e-04,|bc_loss-test 2.0711e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 2.1262e-03,| Test-Loss 1.9547e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3586e-05,| pde-loss 4.5336e-04,| initc-loss 3.1005e-04,|bc_loss 9.9423e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2391e-05,| pde-loss-test 1.5022e-04,| initc-loss-test 3.7296e-04,|bc_loss-test 6.3156e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 2.2653e-03,| Test-Loss 1.8494e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.5811e-05,| pde-loss 5.1578e-04,| initc-loss 3.7509e-04,|bc_loss 8.3573e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1325e-05,| pde-loss-test 1.3327e-04,| initc-loss-test 3.1749e-04,|bc_loss-test 7.5811e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 2.8457e-03,| Test-Loss 3.2335e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8264e-05,| pde-loss 1.0104e-03,| initc-loss 3.8380e-04,|bc_loss 5.4805e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0692e-04,| pde-loss-test 3.8328e-04,| initc-loss-test 3.3245e-04,|bc_loss-test 2.2353e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 2.6147e-03,| Test-Loss 3.6244e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.4363e-05,| pde-loss 8.3893e-04,| initc-loss 3.0851e-04,|bc_loss 1.0812e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.7783e-05,| pde-loss-test 1.0018e-03,| initc-loss-test 2.7967e-04,|bc_loss-test 1.2992e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 2.6548e-03,| Test-Loss 4.9950e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4455e-05,| pde-loss 8.0195e-04,| initc-loss 3.1066e-04,|bc_loss 1.1372e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7180e-04,| pde-loss-test 1.4776e-03,| initc-loss-test 2.9643e-04,|bc_loss-test 1.7953e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 2.7474e-03,| Test-Loss 2.4910e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.2648e-05,| pde-loss 1.1193e-03,| initc-loss 3.1180e-04,|bc_loss 9.4241e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1792e-05,| pde-loss-test 4.8270e-04,| initc-loss-test 3.1390e-04,|bc_loss-test 8.4708e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 1.8904e-03,| Test-Loss 1.7513e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3466e-05,| pde-loss 2.1928e-04,| initc-loss 3.5023e-04,|bc_loss 6.0213e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9351e-05,| pde-loss-test 1.6399e-04,| initc-loss-test 2.9659e-04,|bc_loss-test 6.0187e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 2.7044e-03,| Test-Loss 1.9823e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4384e-05,| pde-loss 1.0347e-03,| initc-loss 3.4268e-04,|bc_loss 7.8884e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.6805e-05,| pde-loss-test 1.0910e-04,| initc-loss-test 3.4199e-04,|bc_loss-test 8.7555e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 2.0628e-03,| Test-Loss 3.3364e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0263e-05,| pde-loss 3.6668e-04,| initc-loss 3.3742e-04,|bc_loss 6.6780e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6287e-05,| pde-loss-test 5.9074e-04,| initc-loss-test 2.9549e-04,|bc_loss-test 1.0897e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 3.4819e-03,| Test-Loss 2.0480e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8940e-05,| pde-loss 1.8285e-03,| initc-loss 3.2980e-04,|bc_loss 7.1964e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.4426e-05,| pde-loss-test 8.2005e-05,| initc-loss-test 3.4591e-04,|bc_loss-test 1.1402e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 2.2651e-03,| Test-Loss 2.2385e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3608e-05,| pde-loss 6.5104e-04,| initc-loss 2.8816e-04,|bc_loss 1.3747e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.3549e-05,| pde-loss-test 4.1635e-04,| initc-loss-test 3.1789e-04,|bc_loss-test 8.3231e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 3.4486e-03,| Test-Loss 2.7981e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3118e-05,| pde-loss 1.7718e-03,| initc-loss 3.1925e-04,|bc_loss 1.4529e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1008e-05,| pde-loss-test 3.7912e-04,| initc-loss-test 3.2509e-04,|bc_loss-test 8.2474e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 2.7617e-03,| Test-Loss 2.6178e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9054e-05,| pde-loss 9.1513e-04,| initc-loss 3.3929e-04,|bc_loss 1.0279e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.7949e-05,| pde-loss-test 6.9804e-04,| initc-loss-test 2.8734e-04,|bc_loss-test 9.3630e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 2.7002e-03,| Test-Loss 2.4186e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7064e-05,| pde-loss 9.6664e-04,| initc-loss 3.2086e-04,|bc_loss 1.1401e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6079e-05,| pde-loss-test 5.4277e-04,| initc-loss-test 3.3571e-04,|bc_loss-test 1.0928e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 3.6648e-03,| Test-Loss 2.3605e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6752e-04,| pde-loss 1.5105e-03,| initc-loss 3.1419e-04,|bc_loss 3.1047e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.9404e-05,| pde-loss-test 8.9236e-05,| initc-loss-test 4.9018e-04,|bc_loss-test 6.4911e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 3.5692e-03,| Test-Loss 2.5593e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2478e-04,| pde-loss 1.4259e-03,| initc-loss 3.4625e-04,|bc_loss 2.7528e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7296e-04,| pde-loss-test 2.8915e-04,| initc-loss-test 3.3931e-04,|bc_loss-test 1.2087e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 3.6254e-03,| Test-Loss 2.0108e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1510e-04,| pde-loss 1.7397e-03,| initc-loss 3.0313e-04,|bc_loss 2.3336e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8419e-05,| pde-loss-test 1.4093e-04,| initc-loss-test 3.3330e-04,|bc_loss-test 8.7213e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 2.6116e-03,| Test-Loss 2.8990e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.8155e-05,| pde-loss 1.0319e-03,| initc-loss 2.8681e-04,|bc_loss 9.4179e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0706e-05,| pde-loss-test 4.3677e-04,| initc-loss-test 3.0894e-04,|bc_loss-test 8.3999e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 2.9185e-03,| Test-Loss 2.4744e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9277e-05,| pde-loss 1.3260e-03,| initc-loss 3.1680e-04,|bc_loss 7.7562e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0413e-05,| pde-loss-test 5.8408e-04,| initc-loss-test 3.4293e-04,|bc_loss-test 7.1686e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 2.5189e-03,| Test-Loss 4.6045e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7353e-05,| pde-loss 8.2687e-04,| initc-loss 2.8739e-04,|bc_loss 1.0442e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0226e-04,| pde-loss-test 1.0647e-03,| initc-loss-test 2.7885e-04,|bc_loss-test 1.1431e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 4.0712e-03,| Test-Loss 1.9985e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.9536e-05,| pde-loss 2.2491e-03,| initc-loss 3.0871e-04,|bc_loss 2.0036e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2789e-05,| pde-loss-test 9.7600e-05,| initc-loss-test 3.5496e-04,|bc_loss-test 1.1767e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 2.2414e-03,| Test-Loss 2.1203e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0971e-05,| pde-loss 4.2162e-04,| initc-loss 3.6532e-04,|bc_loss 8.7209e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.4173e-05,| pde-loss-test 1.1353e-04,| initc-loss-test 3.7998e-04,|bc_loss-test 7.0720e-05|
# ...
# | Data-loss-test 3.5228e-05,| pde-loss-test 1.4943e-04,| initc-loss-test 3.5463e-04,|bc_loss-test 6.6467e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 781,            | Training-Loss 2.6812e-03,| Test-Loss 2.4164e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7085e-05,| pde-loss 7.9898e-04,| initc-loss 3.4529e-04,|bc_loss 1.4895e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0428e-04,| pde-loss-test 8.4537e-05,| initc-loss-test 3.5145e-04,|bc_loss-test 1.3607e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 791,            | Training-Loss 2.9400e-03,| Test-Loss 2.4616e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0164e-04,| pde-loss 9.3586e-04,| initc-loss 3.3865e-04,|bc_loss 2.1867e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.7005e-05,| pde-loss-test 3.8632e-04,| initc-loss-test 3.1107e-04,|bc_loss-test 1.0870e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 801,            | Training-Loss 3.2031e-03,| Test-Loss 2.1943e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5075e-05,| pde-loss 1.4436e-03,| initc-loss 3.2625e-04,|bc_loss 1.3114e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.6502e-05,| pde-loss-test 2.3744e-04,| initc-loss-test 3.5999e-04,|bc_loss-test 9.7812e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 811,            | Training-Loss 3.1816e-03,| Test-Loss 2.2380e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2097e-05,| pde-loss 9.8865e-04,| initc-loss 4.3003e-04,|bc_loss 1.0042e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2034e-05,| pde-loss-test 1.5648e-04,| initc-loss-test 3.8494e-04,|bc_loss-test 1.0539e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 821,            | Training-Loss 3.2093e-03,| Test-Loss 2.6112e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3925e-05,| pde-loss 9.3129e-04,| initc-loss 3.7640e-04,|bc_loss 1.5730e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9951e-04,| pde-loss-test 5.6160e-05,| initc-loss-test 3.7605e-04,|bc_loss-test 2.2581e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 831,            | Training-Loss 2.5388e-03,| Test-Loss 3.7909e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4168e-05,| pde-loss 8.0793e-04,| initc-loss 3.3063e-04,|bc_loss 9.1019e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.1931e-05,| pde-loss-test 8.5963e-04,| initc-loss-test 2.7826e-04,|bc_loss-test 7.8191e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 841,            | Training-Loss 2.3114e-03,| Test-Loss 2.9668e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3680e-05,| pde-loss 6.2082e-04,| initc-loss 3.3893e-04,|bc_loss 6.9523e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.3240e-05,| pde-loss-test 5.1285e-04,| initc-loss-test 3.0440e-04,|bc_loss-test 8.9506e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 851,            | Training-Loss 3.0044e-03,| Test-Loss 2.2855e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5743e-05,| pde-loss 1.0729e-03,| initc-loss 3.2595e-04,|bc_loss 1.4375e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0798e-04,| pde-loss-test 2.9871e-04,| initc-loss-test 3.0932e-04,|bc_loss-test 8.5843e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 861,            | Training-Loss 3.1501e-03,| Test-Loss 2.0435e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6359e-05,| pde-loss 1.3054e-03,| initc-loss 3.3292e-04,|bc_loss 1.4500e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0566e-05,| pde-loss-test 1.7374e-04,| initc-loss-test 3.6576e-04,|bc_loss-test 6.8564e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 871,            | Training-Loss 3.8458e-03,| Test-Loss 2.3313e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1436e-05,| pde-loss 2.0050e-03,| initc-loss 2.9324e-04,|bc_loss 1.4575e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.6064e-05,| pde-loss-test 1.2790e-04,| initc-loss-test 3.1529e-04,|bc_loss-test 8.8296e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 881,            | Training-Loss 2.3395e-03,| Test-Loss 2.1627e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.2356e-05,| pde-loss 4.3611e-04,| initc-loss 3.3743e-04,|bc_loss 1.7384e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.3522e-05,| pde-loss-test 8.0157e-05,| initc-loss-test 3.6380e-04,|bc_loss-test 1.3097e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 891,            | Training-Loss 2.7924e-03,| Test-Loss 3.1983e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.6385e-05,| pde-loss 1.2355e-03,| initc-loss 2.9535e-04,|bc_loss 8.8175e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0439e-04,| pde-loss-test 7.6328e-04,| initc-loss-test 3.1177e-04,|bc_loss-test 1.5022e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 901,            | Training-Loss 2.5456e-03,| Test-Loss 2.0706e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8350e-05,| pde-loss 5.7795e-04,| initc-loss 3.7282e-04,|bc_loss 9.3046e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.5961e-05,| pde-loss-test 1.4863e-04,| initc-loss-test 3.7353e-04,|bc_loss-test 7.9224e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 911,            | Training-Loss 2.7104e-03,| Test-Loss 1.9402e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0551e-04,| pde-loss 7.8853e-04,| initc-loss 3.2522e-04,|bc_loss 2.1245e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0174e-05,| pde-loss-test 6.7371e-05,| initc-loss-test 2.8240e-04,|bc_loss-test 1.1732e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 921,            | Training-Loss 2.2889e-03,| Test-Loss 2.7734e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8475e-05,| pde-loss 3.3689e-04,| initc-loss 3.5884e-04,|bc_loss 1.0668e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7500e-05,| pde-loss-test 6.7886e-04,| initc-loss-test 3.3015e-04,|bc_loss-test 1.0611e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 931,            | Training-Loss 3.2533e-03,| Test-Loss 3.9878e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6479e-05,| pde-loss 1.3645e-03,| initc-loss 3.7577e-04,|bc_loss 7.1889e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0422e-04,| pde-loss-test 6.8346e-04,| initc-loss-test 3.1089e-04,|bc_loss-test 2.1454e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 941,            | Training-Loss 3.1475e-03,| Test-Loss 3.3978e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.0707e-05,| pde-loss 1.3016e-03,| initc-loss 3.0507e-04,|bc_loss 1.2528e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3133e-05,| pde-loss-test 8.5148e-04,| initc-loss-test 3.1785e-04,|bc_loss-test 1.3937e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 951,            | Training-Loss 2.1583e-03,| Test-Loss 2.1807e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.6634e-05,| pde-loss 3.7982e-04,| initc-loss 3.3275e-04,|bc_loss 1.3114e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1591e-05,| pde-loss-test 3.8514e-04,| initc-loss-test 3.1097e-04,|bc_loss-test 1.0252e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 961,            | Training-Loss 3.2858e-03,| Test-Loss 2.9221e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8274e-05,| pde-loss 1.7778e-03,| initc-loss 2.8615e-04,|bc_loss 8.1147e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.8894e-05,| pde-loss-test 8.5314e-04,| initc-loss-test 2.9627e-04,|bc_loss-test 8.3360e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 971,            | Training-Loss 2.0346e-03,| Test-Loss 2.1052e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1092e-05,| pde-loss 3.3537e-04,| initc-loss 3.3633e-04,|bc_loss 1.1836e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5101e-05,| pde-loss-test 2.3870e-04,| initc-loss-test 3.4944e-04,|bc_loss-test 5.7085e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 981,            | Training-Loss 3.2654e-03,| Test-Loss 3.9600e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6066e-05,| pde-loss 1.4920e-03,| initc-loss 3.7701e-04,|bc_loss 6.4459e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.7471e-04,| pde-loss-test 5.2957e-04,| initc-loss-test 3.0455e-04,|bc_loss-test 2.2574e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 991,            | Training-Loss 2.6220e-03,| Test-Loss 6.1894e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7999e-05,| pde-loss 8.3532e-04,| initc-loss 2.6868e-04,|bc_loss 1.2430e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2216e-04,| pde-loss-test 2.1678e-03,| initc-loss-test 2.7509e-04,|bc_loss-test 1.4429e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1000,            | Training-Loss 1.0125e-02,| Test-Loss 9.4967e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8510e-05,| pde-loss 5.9301e-04,| initc-loss 3.2259e-04,|bc_loss 2.3040e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9301e-05,| pde-loss-test 1.7229e-04,| initc-loss-test 4.8831e-04,|bc_loss-test 6.9819e-05|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_data = loss_train['data-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_data, label='Data Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,temp_init,t_surr) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[853.7806 ]
#  [856.1191 ]
#  [858.3422 ]
#  ...
#  [810.7898 ]
#  [810.8501 ]
#  [810.91113]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
# plot initial temperature
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(0, length, numpoints), temp_d[0,:], label='Actual Temperature')
plt.plot(np.linspace(0, length, numpoints), temp_nn_t[0,:], label='Predicted Temperature')
plt.xlabel('Distance (m)')
plt.ylabel('Temperature (K)')
plt.title('Initial Temperature Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583
# 0.9999180924377908

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[853.7806 ]
#  [853.81647]
#  [853.8524 ]
#  ...
#  [822.1911 ]
#  [822.18616]
#  [822.1812 ]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

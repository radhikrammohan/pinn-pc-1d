# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc_icc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_norm import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# MPS is available
# Using device: mps
# MPS is available
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(32)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
# plot the intial temperature field
plt.figure(figsize=(8, 6))
plt.plot( tempfield[0, :], label='Initial Temperature Field')
plt.title('Initial Temperature Field')
plt.xlabel('Position (x)')
plt.ylabel('Temperature')
plt.legend()
plt.grid()

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 0.9999180924377908

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_l = props['k_l']
k_s = props['k_s']
rho_l = props['rho_l']
rho_s = props['rho_s']
cp_l = props['cp_l']
cp_s = props['cp_s']
alpha_l = k_l / (rho_l * cp_l)
alpha_s = k_s / (rho_s * cp_s)

alpha_max = max(alpha_l, alpha_s)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# The number of points in the initial condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+20002=20002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+16002=16002.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+4002=4002.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data_new2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=1000)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=1000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=1000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=1000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=1000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=1000 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=1000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=1000)  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=1000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=1000) # random sampler for bc right residuals
batch_size = 153
train_loader = DataLoader(inp_dataset, batch_size=batch_size, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=batch_size, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=batch_size, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=batch_size, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=batch_size, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=batch_size, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=batch_size, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=batch_size, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=batch_size, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=batch_size, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 364#  best yet is 8
output_size=1

learning_rate = 0.0002 # 0.001
hidden_layers = 2  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =2000
epochs_2 = 100
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate,line_search_fn ='strong_wolfe')

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 8.9198e+01,| Test-Loss 5.7253e+01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4088e-01,| pde-loss 9.3328e-02,| initc-loss 5.2158e-02,|bc_loss 2.0563e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.5462e-02,| pde-loss-test 9.6885e-03,| initc-loss-test 3.9784e-02,|bc_loss-test 4.1352e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 1.2846e+00,| Test-Loss 1.3169e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7445e-03,| pde-loss 1.4645e-03,| initc-loss 8.7403e-04,|bc_loss 6.0839e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.6106e-04,| pde-loss-test 3.5669e-04,| initc-loss-test 7.2170e-04,|bc_loss-test 1.1131e-03|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 4.4722e-01,| Test-Loss 5.7421e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.8053e-04,| pde-loss 8.1106e-04,| initc-loss 4.5617e-04,|bc_loss 2.2740e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2469e-04,| pde-loss-test 2.3929e-04,| initc-loss-test 3.9034e-04,|bc_loss-test 3.4788e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 3.9536e-01,| Test-Loss 4.9900e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1022e-04,| pde-loss 1.9413e-03,| initc-loss 4.4999e-04,|bc_loss 1.9381e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4023e-04,| pde-loss-test 5.7944e-04,| initc-loss-test 3.6031e-04,|bc_loss-test 4.0640e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 3.5866e-01,| Test-Loss 4.5094e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1955e-04,| pde-loss 2.0509e-03,| initc-loss 3.8900e-04,|bc_loss 1.2693e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6280e-04,| pde-loss-test 6.1722e-04,| initc-loss-test 3.6637e-04,|bc_loss-test 2.5900e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 3.4430e-01,| Test-Loss 4.5041e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.9892e-04,| pde-loss 2.1125e-03,| initc-loss 3.5307e-04,|bc_loss 1.5394e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1046e-04,| pde-loss-test 5.6841e-04,| initc-loss-test 3.2057e-04,|bc_loss-test 2.9806e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 3.3237e-01,| Test-Loss 4.3536e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6928e-04,| pde-loss 2.1815e-03,| initc-loss 2.8119e-04,|bc_loss 1.3445e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0296e-04,| pde-loss-test 5.1722e-04,| initc-loss-test 3.5173e-04,|bc_loss-test 2.7278e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 3.3520e-01,| Test-Loss 4.1021e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7950e-04,| pde-loss 2.2390e-03,| initc-loss 3.2931e-04,|bc_loss 1.1544e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0201e-04,| pde-loss-test 5.8626e-04,| initc-loss-test 3.4881e-04,|bc_loss-test 2.6103e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 3.1990e-01,| Test-Loss 3.8178e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9665e-04,| pde-loss 2.2211e-03,| initc-loss 3.1135e-04,|bc_loss 1.0690e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.9421e-05,| pde-loss-test 7.5092e-04,| initc-loss-test 3.1919e-04,|bc_loss-test 1.5859e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 3.0844e-01,| Test-Loss 3.6831e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.0313e-04,| pde-loss 2.2667e-03,| initc-loss 2.9594e-04,|bc_loss 9.6228e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2617e-04,| pde-loss-test 5.9217e-04,| initc-loss-test 3.3679e-04,|bc_loss-test 1.7100e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 2.9827e-01,| Test-Loss 3.5270e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5206e-04,| pde-loss 2.4059e-03,| initc-loss 3.5641e-04,|bc_loss 7.9861e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.4545e-05,| pde-loss-test 6.1084e-04,| initc-loss-test 3.4745e-04,|bc_loss-test 1.5756e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 2.9606e-01,| Test-Loss 3.3113e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5474e-04,| pde-loss 2.5444e-03,| initc-loss 3.7795e-04,|bc_loss 6.2792e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.4787e-05,| pde-loss-test 7.5819e-04,| initc-loss-test 2.8427e-04,|bc_loss-test 1.9242e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 2.9746e-01,| Test-Loss 3.2694e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8254e-04,| pde-loss 2.8417e-03,| initc-loss 3.1291e-04,|bc_loss 6.0780e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.9548e-05,| pde-loss-test 6.7949e-04,| initc-loss-test 3.2424e-04,|bc_loss-test 1.7978e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 2.7691e-01,| Test-Loss 3.0737e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.7633e-04,| pde-loss 2.8829e-03,| initc-loss 3.2103e-04,|bc_loss 8.5683e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3988e-05,| pde-loss-test 9.0897e-04,| initc-loss-test 3.1541e-04,|bc_loss-test 1.0415e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 2.6341e-01,| Test-Loss 2.9015e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.2898e-04,| pde-loss 3.1424e-03,| initc-loss 2.5390e-04,|bc_loss 7.3899e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.0004e-05,| pde-loss-test 9.8373e-04,| initc-loss-test 3.0160e-04,|bc_loss-test 1.2282e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 2.4834e-01,| Test-Loss 2.6467e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.3022e-04,| pde-loss 3.5924e-03,| initc-loss 2.4379e-04,|bc_loss 5.5672e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2831e-05,| pde-loss-test 1.0341e-03,| initc-loss-test 2.7643e-04,|bc_loss-test 4.4431e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 2.3564e-01,| Test-Loss 2.5353e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8601e-04,| pde-loss 3.7979e-03,| initc-loss 2.7966e-04,|bc_loss 4.7221e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0473e-04,| pde-loss-test 1.0405e-03,| initc-loss-test 2.1767e-04,|bc_loss-test 1.2624e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 2.1440e-01,| Test-Loss 2.6388e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8616e-04,| pde-loss 3.6339e-03,| initc-loss 2.2975e-04,|bc_loss 2.8720e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1575e-04,| pde-loss-test 7.0714e-04,| initc-loss-test 2.5412e-04,|bc_loss-test 1.5732e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 1.8557e-01,| Test-Loss 1.9658e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8995e-04,| pde-loss 3.2445e-03,| initc-loss 2.0904e-04,|bc_loss 4.1037e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0949e-04,| pde-loss-test 8.9693e-04,| initc-loss-test 2.1292e-04,|bc_loss-test 7.0062e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 1.6313e-01,| Test-Loss 1.7438e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9243e-04,| pde-loss 3.8695e-03,| initc-loss 1.9196e-04,|bc_loss 5.6889e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.7233e-05,| pde-loss-test 1.1393e-03,| initc-loss-test 1.5869e-04,|bc_loss-test 5.5375e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 1.2209e-01,| Test-Loss 1.4082e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7774e-04,| pde-loss 5.3598e-03,| initc-loss 1.2762e-04,|bc_loss 2.3833e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9672e-04,| pde-loss-test 2.3089e-03,| initc-loss-test 1.2950e-04,|bc_loss-test 4.0485e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 9.6982e-02,| Test-Loss 1.0839e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.5783e-04,| pde-loss 8.8798e-03,| initc-loss 1.0441e-04,|bc_loss 2.4499e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3890e-04,| pde-loss-test 6.0593e-03,| initc-loss-test 1.1258e-04,|bc_loss-test 4.1767e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 9.8151e-02,| Test-Loss 1.7425e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2455e-03,| pde-loss 2.1831e-02,| initc-loss 6.6632e-05,|bc_loss 4.0854e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.8656e-05,| pde-loss-test 5.5149e-03,| initc-loss-test 7.3326e-05,|bc_loss-test 1.5193e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 1.1406e-01,| Test-Loss 1.2201e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6134e-03,| pde-loss 3.7135e-02,| initc-loss 5.2599e-05,|bc_loss 3.0222e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0297e-04,| pde-loss-test 1.9564e-02,| initc-loss-test 6.0728e-05,|bc_loss-test 6.0140e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 9.1636e-02,| Test-Loss 9.0941e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4887e-03,| pde-loss 3.8107e-02,| initc-loss 3.9605e-05,|bc_loss 4.6033e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.8846e-04,| pde-loss-test 1.0125e-02,| initc-loss-test 5.2011e-05,|bc_loss-test 2.5415e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 1.0455e-01,| Test-Loss 9.4059e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5086e-03,| pde-loss 4.2773e-02,| initc-loss 4.7733e-05,|bc_loss 1.8236e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.9622e-04,| pde-loss-test 1.2430e-02,| initc-loss-test 4.3519e-05,|bc_loss-test 3.2850e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 8.7442e-02,| Test-Loss 1.0673e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1594e-03,| pde-loss 4.8202e-02,| initc-loss 4.4830e-05,|bc_loss 1.3144e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8592e-04,| pde-loss-test 3.7605e-03,| initc-loss-test 3.9501e-05,|bc_loss-test 4.3753e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 8.1885e-02,| Test-Loss 9.2267e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1111e-03,| pde-loss 3.7487e-02,| initc-loss 4.8857e-05,|bc_loss 9.2558e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2551e-04,| pde-loss-test 1.3910e-02,| initc-loss-test 3.8163e-05,|bc_loss-test 1.3004e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 9.2722e-02,| Test-Loss 1.8491e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0888e-03,| pde-loss 4.7343e-02,| initc-loss 3.6341e-05,|bc_loss 5.0268e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6685e-05,| pde-loss-test 6.7119e-03,| initc-loss-test 5.0463e-05,|bc_loss-test 1.6040e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 9.5638e-02,| Test-Loss 1.8840e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.9082e-04,| pde-loss 5.1301e-02,| initc-loss 3.5013e-05,|bc_loss 4.1292e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6313e-04,| pde-loss-test 1.7493e-02,| initc-loss-test 6.1169e-05,|bc_loss-test 1.3023e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 6.5209e-02,| Test-Loss 8.1069e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.7523e-04,| pde-loss 3.5093e-02,| initc-loss 3.2912e-05,|bc_loss 5.7546e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9839e-04,| pde-loss-test 1.4226e-02,| initc-loss-test 3.3571e-05,|bc_loss-test 1.3350e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 1.4464e-01,| Test-Loss 2.5381e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2551e-03,| pde-loss 5.3069e-02,| initc-loss 3.6926e-05,|bc_loss 1.3527e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2095e-04,| pde-loss-test 2.7075e-02,| initc-loss-test 2.9671e-05,|bc_loss-test 2.3109e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 8.6264e-02,| Test-Loss 7.5055e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.5127e-04,| pde-loss 5.6745e-02,| initc-loss 3.5983e-05,|bc_loss 6.9211e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0066e-04,| pde-loss-test 7.7771e-03,| initc-loss-test 2.7838e-05,|bc_loss-test 6.6387e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 7.6920e-02,| Test-Loss 8.0059e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0761e-04,| pde-loss 4.1022e-02,| initc-loss 3.6075e-05,|bc_loss 1.3446e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3387e-04,| pde-loss-test 1.0923e-02,| initc-loss-test 3.6465e-05,|bc_loss-test 1.5133e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 6.4706e-02,| Test-Loss 8.7783e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5106e-04,| pde-loss 3.6958e-02,| initc-loss 3.0072e-05,|bc_loss 6.4058e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9278e-04,| pde-loss-test 1.1619e-02,| initc-loss-test 3.0376e-05,|bc_loss-test 1.7469e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 2.3938e-01,| Test-Loss 2.6033e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0415e-03,| pde-loss 4.7875e-02,| initc-loss 4.0497e-05,|bc_loss 2.7631e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7042e-04,| pde-loss-test 1.9286e-02,| initc-loss-test 3.4247e-05,|bc_loss-test 2.4342e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 5.6638e-02,| Test-Loss 6.3469e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3289e-04,| pde-loss 3.0802e-02,| initc-loss 2.9897e-05,|bc_loss 5.0996e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2503e-04,| pde-loss-test 1.5429e-02,| initc-loss-test 2.5037e-05,|bc_loss-test 7.0321e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 7.5480e-02,| Test-Loss 1.3349e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4399e-04,| pde-loss 4.0647e-02,| initc-loss 3.8236e-05,|bc_loss 1.8350e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.9379e-04,| pde-loss-test 8.8319e-03,| initc-loss-test 3.5289e-05,|bc_loss-test 8.7891e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 5.8630e-02,| Test-Loss 7.0720e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5125e-04,| pde-loss 3.5056e-02,| initc-loss 2.7371e-05,|bc_loss 2.8847e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0677e-04,| pde-loss-test 1.5862e-02,| initc-loss-test 2.8638e-05,|bc_loss-test 1.1058e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 6.5364e-02,| Test-Loss 7.8322e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4068e-04,| pde-loss 4.1412e-02,| initc-loss 2.6126e-05,|bc_loss 1.0242e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8170e-04,| pde-loss-test 6.1060e-03,| initc-loss-test 2.4383e-05,|bc_loss-test 2.2974e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 7.5802e-02,| Test-Loss 1.0584e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5288e-04,| pde-loss 4.1469e-02,| initc-loss 2.4421e-05,|bc_loss 4.4355e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8571e-05,| pde-loss-test 1.7975e-02,| initc-loss-test 3.6155e-05,|bc_loss-test 5.7709e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 6.6183e-02,| Test-Loss 7.0180e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1602e-04,| pde-loss 3.6757e-02,| initc-loss 2.9723e-05,|bc_loss 1.0981e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1540e-05,| pde-loss-test 6.4098e-03,| initc-loss-test 2.9564e-05,|bc_loss-test 2.4389e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 5.1433e-02,| Test-Loss 7.2431e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.2615e-04,| pde-loss 3.0966e-02,| initc-loss 2.4096e-05,|bc_loss 2.7053e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2355e-04,| pde-loss-test 1.2881e-02,| initc-loss-test 2.6800e-05,|bc_loss-test 1.8021e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 5.8509e-02,| Test-Loss 7.3074e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3088e-04,| pde-loss 3.3474e-02,| initc-loss 3.3893e-05,|bc_loss 1.4380e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2746e-04,| pde-loss-test 1.1932e-02,| initc-loss-test 2.6147e-05,|bc_loss-test 1.2892e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 6.6402e-02,| Test-Loss 6.8169e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9616e-04,| pde-loss 4.5626e-02,| initc-loss 2.3046e-05,|bc_loss 4.5465e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.3918e-05,| pde-loss-test 1.4466e-02,| initc-loss-test 1.9443e-05,|bc_loss-test 1.1957e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 8.3580e-02,| Test-Loss 7.4975e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.7797e-04,| pde-loss 4.2386e-02,| initc-loss 2.3416e-05,|bc_loss 3.3244e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.1935e-05,| pde-loss-test 1.6805e-02,| initc-loss-test 1.6256e-05,|bc_loss-test 1.1346e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 5.8096e-02,| Test-Loss 5.7240e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5994e-04,| pde-loss 3.9097e-02,| initc-loss 2.1005e-05,|bc_loss 3.9910e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0518e-05,| pde-loss-test 1.4426e-02,| initc-loss-test 2.4174e-05,|bc_loss-test 5.7593e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 6.1575e-02,| Test-Loss 5.6954e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2478e-04,| pde-loss 4.2462e-02,| initc-loss 1.9848e-05,|bc_loss 4.1065e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1070e-05,| pde-loss-test 8.3477e-03,| initc-loss-test 2.5869e-05,|bc_loss-test 9.3640e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 1.1015e-01,| Test-Loss 8.8939e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.9573e-04,| pde-loss 3.2467e-02,| initc-loss 2.2671e-05,|bc_loss 7.6170e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0391e-04,| pde-loss-test 1.1299e-02,| initc-loss-test 2.4371e-05,|bc_loss-test 3.3321e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 8.9237e-02,| Test-Loss 5.7835e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1064e-04,| pde-loss 3.2527e-02,| initc-loss 2.3664e-05,|bc_loss 5.2035e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.9481e-06,| pde-loss-test 6.9311e-04,| initc-loss-test 2.1472e-05,|bc_loss-test 2.4762e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 6.1009e-02,| Test-Loss 7.8334e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6086e-04,| pde-loss 3.6092e-02,| initc-loss 1.8629e-05,|bc_loss 1.0940e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2698e-05,| pde-loss-test 7.8557e-03,| initc-loss-test 2.0136e-05,|bc_loss-test 3.0643e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 6.6741e-02,| Test-Loss 6.3362e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7651e-04,| pde-loss 3.8387e-02,| initc-loss 1.8935e-05,|bc_loss 2.6036e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8079e-05,| pde-loss-test 1.0146e-02,| initc-loss-test 2.0396e-05,|bc_loss-test 1.9015e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 5.2353e-02,| Test-Loss 6.7251e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.2571e-05,| pde-loss 3.2522e-02,| initc-loss 1.9807e-05,|bc_loss 5.2502e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0170e-05,| pde-loss-test 7.4551e-03,| initc-loss-test 1.9832e-05,|bc_loss-test 2.1094e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 5.6129e-02,| Test-Loss 5.1500e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5138e-05,| pde-loss 3.3654e-02,| initc-loss 2.1182e-05,|bc_loss 2.4635e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0209e-05,| pde-loss-test 7.2462e-03,| initc-loss-test 2.2221e-05,|bc_loss-test 7.5008e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 6.0203e-02,| Test-Loss 6.2545e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2656e-04,| pde-loss 3.2448e-02,| initc-loss 1.9563e-05,|bc_loss 4.1249e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.5392e-06,| pde-loss-test 1.3640e-02,| initc-loss-test 2.2715e-05,|bc_loss-test 2.5163e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 5.4052e-02,| Test-Loss 5.9466e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4254e-05,| pde-loss 3.5187e-02,| initc-loss 2.2636e-05,|bc_loss 1.0961e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.8269e-05,| pde-loss-test 1.4117e-02,| initc-loss-test 1.9254e-05,|bc_loss-test 1.6984e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 4.3511e-02,| Test-Loss 6.4764e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6136e-05,| pde-loss 2.6319e-02,| initc-loss 2.1173e-05,|bc_loss 6.1600e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.5763e-05,| pde-loss-test 8.0601e-03,| initc-loss-test 2.0192e-05,|bc_loss-test 1.9561e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 8.6919e-02,| Test-Loss 6.5926e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.7288e-04,| pde-loss 3.6089e-02,| initc-loss 1.8506e-05,|bc_loss 3.8492e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.3187e-05,| pde-loss-test 7.9929e-03,| initc-loss-test 1.9846e-05,|bc_loss-test 2.2044e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 5.3601e-02,| Test-Loss 4.1746e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2745e-04,| pde-loss 2.8528e-02,| initc-loss 1.5833e-05,|bc_loss 1.3889e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0044e-05,| pde-loss-test 5.4278e-03,| initc-loss-test 2.2500e-05,|bc_loss-test 7.4826e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 5.1318e-02,| Test-Loss 5.8274e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.5501e-05,| pde-loss 3.3421e-02,| initc-loss 1.5254e-05,|bc_loss 1.2253e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.3552e-05,| pde-loss-test 4.1187e-03,| initc-loss-test 2.1834e-05,|bc_loss-test 2.1975e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 6.1376e-02,| Test-Loss 5.5731e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5484e-04,| pde-loss 3.3699e-02,| initc-loss 1.7156e-05,|bc_loss 9.8756e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2899e-05,| pde-loss-test 1.1295e-02,| initc-loss-test 1.8089e-05,|bc_loss-test 1.7799e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 4.8236e-02,| Test-Loss 6.6185e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0708e-04,| pde-loss 2.6410e-02,| initc-loss 1.8735e-05,|bc_loss 1.5056e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.5210e-05,| pde-loss-test 1.7122e-02,| initc-loss-test 1.5574e-05,|bc_loss-test 2.1653e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 5.9448e-02,| Test-Loss 6.7518e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7987e-04,| pde-loss 3.0710e-02,| initc-loss 1.9355e-05,|bc_loss 2.2640e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5916e-05,| pde-loss-test 3.4030e-03,| initc-loss-test 1.8731e-05,|bc_loss-test 4.6607e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 4.5119e-01,| Test-Loss 7.0026e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.8616e-03,| pde-loss 3.7653e-02,| initc-loss 4.0496e-05,|bc_loss 3.4138e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2042e-05,| pde-loss-test 5.2748e-03,| initc-loss-test 1.9120e-05,|bc_loss-test 5.0285e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 4.7696e-02,| Test-Loss 4.9743e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.7611e-05,| pde-loss 3.3723e-02,| initc-loss 1.7851e-05,|bc_loss 3.2066e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1413e-06,| pde-loss-test 1.5942e-02,| initc-loss-test 1.7981e-05,|bc_loss-test 6.7883e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 4.0837e-02,| Test-Loss 4.4270e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.6248e-05,| pde-loss 2.7006e-02,| initc-loss 1.6087e-05,|bc_loss 2.0508e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8344e-06,| pde-loss-test 1.6228e-02,| initc-loss-test 1.6115e-05,|bc_loss-test 6.0051e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 4.2099e-02,| Test-Loss 4.0333e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8861e-05,| pde-loss 2.8040e-02,| initc-loss 1.6668e-05,|bc_loss 3.3223e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2412e-06,| pde-loss-test 7.5087e-03,| initc-loss-test 1.5251e-05,|bc_loss-test 8.9054e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 4.7182e-02,| Test-Loss 4.1085e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0524e-05,| pde-loss 3.3639e-02,| initc-loss 1.7262e-05,|bc_loss 3.8517e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6890e-06,| pde-loss-test 1.4596e-02,| initc-loss-test 1.7504e-05,|bc_loss-test 5.5831e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 2.0431e-01,| Test-Loss 5.7518e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5867e-03,| pde-loss 3.0435e-02,| initc-loss 2.0683e-05,|bc_loss 4.2772e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.7993e-04,| pde-loss-test 1.1951e-02,| initc-loss-test 1.9854e-05,|bc_loss-test 7.2917e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 4.1069e-02,| Test-Loss 3.5558e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0803e-05,| pde-loss 2.7265e-02,| initc-loss 1.8011e-05,|bc_loss 2.0706e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.9590e-06,| pde-loss-test 6.9481e-03,| initc-loss-test 1.6036e-05,|bc_loss-test 4.7205e-06|
# ...
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1781,            | Training-Loss 5.7549e-03,| Test-Loss 5.2605e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1111e-04,| pde-loss 4.8334e-03,| initc-loss 8.0791e-07,|bc_loss 7.9169e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3421e-05,| pde-loss-test 1.2358e-03,| initc-loss-test 8.4913e-07,|bc_loss-test 8.6245e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1791,            | Training-Loss 6.5728e-03,| Test-Loss 1.0246e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0038e-04,| pde-loss 4.8194e-03,| initc-loss 7.9575e-07,|bc_loss 1.7658e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8794e-05,| pde-loss-test 3.7383e-04,| initc-loss-test 7.9243e-07,|bc_loss-test 8.0890e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1801,            | Training-Loss 7.9993e-03,| Test-Loss 1.1369e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3047e-04,| pde-loss 5.4086e-03,| initc-loss 8.1370e-07,|bc_loss 5.6019e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6180e-05,| pde-loss-test 7.3863e-04,| initc-loss-test 7.8936e-07,|bc_loss-test 8.7863e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1811,            | Training-Loss 4.8493e-03,| Test-Loss 6.2346e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.1593e-05,| pde-loss 4.1581e-03,| initc-loss 6.2076e-07,|bc_loss 2.4773e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9288e-05,| pde-loss-test 2.5162e-03,| initc-loss-test 5.3976e-07,|bc_loss-test 5.4964e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1821,            | Training-Loss 2.2335e-02,| Test-Loss 7.3559e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4369e-04,| pde-loss 4.8643e-03,| initc-loss 7.0761e-06,|bc_loss 4.1887e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4217e-05,| pde-loss-test 2.9706e-04,| initc-loss-test 2.7651e-06,|bc_loss-test 9.5896e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1831,            | Training-Loss 9.4541e-03,| Test-Loss 8.6565e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3079e-04,| pde-loss 5.1696e-03,| initc-loss 1.3194e-06,|bc_loss 2.5889e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.7846e-05,| pde-loss-test 1.1766e-03,| initc-loss-test 1.1093e-06,|bc_loss-test 4.2446e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1841,            | Training-Loss 1.2572e-02,| Test-Loss 1.8811e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4948e-04,| pde-loss 4.7973e-03,| initc-loss 5.1739e-07,|bc_loss 1.4034e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9091e-05,| pde-loss-test 2.0240e-03,| initc-loss-test 5.6286e-07,|bc_loss-test 2.0746e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1851,            | Training-Loss 5.6240e-03,| Test-Loss 9.5332e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.6222e-05,| pde-loss 4.1393e-03,| initc-loss 7.9137e-07,|bc_loss 1.8096e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2924e-05,| pde-loss-test 2.0794e-03,| initc-loss-test 2.0630e-06,|bc_loss-test 3.1186e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1861,            | Training-Loss 1.1819e-02,| Test-Loss 1.5116e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3067e-04,| pde-loss 4.6447e-03,| initc-loss 6.9700e-07,|bc_loss 5.5038e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0385e-05,| pde-loss-test 1.2240e-03,| initc-loss-test 4.2043e-07,|bc_loss-test 1.4773e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1871,            | Training-Loss 5.8270e-03,| Test-Loss 3.7420e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.6123e-05,| pde-loss 5.1437e-03,| initc-loss 9.0959e-07,|bc_loss 6.1889e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0265e-05,| pde-loss-test 1.8567e-04,| initc-loss-test 6.5616e-07,|bc_loss-test 7.6639e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1881,            | Training-Loss 7.1996e-03,| Test-Loss 5.9101e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.9568e-05,| pde-loss 5.8263e-03,| initc-loss 5.1202e-07,|bc_loss 6.8192e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0997e-05,| pde-loss-test 1.2319e-03,| initc-loss-test 5.3672e-07,|bc_loss-test 1.0157e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1891,            | Training-Loss 9.1931e-03,| Test-Loss 5.1552e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2167e-04,| pde-loss 5.5356e-03,| initc-loss 8.1818e-07,|bc_loss 9.6564e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.2444e-05,| pde-loss-test 1.8824e-03,| initc-loss-test 7.2520e-07,|bc_loss-test 1.2456e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1901,            | Training-Loss 6.3181e-03,| Test-Loss 4.9620e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1113e-04,| pde-loss 4.6965e-03,| initc-loss 4.3382e-07,|bc_loss 4.3062e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.2024e-05,| pde-loss-test 6.4084e-04,| initc-loss-test 7.0553e-07,|bc_loss-test 1.2609e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1911,            | Training-Loss 9.4388e-03,| Test-Loss 1.0778e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2284e-04,| pde-loss 5.6365e-03,| initc-loss 8.3161e-07,|bc_loss 3.3957e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4484e-05,| pde-loss-test 1.7589e-03,| initc-loss-test 6.5858e-07,|bc_loss-test 8.5539e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1921,            | Training-Loss 5.4476e-03,| Test-Loss 9.1959e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0419e-04,| pde-loss 4.3423e-03,| initc-loss 4.3671e-07,|bc_loss 1.6662e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.9175e-05,| pde-loss-test 1.9276e-03,| initc-loss-test 4.9279e-07,|bc_loss-test 7.4405e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1931,            | Training-Loss 6.1459e-03,| Test-Loss 5.5693e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7917e-05,| pde-loss 4.1211e-03,| initc-loss 3.4219e-07,|bc_loss 8.9348e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9915e-05,| pde-loss-test 2.0128e-03,| initc-loss-test 7.0338e-07,|bc_loss-test 1.2858e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1941,            | Training-Loss 7.0337e-03,| Test-Loss 8.0212e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.4653e-05,| pde-loss 4.3827e-03,| initc-loss 4.1381e-07,|bc_loss 7.2383e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.6160e-05,| pde-loss-test 1.8680e-04,| initc-loss-test 2.7585e-06,|bc_loss-test 3.1131e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1951,            | Training-Loss 1.4806e-02,| Test-Loss 2.8739e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.6020e-04,| pde-loss 5.3586e-03,| initc-loss 6.3393e-07,|bc_loss 7.2191e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.4278e-05,| pde-loss-test 1.4866e-04,| initc-loss-test 9.0127e-07,|bc_loss-test 3.4546e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1961,            | Training-Loss 6.4547e-03,| Test-Loss 4.4869e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7946e-05,| pde-loss 4.0485e-03,| initc-loss 1.3656e-06,|bc_loss 1.2743e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4349e-05,| pde-loss-test 6.7878e-04,| initc-loss-test 5.0469e-07,|bc_loss-test 1.3951e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1971,            | Training-Loss 6.1341e-03,| Test-Loss 5.1858e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7680e-05,| pde-loss 3.7752e-03,| initc-loss 3.8280e-07,|bc_loss 2.5870e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.7436e-05,| pde-loss-test 1.0739e-03,| initc-loss-test 6.6324e-07,|bc_loss-test 1.1195e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1981,            | Training-Loss 5.4650e-02,| Test-Loss 1.3734e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8688e-04,| pde-loss 3.9350e-03,| initc-loss 9.9578e-06,|bc_loss 9.2291e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0567e-04,| pde-loss-test 8.4927e-04,| initc-loss-test 4.6705e-06,|bc_loss-test 1.9306e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1991,            | Training-Loss 4.7870e-03,| Test-Loss 5.3360e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.9247e-05,| pde-loss 3.8894e-03,| initc-loss 2.7013e-07,|bc_loss 6.8540e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0761e-05,| pde-loss-test 1.5648e-03,| initc-loss-test 3.2410e-07,|bc_loss-test 9.4783e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 2000,            | Training-Loss 5.7548e-03,| Test-Loss 1.1975e-02   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.6572e-05,| pde-loss 3.8139e-03,| initc-loss 9.7260e-07,|bc_loss 3.9821e-06|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.6136e-05,| pde-loss-test 1.3344e-03,| initc-loss-test 4.5029e-07,|bc_loss-test 1.1822e-05|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_data = loss_train['data-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_data, label='Data Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,temp_init,t_surr) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[818.7972 ]
#  [825.2275 ]
#  [831.70325]
#  ...
#  [815.6744 ]
#  [815.9025 ]
#  [816.14136]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
# plot initial temperature
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(0, length, numpoints), temp_d[0,:], label='Actual Temperature')
plt.plot(np.linspace(0, length, numpoints), temp_nn_t[0,:], label='Predicted Temperature')
plt.xlabel('Distance (m)')
plt.ylabel('Temperature (K)')
plt.title('Initial Temperature Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583
# 0.9999180924377908

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[818.7972 ]
#  [818.8932 ]
#  [818.98914]
#  ...
#  [806.4851 ]
#  [806.4818 ]
#  [806.4783 ]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

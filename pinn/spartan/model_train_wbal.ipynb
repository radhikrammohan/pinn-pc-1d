# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc_icc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_wbal import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# MPS is available
# Using device: mps
# MPS is available
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(32)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
# plot the intial temperature field
plt.figure(figsize=(8, 6))
plt.plot( tempfield[0, :], label='Initial Temperature Field')
plt.title('Initial Temperature Field')
plt.xlabel('Position (x)')
plt.ylabel('Temperature')
plt.legend()
plt.grid()

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 0.9999180924377908

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_l = props['k_l']
k_s = props['k_s']
rho_l = props['rho_l']
rho_s = props['rho_s']
cp_l = props['cp_l']
cp_s = props['cp_s']
alpha_l = k_l / (rho_l * cp_l)
alpha_s = k_s / (rho_s * cp_s)

alpha_max = max(alpha_l, alpha_s)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# The number of points in the initial condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+20002=20002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+16002=16002.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+4002=4002.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data_new2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=1000)  # random sampler for training/simulation data
rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=1000) # random sampler for pde residuals-training
rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=1000)  # random sampler for ic residuals-training
rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=1000) # random sampler for bc left residuals-training
rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=1000) # random sampler for bc right residuals-training

rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=1000 )  # random sampler for testing/simulation data
rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=1000)  # random sampler for pde residuals
rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=1000)  # random sampler for ic residuals
rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=1000) # random sampler for bc left residuals
rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=1000) # random sampler for bc right residuals
batch_size = 153
train_loader = DataLoader(inp_dataset, batch_size=batch_size, sampler=rand_smpl) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=batch_size, sampler=rand_smpl_pde) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=batch_size, sampler=rand_smpl_ic) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=batch_size, sampler=rand_smpl_bcl) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=batch_size, sampler=rand_smpl_bcr) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=batch_size, sampler=rand_smpl_test) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=batch_size, sampler=rand_smpl_pde_test)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=batch_size, sampler=rand_smpl_ic_test)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=batch_size, sampler=rand_smpl_bcl_test)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=batch_size, sampler=rand_smpl_bcr_test)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 364#  best yet is 8
output_size=1

learning_rate = 0.0002 # 0.001
hidden_layers = 2  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =1000
epochs_2 = 100
from Model.model import PINN

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate,line_search_fn ='strong_wolfe')

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 9.1360e-01,| Test-Loss 5.9421e+01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9484e-01,| pde-loss 6.8104e-02,| initc-loss 5.0844e-02,|bc_loss 1.6624e-02|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0506e-02,| pde-loss-test 3.4484e-03,| initc-loss-test 3.8146e-02,|bc_loss-test 4.4550e-02|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 1.2096e-02,| Test-Loss 1.0722e+00   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2994e-03,| pde-loss 7.5543e-04,| initc-loss 8.0276e-04,|bc_loss 4.5569e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.7797e-04,| pde-loss-test 1.8440e-04,| initc-loss-test 6.8201e-04,|bc_loss-test 8.2106e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 5.1604e-03,| Test-Loss 5.8226e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.1761e-04,| pde-loss 6.1092e-04,| initc-loss 4.7722e-04,|bc_loss 2.3002e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1361e-04,| pde-loss-test 1.8117e-04,| initc-loss-test 4.1727e-04,|bc_loss-test 3.4090e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 5.0361e-03,| Test-Loss 5.8852e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.6730e-04,| pde-loss 5.9319e-04,| initc-loss 5.2229e-04,|bc_loss 2.1690e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.3878e-05,| pde-loss-test 1.5558e-04,| initc-loss-test 3.8189e-04,|bc_loss-test 4.8893e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 4.6154e-03,| Test-Loss 5.2970e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.6666e-04,| pde-loss 5.4334e-04,| initc-loss 4.4928e-04,|bc_loss 1.3739e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.7102e-05,| pde-loss-test 1.4851e-04,| initc-loss-test 4.4699e-04,|bc_loss-test 2.9231e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 4.5236e-03,| Test-Loss 5.1726e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4172e-04,| pde-loss 5.5036e-04,| initc-loss 3.9287e-04,|bc_loss 1.9066e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.2123e-05,| pde-loss-test 1.7236e-04,| initc-loss-test 3.7767e-04,|bc_loss-test 3.7219e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 4.3781e-03,| Test-Loss 5.0442e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4960e-04,| pde-loss 5.8044e-04,| initc-loss 3.3263e-04,|bc_loss 1.5654e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0427e-04,| pde-loss-test 1.2413e-04,| initc-loss-test 4.2671e-04,|bc_loss-test 3.0313e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 4.4307e-03,| Test-Loss 4.9609e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4015e-04,| pde-loss 5.5558e-04,| initc-loss 3.6850e-04,|bc_loss 1.8042e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1476e-05,| pde-loss-test 1.5989e-04,| initc-loss-test 3.9232e-04,|bc_loss-test 3.0022e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 4.3565e-03,| Test-Loss 4.8251e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0763e-04,| pde-loss 5.5905e-04,| initc-loss 3.5327e-04,|bc_loss 1.4342e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.9746e-05,| pde-loss-test 1.5824e-04,| initc-loss-test 3.3517e-04,|bc_loss-test 2.8818e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 4.1605e-03,| Test-Loss 4.7457e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3152e-04,| pde-loss 5.0202e-04,| initc-loss 3.4316e-04,|bc_loss 1.3129e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4753e-05,| pde-loss-test 1.2186e-04,| initc-loss-test 4.0163e-04,|bc_loss-test 2.5381e-04|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# train w0: 0.05071160101092527, w1: 0.11655975161490541, w2: 0.5962568057384505, w3: 0.23647184163571872
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
# w0: 0.06842296768774846, w1: 0.14408742924192192, w2: 0.5063532517208182, w3: 0.28113635134951126
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 1.7449e-03,| Test-Loss 1.9578e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0995e-04,| pde-loss 6.5270e-04,| initc-loss 3.5983e-04,|bc_loss 1.6340e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1975e-05,| pde-loss-test 1.7091e-04,| initc-loss-test 3.4127e-04,|bc_loss-test 3.6451e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 4.0122e-03,| Test-Loss 4.4060e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.9707e-04,| pde-loss 4.6426e-04,| initc-loss 4.3423e-04,|bc_loss 1.2186e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.3025e-05,| pde-loss-test 1.1031e-04,| initc-loss-test 3.4045e-04,|bc_loss-test 3.1549e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 4.0015e-03,| Test-Loss 4.2692e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9349e-04,| pde-loss 4.3508e-04,| initc-loss 3.2262e-04,|bc_loss 1.2708e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.5815e-05,| pde-loss-test 1.1660e-04,| initc-loss-test 3.7513e-04,|bc_loss-test 2.7446e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 3.7479e-03,| Test-Loss 4.0920e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.0410e-04,| pde-loss 3.9804e-04,| initc-loss 3.4908e-04,|bc_loss 1.2806e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2754e-05,| pde-loss-test 1.7173e-04,| initc-loss-test 3.4368e-04,|bc_loss-test 2.2709e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 3.5099e-03,| Test-Loss 3.6616e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9519e-04,| pde-loss 3.8203e-04,| initc-loss 2.6053e-04,|bc_loss 1.8792e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.2618e-05,| pde-loss-test 1.7631e-04,| initc-loss-test 3.1058e-04,|bc_loss-test 2.1361e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 3.3379e-03,| Test-Loss 3.4573e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.2961e-04,| pde-loss 3.4694e-04,| initc-loss 2.3272e-04,|bc_loss 2.4320e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.3397e-05,| pde-loss-test 1.5297e-04,| initc-loss-test 2.8235e-04,|bc_loss-test 1.5980e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 2.7590e-03,| Test-Loss 2.8814e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1357e-04,| pde-loss 3.7267e-04,| initc-loss 2.4310e-04,|bc_loss 7.7325e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8262e-05,| pde-loss-test 1.0981e-04,| initc-loss-test 2.0599e-04,|bc_loss-test 1.9420e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 2.8585e-03,| Test-Loss 2.9055e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4978e-04,| pde-loss 6.8828e-04,| initc-loss 2.0620e-04,|bc_loss 7.6749e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0208e-04,| pde-loss-test 3.2466e-04,| initc-loss-test 2.0471e-04,|bc_loss-test 2.2363e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 2.8742e-03,| Test-Loss 3.1492e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0816e-04,| pde-loss 9.9664e-04,| initc-loss 1.9324e-04,|bc_loss 7.8876e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0586e-04,| pde-loss-test 5.4798e-04,| initc-loss-test 1.8139e-04,|bc_loss-test 2.7099e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 3.1485e-03,| Test-Loss 2.3017e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3535e-04,| pde-loss 8.4706e-04,| initc-loss 2.4243e-04,|bc_loss 1.0663e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.4120e-05,| pde-loss-test 6.6311e-05,| initc-loss-test 1.7710e-04,|bc_loss-test 1.2811e-04|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# train w0: 0.05827615456142025, w1: 0.45574170352591153, w2: 0.3522567310789689, w3: 0.13372541083369938
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
# w0: 0.14630633916222796, w1: 0.38231282282652823, w2: 0.2596934546196228, w3: 0.21168738339162105
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 1.3375e-03,| Test-Loss 2.2634e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6554e-04,| pde-loss 1.7391e-03,| initc-loss 1.4167e-04,|bc_loss 1.0171e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.3678e-05,| pde-loss-test 2.8972e-03,| initc-loss-test 1.5702e-04,|bc_loss-test 1.2397e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 3.6789e-03,| Test-Loss 4.5996e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1984e-03,| pde-loss 9.5313e-04,| initc-loss 1.7114e-04,|bc_loss 2.6408e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.7850e-04,| pde-loss-test 2.3773e-04,| initc-loss-test 2.3593e-04,|bc_loss-test 4.8449e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 3.6512e-03,| Test-Loss 2.2981e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.3025e-04,| pde-loss 1.6025e-03,| initc-loss 2.0603e-04,|bc_loss 7.2628e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.9704e-05,| pde-loss-test 6.1694e-05,| initc-loss-test 1.9905e-04,|bc_loss-test 1.4566e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 3.8865e-03,| Test-Loss 2.2532e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.5021e-04,| pde-loss 1.9036e-03,| initc-loss 2.0734e-04,|bc_loss 3.8898e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.4885e-05,| pde-loss-test 5.4136e-04,| initc-loss-test 1.8420e-04,|bc_loss-test 1.4027e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 2.4192e-03,| Test-Loss 2.0574e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2000e-04,| pde-loss 7.0859e-04,| initc-loss 1.6407e-04,|bc_loss 7.4052e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6266e-05,| pde-loss-test 9.5007e-05,| initc-loss-test 2.1799e-04,|bc_loss-test 1.0324e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 2.3874e-03,| Test-Loss 2.0230e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5445e-04,| pde-loss 7.3825e-04,| initc-loss 1.6726e-04,|bc_loss 6.4378e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.3496e-05,| pde-loss-test 5.6180e-04,| initc-loss-test 1.7453e-04,|bc_loss-test 1.1400e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 1.9638e-03,| Test-Loss 2.0811e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0957e-04,| pde-loss 3.4817e-04,| initc-loss 1.9376e-04,|bc_loss 5.1222e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.4357e-05,| pde-loss-test 3.2779e-05,| initc-loss-test 1.7132e-04,|bc_loss-test 1.2742e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 2.2913e-03,| Test-Loss 2.5339e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8862e-04,| pde-loss 4.9550e-04,| initc-loss 2.2676e-04,|bc_loss 6.3120e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0140e-04,| pde-loss-test 5.0121e-04,| initc-loss-test 1.6625e-04,|bc_loss-test 1.9788e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 2.1015e-03,| Test-Loss 1.9704e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5572e-04,| pde-loss 3.7506e-04,| initc-loss 1.7433e-04,|bc_loss 7.9154e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6366e-05,| pde-loss-test 6.8480e-05,| initc-loss-test 2.1574e-04,|bc_loss-test 8.7390e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 4.0576e-03,| Test-Loss 1.9200e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9381e-04,| pde-loss 1.8791e-03,| initc-loss 1.5569e-04,|bc_loss 8.8614e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.1264e-05,| pde-loss-test 1.0347e-04,| initc-loss-test 2.1745e-04,|bc_loss-test 7.6523e-05|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# train w0: 0.04922239552359026, w1: 0.2882423775374231, w2: 0.5120552660550938, w3: 0.15047996088389295
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
# w0: 0.05016488555614356, w1: 0.4579765984111027, w2: 0.3309388249737545, w3: 0.1609196910589992
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 1.1288e-03,| Test-Loss 1.4754e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7387e-04,| pde-loss 1.5873e-03,| initc-loss 1.4799e-04,|bc_loss 6.5436e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.7450e-05,| pde-loss-test 9.5361e-04,| initc-loss-test 1.6807e-04,|bc_loss-test 1.4262e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 2.2158e-03,| Test-Loss 1.9279e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0148e-04,| pde-loss 6.0547e-04,| initc-loss 1.7177e-04,|bc_loss 4.6514e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0142e-05,| pde-loss-test 6.2795e-05,| initc-loss-test 1.8907e-04,|bc_loss-test 9.5735e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 3.4181e-03,| Test-Loss 1.9524e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.7737e-04,| pde-loss 1.3674e-03,| initc-loss 1.7124e-04,|bc_loss 2.4048e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.5530e-05,| pde-loss-test 5.7976e-04,| initc-loss-test 1.6051e-04,|bc_loss-test 1.0044e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 2.6422e-03,| Test-Loss 3.3225e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.1002e-04,| pde-loss 7.1107e-04,| initc-loss 1.6619e-04,|bc_loss 4.9282e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8336e-04,| pde-loss-test 4.3654e-04,| initc-loss-test 1.7741e-04,|bc_loss-test 2.7371e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 3.1701e-03,| Test-Loss 2.4423e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8782e-04,| pde-loss 1.4272e-03,| initc-loss 1.6481e-04,|bc_loss 1.0032e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6468e-04,| pde-loss-test 1.6186e-04,| initc-loss-test 1.6277e-04,|bc_loss-test 2.0002e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 3.0122e-03,| Test-Loss 2.7740e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.9167e-04,| pde-loss 1.2104e-03,| initc-loss 1.6267e-04,|bc_loss 7.6069e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1555e-04,| pde-loss-test 8.0574e-04,| initc-loss-test 1.7227e-04,|bc_loss-test 2.5094e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 2.5834e-03,| Test-Loss 2.2514e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3906e-04,| pde-loss 9.7512e-04,| initc-loss 1.8857e-04,|bc_loss 3.9787e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7792e-05,| pde-loss-test 4.2301e-05,| initc-loss-test 1.6268e-04,|bc_loss-test 1.3527e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 3.7240e-03,| Test-Loss 2.7317e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.4707e-04,| pde-loss 2.0354e-03,| initc-loss 1.9459e-04,|bc_loss 5.6298e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1620e-04,| pde-loss-test 4.8520e-05,| initc-loss-test 1.9403e-04,|bc_loss-test 1.8872e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 2.5323e-03,| Test-Loss 1.7361e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5214e-04,| pde-loss 9.9815e-04,| initc-loss 1.5303e-04,|bc_loss 4.4480e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.2538e-05,| pde-loss-test 5.6668e-04,| initc-loss-test 1.3832e-04,|bc_loss-test 1.0410e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 2.6887e-03,| Test-Loss 1.7067e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1925e-04,| pde-loss 1.0869e-03,| initc-loss 1.4638e-04,|bc_loss 9.7282e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0913e-05,| pde-loss-test 6.9389e-05,| initc-loss-test 1.4894e-04,|bc_loss-test 9.7594e-05|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# train w0: 0.06796391296169167, w1: 0.3105794786829073, w2: 0.4603091880789932, w3: 0.16114742027640797
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
# w0: 0.043654497954769965, w1: 0.5073768771325103, w2: 0.3152858598498765, w3: 0.13368276506284327
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 1.1158e-03,| Test-Loss 2.0174e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5022e-04,| pde-loss 1.7460e-03,| initc-loss 1.3342e-04,|bc_loss 6.4057e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9199e-05,| pde-loss-test 5.6201e-04,| initc-loss-test 1.6914e-04,|bc_loss-test 1.7037e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 3.1765e-03,| Test-Loss 3.1570e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.8436e-04,| pde-loss 1.3540e-03,| initc-loss 1.6992e-04,|bc_loss 4.6581e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.0226e-04,| pde-loss-test 2.0758e-05,| initc-loss-test 1.5261e-04,|bc_loss-test 2.8939e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 2.8563e-03,| Test-Loss 3.6166e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.6987e-04,| pde-loss 9.6444e-04,| initc-loss 1.7843e-04,|bc_loss 8.2814e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.3284e-04,| pde-loss-test 1.2970e-03,| initc-loss-test 1.7119e-04,|bc_loss-test 3.5748e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 2.7745e-03,| Test-Loss 2.0197e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3292e-04,| pde-loss 1.0803e-03,| initc-loss 1.7685e-04,|bc_loss 4.1963e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.2964e-05,| pde-loss-test 4.0861e-04,| initc-loss-test 1.6936e-04,|bc_loss-test 1.2118e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 2.8803e-03,| Test-Loss 1.6448e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.3781e-05,| pde-loss 1.4169e-03,| initc-loss 1.5241e-04,|bc_loss 4.7422e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.7199e-05,| pde-loss-test 1.0085e-04,| initc-loss-test 1.4489e-04,|bc_loss-test 8.4817e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 2.6947e-03,| Test-Loss 2.2092e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2945e-04,| pde-loss 1.0712e-03,| initc-loss 1.6267e-04,|bc_loss 4.9426e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.1097e-05,| pde-loss-test 8.7292e-04,| initc-loss-test 1.0138e-04,|bc_loss-test 1.8418e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 3.8209e-03,| Test-Loss 2.0743e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.0834e-04,| pde-loss 2.2338e-03,| initc-loss 1.5187e-04,|bc_loss 6.7868e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.5875e-05,| pde-loss-test 1.2413e-03,| initc-loss-test 1.4148e-04,|bc_loss-test 1.2760e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 2.7074e-03,| Test-Loss 1.7510e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1616e-04,| pde-loss 1.1332e-03,| initc-loss 1.4751e-04,|bc_loss 5.5725e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.9905e-05,| pde-loss-test 5.7705e-05,| initc-loss-test 1.7199e-04,|bc_loss-test 7.9997e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 2.8389e-03,| Test-Loss 2.1799e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.7992e-04,| pde-loss 8.1521e-04,| initc-loss 1.6758e-04,|bc_loss 5.1319e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.0977e-05,| pde-loss-test 6.9807e-05,| initc-loss-test 1.6280e-04,|bc_loss-test 1.2668e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 2.9227e-03,| Test-Loss 1.7926e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.1050e-04,| pde-loss 1.2578e-03,| initc-loss 1.6140e-04,|bc_loss 5.3209e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.4511e-05,| pde-loss-test 1.1004e-04,| initc-loss-test 1.9325e-04,|bc_loss-test 7.3637e-05|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# train w0: 0.0838457841906787, w1: 0.19754244939817148, w2: 0.5295088762917315, w3: 0.18910289011941844
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
# w0: 0.05447279088448268, w1: 0.36772322886481873, w2: 0.4052176110900598, w3: 0.17258636916063888
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 9.0213e-04,| Test-Loss 1.6535e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5364e-04,| pde-loss 1.0372e-03,| initc-loss 1.4404e-04,|bc_loss 7.4736e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0011e-05,| pde-loss-test 5.4746e-05,| initc-loss-test 1.4261e-04,|bc_loss-test 1.8338e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 3.8124e-03,| Test-Loss 5.1232e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4977e-04,| pde-loss 1.5957e-03,| initc-loss 1.7574e-04,|bc_loss 5.9487e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.1909e-04,| pde-loss-test 9.6709e-04,| initc-loss-test 1.4882e-04,|bc_loss-test 5.6119e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 2.4697e-03,| Test-Loss 1.8633e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0990e-04,| pde-loss 9.6808e-04,| initc-loss 1.4128e-04,|bc_loss 5.0009e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.0257e-05,| pde-loss-test 9.2102e-04,| initc-loss-test 1.5904e-04,|bc_loss-test 1.1771e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 2.9387e-03,| Test-Loss 1.7822e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.2563e-04,| pde-loss 1.2610e-03,| initc-loss 1.6915e-04,|bc_loss 7.3182e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.2039e-05,| pde-loss-test 1.3856e-04,| initc-loss-test 1.6309e-04,|bc_loss-test 7.0712e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 3.0244e-03,| Test-Loss 1.8873e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.4889e-04,| pde-loss 1.2550e-03,| initc-loss 1.3276e-04,|bc_loss 1.4345e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.3493e-05,| pde-loss-test 1.0585e-04,| initc-loss-test 1.6859e-04,|bc_loss-test 1.1453e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 2.4817e-03,| Test-Loss 2.1248e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7461e-04,| pde-loss 9.1520e-04,| initc-loss 1.7062e-04,|bc_loss 6.4559e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.5587e-05,| pde-loss-test 3.5451e-05,| initc-loss-test 1.8553e-04,|bc_loss-test 1.3622e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 3.1268e-03,| Test-Loss 1.6774e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.8661e-04,| pde-loss 1.4842e-03,| initc-loss 1.4827e-04,|bc_loss 5.6005e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4732e-05,| pde-loss-test 1.1536e-04,| initc-loss-test 1.3249e-04,|bc_loss-test 8.9584e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 2.3443e-03,| Test-Loss 1.8724e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0689e-04,| pde-loss 7.8559e-04,| initc-loss 1.6692e-04,|bc_loss 5.3063e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.0642e-05,| pde-loss-test 6.5190e-05,| initc-loss-test 1.6242e-04,|bc_loss-test 9.1119e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 2.0911e-03,| Test-Loss 2.0959e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.7518e-04,| pde-loss 4.4635e-04,| initc-loss 1.8578e-04,|bc_loss 4.6346e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4570e-05,| pde-loss-test 4.3628e-04,| initc-loss-test 1.7190e-04,|bc_loss-test 1.2128e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 2.3626e-03,| Test-Loss 1.7265e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.4218e-04,| pde-loss 8.5794e-04,| initc-loss 1.4136e-04,|bc_loss 8.4250e-05|
# ----------------------------------------------------------------------------------------------------
# ...
# w0: 0.15558880391717397, w1: 0.3847548359645563, w2: 0.24881483144937389, w3: 0.21084152866889574
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 801,            | Training-Loss 1.2646e-03,| Test-Loss 9.4814e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0896e-04,| pde-loss 1.7532e-03,| initc-loss 1.6931e-04,|bc_loss 1.0260e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.9956e-05,| pde-loss-test 3.9976e-04,| initc-loss-test 1.4818e-04,|bc_loss-test 1.5169e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 811,            | Training-Loss 2.3675e-03,| Test-Loss 1.6669e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3789e-04,| pde-loss 8.6710e-04,| initc-loss 1.8407e-04,|bc_loss 3.1027e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6497e-05,| pde-loss-test 1.4354e-04,| initc-loss-test 1.7323e-04,|bc_loss-test 4.9460e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 821,            | Training-Loss 2.2253e-03,| Test-Loss 1.7169e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1351e-04,| pde-loss 8.7250e-04,| initc-loss 1.3512e-04,|bc_loss 4.8833e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6160e-05,| pde-loss-test 1.3318e-03,| initc-loss-test 1.1484e-04,|bc_loss-test 1.3229e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 831,            | Training-Loss 2.8042e-03,| Test-Loss 1.5323e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3296e-04,| pde-loss 1.3743e-03,| initc-loss 1.6700e-04,|bc_loss 6.1845e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.5588e-05,| pde-loss-test 3.8357e-04,| initc-loss-test 1.6481e-04,|bc_loss-test 7.2510e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 841,            | Training-Loss 2.3639e-03,| Test-Loss 1.6283e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1386e-04,| pde-loss 8.4296e-04,| initc-loss 1.5031e-04,|bc_loss 7.7866e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.8909e-05,| pde-loss-test 3.7913e-04,| initc-loss-test 1.4491e-04,|bc_loss-test 1.0980e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 851,            | Training-Loss 2.7105e-03,| Test-Loss 1.9172e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.3502e-04,| pde-loss 6.9325e-04,| initc-loss 1.8150e-04,|bc_loss 5.9398e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.3715e-05,| pde-loss-test 7.5247e-05,| initc-loss-test 2.1148e-04,|bc_loss-test 8.9292e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 861,            | Training-Loss 2.9176e-03,| Test-Loss 1.6761e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.4204e-04,| pde-loss 1.0724e-03,| initc-loss 1.7242e-04,|bc_loss 7.8572e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2973e-05,| pde-loss-test 1.3244e-04,| initc-loss-test 1.8429e-04,|bc_loss-test 8.6138e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 871,            | Training-Loss 2.8104e-03,| Test-Loss 2.0928e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3283e-04,| pde-loss 1.2524e-03,| initc-loss 1.4466e-04,|bc_loss 1.1400e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1388e-04,| pde-loss-test 9.1037e-04,| initc-loss-test 1.4804e-04,|bc_loss-test 1.6585e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 881,            | Training-Loss 2.6931e-03,| Test-Loss 1.7201e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8099e-04,| pde-loss 1.0847e-03,| initc-loss 1.5557e-04,|bc_loss 9.5604e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.6441e-05,| pde-loss-test 1.0690e-04,| initc-loss-test 1.6208e-04,|bc_loss-test 8.7230e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 891,            | Training-Loss 2.4107e-03,| Test-Loss 1.6636e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3266e-04,| pde-loss 9.3926e-04,| initc-loss 1.4225e-04,|bc_loss 3.8480e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.5744e-05,| pde-loss-test 6.4360e-05,| initc-loss-test 1.3370e-04,|bc_loss-test 7.7909e-05|
# ----------------------------------------------------------------------------------------------------
#
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# train w0: 0.08791777930257239, w1: 0.32934172976800236, w2: 0.43219786939797866, w3: 0.1505426215314467
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
# w0: 0.10646817489647083, w1: 0.47670360737481793, w2: 0.2563548060676698, w3: 0.16047341166104148
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 901,            | Training-Loss 1.2350e-03,| Test-Loss 6.8595e-04   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 4.5037e-04,| pde-loss 2.0165e-03,| initc-loss 1.5434e-04,|bc_loss 7.7344e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.2849e-05,| pde-loss-test 1.3219e-04,| initc-loss-test 1.7226e-04,|bc_loss-test 7.5141e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 911,            | Training-Loss 2.3759e-03,| Test-Loss 1.6228e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2405e-04,| pde-loss 9.2022e-04,| initc-loss 1.5161e-04,|bc_loss 5.5329e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.3093e-05,| pde-loss-test 1.0044e-04,| initc-loss-test 1.3141e-04,|bc_loss-test 7.6534e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 921,            | Training-Loss 2.5557e-03,| Test-Loss 2.0614e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8720e-04,| pde-loss 1.0240e-03,| initc-loss 1.7772e-04,|bc_loss 2.7217e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.5778e-05,| pde-loss-test 6.7418e-05,| initc-loss-test 1.6360e-04,|bc_loss-test 1.4500e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 931,            | Training-Loss 3.4784e-03,| Test-Loss 1.9486e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5827e-04,| pde-loss 2.0291e-03,| initc-loss 1.8361e-04,|bc_loss 3.2160e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 4.6144e-05,| pde-loss-test 3.4334e-04,| initc-loss-test 1.2362e-04,|bc_loss-test 1.3021e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 941,            | Training-Loss 3.4459e-03,| Test-Loss 2.4253e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1829e-04,| pde-loss 1.3724e-03,| initc-loss 1.5529e-04,|bc_loss 2.6723e-04|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.6906e-04,| pde-loss-test 3.3339e-04,| initc-loss-test 2.0349e-04,|bc_loss-test 1.4503e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 951,            | Training-Loss 1.8145e-03,| Test-Loss 1.5899e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4761e-05,| pde-loss 4.8290e-04,| initc-loss 1.8641e-04,|bc_loss 1.5750e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.8384e-05,| pde-loss-test 5.7208e-05,| initc-loss-test 1.5184e-04,|bc_loss-test 8.1226e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 961,            | Training-Loss 2.7370e-03,| Test-Loss 1.6826e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.9115e-04,| pde-loss 9.9988e-04,| initc-loss 1.7301e-04,|bc_loss 8.1975e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 3.9084e-05,| pde-loss-test 2.6249e-04,| initc-loss-test 1.7078e-04,|bc_loss-test 7.1404e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 971,            | Training-Loss 2.9628e-03,| Test-Loss 1.7634e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.3018e-04,| pde-loss 1.2421e-03,| initc-loss 1.9568e-04,|bc_loss 9.8962e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.4580e-05,| pde-loss-test 1.7876e-04,| initc-loss-test 1.8909e-04,|bc_loss-test 7.5262e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 981,            | Training-Loss 1.9999e-03,| Test-Loss 1.5690e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4899e-05,| pde-loss 7.8206e-04,| initc-loss 1.4442e-04,|bc_loss 2.3367e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.6789e-05,| pde-loss-test 4.5323e-05,| initc-loss-test 1.3680e-04,|bc_loss-test 9.1141e-05|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 991,            | Training-Loss 2.6138e-03,| Test-Loss 2.5295e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3828e-04,| pde-loss 1.1935e-03,| initc-loss 1.4556e-04,|bc_loss 4.0455e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.8136e-04,| pde-loss-test 3.0799e-04,| initc-loss-test 1.9240e-04,|bc_loss-test 1.7183e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1000,            | Training-Loss 3.3113e-03,| Test-Loss 2.0427e-01   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.5073e-04,| pde-loss 1.3160e-03,| initc-loss 1.6669e-04,|bc_loss 5.5440e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1321e-05,| pde-loss-test 6.0559e-05,| initc-loss-test 1.9162e-04,|bc_loss-test 1.0417e-04|
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_data = loss_train['data-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_data, label='Data Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,temp_init,t_surr) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[853.52106]
#  [858.6642 ]
#  [863.2294 ]
#  ...
#  [830.7465 ]
#  [830.7623 ]
#  [830.7818 ]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
# plot initial temperature
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(0, length, numpoints), temp_d[0,:], label='Actual Temperature')
plt.plot(np.linspace(0, length, numpoints), temp_nn_t[0,:], label='Predicted Temperature')
plt.xlabel('Distance (m)')
plt.ylabel('Temperature (K)')
plt.title('Initial Temperature Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583
# 0.9999180924377908

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[853.52106]
#  [853.6027 ]
#  [853.68414]
#  ...
#  [841.43585]
#  [841.4396 ]
#  [841.443  ]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %% [markdown]
# # Import models

# %%
import sys
import json
import math
import time
import pickle
import argparse
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from itertools import zip_longest
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
from torch.optim import Adam, LBFGS

try:
    current_dir = os.getcwd()
except:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    
training_data_dir = os.path.join(current_dir, '../training_data')
model_dir = os.path.join(current_dir, '../')
sys.path.insert(0,str(training_data_dir))
sys.path.insert(0,str(model_dir))

from simdata_mush_dirc_icc import  *
from Model.loss_func_sol_norm import loss_fn_data,pde_loss,ic_loss,boundary_loss
from Model.train_testloop_sal import *

def set_seed(seed):
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Use deterministic algorithms
    torch.use_deterministic_algorithms(True)

    # This may not exist on macOS if not using GPU or CuDNN
    if torch.backends.mps.is_available():  # MPS = Apple GPU backend
        print("Using Apple Metal Performance Shaders (MPS)")
    elif torch.backends.cudnn.is_available():
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(1234)
# Out:
# Using Apple Metal Performance Shaders (MPS)

# %% [markdown]
# # Get the training data

# %%
settings_path_1 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_1,'r') as file:
    settings = json.load(file)


heat_data = HT_sim(settings)
alpha = heat_data.alpha_l
tempfield = heat_data.datagen()

heat_data.plot_temp(32)
dt = heat_data.dt
dx = heat_data.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583

# %%
# plot the intial temperature field
plt.figure(figsize=(8, 6))
plt.plot( tempfield[0, :], label='Initial Temperature Field')
plt.title('Initial Temperature Field')
plt.xlabel('Position (x)')
plt.ylabel('Temperature')
plt.legend()
plt.grid()

# %%
temp_data = tempfield.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# 0.9999180924377908

# %%
num_steps = tempfield.shape[0]
numpoints = tempfield.shape[1] 

pde_pts= props["pde_pts"]
ic_pts = props["ic_pts"]
bc_pts = props["bc_pts"]

length = props['length']
time_end = props['time_end']

x_c = 1/length
k_l = props['k_l']
k_s = props['k_s']
rho_l = props['rho_l']
rho_s = props['rho_s']
cp_l = props['cp_l']
cp_s = props['cp_s']
alpha_l = k_l / (rho_l * cp_l)
alpha_s = k_s / (rho_s * cp_s)

alpha_max = max(alpha_l, alpha_s)
t_c = (alpha_max/(length**2))
temp_c = props['temp_init']

inp_data = fdd(15e-3, time_end, numpoints, num_steps)


def scale2(x,x_c,t_c):
    scaled_x = x.copy()
    scaled_x[:,0] = x[:,0] * x_c
    scaled_x[:,1] = x[:,1] * t_c
    return scaled_x

inp_data2 = scale2(inp_data,x_c,t_c)

# input dataset-pde residual
# The pde inputs are generated using the pdeinp function in simdata.py
pde_data = pdeinp(dx,length-dx,dt,time_end,pde_pts,"Sobol",scl="False") 

pde_data2 = scale2(pde_data,x_c,t_c)

# input dataset - ic residual
ic_data = icinp(length,ic_pts,scl="False")
ic_data2 = scale2(ic_data,x_c,t_c)
# input dataset - boundary residual
bc_ldata = bcinp(length,time_end,bc_pts,dt,scl="False")[0]
bc_rdata = bcinp(length,time_end,bc_pts,dt,scl="False")[1]

bc_ldata2 = scale2(bc_ldata,x_c,t_c)
bc_rdata2 = scale2(bc_rdata,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# The number of points in the initial condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# The number of points in the left boundary condition is 20000
# The number of points in the right boundary condition is 20000
# scaling not initiated
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+20002=20002.
#   warnings.warn(

# %%
t_lim = 1.5
pde_data_new = pde_act_pts(dx,length-dx,dt,time_end,t_lim,pde_pts,"Sobol",scl="False") 
pde_data_new2 = scale2(pde_data_new,x_c,t_c)
# Out:
# scaling not initiated
# The number of points in the PDE input is 20000
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+16002=16002.
#   warnings.warn(
# /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/skopt/sampler/sobol.py:521: UserWarning: The balance properties of Sobol' points require n to be a power of 2. 0 points have been previously generated, then: n=0+4002=4002.
#   warnings.warn(

# %% [markdown]
# # Prepare  the Inputs

# %%
if torch.backends.mps.is_available():
    print("MPS is available")
    device = torch.device('mps')
else:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('Using device:', device)

# print('Using device:', device)

# %% [markdown]
# ### Tensor inputs

input_t = torch.tensor(inp_data2).float().to(device)
inp_pdet = torch.tensor(pde_data2).float().to(device)
inp_ict = torch.tensor(ic_data2).float().to(device)
inp_bclt = torch.tensor(bc_ldata2).float().to(device)
inp_bclr = torch.tensor(bc_rdata2).float().to(device)



temp_t = torch.tensor(temp_data_s).float().to(device)
temp_t = temp_t.view(-1,1)

temp_init_s= temp_scaler(919.0, temp_init, t_surr)
# temp_init = scaler(temp_init,500.0,919.0)

temp_init_t = torch.tensor(temp_init_s).float().to(device)
T_L = props['T_L']                   #  K -Liquidus Temperature (615 c) AL 380
T_L_s = temp_scaler(T_L,temp_init, t_surr)                     #  K -Liquidus Temperature (615 c) AL 380
# T_L = scaler(T_L,500.0,919.0)
T_S = props['T_S']                   #  K -Solidus Temperature (615 c) AL 380
T_S_s = temp_scaler(T_S,temp_init, t_surr)                     #  K -Solidus Temperature (615 c) AL 380
# T_S = scaler(T_S,500.0,919.0)                     #  K -Solidus Temperature (615 c) AL 380

# t_surr = scaler(t_surr,500.0,919.0)
t_surr = props['t_surr']                   #  K -Surrounding Temperature (500 c) AL 380
t_surr_s = temp_scaler(t_surr, temp_init, t_surr)
T_lt = torch.tensor(T_L_s).float().to(device)    # Liquidus Temperature tensor
T_st = torch.tensor(T_S_s).float().to(device)    # Solidus Temperature tensor
t_surrt = torch.tensor(t_surr_s).float().to(device)   # Surrounding Temperature tensor

die_left = props['die_temp_l']
die_left = temp_scaler(die_left, temp_init, t_surr) # die left temperature
die_right = props['die_temp_r']
die_right = temp_scaler(die_right, temp_init, t_surr) # die right temperature
temp_var = {"T_st":T_st,"T_lt":T_lt,"t_surrt":t_surrt,"temp_init_t":temp_init_t,\
               "die_temp_l":die_left,"die_temp_r":die_right} # temperature variables dictionary
print(temp_var)
# %% [markdown]
# ### Dataset Preparation for pytorch

# %%
train_inputs,test_inputs =train_test_split(input_t,test_size=0.2,random_state=42) # input data split
# print(train_inputs.shape)
tr_inp_pde,ts_inp_pde = train_test_split( inp_pdet,test_size=0.2,random_state=42) # input pde data split
# print(tr_inp_pde.shape)
tr_inp_ic,ts_inp_ic = train_test_split( inp_ict,test_size=0.2,random_state=42) # input ic data split
# print(tr_inp_ic.shape)

tr_inp_bcl,ts_inp_bcl = train_test_split( inp_bclt,test_size=0.2,random_state=42) # input bc left data split
tr_inp_bcr,ts_inp_bcr = train_test_split( inp_bclr,test_size=0.2,random_state=42) # input bc right data split
# nn
# 

train_temp,test_temp = train_test_split(temp_t,test_size=0.2,random_state=42) # output data split



# %%
class Data_Tensor_Dataset(TensorDataset):#dataset class for tsimulation data
    def __init__(self,inputs,outputs,transform=None, target_transform =None):   
        self.inputs = inputs
        self.outputs = outputs

    def __getitem__(self, index):
        return self.inputs[index],self.outputs[index]
    
    def __len__(self):
        return len(self.inputs)

class ResDataset(TensorDataset): #dataset class for pde residuals and bcs,ics
    def __init__(self, inputs,transform=None, target_transform =None):
        self.inputs = inputs
        

    def __getitem__(self, index):
        return self.inputs[index]
    
    def __len__(self):
        return len(self.inputs)

# %% [markdown]
# ### Dataset Preparation

# %%
inp_dataset = Data_Tensor_Dataset(train_inputs,train_temp)
inp_dataset_test = Data_Tensor_Dataset(test_inputs,test_temp)

inp_pde_dataset = ResDataset(tr_inp_pde) # pde residual dataset for training
inp_pde_dataset_test = ResDataset(ts_inp_pde) # pde residual dataset for testing

inp_ic_dataset = ResDataset(tr_inp_ic) # ic residual dataset for training
inp_ic_dataset_test = ResDataset(ts_inp_ic) # ic residual dataset for testing

inp_bcl_dataset = ResDataset(tr_inp_bcl) # bc left residual dataset for training
inp_bcl_dataset_test = ResDataset(ts_inp_bcl) # bc left residual dataset for testing

inp_bcr_dataset = ResDataset(tr_inp_bcr) # bc right residual dataset for training
inp_bcr_dataset_test = ResDataset(ts_inp_bcr)   # bc right residual dataset for testing

# %%
# print(len(inp_ic_dataset))

# %% [markdown]
# ### Dataloader Preparation

# %%
# rand_smpl = RandomSampler(inp_dataset, replacement=False,num_samples=1000)  # random sampler for training/simulation data
# rand_smpl_pde = RandomSampler(inp_pde_dataset, replacement=False, num_samples=1000) # random sampler for pde residuals-training
# rand_smpl_ic = RandomSampler(inp_ic_dataset, replacement=False, num_samples=1000)  # random sampler for ic residuals-training
# rand_smpl_bcl = RandomSampler(inp_bcl_dataset, replacement=False, num_samples=1000) # random sampler for bc left residuals-training
# rand_smpl_bcr = RandomSampler(inp_bcr_dataset, replacement=False, num_samples=1000) # random sampler for bc right residuals-training

# rand_smpl_test = RandomSampler(inp_dataset_test, replacement=False, num_samples=1000 )  # random sampler for testing/simulation data
# rand_smpl_pde_test = RandomSampler(inp_pde_dataset_test,replacement=False, num_samples=1000)  # random sampler for pde residuals
# rand_smpl_ic_test = RandomSampler(inp_ic_dataset_test,replacement=False, num_samples=1000)  # random sampler for ic residuals
# rand_smpl_bcl_test = RandomSampler(inp_bcl_dataset_test,replacement=False, num_samples=1000) # random sampler for bc left residuals
# rand_smpl_bcr_test = RandomSampler(inp_bcr_dataset_test,replacement=False, num_samples=1000) # random sampler for bc right residuals
batch_size = 153
train_loader = DataLoader(inp_dataset, batch_size=batch_size) # training data loader
pde_loader = DataLoader(inp_pde_dataset, batch_size=batch_size) # pde residual data loader training
ic_loader = DataLoader(inp_ic_dataset, batch_size=batch_size) # ic residual data loader training
bcl_loader = DataLoader(inp_bcl_dataset, batch_size=batch_size) # bc left residual data loader training
bcr_loader = DataLoader(inp_bcr_dataset, batch_size=batch_size) # bc right residual data loader training


test_loader = DataLoader(inp_dataset_test, batch_size=batch_size) # testing data loader
pde_loader_test = DataLoader(inp_pde_dataset_test, batch_size=batch_size)
ic_loader_test = DataLoader(inp_ic_dataset_test, batch_size=batch_size)
bcl_loader_test = DataLoader(inp_bcl_dataset_test, batch_size=batch_size)
bcr_loader_test = DataLoader(inp_bcr_dataset_test, batch_size=batch_size)
# Out:
# MPS is available
# {'T_st': tensor(0.8567, device='mps:0'), 'T_lt': tensor(0.9469, device='mps:0'), 't_surrt': tensor(0., device='mps:0'), 'temp_init_t': tensor(1., device='mps:0'), 'die_temp_l': 0.8405797101449275, 'die_temp_r': 0.8405797101449275}

# %% [markdown]
# # Prepare the Model

# %%
input_size = 2
hidden_size = 30#  best yet is 8
output_size=1

learning_rate = 0.0001 # 0.001
hidden_layers = 3  #best yet is 4


# epochs_1 = props['epochs'] # 1000
epochs_1 =5000
epochs_2 = 100
from Model.model import PINN
from Model.selfadaploss import SelfAdaptiveLoss

model = PINN(input_size, hidden_size, output_size,hidden_layers).to(device)
adaptiveloss = SelfAdaptiveLoss()
# optimizer_1 = torch.optim.Adam(model.parameters(), lr=learning_rate)
# optimizer_2 = torch.optim.LBFGS(model.parameters(), lr=learning_rate,line_search_fn ='strong_wolfe')

optimizer_1 = torch.optim.Adam(
    list(model.parameters()) + list(adaptiveloss.parameters()), lr=learning_rate)  # Adam optimizer for training

# %% [markdown]
# # Train the model

# %%
torch.autograd.set_detect_anomaly(True)


loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
                  optimizer_1,adaptiveloss,train_loader,pde_loader, ic_loader,\
                  bcl_loader,bcr_loader,\
                  test_loader,pde_loader_test,ic_loader_test,\
                  bcl_loader_test,bcr_loader_test,\
                  temp_var)

# loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#                   optimizer_2,train_loader,pde_loader, ic_loader,\
#                   bcl_loader,bcr_loader,\
#                   test_loader,pde_loader_test,ic_loader_test,\
#                   bcl_loader_test,bcr_loader_test,\
#                   temp_var)
# Out:
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1,            | Training-Loss 3.9861e-03,| Test-Loss 1.8902e-03   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7150e-03,| pde-loss 3.3362e-04,| initc-loss 7.1990e-05,|bc_loss 1.3652e-05|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.5992e-05,| pde-loss-test 4.6625e-05,| initc-loss-test 2.9394e-04,|bc_loss-test 1.1845e-04|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 11,            | Training-Loss 1.3474e-05,| Test-Loss 1.6382e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1345e-06,| pde-loss 1.7942e-05,| initc-loss 3.8141e-07,|bc_loss 1.9516e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.0876e-07,| pde-loss-test 1.7461e-06,| initc-loss-test 1.3096e-06,|bc_loss-test 1.8425e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 21,            | Training-Loss 9.9143e-06,| Test-Loss 1.1994e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 3.1407e-06,| pde-loss 1.1448e-05,| initc-loss 3.1848e-07,|bc_loss 1.4194e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 2.5316e-07,| pde-loss-test 1.1360e-06,| initc-loss-test 1.1222e-06,|bc_loss-test 1.2858e-06|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 31,            | Training-Loss 9.2741e-06,| Test-Loss 1.1332e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 2.3188e-06,| pde-loss 1.9034e-05,| initc-loss 2.5101e-07,|bc_loss 1.0235e-07|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.7449e-07,| pde-loss-test 6.3632e-07,| initc-loss-test 8.9092e-07,|bc_loss-test 8.6727e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 41,            | Training-Loss 8.7796e-06,| Test-Loss 1.0817e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.8373e-06,| pde-loss 2.0367e-05,| initc-loss 2.3305e-07,|bc_loss 8.4485e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.4265e-07,| pde-loss-test 5.9270e-07,| initc-loss-test 8.1984e-07,|bc_loss-test 6.7854e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 51,            | Training-Loss 8.3773e-06,| Test-Loss 1.0447e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.5707e-06,| pde-loss 2.1804e-05,| initc-loss 2.1677e-07,|bc_loss 7.7738e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2256e-07,| pde-loss-test 5.1154e-07,| initc-loss-test 7.5840e-07,|bc_loss-test 5.6986e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 61,            | Training-Loss 7.8937e-06,| Test-Loss 1.0208e-05   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.3347e-06,| pde-loss 2.2564e-05,| initc-loss 2.0310e-07,|bc_loss 6.4751e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.1421e-07,| pde-loss-test 5.2850e-07,| initc-loss-test 7.0004e-07,|bc_loss-test 4.5224e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 71,            | Training-Loss 7.5825e-06,| Test-Loss 9.6962e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2683e-06,| pde-loss 2.4467e-05,| initc-loss 1.9053e-07,|bc_loss 6.1670e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.0395e-07,| pde-loss-test 4.9243e-07,| initc-loss-test 6.5273e-07,|bc_loss-test 4.1895e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 81,            | Training-Loss 7.1746e-06,| Test-Loss 9.0578e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2492e-06,| pde-loss 2.5352e-05,| initc-loss 1.8284e-07,|bc_loss 5.5410e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.7773e-08,| pde-loss-test 5.0242e-07,| initc-loss-test 6.2759e-07,|bc_loss-test 3.5265e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 91,            | Training-Loss 6.7080e-06,| Test-Loss 8.4687e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2208e-06,| pde-loss 2.5906e-05,| initc-loss 1.7550e-07,|bc_loss 4.9673e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3409e-08,| pde-loss-test 5.0191e-07,| initc-loss-test 6.0492e-07,|bc_loss-test 2.9956e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 101,            | Training-Loss 6.3059e-06,| Test-Loss 7.8763e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.2018e-06,| pde-loss 2.7198e-05,| initc-loss 1.6886e-07,|bc_loss 4.4323e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.1977e-08,| pde-loss-test 5.0983e-07,| initc-loss-test 5.8293e-07,|bc_loss-test 2.5799e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 111,            | Training-Loss 5.8463e-06,| Test-Loss 7.2701e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1940e-06,| pde-loss 2.7794e-05,| initc-loss 1.6394e-07,|bc_loss 4.0866e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.0403e-08,| pde-loss-test 5.0367e-07,| initc-loss-test 5.6694e-07,|bc_loss-test 2.3268e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 121,            | Training-Loss 5.3543e-06,| Test-Loss 6.6721e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1875e-06,| pde-loss 2.8042e-05,| initc-loss 1.5856e-07,|bc_loss 3.7563e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.8395e-08,| pde-loss-test 4.8381e-07,| initc-loss-test 5.4919e-07,|bc_loss-test 2.1080e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 131,            | Training-Loss 4.8614e-06,| Test-Loss 6.0966e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1780e-06,| pde-loss 2.8051e-05,| initc-loss 1.5356e-07,|bc_loss 3.4644e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6157e-08,| pde-loss-test 4.5603e-07,| initc-loss-test 5.3325e-07,|bc_loss-test 1.9599e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 141,            | Training-Loss 4.3906e-06,| Test-Loss 5.4924e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1744e-06,| pde-loss 2.7823e-05,| initc-loss 1.4907e-07,|bc_loss 3.2231e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.6663e-08,| pde-loss-test 4.3537e-07,| initc-loss-test 5.2060e-07,|bc_loss-test 1.8177e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 151,            | Training-Loss 3.9807e-06,| Test-Loss 4.8448e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1563e-06,| pde-loss 2.7473e-05,| initc-loss 1.4696e-07,|bc_loss 3.0656e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.9146e-08,| pde-loss-test 3.8566e-07,| initc-loss-test 5.1931e-07,|bc_loss-test 1.6456e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 161,            | Training-Loss 3.5873e-06,| Test-Loss 4.3656e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1533e-06,| pde-loss 2.6973e-05,| initc-loss 1.4367e-07,|bc_loss 2.9221e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.9028e-08,| pde-loss-test 3.5692e-07,| initc-loss-test 5.1117e-07,|bc_loss-test 1.5970e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 171,            | Training-Loss 3.2386e-06,| Test-Loss 3.7627e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1563e-06,| pde-loss 2.6292e-05,| initc-loss 1.4328e-07,|bc_loss 2.8222e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.2813e-08,| pde-loss-test 3.3054e-07,| initc-loss-test 5.1358e-07,|bc_loss-test 1.5572e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 181,            | Training-Loss 2.9057e-06,| Test-Loss 3.3436e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1504e-06,| pde-loss 2.5455e-05,| initc-loss 1.4080e-07,|bc_loss 2.7202e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.0391e-08,| pde-loss-test 2.9683e-07,| initc-loss-test 5.0849e-07,|bc_loss-test 1.5653e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 191,            | Training-Loss 2.5603e-06,| Test-Loss 2.9622e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1278e-06,| pde-loss 2.4059e-05,| initc-loss 1.3618e-07,|bc_loss 2.5391e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.3061e-08,| pde-loss-test 2.5942e-07,| initc-loss-test 4.9811e-07,|bc_loss-test 1.5453e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 201,            | Training-Loss 2.2378e-06,| Test-Loss 2.5336e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0994e-06,| pde-loss 2.2693e-05,| initc-loss 1.3062e-07,|bc_loss 2.2933e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0100e-08,| pde-loss-test 2.4006e-07,| initc-loss-test 4.8841e-07,|bc_loss-test 1.4596e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 211,            | Training-Loss 1.9555e-06,| Test-Loss 2.1520e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0419e-06,| pde-loss 2.1523e-05,| initc-loss 1.2903e-07,|bc_loss 2.2717e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.9244e-08,| pde-loss-test 2.0280e-07,| initc-loss-test 4.8993e-07,|bc_loss-test 1.5658e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 221,            | Training-Loss 1.7826e-06,| Test-Loss 2.0859e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0904e-06,| pde-loss 2.1854e-05,| initc-loss 1.2398e-07,|bc_loss 2.1779e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1605e-08,| pde-loss-test 1.8503e-07,| initc-loss-test 4.7512e-07,|bc_loss-test 1.6376e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 231,            | Training-Loss 1.6137e-06,| Test-Loss 1.8700e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1627e-06,| pde-loss 2.1907e-05,| initc-loss 1.2241e-07,|bc_loss 2.0118e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2492e-08,| pde-loss-test 1.8615e-07,| initc-loss-test 4.7427e-07,|bc_loss-test 1.5521e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 241,            | Training-Loss 1.4685e-06,| Test-Loss 1.7165e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1729e-06,| pde-loss 2.1645e-05,| initc-loss 1.2015e-07,|bc_loss 1.9203e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2729e-08,| pde-loss-test 1.8284e-07,| initc-loss-test 4.6173e-07,|bc_loss-test 1.6999e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 251,            | Training-Loss 1.3386e-06,| Test-Loss 1.5619e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1602e-06,| pde-loss 2.1585e-05,| initc-loss 1.1533e-07,|bc_loss 1.9280e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0409e-08,| pde-loss-test 2.3738e-07,| initc-loss-test 4.4696e-07,|bc_loss-test 1.6917e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 261,            | Training-Loss 1.2034e-06,| Test-Loss 1.3885e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.1115e-06,| pde-loss 2.1151e-05,| initc-loss 1.1260e-07,|bc_loss 1.9025e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.7672e-08,| pde-loss-test 2.2303e-07,| initc-loss-test 4.3874e-07,|bc_loss-test 1.6616e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 271,            | Training-Loss 1.0955e-06,| Test-Loss 1.2498e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0908e-06,| pde-loss 2.0953e-05,| initc-loss 1.1056e-07,|bc_loss 1.9148e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.5904e-08,| pde-loss-test 2.3884e-07,| initc-loss-test 4.3274e-07,|bc_loss-test 1.7554e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 281,            | Training-Loss 9.8371e-07,| Test-Loss 1.1686e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0355e-06,| pde-loss 2.0412e-05,| initc-loss 1.0793e-07,|bc_loss 1.9571e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4930e-08,| pde-loss-test 2.3573e-07,| initc-loss-test 4.2504e-07,|bc_loss-test 1.8862e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 291,            | Training-Loss 8.7744e-07,| Test-Loss 1.2129e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0146e-06,| pde-loss 1.9862e-05,| initc-loss 1.0484e-07,|bc_loss 1.9782e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.3950e-08,| pde-loss-test 1.7809e-07,| initc-loss-test 4.1660e-07,|bc_loss-test 1.9581e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 301,            | Training-Loss 7.8923e-07,| Test-Loss 1.1201e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0092e-06,| pde-loss 1.9355e-05,| initc-loss 1.0268e-07,|bc_loss 1.9758e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.3596e-08,| pde-loss-test 1.7225e-07,| initc-loss-test 4.1081e-07,|bc_loss-test 2.0261e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 311,            | Training-Loss 7.3602e-07,| Test-Loss 1.0225e-06   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.7965e-07,| pde-loss 1.9831e-05,| initc-loss 1.0440e-07,|bc_loss 2.1193e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.7750e-08,| pde-loss-test 1.6725e-07,| initc-loss-test 4.1709e-07,|bc_loss-test 2.2647e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 321,            | Training-Loss 6.8061e-07,| Test-Loss 8.6988e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0441e-06,| pde-loss 2.0015e-05,| initc-loss 1.0740e-07,|bc_loss 1.5157e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6934e-08,| pde-loss-test 1.6400e-07,| initc-loss-test 4.3146e-07,|bc_loss-test 1.8683e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 331,            | Training-Loss 6.0558e-07,| Test-Loss 6.9372e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.8146e-07,| pde-loss 1.8861e-05,| initc-loss 1.0028e-07,|bc_loss 1.7272e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.2200e-08,| pde-loss-test 2.0966e-07,| initc-loss-test 4.0541e-07,|bc_loss-test 1.7734e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 341,            | Training-Loss 5.5092e-07,| Test-Loss 7.5813e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.8303e-07,| pde-loss 1.8535e-05,| initc-loss 9.8868e-08,|bc_loss 1.7421e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1586e-08,| pde-loss-test 1.5509e-07,| initc-loss-test 4.0196e-07,|bc_loss-test 1.8464e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 351,            | Training-Loss 5.0466e-07,| Test-Loss 6.7195e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.6362e-07,| pde-loss 1.8284e-05,| initc-loss 1.0170e-07,|bc_loss 1.7085e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1842e-08,| pde-loss-test 1.5439e-07,| initc-loss-test 4.1390e-07,|bc_loss-test 1.8595e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 361,            | Training-Loss 4.6431e-07,| Test-Loss 6.4194e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.5020e-07,| pde-loss 1.8165e-05,| initc-loss 9.9074e-08,|bc_loss 1.8154e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0938e-08,| pde-loss-test 1.4820e-07,| initc-loss-test 4.0480e-07,|bc_loss-test 1.9075e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 371,            | Training-Loss 4.2205e-07,| Test-Loss 5.9013e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.0836e-07,| pde-loss 1.7688e-05,| initc-loss 9.9503e-08,|bc_loss 1.8231e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1081e-08,| pde-loss-test 1.4688e-07,| initc-loss-test 4.0650e-07,|bc_loss-test 1.9365e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 381,            | Training-Loss 3.8904e-07,| Test-Loss 5.4931e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.2223e-07,| pde-loss 1.7465e-05,| initc-loss 1.0039e-07,|bc_loss 1.8874e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.5838e-08,| pde-loss-test 1.4349e-07,| initc-loss-test 4.0988e-07,|bc_loss-test 2.1515e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 391,            | Training-Loss 3.5153e-07,| Test-Loss 5.0414e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5305e-07,| pde-loss 1.6855e-05,| initc-loss 1.0103e-07,|bc_loss 1.8778e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.6094e-08,| pde-loss-test 1.4039e-07,| initc-loss-test 4.1298e-07,|bc_loss-test 2.1617e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 401,            | Training-Loss 3.2308e-07,| Test-Loss 4.6334e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5062e-07,| pde-loss 1.6596e-05,| initc-loss 1.0209e-07,|bc_loss 1.8929e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7045e-08,| pde-loss-test 1.3850e-07,| initc-loss-test 4.1674e-07,|bc_loss-test 2.1853e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 411,            | Training-Loss 2.9672e-07,| Test-Loss 4.2630e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.6849e-07,| pde-loss 1.6336e-05,| initc-loss 1.0264e-07,|bc_loss 1.9240e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8417e-08,| pde-loss-test 1.3796e-07,| initc-loss-test 4.1865e-07,|bc_loss-test 2.2158e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 421,            | Training-Loss 2.7638e-07,| Test-Loss 3.9070e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 9.0818e-07,| pde-loss 1.6290e-05,| initc-loss 1.0489e-07,|bc_loss 1.8508e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8571e-08,| pde-loss-test 1.4135e-07,| initc-loss-test 4.2595e-07,|bc_loss-test 2.2150e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 431,            | Training-Loss 2.5367e-07,| Test-Loss 3.5619e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8624e-07,| pde-loss 1.5966e-05,| initc-loss 1.0680e-07,|bc_loss 1.8422e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8777e-08,| pde-loss-test 1.4011e-07,| initc-loss-test 4.3262e-07,|bc_loss-test 2.2157e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 441,            | Training-Loss 2.3256e-07,| Test-Loss 3.2576e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8463e-07,| pde-loss 1.5611e-05,| initc-loss 1.0874e-07,|bc_loss 1.8044e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8095e-08,| pde-loss-test 1.4037e-07,| initc-loss-test 4.3932e-07,|bc_loss-test 2.1662e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 451,            | Training-Loss 2.1366e-07,| Test-Loss 2.9350e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7079e-07,| pde-loss 1.5334e-05,| initc-loss 1.1052e-07,|bc_loss 1.7817e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.7971e-08,| pde-loss-test 1.3928e-07,| initc-loss-test 4.4499e-07,|bc_loss-test 2.1413e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 461,            | Training-Loss 1.9610e-07,| Test-Loss 2.6933e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.8133e-07,| pde-loss 1.5005e-05,| initc-loss 1.1242e-07,|bc_loss 1.7880e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8401e-08,| pde-loss-test 1.3751e-07,| initc-loss-test 4.5155e-07,|bc_loss-test 2.1293e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 471,            | Training-Loss 1.7854e-07,| Test-Loss 2.6039e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5832e-07,| pde-loss 1.4671e-05,| initc-loss 1.1193e-07,|bc_loss 1.8063e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4731e-08,| pde-loss-test 1.2938e-07,| initc-loss-test 4.5086e-07,|bc_loss-test 2.2433e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 481,            | Training-Loss 1.6401e-07,| Test-Loss 2.3686e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.7588e-07,| pde-loss 1.4349e-05,| initc-loss 1.1426e-07,|bc_loss 1.7746e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4560e-08,| pde-loss-test 1.2903e-07,| initc-loss-test 4.5836e-07,|bc_loss-test 2.2046e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 491,            | Training-Loss 1.5083e-07,| Test-Loss 2.1640e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.6271e-07,| pde-loss 1.4048e-05,| initc-loss 1.1669e-07,|bc_loss 1.7595e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2824e-08,| pde-loss-test 1.3081e-07,| initc-loss-test 4.6671e-07,|bc_loss-test 2.1340e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 501,            | Training-Loss 1.3853e-07,| Test-Loss 1.9928e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.4207e-07,| pde-loss 1.3818e-05,| initc-loss 1.1886e-07,|bc_loss 1.7613e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4211e-08,| pde-loss-test 1.3015e-07,| initc-loss-test 4.7571e-07,|bc_loss-test 2.1296e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 511,            | Training-Loss 1.2661e-07,| Test-Loss 1.8810e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5698e-07,| pde-loss 1.3358e-05,| initc-loss 1.1904e-07,|bc_loss 1.9413e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2189e-08,| pde-loss-test 1.2996e-07,| initc-loss-test 4.7494e-07,|bc_loss-test 2.2689e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 521,            | Training-Loss 1.1492e-07,| Test-Loss 1.6900e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4632e-07,| pde-loss 1.2965e-05,| initc-loss 1.2254e-07,|bc_loss 1.8297e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.9060e-08,| pde-loss-test 1.2376e-07,| initc-loss-test 4.9106e-07,|bc_loss-test 2.1308e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 531,            | Training-Loss 1.0606e-07,| Test-Loss 1.4965e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.6838e-07,| pde-loss 1.2768e-05,| initc-loss 1.2429e-07,|bc_loss 1.7486e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.2404e-08,| pde-loss-test 1.2911e-07,| initc-loss-test 4.9609e-07,|bc_loss-test 1.9193e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 541,            | Training-Loss 9.6110e-08,| Test-Loss 1.4268e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1642e-07,| pde-loss 1.2279e-05,| initc-loss 1.2622e-07,|bc_loss 1.7904e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0033e-08,| pde-loss-test 1.2858e-07,| initc-loss-test 5.0377e-07,|bc_loss-test 2.0004e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 551,            | Training-Loss 8.7085e-08,| Test-Loss 1.2946e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1639e-07,| pde-loss 1.1820e-05,| initc-loss 1.2811e-07,|bc_loss 1.6723e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.4126e-08,| pde-loss-test 1.3474e-07,| initc-loss-test 5.1303e-07,|bc_loss-test 1.8515e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 561,            | Training-Loss 8.4026e-08,| Test-Loss 9.2940e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.3753e-07,| pde-loss 1.2172e-05,| initc-loss 1.3072e-07,|bc_loss 2.0358e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1726e-08,| pde-loss-test 1.3384e-07,| initc-loss-test 5.1601e-07,|bc_loss-test 2.0109e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 571,            | Training-Loss 7.2821e-08,| Test-Loss 1.1048e-07   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7129e-07,| pde-loss 1.1056e-05,| initc-loss 1.3201e-07,|bc_loss 1.7468e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.1093e-08,| pde-loss-test 1.2947e-07,| initc-loss-test 5.2646e-07,|bc_loss-test 1.9177e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 581,            | Training-Loss 6.7396e-08,| Test-Loss 7.0816e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7769e-07,| pde-loss 1.0916e-05,| initc-loss 1.3735e-07,|bc_loss 1.7344e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8212e-08,| pde-loss-test 1.4093e-07,| initc-loss-test 5.4108e-07,|bc_loss-test 1.6822e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 591,            | Training-Loss 6.1774e-08,| Test-Loss 7.0759e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7416e-07,| pde-loss 1.0679e-05,| initc-loss 1.3700e-07,|bc_loss 1.8201e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 7.1817e-08,| pde-loss-test 1.3605e-07,| initc-loss-test 5.4594e-07,|bc_loss-test 1.6836e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 601,            | Training-Loss 5.8746e-08,| Test-Loss 9.7381e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.4411e-07,| pde-loss 1.0772e-05,| initc-loss 1.3402e-07,|bc_loss 2.4268e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.0723e-08,| pde-loss-test 1.1865e-07,| initc-loss-test 5.3640e-07,|bc_loss-test 1.8710e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 611,            | Training-Loss 5.3924e-08,| Test-Loss 8.8954e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3531e-07,| pde-loss 1.0493e-05,| initc-loss 1.3722e-07,|bc_loss 2.4719e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.3355e-08,| pde-loss-test 1.1550e-07,| initc-loss-test 5.4947e-07,|bc_loss-test 1.9175e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 621,            | Training-Loss 4.7618e-08,| Test-Loss 6.1392e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.0816e-07,| pde-loss 9.6695e-06,| initc-loss 1.3356e-07,|bc_loss 2.3221e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.2829e-08,| pde-loss-test 1.2161e-07,| initc-loss-test 5.2393e-07,|bc_loss-test 1.8014e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 631,            | Training-Loss 4.3030e-08,| Test-Loss 4.3533e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.0420e-07,| pde-loss 9.3651e-06,| initc-loss 1.4706e-07,|bc_loss 1.7426e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1330e-08,| pde-loss-test 1.4384e-07,| initc-loss-test 5.7720e-07,|bc_loss-test 1.4790e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 641,            | Training-Loss 4.1177e-08,| Test-Loss 6.6954e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9814e-07,| pde-loss 9.5958e-06,| initc-loss 1.4254e-07,|bc_loss 2.5925e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 9.8353e-08,| pde-loss-test 1.1754e-07,| initc-loss-test 5.6815e-07,|bc_loss-test 1.9772e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 651,            | Training-Loss 3.4218e-08,| Test-Loss 3.4153e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 5.8284e-07,| pde-loss 8.1921e-06,| initc-loss 1.5059e-07,|bc_loss 1.5156e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.1793e-08,| pde-loss-test 1.5133e-07,| initc-loss-test 5.9707e-07,|bc_loss-test 1.1694e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 661,            | Training-Loss 3.2596e-08,| Test-Loss 3.3186e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1933e-07,| pde-loss 8.4554e-06,| initc-loss 1.4140e-07,|bc_loss 1.8987e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9640e-08,| pde-loss-test 1.3619e-07,| initc-loss-test 5.5654e-07,|bc_loss-test 1.3491e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 671,            | Training-Loss 2.9231e-08,| Test-Loss 2.8331e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4891e-07,| pde-loss 7.8133e-06,| initc-loss 1.4382e-07,|bc_loss 1.8675e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.6620e-08,| pde-loss-test 1.3785e-07,| initc-loss-test 5.6597e-07,|bc_loss-test 1.3337e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 681,            | Training-Loss 2.6641e-08,| Test-Loss 2.5603e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4163e-07,| pde-loss 7.5147e-06,| initc-loss 1.4534e-07,|bc_loss 1.9266e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.7828e-08,| pde-loss-test 1.3862e-07,| initc-loss-test 5.7129e-07,|bc_loss-test 1.3706e-07|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 691,            | Training-Loss 2.5861e-08,| Test-Loss 3.4512e-08   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.8939e-07,| pde-loss 7.8436e-06,| initc-loss 1.4187e-07,|bc_loss 2.9055e-08|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 1.2520e-07,| pde-loss-test 1.3121e-07,| initc-loss-test 5.5807e-07,|bc_loss-test 2.3615e-07|
# ...
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.4682e-08,| pde-loss-test 4.6539e-08,| initc-loss-test 1.2600e-06,|bc_loss-test 3.9170e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1531,            | Training-Loss 1.5637e-10,| Test-Loss 1.7598e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2055e-07,| pde-loss 6.1935e-07,| initc-loss 2.4969e-07,|bc_loss 5.5024e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.3072e-08,| pde-loss-test 2.5426e-08,| initc-loss-test 9.9417e-07,|bc_loss-test 5.0430e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1541,            | Training-Loss 1.5614e-10,| Test-Loss 1.7878e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1476e-07,| pde-loss 5.6183e-07,| initc-loss 2.9561e-07,|bc_loss 5.1264e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1074e-08,| pde-loss-test 4.1408e-08,| initc-loss-test 1.1903e-06,|bc_loss-test 4.1789e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1551,            | Training-Loss 1.5118e-10,| Test-Loss 1.7150e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6512e-07,| pde-loss 5.8669e-07,| initc-loss 2.7668e-07,|bc_loss 5.2521e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.7226e-08,| pde-loss-test 3.9574e-08,| initc-loss-test 1.1150e-06,|bc_loss-test 4.3741e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1561,            | Training-Loss 1.5162e-10,| Test-Loss 1.7094e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.3409e-07,| pde-loss 5.6691e-07,| initc-loss 2.8860e-07,|bc_loss 4.7762e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9360e-08,| pde-loss-test 4.0706e-08,| initc-loss-test 1.1635e-06,|bc_loss-test 3.7846e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1571,            | Training-Loss 1.4334e-10,| Test-Loss 1.6391e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4219e-07,| pde-loss 5.8215e-07,| initc-loss 2.7349e-07,|bc_loss 4.9724e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.6592e-08,| pde-loss-test 3.8278e-08,| initc-loss-test 1.1047e-06,|bc_loss-test 4.0433e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1581,            | Training-Loss 3.5540e-10,| Test-Loss 1.8873e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 1.0208e-06,| pde-loss 2.1810e-06,| initc-loss 3.3492e-07,|bc_loss 6.6302e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 8.0022e-08,| pde-loss-test 6.3164e-08,| initc-loss-test 1.3657e-06,|bc_loss-test 4.4183e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1591,            | Training-Loss 1.3808e-10,| Test-Loss 1.5902e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.2814e-07,| pde-loss 6.0877e-07,| initc-loss 2.5472e-07,|bc_loss 4.9296e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.5311e-08,| pde-loss-test 3.7497e-08,| initc-loss-test 1.0404e-06,|bc_loss-test 3.8205e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1601,            | Training-Loss 1.3441e-10,| Test-Loss 1.5476e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.1188e-07,| pde-loss 6.0968e-07,| initc-loss 2.5065e-07,|bc_loss 4.7988e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.4000e-08,| pde-loss-test 3.6756e-08,| initc-loss-test 1.0195e-06,|bc_loss-test 3.8646e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1611,            | Training-Loss 1.3427e-10,| Test-Loss 1.5374e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.9513e-07,| pde-loss 5.8626e-07,| initc-loss 2.7220e-07,|bc_loss 4.8011e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9451e-08,| pde-loss-test 3.7491e-08,| initc-loss-test 1.1113e-06,|bc_loss-test 3.7032e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1621,            | Training-Loss 1.2915e-10,| Test-Loss 1.5075e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.4679e-07,| pde-loss 5.9039e-07,| initc-loss 2.5828e-07,|bc_loss 4.7853e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.7194e-08,| pde-loss-test 3.6115e-08,| initc-loss-test 1.0573e-06,|bc_loss-test 3.6962e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1631,            | Training-Loss 1.2772e-10,| Test-Loss 1.4791e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.6822e-07,| pde-loss 5.8261e-07,| initc-loss 2.6789e-07,|bc_loss 4.5670e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.8538e-08,| pde-loss-test 3.6642e-08,| initc-loss-test 1.0927e-06,|bc_loss-test 3.5330e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1641,            | Training-Loss 2.6579e-10,| Test-Loss 1.5045e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 8.5292e-07,| pde-loss 1.7602e-06,| initc-loss 2.9846e-07,|bc_loss 4.7506e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.8768e-08,| pde-loss-test 3.8636e-08,| initc-loss-test 1.2115e-06,|bc_loss-test 3.4503e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1651,            | Training-Loss 1.2337e-10,| Test-Loss 1.4360e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7316e-07,| pde-loss 5.8406e-07,| initc-loss 2.6669e-07,|bc_loss 4.5497e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 5.9512e-08,| pde-loss-test 3.5909e-08,| initc-loss-test 1.0952e-06,|bc_loss-test 3.3906e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1661,            | Training-Loss 1.2217e-10,| Test-Loss 1.4294e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 7.1754e-07,| pde-loss 5.8148e-07,| initc-loss 2.6827e-07,|bc_loss 4.3994e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1965e-08,| pde-loss-test 3.3430e-08,| initc-loss-test 1.0974e-06,|bc_loss-test 3.3560e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1671,            | Training-Loss 1.1902e-10,| Test-Loss 1.4117e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.7463e-07,| pde-loss 5.9349e-07,| initc-loss 2.6044e-07,|bc_loss 4.5976e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.1790e-08,| pde-loss-test 3.5244e-08,| initc-loss-test 1.0814e-06,|bc_loss-test 3.3411e-08|
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
# | Epoch 1681,            | Training-Loss 1.1709e-10,| Test-Loss 1.3591e-10   |
# ----------------------------------------------------------------------------------------------------
# | Data-loss 6.8406e-07,| pde-loss 5.9375e-07,| initc-loss 2.5406e-07,|bc_loss 4.8961e-09|
# ----------------------------------------------------------------------------------------------------
# | Data-loss-test 6.0373e-08,| pde-loss-test 3.4461e-08,| initc-loss-test 1.0568e-06,|bc_loss-test 3.5228e-08|
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 4
#       1 torch.autograd.set_detect_anomaly(True)
# ----> 4 loss_train,loss_test,best_model = training_loop(epochs_1, model, loss_fn_data, \
#       5                   optimizer_1,adaptiveloss,train_loader,pde_loader, ic_loader,\
#       6                   bcl_loader,bcr_loader,\
#       7                   test_loader,pde_loader_test,ic_loader_test,\
#       8                   bcl_loader_test,bcr_loader_test,\
#       9                   temp_var)
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofMelbourne/github/pinn-pc-1d/pinn/spartan/../Model/train_testloop_sal.py:86, in training_loop(epochs, model, loss_fn_data, optimizer, adaptiveloss, train_dataloader, train_loader_pde, train_loader_init, train_loader_bc_l, train_loader_bc_r, test_dataloader, pde_test_dataloader, ic_test_dataloader, test_bc_l_dataloader, test_bc_r_dataloader, temp_var)
#      81 bc_r_loss_t = 0
#      84 # Loop through the training data loaders
#      85 for (batch, batch_pde, batch_init, batch_left, batch_right) in \
# ---> 86      zip_longest(train_dataloader, train_loader_pde, train_loader_init, train_loader_bc_l, train_loader_bc_r):
#      87
#      88     # print(len(train_dataloader))
#      89     # print(len(train_loader_pde))
#      90     # print(len(train_loader_init))
#      91     # print(len(train_loader_bc_l))
#      92     # print(len(train_loader_bc_r))
#      93     if batch is None or batch_pde is None or batch_init is None or batch_left is None or batch_right is None:
#      94         continue  # Skip this iteration
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:212, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File /opt/anaconda3/envs/pinn/lib/python3.13/site-packages/torch/utils/data/_utils/collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %% [markdown]
# # Collect the results and store it an folder/ Visualise the results

# %%
def move_to_cpu(obj):
    """Recursively move tensors in a dictionary or list to CPU."""
    if isinstance(obj, torch.Tensor):
        return obj.cpu()
    elif isinstance(obj, list):
        return [move_to_cpu(item) for item in obj]  # Convert tensors inside lists
    elif isinstance(obj, dict):
        return {k: move_to_cpu(v) for k, v in obj.items()}  # Convert tensors inside dicts
    return obj  # Return unchanged for other types

# Ensure all tensors inside lists/dicts are on CPU
loss_train = move_to_cpu(loss_train)
loss_test = move_to_cpu(loss_test)

# %%
# plot the losses

train_loss = loss_train['train-loss']
test_loss = loss_test['test-loss']
loss_data = loss_train['data-loss']
loss_pde = loss_train['pde-loss']
loss_ic = loss_train['ic-loss']
loss_bc = loss_train['bc-loss']


plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
plt.plot(loss_pde, label='Pde Loss')
plt.plot(loss_data, label='Data Loss')
plt.plot(loss_ic, label='IC Loss')
plt.plot(loss_bc, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses')
plt.legend()
plt.yscale('log')
plt.grid()
plt.show()

# %%
inp_data = input_t
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn = model(inp_data[:,0].unsqueeze(1), inp_data[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn = invscaler(temp_nn,temp_init,t_surr) # Inverse transform the predictions
print(temp_nn)
# Out:
# [[817.3688 ]
#  [822.3665 ]
#  [827.35114]
#  ...
#  [820.0116 ]
#  [820.01965]
#  [820.02704]]

# %%
temp_d= temp_data.reshape(num_steps, numpoints) # Reshape the actual temperature data to a 2D array
temp_nn_t = temp_nn.reshape(num_steps, numpoints) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

# %%
# plot initial temperature
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(0, length, numpoints), temp_d[0,:], label='Actual Temperature')
plt.plot(np.linspace(0, length, numpoints), temp_nn_t[0,:], label='Predicted Temperature')
plt.xlabel('Distance (m)')
plt.ylabel('Temperature (K)')
plt.title('Initial Temperature Distribution')
plt.legend()
plt.grid()
plt.show()

# %%
settings_path_2 = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path_2,'r') as file:
    settings = json.load(file)


heat_data2 = HT_sim(settings)
alpha = heat_data2.alpha_l
tempfield2 = heat_data2.datagen()

heat_data2.plot_temp(25)
dt = heat_data2.dt
dx = heat_data2.dx
# print(heat_data.dx)
# print(dt)
settings_path = os.path.join(current_dir, '..', 'training_data', 'settings.json')
with open(settings_path,'r') as file:
    props = json.load(file)


temp_data2 = tempfield2.flatten()

def temp_scaler(temp_data, temp_init, t_surr):
    temp_data = (temp_data - t_surr) / (temp_init - t_surr)
    return temp_data
temp_init = props['temp_init']
t_surr = props['t_surr']
# temp_data = scaler(temp_data,400.0,919.0)

temp_data_s = temp_scaler(temp_data2, temp_init, t_surr)

print(temp_data_s.max())
# Out:
# The spatial step is 0.0003061224489795918
# The time step is 0.000330226858600583
# 0.9999180924377908

# %%
num_steps2 = tempfield2.shape[0]
numpoints2 = tempfield2.shape[1] 
inp_data2 = fdd(15e-3, time_end, numpoints2, num_steps2)

# %%
input_t2 = torch.tensor(inp_data2).float().to(device)
inp_data2 = input_t2
# inp_data = torch.tensor(input_t).float().to(device) # Convert the inputs to a tensor

# load model saved

temp_nn2 = model(inp_data2[:,0].unsqueeze(1), inp_data2[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

dx = heat_data2.dx
time_end = time_end


def invscaler(temp_nn, temp_init, t_surr):
    temp_nn = ((temp_nn * (temp_init - t_surr))) + t_surr
    return temp_nn

temp_nn2 = invscaler(temp_nn2,919.0,298.0) # Inverse transform the predictions
print(temp_nn2)
# Out:
# [[817.3688 ]
#  [817.44366]
#  [817.51855]
#  ...
#  [818.6605 ]
#  [818.66296]
#  [818.66516]]

# %%
temp_d2= temp_data2.reshape(num_steps2, numpoints2) # Reshape the actual temperature data to a 2D array
temp_nn2_t = temp_nn2.reshape(num_steps2, numpoints2) # Reshape the predictions to a 2D array

time_ss= np.linspace(0, time_end, num_steps2)
left , idx, right = 0, 24,50

fig = plt.figure(figsize=(20, 6))
ax1,ax2,ax3 = fig.subplots(1,3)
ax1.plot(time_ss, temp_nn2_t[:,left], label='Predicted Temperature')
ax1.plot(time_ss, temp_d2[:,left], label='Actual Temperature') 
ax1.set_xlabel('Time(s)')
ax1.set_ylabel('Temperature (K)')
ax1.set_title(f'Predicted vs Actual Temperature at x = {(left)*dx*1000:.2f} mm')
ax1.legend()

ax2.plot(time_ss, temp_nn2_t[:,idx-1], label='Predicted Temperature')
ax2.plot(time_ss, temp_d2[:,idx-1], label='Actual Temperature')
ax2.set_xlabel('Time(s)')
ax2.set_ylabel('Temperature (K)')
ax2.set_title(f'Predicted vs Actual Temperature at x = {(idx-1)*dx*1000:.2f} mm')
ax2.legend()

ax3.plot(time_ss, temp_nn2_t[:,right-1], label='Predicted Temperature')
ax3.plot(time_ss, temp_d2[:,right-1], label='Actual Temperature')
ax3.set_xlabel('Time(s)')
ax3.set_ylabel('Temperature (K)')
ax3.set_title(f'Predicted vs Actual Temperature at x = {(right-1)*dx*1000:.2f} mm')
ax3.legend()
plt.show()

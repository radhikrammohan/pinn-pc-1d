# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %% [markdown]
# Material :- AL 380
#
# | Sr.No | Properties  | Symbol | Value  | Unit |Range(source) |
# |:---:|:---:|:---:|:---:|:---:|:--:|
# | 1  | Liquidus Density | $\rho_{l}$  | 2300 | $kg/m^3$  |  2200-2400 (ASM handbook) |
# |  2 |  Solidus Density  |  $\rho_{s}$  | 2500  |  $kg/m^3$  | 2400-2600 (ASM handbook) |
# |  3 |  Mushy Desnity |  $\rho_{m}$  |  2400 | $kg/m^3$   |Increase linearly from liquid to solid (ASM handbook) |
# |  4 |  Liquidus Thermal Conductivity| $k_l$  |  70 | $W/m-K$  |60-80 (ASM handbook) |
# |  5 |  Solidus Thermal Conductivity | $k_s$  | 180  |  $W/m-K$ | 150-210(ASM handbook) |
# |  6 | Mushy Zone Thermal Conductivity | $k_m$  | 125  |  $W/m-K$ |Decrease linearly from liquid to solid (ASM handbook) |
# |  7 | Liquidus Specific Heat | $c_{pl}$  | 1190  | $J/kg-K$  | 1100 -1200 (ASM handbook)|
# |  8 | Solidus Specific Heat | $c_{ps}$  |  1100 |  $J/kg-K$  | 1100-1200 (ASM handbook)|
# |  9 | Mushy Zone Specific Heat |  $c_{pm}$ | 1175 | $J/kg-K$   |decrease lineraly from liquid to solid (ASM handbook)|
# |  10 | Latent Heat of Fusion | $L_{fusion}$  | 450e3  | $J/kg$ | (400-500)e3 (ASM handbook) |
# | 11 | Left Boundary Temperature |$BCT_{l}$|623 |$K$| (623-723) Nissan Data |
# |12 | Right Boundary Temperature | $BCT_{r}$|623 |$K$| (623-723) Nissan Data |
# |13| Freezing time | |60 |sec|||

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# Plot temperature history for debugging
temperature_history_1 = np.array(temperature_history)
print(temperature_history_1.shape)
time_ss= np.linspace(0, time_end, num_steps+1)
# print(time_ss.shape)
plt.figure(figsize=(10, 6))
plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.title('Temperature Distribution Over Time at x = 7.5mm') 
plt.legend()
plt.show()
# Out:
# (31470, 52)

# %%
# # Plot temperature history for debugging
# plt.figure(figsize=(10, 6))
# for i in range(0, num_steps, num_steps // 50):
#     plt.plot(np.linspace(0, length, num_points+2), temperature_history[i], label=f't={i * dt:.2f} s')

# plt.xlabel('Position (m)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time')
# # plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)
phi_history = np.array(phi_history)
# print(temperature_history.shape)
# print(phi_history)

# %%
# Assuming you have temperature_history and phi_history as lists of arrays
temperature_history = np.array(temperature_history)
phi_history = np.array(phi_history)

print(temperature_history.shape)

# Check the new shape after transposing
print("Transposed Temperature History Shape:", temperature_history.shape)
print("Transposed Phi History Shape:", phi_history.shape)

# Create a meshgrid for space and time coordinates
space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots
fig, (ax1) = plt.subplots(1, 1, figsize=(14, 6))

# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
plt.tight_layout()
plt.show()

#plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()
# Out:
# (31470, 52)
# Transposed Temperature History Shape: (31470, 52)
# Transposed Phi History Shape: (31470, 52)

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Data preparation

# %%
space = np.linspace(0, length, num_points+2)
# print(space.shape)
time = np.linspace(0, time_end, num_steps+1)
# print(time.shape)

scaler_space = StandardScaler()
scaler_time = StandardScaler()

space_tr = scaler_space.fit_transform(space.reshape(-1,1))
time_tr = scaler_time.fit_transform(time.reshape(-1,1))

# print(space_tr.shape)
# print(time_tr.shape)


# create mesh grid of space and time

space_tr, time_tr = np.meshgrid(space_tr, time_tr)
space_tr = space_tr.flatten().reshape(-1,1)
time_tr = time_tr.flatten().reshape(-1,1)
inputs = np.hstack([space_tr,time_tr]) # Concatenate the spatial and temporal inputs
inputs = torch.tensor(inputs).float().to(device) # Convert the inputs to a tensor
# print(inputs.shape)

# label/temp data
temp_tr = torch.tensor(temperature_history).float().to(device) # Convert the temperature history to a tensor
temp_inp = temp_tr.reshape(-1,1) # Reshape the temperature tensor to a column vector
# print(temp_inp.shape)



#Data Splitting

train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, \
                                                                                    test_size=0.2, random_state=42)
val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, \
                                                                        test_size=0.8, random_state=42)

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, index):
        X = self.inputs[index]
        y = self.targets[index]

        return X, y




train_dataset = TensorDataset(train_inputs, train_temp_inp) # Create the training dataset
val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs, test_temp_inp) # Create the test dataset

batch_size = 640
random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset
random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader
val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler=random_sampler_test) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size): # This is the constructor
        super(Mushydata, self).__init__()
        self.base = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, output_size)
        )
        
    def forward(self, x, t):                               # This is the forward pass
        input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network


# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data 

# # Apply Xavier initialization
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.xavier_uniform_(m.weight)
#         if m.bias is not None:
#             m.bias.data.fill_(0.01)

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 40
learning_rate = 0.004
epochs = 40000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1).to(device)

# model.apply(init_weights)

# Verify the initialization

lambda_l1 = 0.9
weight_decay = 0.6  
# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # Create the optimizer

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %%
def loss_fn_data(u_pred, u_true):
    return nn.MSELoss()(u_pred, u_true)

def l1_regularization(model, lambd):
    l1_reg = sum(param.abs().sum() for param in model.parameters())
    return l1_reg * lambd
def accuracy(y_pred, y_true):
    return torch.mean((torch.abs(y_pred - y_true) / y_true)*100)

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, val_dataloader,test_loader):
    train_losses = []  # Initialize the list to store the training losses
    val_losses = []    # Initialize the list to store the validation losses

    for epoch in range(epochs):
        model.train()                                                           # Set the model to training mode
        train_loss = 0    
        training_accuracy = 0                                                      # Initialize the training loss
        for batch in train_dataloader:
            inputs, temp_inp = batch                                                      # Get the inputs and the true values
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)             # Move the inputs and true values to the GPU
            optimizer.zero_grad()                                                       # Zero the gradients
            
            # Forward pass
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).to(device) # Get the predictions
            
            # Loss calculation
            data_loss = loss_fn_data(u_pred, temp_inp)                                  # Calculate the data loss
            l1_regularization_loss = l1_regularization(model, lambda_l1)                  # Calculate the L1 regularization loss
            loss = data_loss                                                                # Calculate the total loss
            training_accuracy += accuracy(u_pred, temp_inp)                                # Calculate the training accuracy
            # Backpropagation
            loss.backward()                                                        # Backpropagate the gradients
            
            optimizer.step()                                                                            # Update the weights
            
            train_loss += loss.item()     
                                        # Add the loss to the training set loss
                                                         # Calculate the average training accuracy
        train_losses.append(train_loss)                                                   # Append the training loss to the list of training losses
        
              
        model.eval()
        val_loss = 0                                                                                      # Initialize the validation loss
        val_accuracy = 0                                                                             # Initialize the validation accuracy

        with torch.no_grad():
            for batch in val_dataloader:                                                            # Loop through the validation dataloader
                inputs, temp_inp= batch                                                        # Get the inputs and the true values
                inputs, temp_inp= inputs.to(device), temp_inp.to(device)                                     # Move the inputs and true values to the GPU
                u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).to(device)                       # Get the predictions
                data_loss = loss_fn_data(u_pred, temp_inp)                                          # Calculate the data loss
                l1_regularization_loss = l1_regularization(model, lambda_l1)                  # Calculate the L1 regularization loss
                loss = data_loss                                                                # Calculate the total loss
                val_accuracy += accuracy(u_pred, temp_inp)                                            # Calculate the validation accuracy
                val_loss += loss.item()                                                                     # Add the loss to the validation set loss
                                                                      # Calculate the average validation accuracy
            val_losses.append(val_loss)                                                                 # Append the validation loss to the list of validation losses
                                                                        # Append the validation loss to the list of validation losses

        model.eval()
        test_loss = 0
        test_accuracy = 0
        with torch.no_grad():   
            for batch in test_loader:
                inputs, temp_inp= batch
                inputs, temp_inp= inputs.to(device), temp_inp.to(device)
                u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
                data_loss = loss_fn_data(u_pred, temp_inp)
                l1_regularization_loss = l1_regularization(model, lambda_l1)                  # Calculate the L1 regularization loss
                loss = data_loss  
                test_accuracy = accuracy(u_pred, temp_inp)
                test_loss += loss.item()
            test_losses.append(test_loss)
          

        if epoch % 10 == 0:
            print(f"Epoch {epoch}, Training-Loss {train_loss:.2e}, Validation-Loss {val_loss:.2e}, Test-Loss {test_loss:.2e}")

    return train_losses, val_losses                                                                    # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
    model.eval()
    test_loss = 0
    test_accuracy = 0
    with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss = loss_fn_data(u_pred, temp_inp)
            l1_regularization_loss = l1_regularization(model, lambda_l1)                  # Calculate the L1 regularization loss
            loss = data_loss  
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
    if epochs % 10 == 0:
        print(f"Epoch {epochs}, Test-Loss {test_loss:.2e},Test-Accuracy {test_accuracy:.2e}")    
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, val_losses = training_loop(epochs, model, loss_fn_data, optimizer,train_loader, val_loader, test_loader)  # Train the model
# Out:
# Epoch 0, Training-Loss 6.53e+05, Validation-Loss 6.52e+05, Test-Loss 6.53e+05
# Epoch 10, Training-Loss 6.51e+05, Validation-Loss 6.49e+05, Test-Loss 6.49e+05
# Epoch 20, Training-Loss 6.46e+05, Validation-Loss 6.47e+05, Test-Loss 6.50e+05
# Epoch 30, Training-Loss 6.47e+05, Validation-Loss 6.45e+05, Test-Loss 6.47e+05
# Epoch 40, Training-Loss 6.45e+05, Validation-Loss 6.46e+05, Test-Loss 6.42e+05
# Epoch 50, Training-Loss 6.40e+05, Validation-Loss 6.43e+05, Test-Loss 6.43e+05
# Epoch 60, Training-Loss 6.38e+05, Validation-Loss 6.40e+05, Test-Loss 6.37e+05
# Epoch 70, Training-Loss 6.42e+05, Validation-Loss 6.34e+05, Test-Loss 6.38e+05
# Epoch 80, Training-Loss 6.34e+05, Validation-Loss 6.34e+05, Test-Loss 6.30e+05
# Epoch 90, Training-Loss 6.27e+05, Validation-Loss 6.34e+05, Test-Loss 6.31e+05
# Epoch 100, Training-Loss 6.27e+05, Validation-Loss 6.32e+05, Test-Loss 6.35e+05
# Epoch 110, Training-Loss 6.26e+05, Validation-Loss 6.24e+05, Test-Loss 6.29e+05
# Epoch 120, Training-Loss 6.23e+05, Validation-Loss 6.23e+05, Test-Loss 6.26e+05
# Epoch 130, Training-Loss 6.21e+05, Validation-Loss 6.25e+05, Test-Loss 6.20e+05
# Epoch 140, Training-Loss 6.16e+05, Validation-Loss 6.22e+05, Test-Loss 6.23e+05
# Epoch 150, Training-Loss 6.16e+05, Validation-Loss 6.16e+05, Test-Loss 6.11e+05
# Epoch 160, Training-Loss 6.11e+05, Validation-Loss 6.12e+05, Test-Loss 6.14e+05
# Epoch 170, Training-Loss 6.14e+05, Validation-Loss 6.14e+05, Test-Loss 6.11e+05
# Epoch 180, Training-Loss 6.08e+05, Validation-Loss 6.04e+05, Test-Loss 6.11e+05
# Epoch 190, Training-Loss 6.07e+05, Validation-Loss 6.06e+05, Test-Loss 6.09e+05
# Epoch 200, Training-Loss 6.05e+05, Validation-Loss 6.01e+05, Test-Loss 6.03e+05
# Epoch 210, Training-Loss 6.01e+05, Validation-Loss 6.02e+05, Test-Loss 6.00e+05
# Epoch 220, Training-Loss 5.98e+05, Validation-Loss 5.98e+05, Test-Loss 5.98e+05
# Epoch 230, Training-Loss 5.91e+05, Validation-Loss 5.93e+05, Test-Loss 5.96e+05
# Epoch 240, Training-Loss 5.94e+05, Validation-Loss 5.93e+05, Test-Loss 5.94e+05
# Epoch 250, Training-Loss 5.91e+05, Validation-Loss 5.84e+05, Test-Loss 5.87e+05
# Epoch 260, Training-Loss 5.86e+05, Validation-Loss 5.85e+05, Test-Loss 5.84e+05
# Epoch 270, Training-Loss 5.84e+05, Validation-Loss 5.83e+05, Test-Loss 5.88e+05
# Epoch 280, Training-Loss 5.86e+05, Validation-Loss 5.83e+05, Test-Loss 5.82e+05
# Epoch 290, Training-Loss 5.83e+05, Validation-Loss 5.80e+05, Test-Loss 5.81e+05
# Epoch 300, Training-Loss 5.80e+05, Validation-Loss 5.75e+05, Test-Loss 5.74e+05
# Epoch 310, Training-Loss 5.72e+05, Validation-Loss 5.75e+05, Test-Loss 5.80e+05
# Epoch 320, Training-Loss 5.75e+05, Validation-Loss 5.73e+05, Test-Loss 5.73e+05
# Epoch 330, Training-Loss 5.69e+05, Validation-Loss 5.73e+05, Test-Loss 5.72e+05
# Epoch 340, Training-Loss 5.68e+05, Validation-Loss 5.68e+05, Test-Loss 5.69e+05
# Epoch 350, Training-Loss 5.70e+05, Validation-Loss 5.66e+05, Test-Loss 5.65e+05
# Epoch 360, Training-Loss 5.63e+05, Validation-Loss 5.64e+05, Test-Loss 5.70e+05
# Epoch 370, Training-Loss 5.64e+05, Validation-Loss 5.59e+05, Test-Loss 5.56e+05
# Epoch 380, Training-Loss 5.58e+05, Validation-Loss 5.58e+05, Test-Loss 5.62e+05
# Epoch 390, Training-Loss 5.61e+05, Validation-Loss 5.55e+05, Test-Loss 5.53e+05
# Epoch 400, Training-Loss 5.52e+05, Validation-Loss 5.57e+05, Test-Loss 5.55e+05
# Epoch 410, Training-Loss 5.48e+05, Validation-Loss 5.53e+05, Test-Loss 5.48e+05
# Epoch 420, Training-Loss 5.45e+05, Validation-Loss 5.46e+05, Test-Loss 5.49e+05
# Epoch 430, Training-Loss 5.50e+05, Validation-Loss 5.45e+05, Test-Loss 5.48e+05
# Epoch 440, Training-Loss 5.45e+05, Validation-Loss 5.43e+05, Test-Loss 5.47e+05
# Epoch 450, Training-Loss 5.42e+05, Validation-Loss 5.41e+05, Test-Loss 5.42e+05
# Epoch 460, Training-Loss 5.38e+05, Validation-Loss 5.41e+05, Test-Loss 5.37e+05
# Epoch 470, Training-Loss 5.36e+05, Validation-Loss 5.35e+05, Test-Loss 5.34e+05
# Epoch 480, Training-Loss 5.30e+05, Validation-Loss 5.32e+05, Test-Loss 5.34e+05
# Epoch 490, Training-Loss 5.32e+05, Validation-Loss 5.31e+05, Test-Loss 5.29e+05
# Epoch 500, Training-Loss 5.31e+05, Validation-Loss 5.27e+05, Test-Loss 5.32e+05
# Epoch 510, Training-Loss 5.26e+05, Validation-Loss 5.24e+05, Test-Loss 5.24e+05
# Epoch 520, Training-Loss 5.23e+05, Validation-Loss 5.25e+05, Test-Loss 5.22e+05
# Epoch 530, Training-Loss 5.20e+05, Validation-Loss 5.19e+05, Test-Loss 5.21e+05
# Epoch 540, Training-Loss 5.15e+05, Validation-Loss 5.18e+05, Test-Loss 5.16e+05
# Epoch 550, Training-Loss 5.15e+05, Validation-Loss 5.17e+05, Test-Loss 5.14e+05
# Epoch 560, Training-Loss 5.12e+05, Validation-Loss 5.15e+05, Test-Loss 5.11e+05
# Epoch 570, Training-Loss 5.09e+05, Validation-Loss 5.08e+05, Test-Loss 5.10e+05
# Epoch 580, Training-Loss 5.09e+05, Validation-Loss 5.08e+05, Test-Loss 5.07e+05
# Epoch 590, Training-Loss 5.10e+05, Validation-Loss 5.09e+05, Test-Loss 5.05e+05
# Epoch 600, Training-Loss 5.08e+05, Validation-Loss 5.03e+05, Test-Loss 5.00e+05
# Epoch 610, Training-Loss 5.02e+05, Validation-Loss 4.99e+05, Test-Loss 5.02e+05
# Epoch 620, Training-Loss 4.96e+05, Validation-Loss 4.97e+05, Test-Loss 4.99e+05
# Epoch 630, Training-Loss 4.97e+05, Validation-Loss 5.03e+05, Test-Loss 4.95e+05
# Epoch 640, Training-Loss 4.92e+05, Validation-Loss 4.97e+05, Test-Loss 4.97e+05
# Epoch 650, Training-Loss 4.94e+05, Validation-Loss 4.89e+05, Test-Loss 4.93e+05
# Epoch 660, Training-Loss 4.86e+05, Validation-Loss 4.89e+05, Test-Loss 4.91e+05
# Epoch 670, Training-Loss 4.87e+05, Validation-Loss 4.87e+05, Test-Loss 4.92e+05
# Epoch 680, Training-Loss 4.85e+05, Validation-Loss 4.81e+05, Test-Loss 4.86e+05
# Epoch 690, Training-Loss 4.83e+05, Validation-Loss 4.79e+05, Test-Loss 4.83e+05
# Epoch 700, Training-Loss 4.79e+05, Validation-Loss 4.83e+05, Test-Loss 4.80e+05
# Epoch 710, Training-Loss 4.77e+05, Validation-Loss 4.77e+05, Test-Loss 4.77e+05
# Epoch 720, Training-Loss 4.77e+05, Validation-Loss 4.76e+05, Test-Loss 4.73e+05
# Epoch 730, Training-Loss 4.77e+05, Validation-Loss 4.70e+05, Test-Loss 4.71e+05
# Epoch 740, Training-Loss 4.68e+05, Validation-Loss 4.71e+05, Test-Loss 4.71e+05
# Epoch 750, Training-Loss 4.69e+05, Validation-Loss 4.67e+05, Test-Loss 4.65e+05
# Epoch 760, Training-Loss 4.65e+05, Validation-Loss 4.66e+05, Test-Loss 4.69e+05
# Epoch 770, Training-Loss 4.67e+05, Validation-Loss 4.65e+05, Test-Loss 4.64e+05
# Epoch 780, Training-Loss 4.63e+05, Validation-Loss 4.61e+05, Test-Loss 4.63e+05
# Epoch 790, Training-Loss 4.62e+05, Validation-Loss 4.57e+05, Test-Loss 4.61e+05
# Epoch 800, Training-Loss 4.61e+05, Validation-Loss 4.57e+05, Test-Loss 4.59e+05
# Epoch 810, Training-Loss 4.60e+05, Validation-Loss 4.57e+05, Test-Loss 4.55e+05
# Epoch 820, Training-Loss 4.50e+05, Validation-Loss 4.55e+05, Test-Loss 4.52e+05
# Epoch 830, Training-Loss 4.51e+05, Validation-Loss 4.52e+05, Test-Loss 4.54e+05
# Epoch 840, Training-Loss 4.49e+05, Validation-Loss 4.51e+05, Test-Loss 4.50e+05
# Epoch 850, Training-Loss 4.52e+05, Validation-Loss 4.48e+05, Test-Loss 4.48e+05
# Epoch 860, Training-Loss 4.49e+05, Validation-Loss 4.46e+05, Test-Loss 4.41e+05
# Epoch 870, Training-Loss 4.45e+05, Validation-Loss 4.43e+05, Test-Loss 4.41e+05
# Epoch 880, Training-Loss 4.45e+05, Validation-Loss 4.43e+05, Test-Loss 4.37e+05
# Epoch 890, Training-Loss 4.42e+05, Validation-Loss 4.36e+05, Test-Loss 4.37e+05
# Epoch 900, Training-Loss 4.35e+05, Validation-Loss 4.37e+05, Test-Loss 4.38e+05
# Epoch 910, Training-Loss 4.35e+05, Validation-Loss 4.35e+05, Test-Loss 4.35e+05
# Epoch 920, Training-Loss 4.38e+05, Validation-Loss 4.32e+05, Test-Loss 4.33e+05
# Epoch 930, Training-Loss 4.30e+05, Validation-Loss 4.28e+05, Test-Loss 4.32e+05
# Epoch 940, Training-Loss 4.27e+05, Validation-Loss 4.28e+05, Test-Loss 4.30e+05
# Epoch 950, Training-Loss 4.21e+05, Validation-Loss 4.30e+05, Test-Loss 4.28e+05
# Epoch 960, Training-Loss 4.25e+05, Validation-Loss 4.25e+05, Test-Loss 4.25e+05
# Epoch 970, Training-Loss 4.24e+05, Validation-Loss 4.22e+05, Test-Loss 4.22e+05
# Epoch 980, Training-Loss 4.24e+05, Validation-Loss 4.22e+05, Test-Loss 4.22e+05
# Epoch 990, Training-Loss 4.20e+05, Validation-Loss 4.20e+05, Test-Loss 4.15e+05
# Epoch 1000, Training-Loss 4.20e+05, Validation-Loss 4.18e+05, Test-Loss 4.14e+05
# Epoch 1010, Training-Loss 4.18e+05, Validation-Loss 4.18e+05, Test-Loss 4.19e+05
# Epoch 1020, Training-Loss 4.16e+05, Validation-Loss 4.14e+05, Test-Loss 4.16e+05
# Epoch 1030, Training-Loss 4.10e+05, Validation-Loss 4.09e+05, Test-Loss 4.13e+05
# Epoch 1040, Training-Loss 4.11e+05, Validation-Loss 4.10e+05, Test-Loss 4.09e+05
# Epoch 1050, Training-Loss 4.07e+05, Validation-Loss 4.08e+05, Test-Loss 4.06e+05
# Epoch 1060, Training-Loss 4.08e+05, Validation-Loss 4.07e+05, Test-Loss 4.07e+05
# Epoch 1070, Training-Loss 4.04e+05, Validation-Loss 4.03e+05, Test-Loss 4.02e+05
# Epoch 1080, Training-Loss 4.05e+05, Validation-Loss 4.00e+05, Test-Loss 4.02e+05
# Epoch 1090, Training-Loss 4.01e+05, Validation-Loss 3.99e+05, Test-Loss 3.99e+05
# Epoch 1100, Training-Loss 3.98e+05, Validation-Loss 4.01e+05, Test-Loss 3.98e+05
# Epoch 1110, Training-Loss 3.94e+05, Validation-Loss 3.96e+05, Test-Loss 3.97e+05
# Epoch 1120, Training-Loss 3.95e+05, Validation-Loss 3.98e+05, Test-Loss 3.96e+05
# Epoch 1130, Training-Loss 3.91e+05, Validation-Loss 3.91e+05, Test-Loss 3.94e+05
# Epoch 1140, Training-Loss 3.91e+05, Validation-Loss 3.90e+05, Test-Loss 3.90e+05
# Epoch 1150, Training-Loss 3.91e+05, Validation-Loss 3.91e+05, Test-Loss 3.86e+05
# Epoch 1160, Training-Loss 3.90e+05, Validation-Loss 3.88e+05, Test-Loss 3.85e+05
# Epoch 1170, Training-Loss 3.85e+05, Validation-Loss 3.85e+05, Test-Loss 3.84e+05
# Epoch 1180, Training-Loss 3.84e+05, Validation-Loss 3.82e+05, Test-Loss 3.81e+05
# Epoch 1190, Training-Loss 3.81e+05, Validation-Loss 3.80e+05, Test-Loss 3.86e+05
# Epoch 1200, Training-Loss 3.78e+05, Validation-Loss 3.80e+05, Test-Loss 3.84e+05
# Epoch 1210, Training-Loss 3.77e+05, Validation-Loss 3.78e+05, Test-Loss 3.78e+05
# Epoch 1220, Training-Loss 3.81e+05, Validation-Loss 3.72e+05, Test-Loss 3.78e+05
# Epoch 1230, Training-Loss 3.71e+05, Validation-Loss 3.73e+05, Test-Loss 3.75e+05
# Epoch 1240, Training-Loss 3.73e+05, Validation-Loss 3.73e+05, Test-Loss 3.70e+05
# Epoch 1250, Training-Loss 3.73e+05, Validation-Loss 3.70e+05, Test-Loss 3.69e+05
# Epoch 1260, Training-Loss 3.69e+05, Validation-Loss 3.66e+05, Test-Loss 3.69e+05
# Epoch 1270, Training-Loss 3.66e+05, Validation-Loss 3.67e+05, Test-Loss 3.67e+05
# Epoch 1280, Training-Loss 3.67e+05, Validation-Loss 3.68e+05, Test-Loss 3.61e+05
# Epoch 1290, Training-Loss 3.64e+05, Validation-Loss 3.64e+05, Test-Loss 3.62e+05
# Epoch 1300, Training-Loss 3.63e+05, Validation-Loss 3.63e+05, Test-Loss 3.58e+05
# Epoch 1310, Training-Loss 3.59e+05, Validation-Loss 3.58e+05, Test-Loss 3.59e+05
# Epoch 1320, Training-Loss 3.59e+05, Validation-Loss 3.58e+05, Test-Loss 3.59e+05
# Epoch 1330, Training-Loss 3.60e+05, Validation-Loss 3.56e+05, Test-Loss 3.56e+05
# Epoch 1340, Training-Loss 3.57e+05, Validation-Loss 3.53e+05, Test-Loss 3.54e+05
# Epoch 1350, Training-Loss 3.58e+05, Validation-Loss 3.52e+05, Test-Loss 3.54e+05
# Epoch 1360, Training-Loss 3.51e+05, Validation-Loss 3.50e+05, Test-Loss 3.49e+05
# Epoch 1370, Training-Loss 3.49e+05, Validation-Loss 3.50e+05, Test-Loss 3.51e+05
# Epoch 1380, Training-Loss 3.49e+05, Validation-Loss 3.47e+05, Test-Loss 3.45e+05
# Epoch 1390, Training-Loss 3.41e+05, Validation-Loss 3.44e+05, Test-Loss 3.45e+05
# Epoch 1400, Training-Loss 3.46e+05, Validation-Loss 3.45e+05, Test-Loss 3.42e+05
# Epoch 1410, Training-Loss 3.44e+05, Validation-Loss 3.41e+05, Test-Loss 3.43e+05
# Epoch 1420, Training-Loss 3.41e+05, Validation-Loss 3.41e+05, Test-Loss 3.38e+05
# Epoch 1430, Training-Loss 3.39e+05, Validation-Loss 3.39e+05, Test-Loss 3.37e+05
# Epoch 1440, Training-Loss 3.36e+05, Validation-Loss 3.37e+05, Test-Loss 3.35e+05
# Epoch 1450, Training-Loss 3.36e+05, Validation-Loss 3.36e+05, Test-Loss 3.36e+05
# Epoch 1460, Training-Loss 3.35e+05, Validation-Loss 3.35e+05, Test-Loss 3.34e+05
# Epoch 1470, Training-Loss 3.33e+05, Validation-Loss 3.30e+05, Test-Loss 3.33e+05
# Epoch 1480, Training-Loss 3.32e+05, Validation-Loss 3.30e+05, Test-Loss 3.33e+05
# Epoch 1490, Training-Loss 3.34e+05, Validation-Loss 3.31e+05, Test-Loss 3.27e+05
# Epoch 1500, Training-Loss 3.27e+05, Validation-Loss 3.29e+05, Test-Loss 3.26e+05
# Epoch 1510, Training-Loss 3.30e+05, Validation-Loss 3.26e+05, Test-Loss 3.20e+05
# Epoch 1520, Training-Loss 3.27e+05, Validation-Loss 3.23e+05, Test-Loss 3.22e+05
# Epoch 1530, Training-Loss 3.20e+05, Validation-Loss 3.24e+05, Test-Loss 3.25e+05
# Epoch 1540, Training-Loss 3.23e+05, Validation-Loss 3.23e+05, Test-Loss 3.18e+05
# Epoch 1550, Training-Loss 3.19e+05, Validation-Loss 3.18e+05, Test-Loss 3.21e+05
# Epoch 1560, Training-Loss 3.19e+05, Validation-Loss 3.18e+05, Test-Loss 3.22e+05
# Epoch 1570, Training-Loss 3.17e+05, Validation-Loss 3.16e+05, Test-Loss 3.15e+05
# Epoch 1580, Training-Loss 3.15e+05, Validation-Loss 3.13e+05, Test-Loss 3.15e+05
# Epoch 1590, Training-Loss 3.12e+05, Validation-Loss 3.12e+05, Test-Loss 3.08e+05
# Epoch 1600, Training-Loss 3.10e+05, Validation-Loss 3.11e+05, Test-Loss 3.11e+05
# Epoch 1610, Training-Loss 3.09e+05, Validation-Loss 3.10e+05, Test-Loss 3.09e+05
# Epoch 1620, Training-Loss 3.09e+05, Validation-Loss 3.08e+05, Test-Loss 3.09e+05
# Epoch 1630, Training-Loss 3.07e+05, Validation-Loss 3.08e+05, Test-Loss 3.08e+05
# Epoch 1640, Training-Loss 3.06e+05, Validation-Loss 3.06e+05, Test-Loss 3.03e+05
# Epoch 1650, Training-Loss 3.04e+05, Validation-Loss 3.03e+05, Test-Loss 3.07e+05
# Epoch 1660, Training-Loss 3.01e+05, Validation-Loss 3.03e+05, Test-Loss 3.02e+05
# Epoch 1670, Training-Loss 3.01e+05, Validation-Loss 2.99e+05, Test-Loss 3.02e+05
# Epoch 1680, Training-Loss 2.99e+05, Validation-Loss 2.99e+05, Test-Loss 3.00e+05
# Epoch 1690, Training-Loss 2.96e+05, Validation-Loss 2.97e+05, Test-Loss 2.94e+05
# Epoch 1700, Training-Loss 2.97e+05, Validation-Loss 2.94e+05, Test-Loss 2.96e+05
# Epoch 1710, Training-Loss 2.95e+05, Validation-Loss 2.93e+05, Test-Loss 2.92e+05
# Epoch 1720, Training-Loss 2.94e+05, Validation-Loss 2.91e+05, Test-Loss 2.91e+05
# Epoch 1730, Training-Loss 2.89e+05, Validation-Loss 2.89e+05, Test-Loss 2.92e+05
# Epoch 1740, Training-Loss 2.89e+05, Validation-Loss 2.90e+05, Test-Loss 2.89e+05
# Epoch 1750, Training-Loss 2.88e+05, Validation-Loss 2.89e+05, Test-Loss 2.87e+05
# Epoch 1760, Training-Loss 2.86e+05, Validation-Loss 2.86e+05, Test-Loss 2.85e+05
# Epoch 1770, Training-Loss 2.86e+05, Validation-Loss 2.83e+05, Test-Loss 2.85e+05
# Epoch 1780, Training-Loss 2.84e+05, Validation-Loss 2.80e+05, Test-Loss 2.88e+05
# Epoch 1790, Training-Loss 2.82e+05, Validation-Loss 2.83e+05, Test-Loss 2.83e+05
# Epoch 1800, Training-Loss 2.82e+05, Validation-Loss 2.80e+05, Test-Loss 2.80e+05
# Epoch 1810, Training-Loss 2.79e+05, Validation-Loss 2.80e+05, Test-Loss 2.80e+05
# Epoch 1820, Training-Loss 2.76e+05, Validation-Loss 2.79e+05, Test-Loss 2.77e+05
# Epoch 1830, Training-Loss 2.79e+05, Validation-Loss 2.73e+05, Test-Loss 2.80e+05
# Epoch 1840, Training-Loss 2.76e+05, Validation-Loss 2.74e+05, Test-Loss 2.74e+05
# Epoch 1850, Training-Loss 2.76e+05, Validation-Loss 2.74e+05, Test-Loss 2.72e+05
# Epoch 1860, Training-Loss 2.70e+05, Validation-Loss 2.72e+05, Test-Loss 2.73e+05
# Epoch 1870, Training-Loss 2.69e+05, Validation-Loss 2.66e+05, Test-Loss 2.69e+05
# Epoch 1880, Training-Loss 2.67e+05, Validation-Loss 2.68e+05, Test-Loss 2.68e+05
# Epoch 1890, Training-Loss 2.68e+05, Validation-Loss 2.69e+05, Test-Loss 2.68e+05
# Epoch 1900, Training-Loss 2.64e+05, Validation-Loss 2.67e+05, Test-Loss 2.67e+05
# Epoch 1910, Training-Loss 2.64e+05, Validation-Loss 2.65e+05, Test-Loss 2.64e+05
# Epoch 1920, Training-Loss 2.62e+05, Validation-Loss 2.64e+05, Test-Loss 2.63e+05
# Epoch 1930, Training-Loss 2.61e+05, Validation-Loss 2.61e+05, Test-Loss 2.62e+05
# Epoch 1940, Training-Loss 2.62e+05, Validation-Loss 2.60e+05, Test-Loss 2.58e+05
# Epoch 1950, Training-Loss 2.61e+05, Validation-Loss 2.58e+05, Test-Loss 2.58e+05
# Epoch 1960, Training-Loss 2.57e+05, Validation-Loss 2.60e+05, Test-Loss 2.55e+05
# Epoch 1970, Training-Loss 2.57e+05, Validation-Loss 2.58e+05, Test-Loss 2.59e+05
# Epoch 1980, Training-Loss 2.56e+05, Validation-Loss 2.51e+05, Test-Loss 2.53e+05
# Epoch 1990, Training-Loss 2.54e+05, Validation-Loss 2.56e+05, Test-Loss 2.56e+05
# Epoch 2000, Training-Loss 2.51e+05, Validation-Loss 2.50e+05, Test-Loss 2.53e+05
# Epoch 2010, Training-Loss 2.49e+05, Validation-Loss 2.51e+05, Test-Loss 2.50e+05
# Epoch 2020, Training-Loss 2.50e+05, Validation-Loss 2.50e+05, Test-Loss 2.50e+05
# Epoch 2030, Training-Loss 2.52e+05, Validation-Loss 2.47e+05, Test-Loss 2.48e+05
# Epoch 2040, Training-Loss 2.46e+05, Validation-Loss 2.46e+05, Test-Loss 2.49e+05
# Epoch 2050, Training-Loss 2.47e+05, Validation-Loss 2.44e+05, Test-Loss 2.42e+05
# Epoch 2060, Training-Loss 2.42e+05, Validation-Loss 2.43e+05, Test-Loss 2.46e+05
# Epoch 2070, Training-Loss 2.41e+05, Validation-Loss 2.41e+05, Test-Loss 2.44e+05
# Epoch 2080, Training-Loss 2.42e+05, Validation-Loss 2.43e+05, Test-Loss 2.41e+05
# Epoch 2090, Training-Loss 2.40e+05, Validation-Loss 2.41e+05, Test-Loss 2.39e+05
# Epoch 2100, Training-Loss 2.38e+05, Validation-Loss 2.37e+05, Test-Loss 2.40e+05
# Epoch 2110, Training-Loss 2.40e+05, Validation-Loss 2.39e+05, Test-Loss 2.37e+05
# Epoch 2120, Training-Loss 2.35e+05, Validation-Loss 2.33e+05, Test-Loss 2.38e+05
# Epoch 2130, Training-Loss 2.34e+05, Validation-Loss 2.33e+05, Test-Loss 2.37e+05
# Epoch 2140, Training-Loss 2.35e+05, Validation-Loss 2.34e+05, Test-Loss 2.35e+05
# Epoch 2150, Training-Loss 2.35e+05, Validation-Loss 2.30e+05, Test-Loss 2.32e+05
# Epoch 2160, Training-Loss 2.31e+05, Validation-Loss 2.28e+05, Test-Loss 2.30e+05
# Epoch 2170, Training-Loss 2.30e+05, Validation-Loss 2.32e+05, Test-Loss 2.30e+05
# Epoch 2180, Training-Loss 2.28e+05, Validation-Loss 2.30e+05, Test-Loss 2.28e+05
# Epoch 2190, Training-Loss 2.27e+05, Validation-Loss 2.26e+05, Test-Loss 2.24e+05
# Epoch 2200, Training-Loss 2.27e+05, Validation-Loss 2.23e+05, Test-Loss 2.23e+05
# Epoch 2210, Training-Loss 2.26e+05, Validation-Loss 2.23e+05, Test-Loss 2.24e+05
# Epoch 2220, Training-Loss 2.26e+05, Validation-Loss 2.24e+05, Test-Loss 2.25e+05
# Epoch 2230, Training-Loss 2.23e+05, Validation-Loss 2.23e+05, Test-Loss 2.24e+05
# Epoch 2240, Training-Loss 2.19e+05, Validation-Loss 2.21e+05, Test-Loss 2.23e+05
# Epoch 2250, Training-Loss 2.21e+05, Validation-Loss 2.20e+05, Test-Loss 2.21e+05
# Epoch 2260, Training-Loss 2.18e+05, Validation-Loss 2.18e+05, Test-Loss 2.19e+05
# Epoch 2270, Training-Loss 2.17e+05, Validation-Loss 2.16e+05, Test-Loss 2.17e+05
# Epoch 2280, Training-Loss 2.15e+05, Validation-Loss 2.14e+05, Test-Loss 2.18e+05
# Epoch 2290, Training-Loss 2.15e+05, Validation-Loss 2.16e+05, Test-Loss 2.16e+05
# Epoch 2300, Training-Loss 2.14e+05, Validation-Loss 2.11e+05, Test-Loss 2.12e+05
# Epoch 2310, Training-Loss 2.13e+05, Validation-Loss 2.14e+05, Test-Loss 2.10e+05
# Epoch 2320, Training-Loss 2.09e+05, Validation-Loss 2.11e+05, Test-Loss 2.10e+05
# Epoch 2330, Training-Loss 2.10e+05, Validation-Loss 2.08e+05, Test-Loss 2.10e+05
# Epoch 2340, Training-Loss 2.08e+05, Validation-Loss 2.08e+05, Test-Loss 2.06e+05
# Epoch 2350, Training-Loss 2.07e+05, Validation-Loss 2.06e+05, Test-Loss 2.10e+05
# Epoch 2360, Training-Loss 2.08e+05, Validation-Loss 2.05e+05, Test-Loss 2.07e+05
# Epoch 2370, Training-Loss 2.07e+05, Validation-Loss 2.06e+05, Test-Loss 2.03e+05
# Epoch 2380, Training-Loss 2.03e+05, Validation-Loss 2.04e+05, Test-Loss 2.03e+05
# Epoch 2390, Training-Loss 2.04e+05, Validation-Loss 1.99e+05, Test-Loss 2.02e+05
# Epoch 2400, Training-Loss 2.03e+05, Validation-Loss 2.01e+05, Test-Loss 2.01e+05
# Epoch 2410, Training-Loss 2.00e+05, Validation-Loss 2.00e+05, Test-Loss 1.97e+05
# Epoch 2420, Training-Loss 1.99e+05, Validation-Loss 2.00e+05, Test-Loss 1.99e+05
# Epoch 2430, Training-Loss 1.97e+05, Validation-Loss 1.98e+05, Test-Loss 1.97e+05
# Epoch 2440, Training-Loss 1.98e+05, Validation-Loss 1.96e+05, Test-Loss 1.97e+05
# Epoch 2450, Training-Loss 1.96e+05, Validation-Loss 1.96e+05, Test-Loss 1.98e+05
# Epoch 2460, Training-Loss 1.94e+05, Validation-Loss 1.94e+05, Test-Loss 1.93e+05
# Epoch 2470, Training-Loss 1.93e+05, Validation-Loss 1.92e+05, Test-Loss 1.93e+05
# Epoch 2480, Training-Loss 1.92e+05, Validation-Loss 1.91e+05, Test-Loss 1.92e+05
# Epoch 2490, Training-Loss 1.90e+05, Validation-Loss 1.88e+05, Test-Loss 1.90e+05
# Epoch 2500, Training-Loss 1.89e+05, Validation-Loss 1.88e+05, Test-Loss 1.88e+05
# Epoch 2510, Training-Loss 1.88e+05, Validation-Loss 1.89e+05, Test-Loss 1.90e+05
# Epoch 2520, Training-Loss 1.87e+05, Validation-Loss 1.85e+05, Test-Loss 1.88e+05
# Epoch 2530, Training-Loss 1.88e+05, Validation-Loss 1.86e+05, Test-Loss 1.89e+05
# Epoch 2540, Training-Loss 1.83e+05, Validation-Loss 1.86e+05, Test-Loss 1.83e+05
# Epoch 2550, Training-Loss 1.83e+05, Validation-Loss 1.83e+05, Test-Loss 1.84e+05
# Epoch 2560, Training-Loss 1.84e+05, Validation-Loss 1.83e+05, Test-Loss 1.85e+05
# Epoch 2570, Training-Loss 1.82e+05, Validation-Loss 1.79e+05, Test-Loss 1.81e+05
# Epoch 2580, Training-Loss 1.80e+05, Validation-Loss 1.81e+05, Test-Loss 1.82e+05
# Epoch 2590, Training-Loss 1.78e+05, Validation-Loss 1.80e+05, Test-Loss 1.80e+05
# Epoch 2600, Training-Loss 1.80e+05, Validation-Loss 1.78e+05, Test-Loss 1.79e+05
# Epoch 2610, Training-Loss 1.77e+05, Validation-Loss 1.78e+05, Test-Loss 1.79e+05
# Epoch 2620, Training-Loss 1.77e+05, Validation-Loss 1.76e+05, Test-Loss 1.76e+05
# Epoch 2630, Training-Loss 1.73e+05, Validation-Loss 1.75e+05, Test-Loss 1.74e+05
# Epoch 2640, Training-Loss 1.73e+05, Validation-Loss 1.74e+05, Test-Loss 1.76e+05
# Epoch 2650, Training-Loss 1.75e+05, Validation-Loss 1.72e+05, Test-Loss 1.72e+05
# Epoch 2660, Training-Loss 1.74e+05, Validation-Loss 1.70e+05, Test-Loss 1.72e+05
# Epoch 2670, Training-Loss 1.71e+05, Validation-Loss 1.69e+05, Test-Loss 1.73e+05
# Epoch 2680, Training-Loss 1.70e+05, Validation-Loss 1.72e+05, Test-Loss 1.68e+05
# Epoch 2690, Training-Loss 1.70e+05, Validation-Loss 1.69e+05, Test-Loss 1.72e+05
# Epoch 2700, Training-Loss 1.68e+05, Validation-Loss 1.68e+05, Test-Loss 1.68e+05
# Epoch 2710, Training-Loss 1.68e+05, Validation-Loss 1.66e+05, Test-Loss 1.65e+05
# Epoch 2720, Training-Loss 1.67e+05, Validation-Loss 1.65e+05, Test-Loss 1.64e+05
# Epoch 2730, Training-Loss 1.64e+05, Validation-Loss 1.64e+05, Test-Loss 1.64e+05
# Epoch 2740, Training-Loss 1.63e+05, Validation-Loss 1.64e+05, Test-Loss 1.63e+05
# Epoch 2750, Training-Loss 1.60e+05, Validation-Loss 1.63e+05, Test-Loss 1.63e+05
# Epoch 2760, Training-Loss 1.61e+05, Validation-Loss 1.60e+05, Test-Loss 1.62e+05
# Epoch 2770, Training-Loss 1.62e+05, Validation-Loss 1.60e+05, Test-Loss 1.61e+05
# Epoch 2780, Training-Loss 1.61e+05, Validation-Loss 1.59e+05, Test-Loss 1.59e+05
# Epoch 2790, Training-Loss 1.61e+05, Validation-Loss 1.56e+05, Test-Loss 1.59e+05
# Epoch 2800, Training-Loss 1.58e+05, Validation-Loss 1.56e+05, Test-Loss 1.57e+05
# Epoch 2810, Training-Loss 1.57e+05, Validation-Loss 1.57e+05, Test-Loss 1.58e+05
# Epoch 2820, Training-Loss 1.56e+05, Validation-Loss 1.56e+05, Test-Loss 1.55e+05
# Epoch 2830, Training-Loss 1.54e+05, Validation-Loss 1.55e+05, Test-Loss 1.53e+05
# Epoch 2840, Training-Loss 1.52e+05, Validation-Loss 1.52e+05, Test-Loss 1.54e+05
# Epoch 2850, Training-Loss 1.53e+05, Validation-Loss 1.50e+05, Test-Loss 1.54e+05
# Epoch 2860, Training-Loss 1.50e+05, Validation-Loss 1.52e+05, Test-Loss 1.51e+05
# Epoch 2870, Training-Loss 1.53e+05, Validation-Loss 1.50e+05, Test-Loss 1.50e+05
# Epoch 2880, Training-Loss 1.51e+05, Validation-Loss 1.49e+05, Test-Loss 1.50e+05
# Epoch 2890, Training-Loss 1.48e+05, Validation-Loss 1.50e+05, Test-Loss 1.49e+05
# Epoch 2900, Training-Loss 1.48e+05, Validation-Loss 1.47e+05, Test-Loss 1.47e+05
# Epoch 2910, Training-Loss 1.47e+05, Validation-Loss 1.46e+05, Test-Loss 1.48e+05
# Epoch 2920, Training-Loss 1.46e+05, Validation-Loss 1.46e+05, Test-Loss 1.47e+05
# Epoch 2930, Training-Loss 1.47e+05, Validation-Loss 1.43e+05, Test-Loss 1.46e+05
# Epoch 2940, Training-Loss 1.46e+05, Validation-Loss 1.46e+05, Test-Loss 1.44e+05
# Epoch 2950, Training-Loss 1.43e+05, Validation-Loss 1.43e+05, Test-Loss 1.46e+05
# Epoch 2960, Training-Loss 1.40e+05, Validation-Loss 1.41e+05, Test-Loss 1.42e+05
# Epoch 2970, Training-Loss 1.44e+05, Validation-Loss 1.41e+05, Test-Loss 1.41e+05
# Epoch 2980, Training-Loss 1.41e+05, Validation-Loss 1.38e+05, Test-Loss 1.40e+05
# Epoch 2990, Training-Loss 1.36e+05, Validation-Loss 1.37e+05, Test-Loss 1.38e+05
# Epoch 3000, Training-Loss 1.36e+05, Validation-Loss 1.38e+05, Test-Loss 1.39e+05
# Epoch 3010, Training-Loss 1.36e+05, Validation-Loss 1.35e+05, Test-Loss 1.38e+05
# Epoch 3020, Training-Loss 1.36e+05, Validation-Loss 1.35e+05, Test-Loss 1.35e+05
# Epoch 3030, Training-Loss 1.35e+05, Validation-Loss 1.34e+05, Test-Loss 1.37e+05
# Epoch 3040, Training-Loss 1.36e+05, Validation-Loss 1.36e+05, Test-Loss 1.36e+05
# Epoch 3050, Training-Loss 1.36e+05, Validation-Loss 1.34e+05, Test-Loss 1.35e+05
# Epoch 3060, Training-Loss 1.35e+05, Validation-Loss 1.33e+05, Test-Loss 1.32e+05
# Epoch 3070, Training-Loss 1.34e+05, Validation-Loss 1.32e+05, Test-Loss 1.33e+05
# Epoch 3080, Training-Loss 1.32e+05, Validation-Loss 1.32e+05, Test-Loss 1.31e+05
# Epoch 3090, Training-Loss 1.32e+05, Validation-Loss 1.30e+05, Test-Loss 1.32e+05
# Epoch 3100, Training-Loss 1.29e+05, Validation-Loss 1.27e+05, Test-Loss 1.31e+05
# Epoch 3110, Training-Loss 1.28e+05, Validation-Loss 1.27e+05, Test-Loss 1.29e+05
# Epoch 3120, Training-Loss 1.29e+05, Validation-Loss 1.29e+05, Test-Loss 1.28e+05
# Epoch 3130, Training-Loss 1.26e+05, Validation-Loss 1.24e+05, Test-Loss 1.28e+05
# Epoch 3140, Training-Loss 1.26e+05, Validation-Loss 1.25e+05, Test-Loss 1.27e+05
# Epoch 3150, Training-Loss 1.23e+05, Validation-Loss 1.24e+05, Test-Loss 1.26e+05
# Epoch 3160, Training-Loss 1.23e+05, Validation-Loss 1.22e+05, Test-Loss 1.25e+05
# Epoch 3170, Training-Loss 1.25e+05, Validation-Loss 1.22e+05, Test-Loss 1.22e+05
# Epoch 3180, Training-Loss 1.21e+05, Validation-Loss 1.22e+05, Test-Loss 1.23e+05
# Epoch 3190, Training-Loss 1.21e+05, Validation-Loss 1.23e+05, Test-Loss 1.22e+05
# Epoch 3200, Training-Loss 1.20e+05, Validation-Loss 1.21e+05, Test-Loss 1.21e+05
# Epoch 3210, Training-Loss 1.22e+05, Validation-Loss 1.21e+05, Test-Loss 1.20e+05
# Epoch 3220, Training-Loss 1.19e+05, Validation-Loss 1.20e+05, Test-Loss 1.20e+05
# Epoch 3230, Training-Loss 1.19e+05, Validation-Loss 1.17e+05, Test-Loss 1.18e+05
# Epoch 3240, Training-Loss 1.20e+05, Validation-Loss 1.17e+05, Test-Loss 1.18e+05
# Epoch 3250, Training-Loss 1.16e+05, Validation-Loss 1.16e+05, Test-Loss 1.18e+05
# Epoch 3260, Training-Loss 1.15e+05, Validation-Loss 1.15e+05, Test-Loss 1.16e+05
# Epoch 3270, Training-Loss 1.15e+05, Validation-Loss 1.15e+05, Test-Loss 1.14e+05
# Epoch 3280, Training-Loss 1.14e+05, Validation-Loss 1.14e+05, Test-Loss 1.14e+05
# Epoch 3290, Training-Loss 1.14e+05, Validation-Loss 1.12e+05, Test-Loss 1.12e+05
# Epoch 3300, Training-Loss 1.14e+05, Validation-Loss 1.11e+05, Test-Loss 1.14e+05
# Epoch 3310, Training-Loss 1.13e+05, Validation-Loss 1.11e+05, Test-Loss 1.11e+05
# Epoch 3320, Training-Loss 1.11e+05, Validation-Loss 1.11e+05, Test-Loss 1.11e+05
# Epoch 3330, Training-Loss 1.10e+05, Validation-Loss 1.11e+05, Test-Loss 1.09e+05
# Epoch 3340, Training-Loss 1.11e+05, Validation-Loss 1.11e+05, Test-Loss 1.09e+05
# Epoch 3350, Training-Loss 1.09e+05, Validation-Loss 1.10e+05, Test-Loss 1.07e+05
# Epoch 3360, Training-Loss 1.07e+05, Validation-Loss 1.08e+05, Test-Loss 1.08e+05
# Epoch 3370, Training-Loss 1.07e+05, Validation-Loss 1.06e+05, Test-Loss 1.06e+05
# Epoch 3380, Training-Loss 1.07e+05, Validation-Loss 1.08e+05, Test-Loss 1.05e+05
# Epoch 3390, Training-Loss 1.06e+05, Validation-Loss 1.06e+05, Test-Loss 1.07e+05
# Epoch 3400, Training-Loss 1.03e+05, Validation-Loss 1.04e+05, Test-Loss 1.04e+05
# Epoch 3410, Training-Loss 1.04e+05, Validation-Loss 1.06e+05, Test-Loss 1.03e+05
# Epoch 3420, Training-Loss 1.04e+05, Validation-Loss 1.06e+05, Test-Loss 1.02e+05
# Epoch 3430, Training-Loss 1.02e+05, Validation-Loss 1.03e+05, Test-Loss 1.01e+05
# Epoch 3440, Training-Loss 9.94e+04, Validation-Loss 1.01e+05, Test-Loss 1.02e+05
# Epoch 3450, Training-Loss 9.87e+04, Validation-Loss 1.02e+05, Test-Loss 1.01e+05
# Epoch 3460, Training-Loss 1.01e+05, Validation-Loss 1.02e+05, Test-Loss 9.97e+04
# Epoch 3470, Training-Loss 9.95e+04, Validation-Loss 9.79e+04, Test-Loss 9.88e+04
# Epoch 3480, Training-Loss 9.75e+04, Validation-Loss 9.91e+04, Test-Loss 1.00e+05
# Epoch 3490, Training-Loss 9.76e+04, Validation-Loss 9.70e+04, Test-Loss 9.71e+04
# Epoch 3500, Training-Loss 9.90e+04, Validation-Loss 9.62e+04, Test-Loss 9.77e+04
# Epoch 3510, Training-Loss 9.72e+04, Validation-Loss 9.64e+04, Test-Loss 9.75e+04
# Epoch 3520, Training-Loss 9.51e+04, Validation-Loss 9.56e+04, Test-Loss 9.61e+04
# Epoch 3530, Training-Loss 9.35e+04, Validation-Loss 9.54e+04, Test-Loss 9.71e+04
# Epoch 3540, Training-Loss 9.55e+04, Validation-Loss 9.43e+04, Test-Loss 9.47e+04
# Epoch 3550, Training-Loss 9.52e+04, Validation-Loss 9.42e+04, Test-Loss 9.31e+04
# Epoch 3560, Training-Loss 9.27e+04, Validation-Loss 9.31e+04, Test-Loss 9.34e+04
# Epoch 3570, Training-Loss 9.18e+04, Validation-Loss 9.10e+04, Test-Loss 9.28e+04
# Epoch 3580, Training-Loss 9.29e+04, Validation-Loss 9.14e+04, Test-Loss 9.17e+04
# Epoch 3590, Training-Loss 8.96e+04, Validation-Loss 8.90e+04, Test-Loss 9.03e+04
# Epoch 3600, Training-Loss 9.09e+04, Validation-Loss 8.84e+04, Test-Loss 8.93e+04
# Epoch 3610, Training-Loss 8.86e+04, Validation-Loss 8.96e+04, Test-Loss 8.98e+04
# Epoch 3620, Training-Loss 8.79e+04, Validation-Loss 8.91e+04, Test-Loss 8.91e+04
# Epoch 3630, Training-Loss 8.99e+04, Validation-Loss 8.82e+04, Test-Loss 8.66e+04
# Epoch 3640, Training-Loss 8.80e+04, Validation-Loss 8.69e+04, Test-Loss 8.71e+04
# Epoch 3650, Training-Loss 8.67e+04, Validation-Loss 8.82e+04, Test-Loss 8.71e+04
# Epoch 3660, Training-Loss 8.56e+04, Validation-Loss 8.49e+04, Test-Loss 8.68e+04
# Epoch 3670, Training-Loss 8.77e+04, Validation-Loss 8.54e+04, Test-Loss 8.57e+04
# Epoch 3680, Training-Loss 8.32e+04, Validation-Loss 8.41e+04, Test-Loss 8.38e+04
# Epoch 3690, Training-Loss 8.35e+04, Validation-Loss 8.35e+04, Test-Loss 8.46e+04
# Epoch 3700, Training-Loss 8.41e+04, Validation-Loss 8.31e+04, Test-Loss 8.28e+04
# Epoch 3710, Training-Loss 8.28e+04, Validation-Loss 8.33e+04, Test-Loss 8.27e+04
# Epoch 3720, Training-Loss 8.16e+04, Validation-Loss 8.12e+04, Test-Loss 8.11e+04
# Epoch 3730, Training-Loss 8.07e+04, Validation-Loss 8.16e+04, Test-Loss 8.11e+04
# Epoch 3740, Training-Loss 7.97e+04, Validation-Loss 8.00e+04, Test-Loss 8.04e+04
# Epoch 3750, Training-Loss 8.10e+04, Validation-Loss 8.05e+04, Test-Loss 8.11e+04
# Epoch 3760, Training-Loss 8.03e+04, Validation-Loss 7.98e+04, Test-Loss 8.06e+04
# Epoch 3770, Training-Loss 8.00e+04, Validation-Loss 7.93e+04, Test-Loss 7.87e+04
# Epoch 3780, Training-Loss 7.69e+04, Validation-Loss 7.92e+04, Test-Loss 7.96e+04
# Epoch 3790, Training-Loss 7.75e+04, Validation-Loss 7.78e+04, Test-Loss 7.76e+04
# Epoch 3800, Training-Loss 7.80e+04, Validation-Loss 7.73e+04, Test-Loss 7.69e+04
# Epoch 3810, Training-Loss 7.78e+04, Validation-Loss 7.64e+04, Test-Loss 7.81e+04
# Epoch 3820, Training-Loss 7.54e+04, Validation-Loss 7.60e+04, Test-Loss 7.60e+04
# Epoch 3830, Training-Loss 7.60e+04, Validation-Loss 7.50e+04, Test-Loss 7.58e+04
# Epoch 3840, Training-Loss 7.47e+04, Validation-Loss 7.28e+04, Test-Loss 7.34e+04
# Epoch 3850, Training-Loss 7.61e+04, Validation-Loss 7.60e+04, Test-Loss 7.34e+04
# Epoch 3860, Training-Loss 7.29e+04, Validation-Loss 7.34e+04, Test-Loss 7.24e+04
# Epoch 3870, Training-Loss 7.42e+04, Validation-Loss 7.37e+04, Test-Loss 7.20e+04
# Epoch 3880, Training-Loss 7.14e+04, Validation-Loss 7.25e+04, Test-Loss 7.16e+04
# Epoch 3890, Training-Loss 7.28e+04, Validation-Loss 7.19e+04, Test-Loss 7.17e+04
# Epoch 3900, Training-Loss 7.28e+04, Validation-Loss 7.08e+04, Test-Loss 7.18e+04
# Epoch 3910, Training-Loss 7.05e+04, Validation-Loss 6.99e+04, Test-Loss 7.22e+04
# Epoch 3920, Training-Loss 7.21e+04, Validation-Loss 7.12e+04, Test-Loss 7.11e+04
# Epoch 3930, Training-Loss 7.01e+04, Validation-Loss 6.98e+04, Test-Loss 6.98e+04
# Epoch 3940, Training-Loss 6.96e+04, Validation-Loss 6.95e+04, Test-Loss 7.16e+04
# Epoch 3950, Training-Loss 6.69e+04, Validation-Loss 6.79e+04, Test-Loss 6.89e+04
# Epoch 3960, Training-Loss 6.84e+04, Validation-Loss 6.71e+04, Test-Loss 6.74e+04
# Epoch 3970, Training-Loss 6.74e+04, Validation-Loss 6.73e+04, Test-Loss 6.76e+04
# Epoch 3980, Training-Loss 6.91e+04, Validation-Loss 6.62e+04, Test-Loss 6.55e+04
# Epoch 3990, Training-Loss 6.52e+04, Validation-Loss 6.59e+04, Test-Loss 6.62e+04
# Epoch 4000, Training-Loss 6.57e+04, Validation-Loss 6.41e+04, Test-Loss 6.54e+04
# Epoch 4010, Training-Loss 6.49e+04, Validation-Loss 6.41e+04, Test-Loss 6.42e+04
# Epoch 4020, Training-Loss 6.45e+04, Validation-Loss 6.37e+04, Test-Loss 6.58e+04
# Epoch 4030, Training-Loss 6.34e+04, Validation-Loss 6.40e+04, Test-Loss 6.18e+04
# Epoch 4040, Training-Loss 6.33e+04, Validation-Loss 6.42e+04, Test-Loss 6.47e+04
# Epoch 4050, Training-Loss 6.25e+04, Validation-Loss 6.16e+04, Test-Loss 6.18e+04
# Epoch 4060, Training-Loss 6.23e+04, Validation-Loss 6.08e+04, Test-Loss 6.20e+04
# Epoch 4070, Training-Loss 6.27e+04, Validation-Loss 6.00e+04, Test-Loss 6.30e+04
# Epoch 4080, Training-Loss 6.16e+04, Validation-Loss 6.04e+04, Test-Loss 6.07e+04
# Epoch 4090, Training-Loss 5.94e+04, Validation-Loss 6.11e+04, Test-Loss 6.09e+04
# Epoch 4100, Training-Loss 5.91e+04, Validation-Loss 5.93e+04, Test-Loss 6.08e+04
# Epoch 4110, Training-Loss 6.01e+04, Validation-Loss 5.86e+04, Test-Loss 6.04e+04
# Epoch 4120, Training-Loss 5.92e+04, Validation-Loss 5.85e+04, Test-Loss 5.87e+04
# Epoch 4130, Training-Loss 5.76e+04, Validation-Loss 5.87e+04, Test-Loss 5.99e+04
# Epoch 4140, Training-Loss 5.84e+04, Validation-Loss 5.83e+04, Test-Loss 5.74e+04
# Epoch 4150, Training-Loss 5.63e+04, Validation-Loss 5.83e+04, Test-Loss 5.66e+04
# Epoch 4160, Training-Loss 5.79e+04, Validation-Loss 5.64e+04, Test-Loss 5.76e+04
# Epoch 4170, Training-Loss 5.76e+04, Validation-Loss 5.59e+04, Test-Loss 5.71e+04
# Epoch 4180, Training-Loss 5.74e+04, Validation-Loss 5.50e+04, Test-Loss 5.55e+04
# Epoch 4190, Training-Loss 5.51e+04, Validation-Loss 5.48e+04, Test-Loss 5.57e+04
# Epoch 4200, Training-Loss 5.62e+04, Validation-Loss 5.32e+04, Test-Loss 5.45e+04
# Epoch 4210, Training-Loss 5.52e+04, Validation-Loss 5.43e+04, Test-Loss 5.47e+04
# Epoch 4220, Training-Loss 5.28e+04, Validation-Loss 5.37e+04, Test-Loss 5.48e+04
# Epoch 4230, Training-Loss 5.35e+04, Validation-Loss 5.41e+04, Test-Loss 5.21e+04
# Epoch 4240, Training-Loss 5.23e+04, Validation-Loss 5.32e+04, Test-Loss 5.26e+04
# Epoch 4250, Training-Loss 5.20e+04, Validation-Loss 5.33e+04, Test-Loss 5.32e+04
# Epoch 4260, Training-Loss 5.29e+04, Validation-Loss 5.21e+04, Test-Loss 5.27e+04
# Epoch 4270, Training-Loss 5.15e+04, Validation-Loss 5.07e+04, Test-Loss 5.07e+04
# Epoch 4280, Training-Loss 5.12e+04, Validation-Loss 5.02e+04, Test-Loss 5.02e+04
# Epoch 4290, Training-Loss 5.09e+04, Validation-Loss 5.20e+04, Test-Loss 5.10e+04
# Epoch 4300, Training-Loss 5.03e+04, Validation-Loss 4.89e+04, Test-Loss 5.09e+04
# Epoch 4310, Training-Loss 5.03e+04, Validation-Loss 4.96e+04, Test-Loss 5.06e+04
# Epoch 4320, Training-Loss 4.91e+04, Validation-Loss 5.10e+04, Test-Loss 4.91e+04
# Epoch 4330, Training-Loss 4.91e+04, Validation-Loss 4.86e+04, Test-Loss 4.92e+04
# Epoch 4340, Training-Loss 4.84e+04, Validation-Loss 4.82e+04, Test-Loss 4.85e+04
# Epoch 4350, Training-Loss 4.95e+04, Validation-Loss 4.69e+04, Test-Loss 4.63e+04
# Epoch 4360, Training-Loss 4.69e+04, Validation-Loss 4.79e+04, Test-Loss 4.79e+04
# Epoch 4370, Training-Loss 4.73e+04, Validation-Loss 4.66e+04, Test-Loss 4.77e+04
# Epoch 4380, Training-Loss 4.76e+04, Validation-Loss 4.61e+04, Test-Loss 4.75e+04
# Epoch 4390, Training-Loss 4.67e+04, Validation-Loss 4.54e+04, Test-Loss 4.72e+04
# Epoch 4400, Training-Loss 4.59e+04, Validation-Loss 4.63e+04, Test-Loss 4.51e+04
# Epoch 4410, Training-Loss 4.61e+04, Validation-Loss 4.42e+04, Test-Loss 4.35e+04
# Epoch 4420, Training-Loss 4.57e+04, Validation-Loss 4.31e+04, Test-Loss 4.43e+04
# Epoch 4430, Training-Loss 4.48e+04, Validation-Loss 4.41e+04, Test-Loss 4.44e+04
# Epoch 4440, Training-Loss 4.37e+04, Validation-Loss 4.43e+04, Test-Loss 4.40e+04
# Epoch 4450, Training-Loss 4.35e+04, Validation-Loss 4.34e+04, Test-Loss 4.39e+04
# Epoch 4460, Training-Loss 4.30e+04, Validation-Loss 4.27e+04, Test-Loss 4.33e+04
# Epoch 4470, Training-Loss 4.32e+04, Validation-Loss 4.20e+04, Test-Loss 4.26e+04
# Epoch 4480, Training-Loss 4.26e+04, Validation-Loss 4.31e+04, Test-Loss 4.34e+04
# Epoch 4490, Training-Loss 4.17e+04, Validation-Loss 4.14e+04, Test-Loss 4.11e+04
# Epoch 4500, Training-Loss 4.22e+04, Validation-Loss 4.23e+04, Test-Loss 4.18e+04
# Epoch 4510, Training-Loss 4.12e+04, Validation-Loss 4.01e+04, Test-Loss 4.15e+04
# Epoch 4520, Training-Loss 4.05e+04, Validation-Loss 4.13e+04, Test-Loss 4.01e+04
# Epoch 4530, Training-Loss 4.01e+04, Validation-Loss 4.04e+04, Test-Loss 4.06e+04
# Epoch 4540, Training-Loss 4.05e+04, Validation-Loss 4.01e+04, Test-Loss 4.02e+04
# Epoch 4550, Training-Loss 4.00e+04, Validation-Loss 3.94e+04, Test-Loss 3.99e+04
# Epoch 4560, Training-Loss 3.93e+04, Validation-Loss 3.91e+04, Test-Loss 3.92e+04
# Epoch 4570, Training-Loss 4.03e+04, Validation-Loss 3.92e+04, Test-Loss 3.94e+04
# Epoch 4580, Training-Loss 3.89e+04, Validation-Loss 3.81e+04, Test-Loss 3.87e+04
# Epoch 4590, Training-Loss 3.82e+04, Validation-Loss 3.85e+04, Test-Loss 3.78e+04
# Epoch 4600, Training-Loss 3.82e+04, Validation-Loss 3.67e+04, Test-Loss 3.84e+04
# Epoch 4610, Training-Loss 3.74e+04, Validation-Loss 3.75e+04, Test-Loss 3.65e+04
# Epoch 4620, Training-Loss 3.71e+04, Validation-Loss 3.66e+04, Test-Loss 3.65e+04
# Epoch 4630, Training-Loss 3.58e+04, Validation-Loss 3.61e+04, Test-Loss 3.66e+04
# Epoch 4640, Training-Loss 3.67e+04, Validation-Loss 3.69e+04, Test-Loss 3.49e+04
# Epoch 4650, Training-Loss 3.53e+04, Validation-Loss 3.47e+04, Test-Loss 3.77e+04
# Epoch 4660, Training-Loss 3.63e+04, Validation-Loss 3.57e+04, Test-Loss 3.57e+04
# Epoch 4670, Training-Loss 3.56e+04, Validation-Loss 3.61e+04, Test-Loss 3.54e+04
# Epoch 4680, Training-Loss 3.44e+04, Validation-Loss 3.44e+04, Test-Loss 3.51e+04
# Epoch 4690, Training-Loss 3.46e+04, Validation-Loss 3.37e+04, Test-Loss 3.42e+04
# Epoch 4700, Training-Loss 3.33e+04, Validation-Loss 3.36e+04, Test-Loss 3.46e+04
# Epoch 4710, Training-Loss 3.43e+04, Validation-Loss 3.35e+04, Test-Loss 3.35e+04
# Epoch 4720, Training-Loss 3.45e+04, Validation-Loss 3.39e+04, Test-Loss 3.29e+04
# Epoch 4730, Training-Loss 3.40e+04, Validation-Loss 3.22e+04, Test-Loss 3.29e+04
# Epoch 4740, Training-Loss 3.20e+04, Validation-Loss 3.24e+04, Test-Loss 3.35e+04
# Epoch 4750, Training-Loss 3.24e+04, Validation-Loss 3.34e+04, Test-Loss 3.23e+04
# Epoch 4760, Training-Loss 3.22e+04, Validation-Loss 3.29e+04, Test-Loss 3.26e+04
# Epoch 4770, Training-Loss 3.13e+04, Validation-Loss 3.11e+04, Test-Loss 3.18e+04
# Epoch 4780, Training-Loss 3.08e+04, Validation-Loss 3.20e+04, Test-Loss 3.11e+04
# Epoch 4790, Training-Loss 3.11e+04, Validation-Loss 3.11e+04, Test-Loss 3.04e+04
# Epoch 4800, Training-Loss 2.98e+04, Validation-Loss 3.06e+04, Test-Loss 3.14e+04
# Epoch 4810, Training-Loss 3.07e+04, Validation-Loss 2.94e+04, Test-Loss 3.02e+04
# Epoch 4820, Training-Loss 3.02e+04, Validation-Loss 2.92e+04, Test-Loss 2.95e+04
# Epoch 4830, Training-Loss 3.03e+04, Validation-Loss 2.91e+04, Test-Loss 3.02e+04
# Epoch 4840, Training-Loss 2.91e+04, Validation-Loss 2.93e+04, Test-Loss 3.05e+04
# Epoch 4850, Training-Loss 2.96e+04, Validation-Loss 2.85e+04, Test-Loss 2.84e+04
# Epoch 4860, Training-Loss 2.85e+04, Validation-Loss 2.91e+04, Test-Loss 2.84e+04
# Epoch 4870, Training-Loss 2.89e+04, Validation-Loss 2.89e+04, Test-Loss 2.82e+04
# Epoch 4880, Training-Loss 2.79e+04, Validation-Loss 2.90e+04, Test-Loss 2.92e+04
# Epoch 4890, Training-Loss 2.85e+04, Validation-Loss 2.89e+04, Test-Loss 2.82e+04
# Epoch 4900, Training-Loss 2.69e+04, Validation-Loss 2.72e+04, Test-Loss 2.79e+04
# Epoch 4910, Training-Loss 2.79e+04, Validation-Loss 2.73e+04, Test-Loss 2.81e+04
# Epoch 4920, Training-Loss 2.63e+04, Validation-Loss 2.60e+04, Test-Loss 2.74e+04
# Epoch 4930, Training-Loss 2.66e+04, Validation-Loss 2.65e+04, Test-Loss 2.70e+04
# Epoch 4940, Training-Loss 2.65e+04, Validation-Loss 2.59e+04, Test-Loss 2.64e+04
# Epoch 4950, Training-Loss 2.59e+04, Validation-Loss 2.57e+04, Test-Loss 2.64e+04
# Epoch 4960, Training-Loss 2.66e+04, Validation-Loss 2.59e+04, Test-Loss 2.43e+04
# Epoch 4970, Training-Loss 2.58e+04, Validation-Loss 2.51e+04, Test-Loss 2.56e+04
# Epoch 4980, Training-Loss 2.57e+04, Validation-Loss 2.51e+04, Test-Loss 2.49e+04
# Epoch 4990, Training-Loss 2.52e+04, Validation-Loss 2.47e+04, Test-Loss 2.44e+04
# Epoch 5000, Training-Loss 2.46e+04, Validation-Loss 2.46e+04, Test-Loss 2.43e+04
# Epoch 5010, Training-Loss 2.46e+04, Validation-Loss 2.48e+04, Test-Loss 2.47e+04
# Epoch 5020, Training-Loss 2.49e+04, Validation-Loss 2.41e+04, Test-Loss 2.45e+04
# Epoch 5030, Training-Loss 2.39e+04, Validation-Loss 2.34e+04, Test-Loss 2.36e+04
# Epoch 5040, Training-Loss 2.39e+04, Validation-Loss 2.33e+04, Test-Loss 2.41e+04
# Epoch 5050, Training-Loss 2.35e+04, Validation-Loss 2.38e+04, Test-Loss 2.36e+04
# Epoch 5060, Training-Loss 2.33e+04, Validation-Loss 2.23e+04, Test-Loss 2.30e+04
# Epoch 5070, Training-Loss 2.36e+04, Validation-Loss 2.25e+04, Test-Loss 2.28e+04
# Epoch 5080, Training-Loss 2.25e+04, Validation-Loss 2.23e+04, Test-Loss 2.32e+04
# Epoch 5090, Training-Loss 2.14e+04, Validation-Loss 2.20e+04, Test-Loss 2.15e+04
# Epoch 5100, Training-Loss 2.21e+04, Validation-Loss 2.21e+04, Test-Loss 2.26e+04
# Epoch 5110, Training-Loss 2.24e+04, Validation-Loss 2.20e+04, Test-Loss 2.21e+04
# Epoch 5120, Training-Loss 2.24e+04, Validation-Loss 2.06e+04, Test-Loss 2.26e+04
# Epoch 5130, Training-Loss 2.09e+04, Validation-Loss 2.18e+04, Test-Loss 2.14e+04
# Epoch 5140, Training-Loss 2.09e+04, Validation-Loss 2.11e+04, Test-Loss 2.19e+04
# Epoch 5150, Training-Loss 2.12e+04, Validation-Loss 2.04e+04, Test-Loss 2.08e+04
# Epoch 5160, Training-Loss 2.11e+04, Validation-Loss 2.02e+04, Test-Loss 1.96e+04
# Epoch 5170, Training-Loss 1.98e+04, Validation-Loss 2.03e+04, Test-Loss 1.96e+04
# Epoch 5180, Training-Loss 2.02e+04, Validation-Loss 1.91e+04, Test-Loss 2.00e+04
# Epoch 5190, Training-Loss 2.02e+04, Validation-Loss 1.96e+04, Test-Loss 1.97e+04
# Epoch 5200, Training-Loss 1.98e+04, Validation-Loss 1.95e+04, Test-Loss 1.90e+04
# Epoch 5210, Training-Loss 1.92e+04, Validation-Loss 1.93e+04, Test-Loss 1.91e+04
# Epoch 5220, Training-Loss 1.86e+04, Validation-Loss 1.90e+04, Test-Loss 1.88e+04
# Epoch 5230, Training-Loss 1.94e+04, Validation-Loss 1.88e+04, Test-Loss 1.88e+04
# Epoch 5240, Training-Loss 1.85e+04, Validation-Loss 1.83e+04, Test-Loss 1.89e+04
# Epoch 5250, Training-Loss 1.86e+04, Validation-Loss 1.83e+04, Test-Loss 1.86e+04
# Epoch 5260, Training-Loss 1.79e+04, Validation-Loss 1.85e+04, Test-Loss 1.87e+04
# Epoch 5270, Training-Loss 1.81e+04, Validation-Loss 1.80e+04, Test-Loss 1.81e+04
# Epoch 5280, Training-Loss 1.81e+04, Validation-Loss 1.80e+04, Test-Loss 1.77e+04
# Epoch 5290, Training-Loss 1.81e+04, Validation-Loss 1.76e+04, Test-Loss 1.72e+04
# Epoch 5300, Training-Loss 1.78e+04, Validation-Loss 1.72e+04, Test-Loss 1.65e+04
# Epoch 5310, Training-Loss 1.67e+04, Validation-Loss 1.63e+04, Test-Loss 1.83e+04
# Epoch 5320, Training-Loss 1.69e+04, Validation-Loss 1.60e+04, Test-Loss 1.72e+04
# Epoch 5330, Training-Loss 1.62e+04, Validation-Loss 1.61e+04, Test-Loss 1.68e+04
# Epoch 5340, Training-Loss 1.64e+04, Validation-Loss 1.68e+04, Test-Loss 1.67e+04
# Epoch 5350, Training-Loss 1.60e+04, Validation-Loss 1.68e+04, Test-Loss 1.62e+04
# Epoch 5360, Training-Loss 1.65e+04, Validation-Loss 1.62e+04, Test-Loss 1.63e+04
# Epoch 5370, Training-Loss 1.60e+04, Validation-Loss 1.61e+04, Test-Loss 1.59e+04
# Epoch 5380, Training-Loss 1.61e+04, Validation-Loss 1.53e+04, Test-Loss 1.55e+04
# Epoch 5390, Training-Loss 1.62e+04, Validation-Loss 1.57e+04, Test-Loss 1.48e+04
# Epoch 5400, Training-Loss 1.53e+04, Validation-Loss 1.55e+04, Test-Loss 1.55e+04
# Epoch 5410, Training-Loss 1.51e+04, Validation-Loss 1.46e+04, Test-Loss 1.50e+04
# Epoch 5420, Training-Loss 1.47e+04, Validation-Loss 1.53e+04, Test-Loss 1.52e+04
# Epoch 5430, Training-Loss 1.49e+04, Validation-Loss 1.49e+04, Test-Loss 1.45e+04
# Epoch 5440, Training-Loss 1.49e+04, Validation-Loss 1.44e+04, Test-Loss 1.43e+04
# Epoch 5450, Training-Loss 1.58e+04, Validation-Loss 1.42e+04, Test-Loss 1.41e+04
# Epoch 5460, Training-Loss 1.41e+04, Validation-Loss 1.40e+04, Test-Loss 1.43e+04
# Epoch 5470, Training-Loss 1.45e+04, Validation-Loss 1.42e+04, Test-Loss 1.45e+04
# Epoch 5480, Training-Loss 1.32e+04, Validation-Loss 1.35e+04, Test-Loss 1.40e+04
# Epoch 5490, Training-Loss 1.34e+04, Validation-Loss 1.43e+04, Test-Loss 1.50e+04
# Epoch 5500, Training-Loss 1.34e+04, Validation-Loss 1.30e+04, Test-Loss 1.42e+04
# Epoch 5510, Training-Loss 1.39e+04, Validation-Loss 1.32e+04, Test-Loss 1.34e+04
# Epoch 5520, Training-Loss 1.39e+04, Validation-Loss 1.32e+04, Test-Loss 1.35e+04
# Epoch 5530, Training-Loss 1.31e+04, Validation-Loss 1.31e+04, Test-Loss 1.29e+04
# Epoch 5540, Training-Loss 1.28e+04, Validation-Loss 1.30e+04, Test-Loss 1.29e+04
# Epoch 5550, Training-Loss 1.26e+04, Validation-Loss 1.29e+04, Test-Loss 1.34e+04
# Epoch 5560, Training-Loss 1.17e+04, Validation-Loss 1.26e+04, Test-Loss 1.21e+04
# Epoch 5570, Training-Loss 1.20e+04, Validation-Loss 1.29e+04, Test-Loss 1.24e+04
# Epoch 5580, Training-Loss 1.25e+04, Validation-Loss 1.23e+04, Test-Loss 1.25e+04
# Epoch 5590, Training-Loss 1.18e+04, Validation-Loss 1.19e+04, Test-Loss 1.17e+04
# Epoch 5600, Training-Loss 1.21e+04, Validation-Loss 1.15e+04, Test-Loss 1.19e+04
# Epoch 5610, Training-Loss 1.20e+04, Validation-Loss 1.15e+04, Test-Loss 1.12e+04
# Epoch 5620, Training-Loss 1.18e+04, Validation-Loss 1.16e+04, Test-Loss 1.19e+04
# Epoch 5630, Training-Loss 1.07e+04, Validation-Loss 1.16e+04, Test-Loss 1.17e+04
# Epoch 5640, Training-Loss 1.12e+04, Validation-Loss 1.15e+04, Test-Loss 1.15e+04
# Epoch 5650, Training-Loss 1.14e+04, Validation-Loss 1.13e+04, Test-Loss 1.17e+04
# Epoch 5660, Training-Loss 1.09e+04, Validation-Loss 1.07e+04, Test-Loss 1.12e+04
# Epoch 5670, Training-Loss 1.07e+04, Validation-Loss 1.09e+04, Test-Loss 1.10e+04
# Epoch 5680, Training-Loss 1.06e+04, Validation-Loss 1.05e+04, Test-Loss 1.11e+04
# Epoch 5690, Training-Loss 1.04e+04, Validation-Loss 9.77e+03, Test-Loss 1.02e+04
# Epoch 5700, Training-Loss 1.01e+04, Validation-Loss 1.06e+04, Test-Loss 1.10e+04
# Epoch 5710, Training-Loss 1.00e+04, Validation-Loss 1.05e+04, Test-Loss 1.01e+04
# Epoch 5720, Training-Loss 9.86e+03, Validation-Loss 9.44e+03, Test-Loss 9.61e+03
# Epoch 5730, Training-Loss 9.61e+03, Validation-Loss 9.43e+03, Test-Loss 1.05e+04
# Epoch 5740, Training-Loss 9.94e+03, Validation-Loss 9.75e+03, Test-Loss 1.01e+04
# Epoch 5750, Training-Loss 9.25e+03, Validation-Loss 9.63e+03, Test-Loss 9.98e+03
# Epoch 5760, Training-Loss 9.82e+03, Validation-Loss 9.60e+03, Test-Loss 9.96e+03
# Epoch 5770, Training-Loss 9.39e+03, Validation-Loss 9.51e+03, Test-Loss 9.33e+03
# Epoch 5780, Training-Loss 9.21e+03, Validation-Loss 8.99e+03, Test-Loss 9.00e+03
# Epoch 5790, Training-Loss 9.40e+03, Validation-Loss 9.00e+03, Test-Loss 9.29e+03
# Epoch 5800, Training-Loss 8.69e+03, Validation-Loss 8.44e+03, Test-Loss 9.29e+03
# Epoch 5810, Training-Loss 9.27e+03, Validation-Loss 9.18e+03, Test-Loss 8.55e+03
# Epoch 5820, Training-Loss 8.91e+03, Validation-Loss 8.30e+03, Test-Loss 8.93e+03
# Epoch 5830, Training-Loss 8.76e+03, Validation-Loss 8.84e+03, Test-Loss 8.39e+03
# Epoch 5840, Training-Loss 8.86e+03, Validation-Loss 8.38e+03, Test-Loss 8.20e+03
# Epoch 5850, Training-Loss 8.48e+03, Validation-Loss 8.40e+03, Test-Loss 8.75e+03
# Epoch 5860, Training-Loss 8.10e+03, Validation-Loss 8.16e+03, Test-Loss 8.57e+03
# Epoch 5870, Training-Loss 8.26e+03, Validation-Loss 7.81e+03, Test-Loss 7.52e+03
# Epoch 5880, Training-Loss 8.61e+03, Validation-Loss 8.30e+03, Test-Loss 7.67e+03
# Epoch 5890, Training-Loss 8.39e+03, Validation-Loss 7.59e+03, Test-Loss 7.88e+03
# Epoch 5900, Training-Loss 8.04e+03, Validation-Loss 8.17e+03, Test-Loss 7.93e+03
# Epoch 5910, Training-Loss 7.37e+03, Validation-Loss 8.29e+03, Test-Loss 7.91e+03
# Epoch 5920, Training-Loss 7.87e+03, Validation-Loss 8.03e+03, Test-Loss 7.51e+03
# ...
# Epoch 38050, Training-Loss 5.44e-01, Validation-Loss 4.35e-01, Test-Loss 4.35e-01
# Epoch 38060, Training-Loss 2.66e-01, Validation-Loss 2.65e-01, Test-Loss 2.85e-01
# Epoch 38070, Training-Loss 3.37e-01, Validation-Loss 2.78e-01, Test-Loss 3.50e-01
# Epoch 38080, Training-Loss 3.81e-01, Validation-Loss 2.42e-01, Test-Loss 2.91e-01
# Epoch 38090, Training-Loss 2.86e-01, Validation-Loss 2.62e-01, Test-Loss 2.20e-01
# Epoch 38100, Training-Loss 2.95e-01, Validation-Loss 3.44e-01, Test-Loss 4.02e-01
# Epoch 38110, Training-Loss 2.22e-01, Validation-Loss 3.84e-01, Test-Loss 4.48e-01
# Epoch 38120, Training-Loss 5.81e-01, Validation-Loss 5.89e-01, Test-Loss 6.33e-01
# Epoch 38130, Training-Loss 4.11e-01, Validation-Loss 7.10e-01, Test-Loss 7.48e-01
# Epoch 38140, Training-Loss 9.75e-01, Validation-Loss 5.18e-01, Test-Loss 5.11e-01
# Epoch 38150, Training-Loss 1.04e+00, Validation-Loss 9.32e-01, Test-Loss 9.31e-01
# Epoch 38160, Training-Loss 7.42e-01, Validation-Loss 7.76e-01, Test-Loss 7.18e-01
# Epoch 38170, Training-Loss 3.42e-01, Validation-Loss 3.00e-01, Test-Loss 3.17e-01
# Epoch 38180, Training-Loss 3.57e-01, Validation-Loss 3.17e-01, Test-Loss 2.89e-01
# Epoch 38190, Training-Loss 4.75e-01, Validation-Loss 4.45e-01, Test-Loss 3.81e-01
# Epoch 38200, Training-Loss 5.14e-01, Validation-Loss 4.57e-01, Test-Loss 3.55e-01
# Epoch 38210, Training-Loss 2.92e-01, Validation-Loss 2.85e-01, Test-Loss 2.89e-01
# Epoch 38220, Training-Loss 2.72e-01, Validation-Loss 2.29e-01, Test-Loss 2.82e-01
# Epoch 38230, Training-Loss 2.14e-01, Validation-Loss 2.51e-01, Test-Loss 2.68e-01
# Epoch 38240, Training-Loss 2.80e-01, Validation-Loss 2.54e-01, Test-Loss 3.03e-01
# Epoch 38250, Training-Loss 3.13e-01, Validation-Loss 2.86e-01, Test-Loss 2.35e-01
# Epoch 38260, Training-Loss 2.22e-01, Validation-Loss 2.14e-01, Test-Loss 2.40e-01
# Epoch 38270, Training-Loss 2.78e-01, Validation-Loss 2.81e-01, Test-Loss 2.35e-01
# Epoch 38280, Training-Loss 3.14e-01, Validation-Loss 3.67e-01, Test-Loss 4.12e-01
# Epoch 38290, Training-Loss 3.04e-01, Validation-Loss 4.59e-01, Test-Loss 4.36e-01
# Epoch 38300, Training-Loss 3.27e-01, Validation-Loss 3.37e-01, Test-Loss 3.06e-01
# Epoch 38310, Training-Loss 4.11e-01, Validation-Loss 5.01e-01, Test-Loss 5.14e-01
# Epoch 38320, Training-Loss 3.80e-01, Validation-Loss 2.92e-01, Test-Loss 2.80e-01
# Epoch 38330, Training-Loss 5.17e-01, Validation-Loss 6.39e-01, Test-Loss 5.73e-01
# Epoch 38340, Training-Loss 3.50e-01, Validation-Loss 3.10e-01, Test-Loss 3.13e-01
# Epoch 38350, Training-Loss 4.41e-01, Validation-Loss 4.31e-01, Test-Loss 4.68e-01
# Epoch 38360, Training-Loss 2.93e-01, Validation-Loss 3.09e-01, Test-Loss 2.95e-01
# Epoch 38370, Training-Loss 5.50e-01, Validation-Loss 3.31e-01, Test-Loss 5.76e-01
# Epoch 38380, Training-Loss 2.89e-01, Validation-Loss 2.80e-01, Test-Loss 2.70e-01
# Epoch 38390, Training-Loss 2.84e-01, Validation-Loss 2.66e-01, Test-Loss 2.84e-01
# Epoch 38400, Training-Loss 2.63e-01, Validation-Loss 2.72e-01, Test-Loss 3.20e-01
# Epoch 38410, Training-Loss 3.34e-01, Validation-Loss 3.27e-01, Test-Loss 3.71e-01
# Epoch 38420, Training-Loss 4.72e-01, Validation-Loss 4.92e-01, Test-Loss 4.88e-01
# Epoch 38430, Training-Loss 9.15e-01, Validation-Loss 9.35e-01, Test-Loss 1.18e+00
# Epoch 38440, Training-Loss 6.42e-01, Validation-Loss 3.38e-01, Test-Loss 3.65e-01
# Epoch 38450, Training-Loss 4.23e-01, Validation-Loss 5.00e-01, Test-Loss 5.21e-01
# Epoch 38460, Training-Loss 3.03e-01, Validation-Loss 2.52e-01, Test-Loss 3.48e-01
# Epoch 38470, Training-Loss 3.15e-01, Validation-Loss 2.48e-01, Test-Loss 2.85e-01
# Epoch 38480, Training-Loss 2.88e-01, Validation-Loss 3.47e-01, Test-Loss 3.46e-01
# Epoch 38490, Training-Loss 5.72e-01, Validation-Loss 4.88e-01, Test-Loss 5.38e-01
# Epoch 38500, Training-Loss 3.05e-01, Validation-Loss 3.74e-01, Test-Loss 3.71e-01
# Epoch 38510, Training-Loss 5.95e-01, Validation-Loss 5.40e-01, Test-Loss 4.99e-01
# Epoch 38520, Training-Loss 3.69e-01, Validation-Loss 9.80e-01, Test-Loss 9.70e-01
# Epoch 38530, Training-Loss 1.21e+00, Validation-Loss 8.35e-01, Test-Loss 8.77e-01
# Epoch 38540, Training-Loss 5.82e-01, Validation-Loss 8.45e-01, Test-Loss 1.15e+00
# Epoch 38550, Training-Loss 2.91e-01, Validation-Loss 2.92e-01, Test-Loss 2.28e-01
# Epoch 38560, Training-Loss 5.53e-01, Validation-Loss 6.83e-01, Test-Loss 6.80e-01
# Epoch 38570, Training-Loss 3.34e-01, Validation-Loss 4.65e-01, Test-Loss 4.45e-01
# Epoch 38580, Training-Loss 2.99e-01, Validation-Loss 3.52e-01, Test-Loss 4.70e-01
# Epoch 38590, Training-Loss 2.72e-01, Validation-Loss 4.26e-01, Test-Loss 3.06e-01
# Epoch 38600, Training-Loss 2.45e-01, Validation-Loss 2.44e-01, Test-Loss 2.81e-01
# Epoch 38610, Training-Loss 3.04e-01, Validation-Loss 3.26e-01, Test-Loss 3.32e-01
# Epoch 38620, Training-Loss 3.19e-01, Validation-Loss 3.53e-01, Test-Loss 4.29e-01
# Epoch 38630, Training-Loss 2.69e-01, Validation-Loss 4.09e-01, Test-Loss 4.19e-01
# Epoch 38640, Training-Loss 6.17e-01, Validation-Loss 6.14e-01, Test-Loss 6.70e-01
# Epoch 38650, Training-Loss 2.86e-01, Validation-Loss 3.53e-01, Test-Loss 4.30e-01
# Epoch 38660, Training-Loss 4.70e-01, Validation-Loss 3.22e-01, Test-Loss 3.46e-01
# Epoch 38670, Training-Loss 2.78e-01, Validation-Loss 2.39e-01, Test-Loss 2.17e-01
# Epoch 38680, Training-Loss 2.50e-01, Validation-Loss 2.78e-01, Test-Loss 2.87e-01
# Epoch 38690, Training-Loss 3.01e-01, Validation-Loss 2.91e-01, Test-Loss 2.27e-01
# Epoch 38700, Training-Loss 3.77e-01, Validation-Loss 2.81e-01, Test-Loss 3.46e-01
# Epoch 38710, Training-Loss 4.07e-01, Validation-Loss 7.09e-01, Test-Loss 7.56e-01
# Epoch 38720, Training-Loss 3.13e-01, Validation-Loss 2.17e-01, Test-Loss 2.31e-01
# Epoch 38730, Training-Loss 2.75e-01, Validation-Loss 2.90e-01, Test-Loss 2.32e-01
# Epoch 38740, Training-Loss 3.53e-01, Validation-Loss 6.21e-01, Test-Loss 6.88e-01
# Epoch 38750, Training-Loss 3.68e-01, Validation-Loss 3.62e-01, Test-Loss 3.39e-01
# Epoch 38760, Training-Loss 3.19e-01, Validation-Loss 2.74e-01, Test-Loss 3.25e-01
# Epoch 38770, Training-Loss 5.18e-01, Validation-Loss 5.48e-01, Test-Loss 4.90e-01
# Epoch 38780, Training-Loss 8.88e-01, Validation-Loss 5.19e-01, Test-Loss 4.28e-01
# Epoch 38790, Training-Loss 3.44e-01, Validation-Loss 4.74e-01, Test-Loss 3.91e-01
# Epoch 38800, Training-Loss 4.07e-01, Validation-Loss 3.37e-01, Test-Loss 3.35e-01
# Epoch 38810, Training-Loss 3.51e-01, Validation-Loss 3.95e-01, Test-Loss 3.22e-01
# Epoch 38820, Training-Loss 3.70e-01, Validation-Loss 2.80e-01, Test-Loss 4.56e-01
# Epoch 38830, Training-Loss 4.97e-01, Validation-Loss 3.95e-01, Test-Loss 4.00e-01
# Epoch 38840, Training-Loss 4.06e-01, Validation-Loss 4.02e-01, Test-Loss 4.77e-01
# Epoch 38850, Training-Loss 2.85e-01, Validation-Loss 3.26e-01, Test-Loss 2.88e-01
# Epoch 38860, Training-Loss 3.30e-01, Validation-Loss 5.20e-01, Test-Loss 5.62e-01
# Epoch 38870, Training-Loss 3.31e-01, Validation-Loss 3.96e-01, Test-Loss 2.80e-01
# Epoch 38880, Training-Loss 3.92e-01, Validation-Loss 3.54e-01, Test-Loss 3.48e-01
# Epoch 38890, Training-Loss 4.75e-01, Validation-Loss 3.30e-01, Test-Loss 2.83e-01
# Epoch 38900, Training-Loss 7.04e-01, Validation-Loss 4.96e-01, Test-Loss 5.59e-01
# Epoch 38910, Training-Loss 7.60e-01, Validation-Loss 1.38e+00, Test-Loss 1.33e+00
# Epoch 38920, Training-Loss 3.86e-01, Validation-Loss 3.89e-01, Test-Loss 4.12e-01
# Epoch 38930, Training-Loss 2.97e-01, Validation-Loss 3.33e-01, Test-Loss 2.73e-01
# Epoch 38940, Training-Loss 2.91e-01, Validation-Loss 2.55e-01, Test-Loss 2.27e-01
# Epoch 38950, Training-Loss 3.44e-01, Validation-Loss 2.45e-01, Test-Loss 2.52e-01
# Epoch 38960, Training-Loss 3.83e-01, Validation-Loss 3.21e-01, Test-Loss 3.04e-01
# Epoch 38970, Training-Loss 2.35e-01, Validation-Loss 3.23e-01, Test-Loss 3.57e-01
# Epoch 38980, Training-Loss 2.85e-01, Validation-Loss 2.60e-01, Test-Loss 3.42e-01
# Epoch 38990, Training-Loss 5.26e-01, Validation-Loss 4.87e-01, Test-Loss 4.41e-01
# Epoch 39000, Training-Loss 6.59e-01, Validation-Loss 7.38e-01, Test-Loss 8.40e-01
# Epoch 39010, Training-Loss 2.48e-01, Validation-Loss 5.20e-01, Test-Loss 5.99e-01
# Epoch 39020, Training-Loss 6.35e-01, Validation-Loss 3.69e-01, Test-Loss 4.25e-01
# Epoch 39030, Training-Loss 5.99e-01, Validation-Loss 5.49e-01, Test-Loss 5.43e-01
# Epoch 39040, Training-Loss 5.32e-01, Validation-Loss 8.28e-01, Test-Loss 8.23e-01
# Epoch 39050, Training-Loss 2.76e-01, Validation-Loss 3.42e-01, Test-Loss 3.39e-01
# Epoch 39060, Training-Loss 2.22e-01, Validation-Loss 2.41e-01, Test-Loss 2.85e-01
# Epoch 39070, Training-Loss 2.50e-01, Validation-Loss 2.35e-01, Test-Loss 2.97e-01
# Epoch 39080, Training-Loss 4.26e-01, Validation-Loss 3.01e-01, Test-Loss 2.95e-01
# Epoch 39090, Training-Loss 3.24e-01, Validation-Loss 2.66e-01, Test-Loss 2.84e-01
# Epoch 39100, Training-Loss 9.69e-01, Validation-Loss 6.85e-01, Test-Loss 7.53e-01
# Epoch 39110, Training-Loss 1.28e+00, Validation-Loss 1.63e+00, Test-Loss 1.68e+00
# Epoch 39120, Training-Loss 1.10e+00, Validation-Loss 1.70e+00, Test-Loss 1.64e+00
# Epoch 39130, Training-Loss 5.01e-01, Validation-Loss 3.75e-01, Test-Loss 3.58e-01
# Epoch 39140, Training-Loss 2.35e-01, Validation-Loss 4.13e-01, Test-Loss 3.56e-01
# Epoch 39150, Training-Loss 2.67e-01, Validation-Loss 3.92e-01, Test-Loss 2.88e-01
# Epoch 39160, Training-Loss 3.25e-01, Validation-Loss 3.66e-01, Test-Loss 3.34e-01
# Epoch 39170, Training-Loss 4.17e-01, Validation-Loss 2.46e-01, Test-Loss 3.25e-01
# Epoch 39180, Training-Loss 5.55e-01, Validation-Loss 6.09e-01, Test-Loss 5.87e-01
# Epoch 39190, Training-Loss 6.49e-01, Validation-Loss 4.39e-01, Test-Loss 4.37e-01
# Epoch 39200, Training-Loss 4.04e-01, Validation-Loss 3.08e-01, Test-Loss 2.93e-01
# Epoch 39210, Training-Loss 2.84e-01, Validation-Loss 2.53e-01, Test-Loss 2.45e-01
# Epoch 39220, Training-Loss 4.60e-01, Validation-Loss 7.16e-01, Test-Loss 5.46e-01
# Epoch 39230, Training-Loss 3.13e-01, Validation-Loss 3.69e-01, Test-Loss 3.27e-01
# Epoch 39240, Training-Loss 3.32e-01, Validation-Loss 2.31e-01, Test-Loss 2.77e-01
# Epoch 39250, Training-Loss 4.41e-01, Validation-Loss 3.10e-01, Test-Loss 3.94e-01
# Epoch 39260, Training-Loss 3.72e-01, Validation-Loss 2.92e-01, Test-Loss 3.17e-01
# Epoch 39270, Training-Loss 2.77e-01, Validation-Loss 3.99e-01, Test-Loss 4.67e-01
# Epoch 39280, Training-Loss 4.91e-01, Validation-Loss 5.54e-01, Test-Loss 5.67e-01
# Epoch 39290, Training-Loss 1.20e+00, Validation-Loss 1.11e+00, Test-Loss 1.11e+00
# Epoch 39300, Training-Loss 7.90e-01, Validation-Loss 5.78e-01, Test-Loss 4.95e-01
# Epoch 39310, Training-Loss 8.25e-01, Validation-Loss 3.76e-01, Test-Loss 3.55e-01
# Epoch 39320, Training-Loss 3.45e-01, Validation-Loss 2.54e-01, Test-Loss 3.35e-01
# Epoch 39330, Training-Loss 2.27e-01, Validation-Loss 2.44e-01, Test-Loss 2.57e-01
# Epoch 39340, Training-Loss 3.55e-01, Validation-Loss 3.04e-01, Test-Loss 2.65e-01
# Epoch 39350, Training-Loss 2.95e-01, Validation-Loss 2.71e-01, Test-Loss 2.86e-01
# Epoch 39360, Training-Loss 3.17e-01, Validation-Loss 4.05e-01, Test-Loss 3.52e-01
# Epoch 39370, Training-Loss 2.75e-01, Validation-Loss 2.95e-01, Test-Loss 2.83e-01
# Epoch 39380, Training-Loss 3.16e-01, Validation-Loss 2.43e-01, Test-Loss 2.86e-01
# Epoch 39390, Training-Loss 4.07e-01, Validation-Loss 2.12e-01, Test-Loss 2.81e-01
# Epoch 39400, Training-Loss 3.13e-01, Validation-Loss 3.07e-01, Test-Loss 3.07e-01
# Epoch 39410, Training-Loss 2.71e-01, Validation-Loss 4.23e-01, Test-Loss 3.15e-01
# Epoch 39420, Training-Loss 3.45e-01, Validation-Loss 2.38e-01, Test-Loss 3.11e-01
# Epoch 39430, Training-Loss 4.76e-01, Validation-Loss 3.69e-01, Test-Loss 3.72e-01
# Epoch 39440, Training-Loss 1.88e-01, Validation-Loss 2.65e-01, Test-Loss 2.43e-01
# Epoch 39450, Training-Loss 3.72e-01, Validation-Loss 2.97e-01, Test-Loss 2.55e-01
# Epoch 39460, Training-Loss 3.82e-01, Validation-Loss 2.69e-01, Test-Loss 2.45e-01
# Epoch 39470, Training-Loss 2.87e-01, Validation-Loss 3.24e-01, Test-Loss 3.12e-01
# Epoch 39480, Training-Loss 3.60e-01, Validation-Loss 3.08e-01, Test-Loss 2.34e-01
# Epoch 39490, Training-Loss 3.10e-01, Validation-Loss 3.01e-01, Test-Loss 2.79e-01
# Epoch 39500, Training-Loss 8.31e-01, Validation-Loss 5.82e-01, Test-Loss 5.69e-01
# Epoch 39510, Training-Loss 5.49e-01, Validation-Loss 7.95e-01, Test-Loss 6.74e-01
# Epoch 39520, Training-Loss 2.50e-01, Validation-Loss 3.11e-01, Test-Loss 2.79e-01
# Epoch 39530, Training-Loss 2.80e-01, Validation-Loss 3.63e-01, Test-Loss 2.74e-01
# Epoch 39540, Training-Loss 3.35e-01, Validation-Loss 2.90e-01, Test-Loss 2.63e-01
# Epoch 39550, Training-Loss 5.32e-01, Validation-Loss 7.30e-01, Test-Loss 7.10e-01
# Epoch 39560, Training-Loss 3.43e-01, Validation-Loss 3.46e-01, Test-Loss 4.13e-01
# Epoch 39570, Training-Loss 4.09e-01, Validation-Loss 3.08e-01, Test-Loss 3.35e-01
# Epoch 39580, Training-Loss 2.91e-01, Validation-Loss 2.57e-01, Test-Loss 2.99e-01
# Epoch 39590, Training-Loss 6.22e-01, Validation-Loss 4.46e-01, Test-Loss 5.31e-01
# Epoch 39600, Training-Loss 7.36e-01, Validation-Loss 7.91e-01, Test-Loss 8.52e-01
# Epoch 39610, Training-Loss 2.53e-01, Validation-Loss 2.40e-01, Test-Loss 2.60e-01
# Epoch 39620, Training-Loss 3.49e-01, Validation-Loss 3.13e-01, Test-Loss 3.59e-01
# Epoch 39630, Training-Loss 6.29e-01, Validation-Loss 5.36e-01, Test-Loss 5.63e-01
# Epoch 39640, Training-Loss 5.51e-01, Validation-Loss 5.98e-01, Test-Loss 4.52e-01
# Epoch 39650, Training-Loss 3.55e-01, Validation-Loss 3.13e-01, Test-Loss 2.93e-01
# Epoch 39660, Training-Loss 3.39e-01, Validation-Loss 4.59e-01, Test-Loss 3.81e-01
# Epoch 39670, Training-Loss 4.17e-01, Validation-Loss 4.12e-01, Test-Loss 4.10e-01
# Epoch 39680, Training-Loss 3.11e-01, Validation-Loss 2.91e-01, Test-Loss 2.91e-01
# Epoch 39690, Training-Loss 2.31e-01, Validation-Loss 2.44e-01, Test-Loss 2.96e-01
# Epoch 39700, Training-Loss 2.41e-01, Validation-Loss 3.12e-01, Test-Loss 2.39e-01
# Epoch 39710, Training-Loss 3.00e-01, Validation-Loss 3.41e-01, Test-Loss 3.78e-01
# Epoch 39720, Training-Loss 3.01e-01, Validation-Loss 2.36e-01, Test-Loss 2.86e-01
# Epoch 39730, Training-Loss 3.78e-01, Validation-Loss 3.06e-01, Test-Loss 3.83e-01
# Epoch 39740, Training-Loss 2.53e-01, Validation-Loss 3.17e-01, Test-Loss 3.09e-01
# Epoch 39750, Training-Loss 4.45e-01, Validation-Loss 7.42e-01, Test-Loss 6.79e-01
# Epoch 39760, Training-Loss 6.99e-01, Validation-Loss 7.00e-01, Test-Loss 5.80e-01
# Epoch 39770, Training-Loss 2.75e-01, Validation-Loss 2.84e-01, Test-Loss 3.18e-01
# Epoch 39780, Training-Loss 3.33e-01, Validation-Loss 2.96e-01, Test-Loss 3.75e-01
# Epoch 39790, Training-Loss 3.82e-01, Validation-Loss 2.85e-01, Test-Loss 3.31e-01
# Epoch 39800, Training-Loss 3.09e-01, Validation-Loss 2.93e-01, Test-Loss 2.74e-01
# Epoch 39810, Training-Loss 4.49e-01, Validation-Loss 4.48e-01, Test-Loss 4.16e-01
# Epoch 39820, Training-Loss 4.16e-01, Validation-Loss 4.91e-01, Test-Loss 4.26e-01
# Epoch 39830, Training-Loss 3.74e-01, Validation-Loss 3.07e-01, Test-Loss 2.62e-01
# Epoch 39840, Training-Loss 6.03e-01, Validation-Loss 6.59e-01, Test-Loss 5.97e-01
# Epoch 39850, Training-Loss 5.46e-01, Validation-Loss 3.74e-01, Test-Loss 4.52e-01
# Epoch 39860, Training-Loss 3.94e-01, Validation-Loss 2.95e-01, Test-Loss 2.93e-01
# Epoch 39870, Training-Loss 3.13e-01, Validation-Loss 2.84e-01, Test-Loss 3.06e-01
# Epoch 39880, Training-Loss 2.41e-01, Validation-Loss 2.44e-01, Test-Loss 2.41e-01
# Epoch 39890, Training-Loss 5.89e-01, Validation-Loss 7.14e-01, Test-Loss 8.24e-01
# Epoch 39900, Training-Loss 7.63e-01, Validation-Loss 2.81e-01, Test-Loss 3.02e-01
# Epoch 39910, Training-Loss 2.14e+00, Validation-Loss 1.86e+00, Test-Loss 1.78e+00
# Epoch 39920, Training-Loss 1.08e+00, Validation-Loss 1.23e+00, Test-Loss 1.21e+00
# Epoch 39930, Training-Loss 1.24e+00, Validation-Loss 1.17e+00, Test-Loss 1.17e+00
# Epoch 39940, Training-Loss 4.61e-01, Validation-Loss 2.74e-01, Test-Loss 3.50e-01
# Epoch 39950, Training-Loss 3.14e-01, Validation-Loss 5.50e-01, Test-Loss 5.06e-01
# Epoch 39960, Training-Loss 3.52e-01, Validation-Loss 2.11e-01, Test-Loss 3.85e-01
# Epoch 39970, Training-Loss 3.12e-01, Validation-Loss 2.76e-01, Test-Loss 2.61e-01
# Epoch 39980, Training-Loss 4.06e-01, Validation-Loss 2.25e-01, Test-Loss 2.52e-01
# Epoch 39990, Training-Loss 4.13e-01, Validation-Loss 2.84e-01, Test-Loss 3.48e-01

# %%
test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# Epoch 40000, Test-Loss 3.35e-01,Test-Accuracy 5.02e-02

# %%
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

temp_nn = temp_nn.reshape(num_steps+1, num_points+2) # Reshape the predictions to a 2D array
print(temp_nn[:,0])
print(temperature_history_1[:,0])
plt.figure
plt.plot(time_ss, temp_nn[:,num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history_1[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()
# Out:
# [909.41626 909.39685 909.37744 ... 718.0757  718.0604  718.04504]
# [919.         917.81871701 917.72868875 ... 718.86453502 718.85175303
#  718.83897177]

# %%
m1 = model(torch.tensor([[0.0]]).to(device), torch.tensor([[25.0]]).to(device)).cpu().detach().numpy()

print(f"Temperature at x=0.0 and t=0.0 is {m1}")
# Out:
# Temperature at x=0.0 and t=0.0 is [[587.6548]]

# %%
# Assuming you have temperature_history and phi_history as lists of arrays
temperature_history = np.array(temperature_history)
phi_history = np.array(phi_history)

print(temperature_history.shape)

# Check the new shape after transposing
print("Transposed Temperature History Shape:", temperature_history.shape)
print("Transposed Phi History Shape:", phi_history.shape)

# Create a meshgrid for space and time coordinates
space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots
fig, (ax1) = plt.subplots(1, 1, figsize=(14, 6))

# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
fig.colorbar(im1, ax=ax1, label='Temperature')
plt.tight_layout()

plt.show()
# Out:
# (31470, 52)
# Transposed Temperature History Shape: (31470, 52)
# Transposed Phi History Shape: (31470, 52)

# %%
train_losses = np.array(train_losses)
test_losses = np.array(val_losses)




plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='ValLoss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

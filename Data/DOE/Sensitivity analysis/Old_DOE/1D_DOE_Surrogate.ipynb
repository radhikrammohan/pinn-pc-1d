# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools

from ht_simNy import sim1d



from pyDOE2 import fullfact
from pyDOE2 import fracfact

import statsmodels.api as sm

from statsmodels.formula.api import ols
from scipy.stats import ttest_ind
import seaborn as sns
from scipy import stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 15
#       9 import itertools
#      11 from ht_simNy import sim1d
# ---> 15 from pyDOE2 import fullfact
#      16 from pyDOE2 import fracfact
#      18 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'pyDOE2'

# %% [markdown]
# ### <center>Pareto analysis</center>

# %% [markdown]
# <p style="font-size:12px; font-family:'Times New Roman', sans-serif; line-height:1.6;">
#
# In this section sensitivity study of the soldification is performed with respect to different material properties and  initial/boundary conditions. The soldification time is the variable under study and it is calcualted based on solution of 1D heat transfer and phase change equation.
#
#
#
# Here the parameters/factors are as follows:-
#
# 1. Density for material in liquid state $\rho_l$.<br>
# 2. Density for material in solid state $\rho_s$.<br>
# 3. Latent Heat of Fusion <br>
# 4. Specific heat of material in liquid state $C_{pl}$ <br>
# 5. Specific heat of material in solid state $C_{ps}$ <br>
# 6. Thermal Conductivity of material in liquid state $k_l$<br>
# 7. Thermal Conductivity of material in solid state $k_s$ <br>
#
#
# Boundary conditions:-
# 8. Surrounding Temperature <br>
#
# Initial Conditions:-
#
# 9. Initial_temperature <br>
#
#
# </p>

# %% [markdown]
# The number of runs are large so a fractional factorial design is adopted.

# %% [markdown]
# ## Fractional Factorial Design

# %%
#Create a fractional factorial design

from pyDOE2 import fracfact

num_levels = 2
levels = [0, 1]
num_vars = 11
design2 = fracfact('a b c d e f abc abd ade aef bcd bcf')
L_level = 0.99
R_level = 1.01
perc_change = [0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.3, 0.03, 0.60, 0.30,0.30]


factor_levels = {
    'rho_l': [2428.20, 2491.79], #A
    'rho_s': [2678.20, 2741.79], #B
    'k_l': [76.64, 131.35],    #C
    'k_s': [68.84,123.55],      #D
    'cp_l': [1211.09, 1279.50], #E
    'cp_s': [928.79, 997.20],  #F
    'Surr_temp': [285.0,298.0], #G
    'L_fusion': [373731,404269], #H
    'temp_init': [901.0, 925.0], # J
    'heat_transfer_coefficient_left': [10.0, 15.0], #K
    'heat_transfer_coefficient_right': [10.0, 15.0], #L
    'Length': [10.0e-3, 20.0e-3],      #M
}


factor_names = list(factor_levels.keys())
# print (313.0 *(1+perc_change[6]))
# Create a DataFrame from the fractional factorial design
doe_df_sol_time_fracfact = pd.DataFrame(design2, columns=factor_names)

for factor, levels in factor_levels.items():
    doe_df_sol_time_fracfact[factor] = doe_df_sol_time_fracfact[factor].map({-1: levels[0], 1: levels[1]})
   
    
print(doe_df_sol_time_fracfact.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 #Create a fractional factorial design
# ----> 3 from pyDOE2 import fracfact
#       5 num_levels = 2
#       6 levels = [0, 1]
#
# ModuleNotFoundError: No module named 'pyDOE2'

# %%
FracFact_doe_sol_time = doe_df_sol_time_fracfact.copy()

FracFact_doe_sol_time['Lowest_Niyama'] = [0.0] * FracFact_doe_sol_time.shape[0] # Data frame inclduing the response variable

print(FracFact_doe_sol_time.shape)
# Out:
# (64, 13)

# %%
for i in range(FracFact_doe_sol_time.shape[0]):
    input_values = FracFact_doe_sol_time.iloc[i,:-1].values
    if input_values.size > 0:
        k = sim1d(*input_values)
        FracFact_doe_sol_time.at[i, 'Lowest_Niyama'] = k
# Out:
# (23120, 48)
# Lowest Niyama:3.78, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (21454, 48)
# Lowest Niyama:0.5, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (10485, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8546, 48)
# Lowest Niyama:7.96, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12095, 48)
# Lowest Niyama:3.41, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10655, 48)
# Lowest Niyama:8.81, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (29769, 48)
# Lowest Niyama:3.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (23811, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (28371, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (22128, 48)
# Lowest Niyama:3.13, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (17263, 48)
# Lowest Niyama:4.11, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (14013, 48)
# Lowest Niyama:3.37, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13793, 48)
# Lowest Niyama:4.56, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10159, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19809, 48)
# Lowest Niyama:0.4, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (17433, 48)
# Lowest Niyama:2.77, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (19796, 48)
# Lowest Niyama:0.66, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (25692, 48)
# Lowest Niyama:4.67, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (9225, 48)
# Lowest Niyama:7.37, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (9900, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10009, 48)
# Lowest Niyama:7.04, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (11771, 48)
# Lowest Niyama:5.77, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (23838, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (27093, 48)
# Lowest Niyama:3.6, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (22764, 48)
# Lowest Niyama:2.84, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (28435, 48)
# Lowest Niyama:0.21, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (13563, 48)
# Lowest Niyama:2.08, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (18288, 48)
# Lowest Niyama:4.99, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10977, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13091, 48)
# Lowest Niyama:5.11, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16029, 48)
# Lowest Niyama:2.32, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (21999, 48)
# Lowest Niyama:0.39, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (9282, 48)
# Lowest Niyama:1.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (12776, 48)
# Lowest Niyama:8.74, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16289, 48)
# Lowest Niyama:3.97, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (18504, 48)
# Lowest Niyama:0.36, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (19415, 48)
# Lowest Niyama:3.82, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (24454, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (12779, 48)
# Lowest Niyama:3.22, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (15285, 48)
# Lowest Niyama:6.68, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11543, 48)
# Lowest Niyama:5.34, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12903, 48)
# Lowest Niyama:2.22, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (25469, 48)
# Lowest Niyama:0.56, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (31187, 48)
# Lowest Niyama:2.69, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (20337, 48)
# Lowest Niyama:0.19, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (22509, 48)
# Lowest Niyama:2.76, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (8111, 48)
# Lowest Niyama:4.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (10203, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11798, 48)
# Lowest Niyama:7.08, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10177, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19819, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (14852, 48)
# Lowest Niyama:4.31, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (22967, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (18898, 48)
# Lowest Niyama:4.78, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (15295, 48)
# Lowest Niyama:6.26, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11632, 48)
# Lowest Niyama:2.97, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13269, 48)
# Lowest Niyama:2.63, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11568, 48)
# Lowest Niyama:5.9, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (30185, 48)
# Lowest Niyama:2.23, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (26977, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (24348, 48)
# Lowest Niyama:2.47, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (19300, 48)
# Lowest Niyama:0.56, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (9394, 48)
# Lowest Niyama:0.27, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8989, 48)
# Lowest Niyama:5.21, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02

# %% [markdown]
# ### Histogram of the Total Solidifcation time is plotted

# %%
plt.hist(FracFact_doe_sol_time['Lowest_Niyama'], bins=10, alpha=0.5, color='b')
plt.title('Lowest Niyama')
plt.xlabel('Dimensionless Niyama Number')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Regression model is developed

# %%
# Create the formula for the ANOVA
formula = 'Lowest_Niyama ~ C(rho_l) + C(rho_s) + C(k_l) + C(k_s) + \
           C(cp_l) + C(cp_s) + C(Surr_temp) + C(L_fusion) \
         + C(temp_init)+ C(heat_transfer_coefficient_left) + C(heat_transfer_coefficient_right)+ C(Length) \
         + C(rho_l):C(k_s) + C(rho_s):C(cp_l) + C(k_l):C(cp_s) + C(Surr_temp):C(L_fusion) + \
              C(temp_init):C(heat_transfer_coefficient_right) + C(heat_transfer_coefficient_left):C(Length)'

# Fit the model
model = sm.OLS.from_formula(formula, data=FracFact_doe_sol_time).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.107
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):              0.377
# Time:                        19:43:22   Log-Likelihood:                -139.17
# No. Observations:                  64   AIC:                             314.3
# Df Residuals:                      46   BIC:                             353.2
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================================================================
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                            1.3366      1.332      1.004      0.321      -1.344       4.017
# C(rho_l)[T.2491.79]                                                  0.5113      0.888      0.576      0.568      -1.276       2.298
# C(rho_s)[T.2741.79]                                                 -0.2787      0.888     -0.314      0.755      -2.066       1.508
# C(k_l)[T.131.35]                                                     0.1169      0.888      0.132      0.896      -1.670       1.904
# C(k_s)[T.123.55]                                                    -1.0387      0.888     -1.170      0.248      -2.826       0.748
# C(cp_l)[T.1279.5]                                                    0.0919      0.888      0.103      0.918      -1.695       1.879
# C(cp_s)[T.997.2]                                                     0.0856      0.888      0.096      0.924      -1.701       1.873
# C(Surr_temp)[T.298.0]                                                0.4394      0.888      0.495      0.623      -1.348       2.226
# C(L_fusion)[T.404269]                                                0.8200      0.888      0.924      0.360      -0.967       2.607
# C(temp_init)[T.925.0]                                                0.8432      0.662      1.274      0.209      -0.489       2.175
# C(heat_transfer_coefficient_left)[T.15.0]                            0.0896      0.662      0.135      0.893      -1.242       1.422
# C(heat_transfer_coefficient_right)[T.15.0]                           0.3594      0.662      0.543      0.590      -0.973       1.691
# C(Length)[T.0.02]                                                    2.0546      0.662      3.105      0.003       0.723       3.387
# C(rho_l)[T.2491.79]:C(k_s)[T.123.55]                                -0.2006      1.256     -0.160      0.874      -2.728       2.327
# C(rho_s)[T.2741.79]:C(cp_l)[T.1279.5]                               -0.2044      1.256     -0.163      0.871      -2.732       2.323
# C(k_l)[T.131.35]:C(cp_s)[T.997.2]                                   -0.3356      1.256     -0.267      0.790      -2.863       2.192
# C(Surr_temp)[T.298.0]:C(L_fusion)[T.404269]                         -1.2619      1.256     -1.005      0.320      -3.789       1.265
# C(temp_init)[T.925.0]:C(heat_transfer_coefficient_right)[T.15.0]    -0.2570      0.662     -0.388      0.700      -1.589       1.075
# C(heat_transfer_coefficient_left)[T.15.0]:C(Length)[T.0.02]          0.2139      0.662      0.323      0.748      -1.118       1.546
# ==============================================================================
# Omnibus:                       18.657   Durbin-Watson:                   2.607
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.476
# Skew:                          -0.229   Prob(JB):                        0.107
# Kurtosis:                       1.788   Cond. No.                     2.45e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.95e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Plot of Residuals

# %%
residuals_ols = model.resid
FracFact_doe_sol_time['Residuals'] =residuals_ols
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model.fittedvalues, residuals_ols)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Fitted Values')
plt.xlabel('Seconds')
plt.ylabel('Residuals')
plt.show()


# print (f"This is followed by the histogram of the residuals")
# plt.hist(residuals_ols, bins=10, alpha=0.5, color='b')
# plt.title('Residuals Histogram')
# plt.xlabel('Seconds')
# plt.ylabel('Frequency')
# plt.show()
# Out:
# The plots of the residuals vs. fitted values are shown below

# %% [markdown]
# ### Normality of Residuals check

# %%
from scipy.stats import shapiro

# Shapiro-Wilk Test
stat, p_value = shapiro(residuals_ols)
print('Shapiro-Wilk Test Statistic:', stat)
print('p-value:', p_value)

if p_value > 0.05:
    print('The residuals are normally distributed (fail to reject H0).')
else:
    print('The residuals are not normally distributed (reject H0).')
# Out:
# Shapiro-Wilk Test Statistic: 0.9387560349188399
# p-value: 0.0033220406615377556
# The residuals are not normally distributed (reject H0).

# %% [markdown]
# The interaction was observed among rho_l and cp_s , rho_s and cp_s , cp_l and cp_s  & cp_s and temp_init.

# %% [markdown]
# ## Center points check

# %%
num_center_points = 1

center_point = {factor: np.mean(levels) for factor,levels in factor_levels.items()}

center_pt_df = pd.DataFrame([center_point] * num_center_points, columns=factor_names)

doe_center_pt = pd.concat([doe_df_sol_time_fracfact, center_pt_df], ignore_index=True)
print(doe_center_pt.shape)
# Out:
# (65, 12)

# %% [markdown]
# ### Factorial design

# %%
Fractional_Factorial_doe_center_pt = doe_center_pt.copy()

Fractional_Factorial_doe_center_pt['Lowest_Niyama'] = [0.0] * Fractional_Factorial_doe_center_pt.shape[0]

print(Fractional_Factorial_doe_center_pt.shape)
# Out:
# (65, 13)

# %%
for i in range(Fractional_Factorial_doe_center_pt.shape[0]):
    input_values = Fractional_Factorial_doe_center_pt.iloc[i,:-1].values
    k= sim1d(*input_values)
    Fractional_Factorial_doe_center_pt.at[i, 'Lowest_Niyama'] = k
# Out:
# (23120, 48)
# Lowest Niyama:3.78, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (21454, 48)
# Lowest Niyama:0.5, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (10485, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8546, 48)
# Lowest Niyama:7.96, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12095, 48)
# Lowest Niyama:3.41, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10655, 48)
# Lowest Niyama:8.81, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (29769, 48)
# Lowest Niyama:3.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (23811, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (28371, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (22128, 48)
# Lowest Niyama:3.13, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (17263, 48)
# Lowest Niyama:4.11, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (14013, 48)
# Lowest Niyama:3.37, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13793, 48)
# Lowest Niyama:4.56, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10159, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19809, 48)
# Lowest Niyama:0.4, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (17433, 48)
# Lowest Niyama:2.77, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (19796, 48)
# Lowest Niyama:0.66, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (25692, 48)
# Lowest Niyama:4.67, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (9225, 48)
# Lowest Niyama:7.37, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (9900, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10009, 48)
# Lowest Niyama:7.04, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (11771, 48)
# Lowest Niyama:5.77, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (23838, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (27093, 48)
# Lowest Niyama:3.6, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (22764, 48)
# Lowest Niyama:2.84, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (28435, 48)
# Lowest Niyama:0.21, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (13563, 48)
# Lowest Niyama:2.08, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (18288, 48)
# Lowest Niyama:4.99, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10977, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13091, 48)
# Lowest Niyama:5.11, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16029, 48)
# Lowest Niyama:2.32, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (21999, 48)
# Lowest Niyama:0.39, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (9282, 48)
# Lowest Niyama:1.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (12776, 48)
# Lowest Niyama:8.74, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16289, 48)
# Lowest Niyama:3.97, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (18504, 48)
# Lowest Niyama:0.36, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (19415, 48)
# Lowest Niyama:3.82, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (24454, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (12779, 48)
# Lowest Niyama:3.22, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (15285, 48)
# Lowest Niyama:6.68, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11543, 48)
# Lowest Niyama:5.34, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12903, 48)
# Lowest Niyama:2.22, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (25469, 48)
# Lowest Niyama:0.56, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (31187, 48)
# Lowest Niyama:2.69, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (20337, 48)
# Lowest Niyama:0.19, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (22509, 48)
# Lowest Niyama:2.76, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (8111, 48)
# Lowest Niyama:4.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (10203, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11798, 48)
# Lowest Niyama:7.08, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10177, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19819, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (14852, 48)
# Lowest Niyama:4.31, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (22967, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (18898, 48)
# Lowest Niyama:4.78, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (15295, 48)
# Lowest Niyama:6.26, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11632, 48)
# Lowest Niyama:2.97, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13269, 48)
# Lowest Niyama:2.63, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11568, 48)
# Lowest Niyama:5.9, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (30185, 48)
# Lowest Niyama:2.23, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (26977, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (24348, 48)
# Lowest Niyama:2.47, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (19300, 48)
# Lowest Niyama:0.56, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (9394, 48)
# Lowest Niyama:0.27, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8989, 48)
# Lowest Niyama:5.21, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (13331, 48)
# Lowest Niyama:4.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015

# %% [markdown]
# CSV file generator

# %% [markdown]
# ### Plot

# %%
counts = range(1,len(Fractional_Factorial_doe_center_pt)+1)

plt.scatter(counts,Fractional_Factorial_doe_center_pt['Lowest_Niyama'], alpha=0.5, color='b')
plt.title('Lowest Niyama')
plt.xlabel('Run Number')
plt.ylabel('Lowest Niyama')
plt.show()

# %% [markdown]
# ### Regression Model

# %%
formula5 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model5 = sm.OLS.from_formula(formula5, data=Fractional_Factorial_doe_center_pt.iloc[:-1]).fit()
print(model5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     1.594
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):              0.123
# Time:                        19:47:27   Log-Likelihood:                -139.95
# No. Observations:                  64   AIC:                             305.9
# Df Residuals:                      51   BIC:                             334.0
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                         -22.9582     46.654     -0.492      0.625    -116.621      70.704
# rho_l                               0.0065      0.009      0.681      0.499      -0.013       0.026
# rho_s                              -0.0060      0.009     -0.631      0.531      -0.025       0.013
# k_l                                -0.0009      0.011     -0.084      0.933      -0.023       0.021
# k_s                                -0.0208      0.011     -1.887      0.065      -0.043       0.001
# cp_l                               -0.0002      0.009     -0.017      0.986      -0.018       0.018
# cp_s                               -0.0012      0.009     -0.136      0.892      -0.019       0.017
# Surr_temp                          -0.0147      0.046     -0.317      0.752      -0.108       0.078
# L_fusion                         6.191e-06   1.98e-05      0.313      0.755   -3.35e-05    4.59e-05
# temp_init                           0.0298      0.025      1.184      0.242      -0.021       0.080
# heat_transfer_coefficient_left      0.0393      0.121      0.326      0.746      -0.203       0.282
# heat_transfer_coefficient_right     0.0462      0.121      0.383      0.704      -0.196       0.289
# Length                            216.1562     60.351      3.582      0.001      94.998     337.315
# ==============================================================================
# Omnibus:                       17.103   Durbin-Watson:                   2.569
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                5.050
# Skew:                          -0.357   Prob(JB):                       0.0801
# Kurtosis:                       1.824   Cond. No.                     7.79e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.79e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model5.predict(Fractional_Factorial_doe_center_pt.iloc[-1])
print(f'Predicted value of the response variable: {y_pred.values[0]}')
error = Fractional_Factorial_doe_center_pt.iloc[-1]['Lowest_Niyama'] - y_pred.values[0]
print(f'Prediction error: {error}')

# Perform a t-test to determine if the prediction error is significantly different from zero
# Extract the residuals from the model
residuals = model5.resid

# Calculate the mean and standard error of the residuals
mean_residuals = np.mean(residuals)
std_error = np.std(residuals, ddof=1) / np.sqrt(len(residuals))

# Perform t-test on the prediction error
t_statistic = (error - mean_residuals) / std_error
df = len(residuals) - 1  # Degrees of freedom
p_value = 2 * (1 - stats.t.cdf(np.abs(t_statistic), df))

print(f't-statistic: {t_statistic}')
print(f'p-value: {p_value}')

# Interpretation of the t-test result
if p_value < 0.05:
    print("The prediction error is significantly different from zero (reject null hypothesis).")
else:
    print("The prediction error is not significantly different from zero (fail to reject null hypothesis).")
# Out:
# Predicted value of the response variable: 2.872343750001903
# Prediction error: 1.667656249998097
# t-statistic: 6.142437385983072
# p-value: 6.067849289692617e-08
# The prediction error is significantly different from zero (reject null hypothesis).

# %%
residual5 = model5.resid
Fractional_Factorial_doe_center_pt['Residuals'] =residual5
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model5.fittedvalues, residual5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Model Output')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()
# Out:
# The plots of the residuals vs. fitted values are shown below

# %% [markdown]
# #### Anova

# %%
from statsmodels.formula.api import ols

formula7 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model7 = ols(formula7, data=Fractional_Factorial_doe_center_pt).fit()

anova_results7 = sm.stats.anova_lm(model7, typ=2)

print(anova_results7)
# Out:
#                                      sum_sq    df          F    PR(>F)
# rho_l                              2.701914   1.0   0.468425  0.496752
# rho_s                              2.321814   1.0   0.402528  0.528568
# k_l                                0.041514   1.0   0.007197  0.932717
# k_s                               20.759414   1.0   3.599012  0.063374
# cp_l                               0.001702   1.0   0.000295  0.986362
# cp_s                               0.108077   1.0   0.018737  0.891652
# Surr_temp                          0.587139   1.0   0.101791  0.750969
# L_fusion                           0.571914   1.0   0.099151  0.754110
# temp_init                          8.172452   1.0   1.416839  0.239330
# heat_transfer_coefficient_left     0.618189   1.0   0.107174  0.744699
# heat_transfer_coefficient_right    0.853314   1.0   0.147937  0.702083
# Length                            74.757639   1.0  12.960559  0.000710
# Residual                         299.940559  52.0        NaN       NaN

# %% [markdown]
# #### Main effects with center points

# %%
mean_response_center = {}

for factor in factor_names:
    mean_response_center[factor] = Fractional_Factorial_doe_center_pt.groupby(factor)['Lowest_Niyama'].mean()

# print(mean_response_center)
plt.figure(figsize=(25, 10))

for i, factor in enumerate(factor_names):
    plt.subplot(2, 8, i+1)

    mean_responses = mean_response_center[factor]


    center_point = mean_responses.iloc[-2]
    center_point_index = mean_responses.index[-2]
    # print(center_point_index,center)
    non_center_points_low = mean_responses.iloc[0]
    non_center_points_low_index = mean_responses.index[0]
    non_center_points_high = mean_responses.iloc[-1]
    non_center_points_high_index = mean_responses.index[-1]

    plt.plot([non_center_points_low_index,non_center_points_high_index], [non_center_points_low,non_center_points_high],marker='o', color='b')
    
    # Plotting the center points
    center_points = mean_response_center[factor]
    plt.scatter([center_point_index], [center_point], color='r', label='Center Points')
    
    # # Plot all individual data points for the factor
    # all_data_points = Fractional_Factorial_doe_center_pt.groupby(factor)['Lowest_Niyama']
    # for key, group in all_data_points:
    #     plt.scatter([key]*len(group), group, alpha=0.3, color='gray')

    plt.title(f'Mean Response vs. {factor}')
    plt.xlabel(factor)
    plt.ylabel('Lowest_Niyama')

plt.tight_layout()
plt.show()

# %%
formula8 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length + rho_l*rho_s + rho_l:rho_s + rho_l:heat_transfer_coefficient_left + rho_l:heat_transfer_coefficient_right + rho_l:Length + rho_s:heat_transfer_coefficient_left + rho_s:heat_transfer_coefficient_right + rho_s:Length + heat_transfer_coefficient_left:heat_transfer_coefficient_right + heat_transfer_coefficient_left:Length + heat_transfer_coefficient_right:Length'

# %%
model8 = ols(formula8, data=Fractional_Factorial_doe_center_pt).fit()
print(model8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     13.85
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):           7.27e-13
# Time:                        19:47:29   Log-Likelihood:                -83.595
# No. Observations:                  65   AIC:                             213.2
# Df Residuals:                      42   BIC:                             263.2
# Df Model:                          22
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -313.9073    906.183     -0.346      0.731   -2142.659    1514.844
# rho_l                                                              0.1459      0.367      0.398      0.693      -0.594       0.886
# rho_s                                                              0.1278      0.333      0.384      0.703      -0.544       0.800
# k_l                                                               -0.0009      0.005     -0.187      0.853      -0.011       0.009
# k_s                                                               -0.0208      0.005     -4.183      0.000      -0.031      -0.011
# cp_l                                                              -0.0002      0.004     -0.038      0.970      -0.008       0.008
# cp_s                                                              -0.0012      0.004     -0.302      0.764      -0.009       0.007
# Surr_temp                                                         -0.0147      0.021     -0.703      0.486      -0.057       0.028
# L_fusion                                                        6.191e-06   8.92e-06      0.694      0.491   -1.18e-05    2.42e-05
# temp_init                                                          0.0298      0.011      2.625      0.012       0.007       0.053
# heat_transfer_coefficient_left                                   -15.4823      6.278     -2.466      0.018     -28.151      -2.814
# heat_transfer_coefficient_right                                    5.4671      6.278      0.871      0.389      -7.202      18.136
# Length                                                           399.7858   3140.700      0.127      0.899   -5938.404    6737.975
# rho_l:rho_s                                                    -5.487e-05      0.000     -0.407      0.686      -0.000       0.000
# rho_l:heat_transfer_coefficient_left                              -0.0004      0.002     -0.242      0.810      -0.004       0.003
# rho_l:heat_transfer_coefficient_right                              0.0006      0.002      0.339      0.737      -0.003       0.004
# rho_l:Length                                                       0.4806      0.856      0.561      0.578      -1.248       2.209
# rho_s:heat_transfer_coefficient_left                               0.0047      0.002      2.744      0.009       0.001       0.008
# rho_s:heat_transfer_coefficient_right                             -0.0040      0.002     -2.317      0.025      -0.007      -0.001
# rho_s:Length                                                      -0.5278      0.856     -0.616      0.541      -2.256       1.201
# heat_transfer_coefficient_left:heat_transfer_coefficient_right     0.3054      0.022     14.020      0.000       0.261       0.349
# heat_transfer_coefficient_left:Length                             -0.8625     10.893     -0.079      0.937     -22.845      21.120
# heat_transfer_coefficient_right:Length                             6.0125     10.893      0.552      0.584     -15.970      27.995
# ==============================================================================
# Omnibus:                        0.074   Durbin-Watson:                   2.446
# Prob(Omnibus):                  0.964   Jarque-Bera (JB):                0.130
# Skew:                          -0.074   Prob(JB):                        0.937
# Kurtosis:                       2.838   Cond. No.                     1.55e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.api as sm
import pandas as pd
import itertools

# Define the list of variables
variables = ['rho_l', 'rho_s', 'k_l', 'k_s', 'cp_l', 'cp_s', 'Surr_temp', 'L_fusion', 'temp_init', 'heat_transfer_coefficient_left', 'heat_transfer_coefficient_right', 'Length']

# Generate interaction terms
combinations = list(itertools.combinations(variables, 2))
interaction_terms = ['{}*{}'.format(a, b) for a, b in combinations]

# Generate quadratic (axial) terms
quadratic_terms = ['np.power({}, 2)'.format(var) for var in variables]

# Base formula with main effects
base_formula = 'Lowest_Niyama ~ ' + ' + '.join(variables)

# Combine all terms into the final formula
all_terms = variables + interaction_terms + quadratic_terms
final_formula = 'Lowest_Niyama ~ ' + ' + '.join(all_terms)

# Print the final formula
print("Final Formula for Statsmodels:")
print(final_formula)

# Assuming Fractional_Factorial_doe_center_pt is your DataFrame with the necessary data
# Fit the model using all but the last row of the DataFrame
model9 = sm.OLS.from_formula(final_formula, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model9.summary())
# Out:
# Final Formula for Statsmodels:
# Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + cp_l + cp_s + Surr_temp + L_fusion + temp_init + heat_transfer_coefficient_left + heat_transfer_coefficient_right + Length + rho_l*rho_s + rho_l*k_l + rho_l*k_s + rho_l*cp_l + rho_l*cp_s + rho_l*Surr_temp + rho_l*L_fusion + rho_l*temp_init + rho_l*heat_transfer_coefficient_left + rho_l*heat_transfer_coefficient_right + rho_l*Length + rho_s*k_l + rho_s*k_s + rho_s*cp_l + rho_s*cp_s + rho_s*Surr_temp + rho_s*L_fusion + rho_s*temp_init + rho_s*heat_transfer_coefficient_left + rho_s*heat_transfer_coefficient_right + rho_s*Length + k_l*k_s + k_l*cp_l + k_l*cp_s + k_l*Surr_temp + k_l*L_fusion + k_l*temp_init + k_l*heat_transfer_coefficient_left + k_l*heat_transfer_coefficient_right + k_l*Length + k_s*cp_l + k_s*cp_s + k_s*Surr_temp + k_s*L_fusion + k_s*temp_init + k_s*heat_transfer_coefficient_left + k_s*heat_transfer_coefficient_right + k_s*Length + cp_l*cp_s + cp_l*Surr_temp + cp_l*L_fusion + cp_l*temp_init + cp_l*heat_transfer_coefficient_left + cp_l*heat_transfer_coefficient_right + cp_l*Length + cp_s*Surr_temp + cp_s*L_fusion + cp_s*temp_init + cp_s*heat_transfer_coefficient_left + cp_s*heat_transfer_coefficient_right + cp_s*Length + Surr_temp*L_fusion + Surr_temp*temp_init + Surr_temp*heat_transfer_coefficient_left + Surr_temp*heat_transfer_coefficient_right + Surr_temp*Length + L_fusion*temp_init + L_fusion*heat_transfer_coefficient_left + L_fusion*heat_transfer_coefficient_right + L_fusion*Length + temp_init*heat_transfer_coefficient_left + temp_init*heat_transfer_coefficient_right + temp_init*Length + heat_transfer_coefficient_left*heat_transfer_coefficient_right + heat_transfer_coefficient_left*Length + heat_transfer_coefficient_right*Length + np.power(rho_l, 2) + np.power(rho_s, 2) + np.power(k_l, 2) + np.power(k_s, 2) + np.power(cp_l, 2) + np.power(cp_s, 2) + np.power(Surr_temp, 2) + np.power(L_fusion, 2) + np.power(temp_init, 2) + np.power(heat_transfer_coefficient_left, 2) + np.power(heat_transfer_coefficient_right, 2) + np.power(Length, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     4.830
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):           0.000136
# Time:                        19:47:30   Log-Likelihood:                -74.599
# No. Observations:                  65   AIC:                             237.2
# Df Residuals:                      21   BIC:                             332.9
# Df Model:                          43
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                      -2.506e-07   3.33e-07     -0.752      0.460   -9.43e-07    4.42e-07
# rho_l                                                          -1.652e-06   1.94e-06     -0.850      0.405    -5.7e-06    2.39e-06
# rho_s                                                           -1.84e-06   2.18e-06     -0.843      0.409   -6.38e-06     2.7e-06
# k_l                                                             -4.16e-08   9.21e-07     -0.045      0.964   -1.96e-06    1.87e-06
# k_s                                                             3.949e-07   5.99e-07      0.659      0.517   -8.51e-07    1.64e-06
# cp_l                                                           -4.983e-07   4.88e-07     -1.022      0.319   -1.51e-06    5.16e-07
# cp_s                                                           -4.061e-07   2.63e-07     -1.542      0.138   -9.54e-07    1.41e-07
# Surr_temp                                                      -2.629e-07   3.78e-07     -0.695      0.495   -1.05e-06    5.24e-07
# L_fusion                                                       -4.303e-05    6.7e-05     -0.642      0.528      -0.000    9.63e-05
# temp_init                                                      -6.126e-07   7.02e-07     -0.872      0.393   -2.07e-06    8.48e-07
# heat_transfer_coefficient_left                                 -1.643e-06   7.36e-07     -2.232      0.037   -3.17e-06   -1.12e-07
# heat_transfer_coefficient_right                                 -2.98e-08   2.42e-07     -0.123      0.903   -5.32e-07    4.73e-07
# Length                                                         -1.661e-05   5.09e-05     -0.327      0.747      -0.000    8.91e-05
# rho_l:rho_s                                                        0.0002      0.000      0.664      0.514      -0.000       0.001
# rho_l:k_l                                                          0.0002      0.000      0.793      0.437      -0.000       0.001
# rho_l:k_s                                                         -0.0001   9.86e-05     -1.039      0.310      -0.000       0.000
# rho_l:cp_l                                                      6.193e-05      0.000      0.415      0.682      -0.000       0.000
# rho_l:cp_s                                                      8.459e-05      0.000      0.509      0.616      -0.000       0.000
# rho_l:Surr_temp                                                   -0.0001      0.000     -0.357      0.724      -0.001       0.001
# rho_l:L_fusion                                                  4.982e-08   5.74e-07      0.087      0.932   -1.14e-06    1.24e-06
# rho_l:temp_init                                                 1.317e-05   9.16e-05      0.144      0.887      -0.000       0.000
# rho_l:heat_transfer_coefficient_left                              -0.0040      0.002     -2.281      0.033      -0.008      -0.000
# rho_l:heat_transfer_coefficient_right                          -5.223e-05      0.001     -0.099      0.922      -0.001       0.001
# rho_l:Length                                                      -0.0409      0.125     -0.327      0.747      -0.301       0.219
# rho_s:k_l                                                      -2.039e-05      0.000     -0.121      0.905      -0.000       0.000
# rho_s:k_s                                                          0.0001      0.000      0.505      0.619      -0.000       0.001
# rho_s:cp_l                                                        -0.0002      0.000     -1.107      0.281      -0.000       0.000
# rho_s:cp_s                                                      4.892e-05      0.000      0.317      0.754      -0.000       0.000
# rho_s:Surr_temp                                                -7.045e-05      0.000     -0.252      0.804      -0.001       0.001
# rho_s:L_fusion                                                  2.152e-07   4.06e-07      0.530      0.602    -6.3e-07    1.06e-06
# rho_s:temp_init                                                -6.761e-05   9.23e-05     -0.733      0.472      -0.000       0.000
# rho_s:heat_transfer_coefficient_left                               0.0047      0.002      2.228      0.037       0.000       0.009
# rho_s:heat_transfer_coefficient_right                          -9.047e-05      0.001     -0.152      0.881      -0.001       0.001
# rho_s:Length                                                      -0.0450      0.138     -0.327      0.747      -0.332       0.242
# k_l:k_s                                                           -0.0003      0.001     -0.510      0.616      -0.002       0.001
# k_l:cp_l                                                        8.633e-05      0.000      0.482      0.635      -0.000       0.000
# k_l:cp_s                                                       -8.202e-05      0.000     -0.454      0.655      -0.000       0.000
# k_l:Surr_temp                                                  -8.204e-05      0.000     -0.275      0.786      -0.001       0.001
# k_l:L_fusion                                                     7.15e-08   4.16e-07      0.172      0.865   -7.93e-07    9.36e-07
# k_l:temp_init                                                     -0.0003      0.001     -0.636      0.531      -0.001       0.001
# k_l:heat_transfer_coefficient_left                                -0.0010      0.002     -0.396      0.696      -0.006       0.004
# k_l:heat_transfer_coefficient_right                            -9.232e-05      0.000     -0.714      0.483      -0.000       0.000
# k_l:Length                                                        -0.0017      0.005     -0.327      0.747      -0.013       0.009
# k_s:cp_l                                                        2.519e-05      0.000      0.154      0.879      -0.000       0.000
# k_s:cp_s                                                           0.0001      0.000      0.712      0.484      -0.000       0.001
# k_s:Surr_temp                                                      0.0001      0.000      0.570      0.575      -0.000       0.001
# k_s:L_fusion                                                   -6.018e-07   8.49e-07     -0.709      0.486   -2.37e-06    1.16e-06
# k_s:temp_init                                                   9.592e-05   9.48e-05      1.011      0.323      -0.000       0.000
# k_s:heat_transfer_coefficient_left                                -0.0002      0.000     -1.302      0.207      -0.001       0.000
# k_s:heat_transfer_coefficient_right                            -6.015e-06      0.000     -0.034      0.973      -0.000       0.000
# k_s:Length                                                        -0.0016      0.005     -0.328      0.746      -0.012       0.009
# cp_l:cp_s                                                          0.0002      0.000      1.316      0.202      -0.000       0.001
# cp_l:Surr_temp                                                 -4.439e-05      0.001     -0.060      0.953      -0.002       0.002
# cp_l:L_fusion                                                   5.208e-08   3.25e-07      0.160      0.874   -6.23e-07    7.28e-07
# cp_l:temp_init                                                    -0.0002      0.000     -1.020      0.319      -0.000       0.000
# cp_l:heat_transfer_coefficient_left                               -0.0021      0.001     -2.408      0.025      -0.004      -0.000
# cp_l:heat_transfer_coefficient_right                               0.0005      0.001      0.505      0.619      -0.002       0.003
# cp_l:Length                                                       -0.0207      0.063     -0.327      0.747      -0.152       0.111
# cp_s:Surr_temp                                                     0.0004      0.001      0.491      0.629      -0.001       0.002
# cp_s:L_fusion                                                  -1.535e-07   3.21e-07     -0.478      0.638   -8.21e-07    5.14e-07
# cp_s:temp_init                                                  6.617e-05      0.000      0.169      0.868      -0.001       0.001
# cp_s:heat_transfer_coefficient_left                               -0.0017      0.001     -2.444      0.023      -0.003      -0.000
# cp_s:heat_transfer_coefficient_right                              -0.0029      0.002     -1.478      0.154      -0.007       0.001
# cp_s:Length                                                       -0.0160      0.049     -0.327      0.747      -0.118       0.086
# Surr_temp:L_fusion                                              -6.02e-07   4.53e-06     -0.133      0.896      -1e-05    8.82e-06
# Surr_temp:temp_init                                                0.0005      0.001      0.481      0.636      -0.002       0.003
# Surr_temp:heat_transfer_coefficient_left                          -0.0016      0.010     -0.153      0.880      -0.023       0.020
# Surr_temp:heat_transfer_coefficient_right                      -2.969e-05   7.72e-05     -0.385      0.704      -0.000       0.000
# Surr_temp:Length                                                  -0.0048      0.015     -0.327      0.747      -0.036       0.026
# L_fusion:temp_init                                              6.524e-07   1.04e-06      0.630      0.536    -1.5e-06    2.81e-06
# L_fusion:heat_transfer_coefficient_left                        -1.068e-06   4.39e-06     -0.243      0.810   -1.02e-05    8.07e-06
# L_fusion:heat_transfer_coefficient_right                       -3.162e-06   6.35e-06     -0.498      0.624   -1.64e-05    1.01e-05
# L_fusion:Length                                                    0.0013      0.002      0.577      0.570      -0.003       0.006
# temp_init:heat_transfer_coefficient_left                          -0.0015      0.001     -2.248      0.035      -0.003      -0.000
# temp_init:heat_transfer_coefficient_right                      -3.033e-05      0.000     -0.151      0.882      -0.000       0.000
# temp_init:Length                                                  -0.0122      0.046     -0.264      0.795      -0.109       0.084
# heat_transfer_coefficient_left:heat_transfer_coefficient_right     0.3055      0.027     11.389      0.000       0.250       0.361
# heat_transfer_coefficient_left:Length                             -0.0002      0.001     -0.327      0.747      -0.002       0.001
# heat_transfer_coefficient_right:Length                            -0.0002      0.001     -0.327      0.747      -0.002       0.001
# np.power(rho_l, 2)                                                -0.0001      0.000     -1.096      0.285      -0.000       0.000
# np.power(rho_s, 2)                                             -8.075e-05      0.000     -0.702      0.490      -0.000       0.000
# np.power(k_l, 2)                                                  -0.0006      0.001     -0.710      0.485      -0.002       0.001
# np.power(k_s, 2)                                                  -0.0005      0.001     -0.716      0.482      -0.002       0.001
# np.power(cp_l, 2)                                               7.255e-05      0.000      0.273      0.788      -0.000       0.001
# np.power(cp_s, 2)                                                 -0.0004      0.000     -0.893      0.382      -0.001       0.000
# np.power(Surr_temp, 2)                                         -6.257e-05      0.000     -0.437      0.667      -0.000       0.000
# np.power(L_fusion, 2)                                          -1.169e-09   2.47e-09     -0.474      0.641    -6.3e-09    3.96e-09
# np.power(temp_init, 2)                                         -1.887e-05   5.94e-05     -0.317      0.754      -0.000       0.000
# np.power(heat_transfer_coefficient_left, 2)                    -4.581e-05   1.76e-05     -2.596      0.017   -8.25e-05   -9.11e-06
# np.power(heat_transfer_coefficient_right, 2)                   -5.486e-06   8.79e-06     -0.624      0.539   -2.38e-05    1.28e-05
# np.power(Length, 2)                                            -4.984e-07   1.53e-06     -0.327      0.747   -3.67e-06    2.67e-06
# ==============================================================================
# Omnibus:                        0.009   Durbin-Watson:                   2.519
# Prob(Omnibus):                  0.996   Jarque-Bera (JB):                0.149
# Skew:                          -0.004   Prob(JB):                        0.928
# Kurtosis:                       2.766   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large,  1e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Study of interaction and quadratic effects

# %%
formula11 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s \
             + cp_l + cp_s + Surr_temp + L_fusion + temp_init + \
            heat_transfer_coefficient_left + heat_transfer_coefficient_right + Length + \
            rho_l*rho_s + rho_l*k_l + rho_l*cp_l + rho_l*cp_s + rho_l*Surr_temp + rho_l*L_fusion + rho_l*heat_transfer_coefficient_left + \
             + rho_l*Length + rho_s*k_l + rho_s*cp_l + \
            rho_s*cp_s + rho_s*Surr_temp + rho_s*L_fusion  + rho_s*heat_transfer_coefficient_left + \
            rho_s*heat_transfer_coefficient_right + rho_s*Length + k_l*cp_l  + k_l*Surr_temp + k_l*L_fusion +\
             + k_l*heat_transfer_coefficient_left  + k_l*Length + k_s*cp_l  + \
            k_s*Surr_temp + k_s*heat_transfer_coefficient_left +  \
            cp_l*cp_s + cp_l*Surr_temp + cp_l*L_fusion + cp_l*temp_init + cp_l*heat_transfer_coefficient_left + \
            cp_l*Length +  cp_s*L_fusion + cp_s*temp_init + cp_s*heat_transfer_coefficient_left + cp_s*heat_transfer_coefficient_right + \
            cp_s*Length + Surr_temp*L_fusion + Surr_temp*temp_init + Surr_temp*heat_transfer_coefficient_left +  \
            Surr_temp*Length + L_fusion*heat_transfer_coefficient_left + L_fusion*heat_transfer_coefficient_right + L_fusion*Length + \
            + heat_transfer_coefficient_left*heat_transfer_coefficient_right + \
            heat_transfer_coefficient_left*Length + heat_transfer_coefficient_right*Length'

# %%
model10 = sm.OLS.from_formula(formula11, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model10.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 28 Aug 2024   Prob (F-statistic):                nan
# Time:                        09:53:03   Log-Likelihood:                    inf
# No. Observations:                  65   AIC:                              -inf
# Df Residuals:                      23   BIC:                              -inf
# Df Model:                          41
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               0          0        nan        nan           0           0
# rho_l                                                                   0          0        nan        nan           0           0
# rho_s                                                                   0          0        nan        nan           0           0
# k_l                                                                     0          0        nan        nan           0           0
# k_s                                                                     0          0        nan        nan           0           0
# cp_l                                                                    0          0        nan        nan           0           0
# cp_s                                                                    0          0        nan        nan           0           0
# Surr_temp                                                               0          0        nan        nan           0           0
# L_fusion                                                                0          0        nan        nan           0           0
# temp_init                                                               0          0        nan        nan           0           0
# heat_transfer_coefficient_left                                          0          0        nan        nan           0           0
# heat_transfer_coefficient_right                                         0          0        nan        nan           0           0
# Length                                                                  0          0        nan        nan           0           0
# rho_l:rho_s                                                             0          0        nan        nan           0           0
# rho_l:k_l                                                               0          0        nan        nan           0           0
# rho_l:cp_l                                                              0          0        nan        nan           0           0
# rho_l:cp_s                                                              0          0        nan        nan           0           0
# rho_l:Surr_temp                                                         0          0        nan        nan           0           0
# rho_l:L_fusion                                                          0          0        nan        nan           0           0
# rho_l:heat_transfer_coefficient_left                                    0          0        nan        nan           0           0
# rho_l:Length                                                            0          0        nan        nan           0           0
# rho_s:k_l                                                               0          0        nan        nan           0           0
# rho_s:cp_l                                                              0          0        nan        nan           0           0
# rho_s:cp_s                                                              0          0        nan        nan           0           0
# rho_s:Surr_temp                                                         0          0        nan        nan           0           0
# rho_s:L_fusion                                                          0          0        nan        nan           0           0
# rho_s:heat_transfer_coefficient_left                                    0          0        nan        nan           0           0
# rho_s:heat_transfer_coefficient_right                                   0          0        nan        nan           0           0
# rho_s:Length                                                            0          0        nan        nan           0           0
# k_l:cp_l                                                                0          0        nan        nan           0           0
# k_l:Surr_temp                                                           0          0        nan        nan           0           0
# k_l:L_fusion                                                            0          0        nan        nan           0           0
# k_l:heat_transfer_coefficient_left                                      0          0        nan        nan           0           0
# k_l:Length                                                              0          0        nan        nan           0           0
# k_s:cp_l                                                                0          0        nan        nan           0           0
# k_s:Surr_temp                                                           0          0        nan        nan           0           0
# k_s:heat_transfer_coefficient_left                                      0          0        nan        nan           0           0
# cp_l:cp_s                                                               0          0        nan        nan           0           0
# cp_l:Surr_temp                                                          0          0        nan        nan           0           0
# cp_l:L_fusion                                                           0          0        nan        nan           0           0
# cp_l:temp_init                                                          0          0        nan        nan           0           0
# cp_l:heat_transfer_coefficient_left                                     0          0        nan        nan           0           0
# cp_l:Length                                                             0          0        nan        nan           0           0
# cp_s:L_fusion                                                           0          0        nan        nan           0           0
# cp_s:temp_init                                                          0          0        nan        nan           0           0
# cp_s:heat_transfer_coefficient_left                                     0          0        nan        nan           0           0
# cp_s:heat_transfer_coefficient_right                                    0          0        nan        nan           0           0
# cp_s:Length                                                             0          0        nan        nan           0           0
# Surr_temp:L_fusion                                                      0          0        nan        nan           0           0
# Surr_temp:temp_init                                                     0          0        nan        nan           0           0
# Surr_temp:heat_transfer_coefficient_left                                0          0        nan        nan           0           0
# Surr_temp:Length                                                        0          0        nan        nan           0           0
# L_fusion:heat_transfer_coefficient_left                                 0          0        nan        nan           0           0
# L_fusion:heat_transfer_coefficient_right                                0          0        nan        nan           0           0
# L_fusion:Length                                                         0          0        nan        nan           0           0
# heat_transfer_coefficient_left:heat_transfer_coefficient_right          0          0        nan        nan           0           0
# heat_transfer_coefficient_left:Length                                   0          0        nan        nan           0           0
# heat_transfer_coefficient_right:Length                                  0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     9.38e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1781: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1870: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:956: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/statsmodels/stats/stattools.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)

# %%
formula12 = 'Lowest_Niyama ~  \
              heat_transfer_coefficient_left*heat_transfer_coefficient_right '

# %%
model12 = sm.OLS.from_formula(formula12, data=Fractional_Factorial_doe_center_pt).fit()

# Print the model summary
print(model12.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     27.00
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):           3.10e-11
# Time:                        19:47:30   Log-Likelihood:                -124.74
# No. Observations:                  65   AIC:                             257.5
# Df Residuals:                      61   BIC:                             266.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                         49.5519      5.532      8.957      0.000      38.490      60.614
# heat_transfer_coefficient_left                                    -3.7785      0.434     -8.707      0.000      -4.646      -2.911
# heat_transfer_coefficient_right                                   -3.7716      0.434     -8.691      0.000      -4.639      -2.904
# heat_transfer_coefficient_left:heat_transfer_coefficient_right     0.3054      0.034      8.971      0.000       0.237       0.374
# ==============================================================================
# Omnibus:                        8.918   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.958
# Skew:                           0.903   Prob(JB):                       0.0113
# Kurtosis:                       3.208   Cond. No.                     4.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
residual11 = model12.resid
Fractional_Factorial_doe_center_pt['Residuals'] =residual5
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model12.fittedvalues, residual11)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Model Output')
plt.xlabel('Lowest Niyama')
plt.ylabel('Residuals')
plt.show()
# Out:
# The plots of the residuals vs. fitted values are shown below

# %%
mse_residuals = np.mean(residual11**2)
print("Mean Squared Error of Residuals:", mse_residuals)
# Out:
# Mean Squared Error of Residuals: 2.7192778509615385

# %%
from scipy.stats import shapiro

# Shapiro-Wilk Test
stat, p_value = shapiro(residual11)
print('Shapiro-Wilk Test Statistic:', stat)
print('p-value:', p_value)

if p_value > 0.05:
    print('The residuals are normally distributed (fail to reject H0).')
else:
    print('The residuals are not normally distributed (reject H0).')
# Out:
# Shapiro-Wilk Test Statistic: 0.9085732985469697
# p-value: 0.00015234270146573166
# The residuals are not normally distributed (reject H0).

# %%
interaction_plot(
    x = Fractional_Factorial_doe_center_pt['heat_transfer_coefficient_left'],
    trace = Fractional_Factorial_doe_center_pt['heat_transfer_coefficient_right'],
    response = Fractional_Factorial_doe_center_pt['Lowest_Niyama'],
    func = np.mean,
    colors=['red', 'blue', 'green'],
    markers=['D', '^', 'o'],
    markersize=10,
    xlabel='htc_l',
    ylabel='Lowest Niyama',
    legendtitle='htc_r',
    legendloc='best',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 interaction_plot(
#       2     x = Fractional_Factorial_doe_center_pt['heat_transfer_coefficient_left'],
#       3     trace = Fractional_Factorial_doe_center_pt['heat_transfer_coefficient_right'],
#       4     response = Fractional_Factorial_doe_center_pt['Lowest_Niyama'],
#       5     func = np.mean,
#       6     colors=['red', 'blue', 'green'],
#       7     markers=['D', '^', 'o'],
#       8     markersize=10,
#       9     xlabel='htc_l',
#      10     ylabel='Lowest Niyama',
#      11     legendtitle='htc_r',
#      12     legendloc='best',
#      13 )
#
# NameError: name 'interaction_plot' is not defined

# %%
L1 = sim1d(2460.0, 2710.0, 104.0, 96.2, 1245.3, 963.0, 298.0, 389000, 913.0, 10.0, 12.0, 15.0e-3)
L2 = sim1d(2460.0, 2710.0, 104.0, 96.2, 1245.3, 963.0, 298.0, 389000, 913.0, 15.0, 12.0, 15.0e-3)
L3 = sim1d(2460.0, 2710.0, 104.0, 96.2, 1245.3, 963.0, 298.0, 389000, 913.0, 12.0, 10.0, 15.0e-3)
L4 = sim1d(2460.0, 2710.0, 104.0, 96.2, 1245.3, 963.0, 298.0, 389000, 913.0, 12.0, 15.0, 15.0e-3)
print(f'Lowest Niyama Number for the first set of input values: {L1}')
print(f'Lowest Niyama Number for the second set of input values: {L2}')
print(f'Lowest Niyama Number for the third set of input values: {L3}')  
print(f'Lowest Niyama Number for the fourth set of input values: {L4}')
# Out:
# (15255, 48)
# Lowest Niyama:2.57, rho_l:2460.0, rho_s:2710.0, k_l:104.0, k_s:96.2, cp_l:1245.3, cp_s:963.0, t_surr:298.0, L_fusion:389000, temp_init:913.0,htc_l:10.0,htc_r:12.0,length:0.015
# (12585, 48)
# Lowest Niyama:0.11, rho_l:2460.0, rho_s:2710.0, k_l:104.0, k_s:96.2, cp_l:1245.3, cp_s:963.0, t_surr:298.0, L_fusion:389000, temp_init:913.0,htc_l:15.0,htc_r:12.0,length:0.015
# (15255, 48)
# Lowest Niyama:2.62, rho_l:2460.0, rho_s:2710.0, k_l:104.0, k_s:96.2, cp_l:1245.3, cp_s:963.0, t_surr:298.0, L_fusion:389000, temp_init:913.0,htc_l:12.0,htc_r:10.0,length:0.015
# (12585, 48)
# Lowest Niyama:0.11, rho_l:2460.0, rho_s:2710.0, k_l:104.0, k_s:96.2, cp_l:1245.3, cp_s:963.0, t_surr:298.0, L_fusion:389000, temp_init:913.0,htc_l:12.0,htc_r:15.0,length:0.015
# Lowest Niyama Number for the first set of input values: 2.57
# Lowest Niyama Number for the second set of input values: 0.11
# Lowest Niyama Number for the third set of input values: 2.62
# Lowest Niyama Number for the fourth set of input values: 0.11

# %%
Fractional_Factorial_doe_center_pt = doe_center_pt.copy()

Fractional_Factorial_doe_center_pt['Lowest_Niyama'] = [0.0] * Fractional_Factorial_doe_center_pt.shape[0]

print(Fractional_Factorial_doe_center_pt.shape)
# Define alpha (distance for axial points, commonly sqrt(2) for rotatable design)
alpha = np.sqrt(2)
center_point = {factor: np.mean(levels) for factor, levels in factor_levels.items()}
# Calculate axial points
axial_points = []
for factor in factor_levels.keys():
    for direction in [-1, 1]:  # -alpha and +alpha direction
        axial_point = center_point.copy()
        axial_point[factor] = center_point[factor] + direction * alpha * (factor_levels[factor][1] - factor_levels[factor][0]) / 2
        axial_point['Lowest_Niyama'] = 0.0  # Assuming this remains 0 for axial points
        axial_points.append(axial_point)

# Create DataFrame for axial points
axial_pt_df = pd.DataFrame(axial_points, columns=Fractional_Factorial_doe_center_pt.columns)

# Combine with the existing DOE DataFrame
Fractional_Factorial_doe_axial = pd.concat([Fractional_Factorial_doe_center_pt, axial_pt_df], ignore_index=True)

# Check the shape of the full DOE with center and axial points
print(Fractional_Factorial_doe_axial.shape)

# Optionally, print the resulting DataFrame to verify
print(Fractional_Factorial_doe_axial)
# Out:
# (65, 13)
# (89, 13)
#        rho_l     rho_s      k_l     k_s      cp_l     cp_s  Surr_temp  \
# 0   2428.200  2678.200   76.640  68.840  1211.090  928.790      285.0
# 1   2491.790  2678.200   76.640  68.840  1211.090  928.790      298.0
# 2   2428.200  2741.790   76.640  68.840  1211.090  928.790      298.0
# 3   2491.790  2741.790   76.640  68.840  1211.090  928.790      285.0
# 4   2428.200  2678.200  131.350  68.840  1211.090  928.790      298.0
# ..       ...       ...      ...     ...       ...      ...        ...
# 84  2459.995  2709.995  103.995  96.195  1245.295  962.995      291.5
# 85  2459.995  2709.995  103.995  96.195  1245.295  962.995      291.5
# 86  2459.995  2709.995  103.995  96.195  1245.295  962.995      291.5
# 87  2459.995  2709.995  103.995  96.195  1245.295  962.995      291.5
# 88  2459.995  2709.995  103.995  96.195  1245.295  962.995      291.5
#
#     L_fusion  temp_init  heat_transfer_coefficient_left  \
# 0   373731.0      901.0                       10.000000
# 1   404269.0      925.0                       15.000000
# 2   404269.0      901.0                       10.000000
# 3   373731.0      925.0                       15.000000
# 4   373731.0      901.0                       10.000000
# ..       ...        ...                             ...
# 84  389000.0      913.0                       16.035534
# 85  389000.0      913.0                       12.500000
# 86  389000.0      913.0                       12.500000
# 87  389000.0      913.0                       12.500000
# 88  389000.0      913.0                       12.500000
#
#     heat_transfer_coefficient_right    Length  Lowest_Niyama
# 0                         10.000000  0.010000            0.0
# 1                         10.000000  0.010000            0.0
# 2                         15.000000  0.020000            0.0
# 3                         15.000000  0.020000            0.0
# 4                         15.000000  0.020000            0.0
# ..                              ...       ...            ...
# 84                        12.500000  0.015000            0.0
# 85                         8.964466  0.015000            0.0
# 86                        16.035534  0.015000            0.0
# 87                        12.500000  0.007929            0.0
# 88                        12.500000  0.022071            0.0
#
# [89 rows x 13 columns]

# %%
for i in range(Fractional_Factorial_doe_axial.shape[0]):
    input_values = Fractional_Factorial_doe_axial.iloc[i,:-1].values
    k= sim1d(*input_values)
    Fractional_Factorial_doe_axial.at[i, 'Lowest_Niyama'] = k
# Out:
# (23120, 48)
# Lowest Niyama:3.78, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (21454, 48)
# Lowest Niyama:0.5, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (10485, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8546, 48)
# Lowest Niyama:7.96, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12095, 48)
# Lowest Niyama:3.41, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10655, 48)
# Lowest Niyama:8.81, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (29769, 48)
# Lowest Niyama:3.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (23811, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (28371, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (22128, 48)
# Lowest Niyama:3.13, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (17263, 48)
# Lowest Niyama:4.11, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (14013, 48)
# Lowest Niyama:3.37, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13793, 48)
# Lowest Niyama:4.56, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10159, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19809, 48)
# Lowest Niyama:0.4, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (17433, 48)
# Lowest Niyama:2.77, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (19796, 48)
# Lowest Niyama:0.66, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (25692, 48)
# Lowest Niyama:4.67, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (9225, 48)
# Lowest Niyama:7.37, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (9900, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (10009, 48)
# Lowest Niyama:7.04, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (11771, 48)
# Lowest Niyama:5.77, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (23838, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (27093, 48)
# Lowest Niyama:3.6, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (22764, 48)
# Lowest Niyama:2.84, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (28435, 48)
# Lowest Niyama:0.21, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (13563, 48)
# Lowest Niyama:2.08, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (18288, 48)
# Lowest Niyama:4.99, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10977, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13091, 48)
# Lowest Niyama:5.11, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16029, 48)
# Lowest Niyama:2.32, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (21999, 48)
# Lowest Niyama:0.39, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:928.79, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (9282, 48)
# Lowest Niyama:1.0, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (12776, 48)
# Lowest Niyama:8.74, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (16289, 48)
# Lowest Niyama:3.97, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (18504, 48)
# Lowest Niyama:0.36, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (19415, 48)
# Lowest Niyama:3.82, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (24454, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (12779, 48)
# Lowest Niyama:3.22, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (15285, 48)
# Lowest Niyama:6.68, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11543, 48)
# Lowest Niyama:5.34, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (12903, 48)
# Lowest Niyama:2.22, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (25469, 48)
# Lowest Niyama:0.56, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (31187, 48)
# Lowest Niyama:2.69, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (20337, 48)
# Lowest Niyama:0.19, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (22509, 48)
# Lowest Niyama:2.76, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (8111, 48)
# Lowest Niyama:4.35, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (10203, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1211.09, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11798, 48)
# Lowest Niyama:7.08, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (10177, 48)
# Lowest Niyama:0.01, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (19819, 48)
# Lowest Niyama:0.01, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (14852, 48)
# Lowest Niyama:4.31, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (22967, 48)
# Lowest Niyama:0.0, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:10.0,htc_r:15.0,length:0.01
# (18898, 48)
# Lowest Niyama:4.78, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:15.0,htc_r:15.0,length:0.01
# (15295, 48)
# Lowest Niyama:6.26, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:10.0,htc_r:10.0,length:0.02
# (11632, 48)
# Lowest Niyama:2.97, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:68.84, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:15.0,htc_r:10.0,length:0.02
# (13269, 48)
# Lowest Niyama:2.63, rho_l:2428.2, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (11568, 48)
# Lowest Niyama:5.9, rho_l:2491.79, rho_s:2678.2, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (30185, 48)
# Lowest Niyama:2.23, rho_l:2428.2, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (26977, 48)
# Lowest Niyama:0.0, rho_l:2491.79, rho_s:2741.79, k_l:76.64, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (24348, 48)
# Lowest Niyama:2.47, rho_l:2428.2, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:901.0,htc_l:10.0,htc_r:10.0,length:0.01
# (19300, 48)
# Lowest Niyama:0.56, rho_l:2491.79, rho_s:2678.2, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:925.0,htc_l:15.0,htc_r:10.0,length:0.01
# (9394, 48)
# Lowest Niyama:0.27, rho_l:2428.2, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:285.0, L_fusion:373731.0, temp_init:901.0,htc_l:10.0,htc_r:15.0,length:0.02
# (8989, 48)
# Lowest Niyama:5.21, rho_l:2491.79, rho_s:2741.79, k_l:131.35, k_s:123.55, cp_l:1279.5, cp_s:997.2, t_surr:298.0, L_fusion:404269.0, temp_init:925.0,htc_l:15.0,htc_r:15.0,length:0.02
# (13331, 48)
# Lowest Niyama:4.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13205, 48)
# Lowest Niyama:4.13, rho_l:2415.0300797843474, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13457, 48)
# Lowest Niyama:5.07, rho_l:2504.9599202156523, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13447, 48)
# Lowest Niyama:4.95, rho_l:2459.995, rho_s:2665.0300797843474, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13219, 48)
# Lowest Niyama:4.23, rho_l:2459.995, rho_s:2754.9599202156523, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (17092, 48)
# Lowest Niyama:4.74, rho_l:2459.995, rho_s:2709.995, k_l:65.30918800128399, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (14165, 48)
# Lowest Niyama:4.35, rho_l:2459.995, rho_s:2709.995, k_l:142.68081199871602, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (15461, 48)
# Lowest Niyama:6.46, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:57.50918800128398, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (15979, 48)
# Lowest Niyama:3.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:134.880811998716, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13224, 48)
# Lowest Niyama:4.53, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1196.9218250990284, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13438, 48)
# Lowest Niyama:4.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1293.6681749009717, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13973, 48)
# Lowest Niyama:4.51, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:914.6218250990282, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (12751, 48)
# Lowest Niyama:4.56, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:1011.3681749009718, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13107, 48)
# Lowest Niyama:4.56, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:282.30761184457486, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13564, 48)
# Lowest Niyama:4.52, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:300.69238815542514, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (12810, 48)
# Lowest Niyama:4.36, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:367406.37311612524, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (13852, 48)
# Lowest Niyama:4.72, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:410593.62688387476, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.015
# (12934, 48)
# Lowest Niyama:4.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:896.0294372515228,htc_l:12.5,htc_r:12.5,length:0.015
# (13717, 48)
# Lowest Niyama:4.54, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:929.9705627484772,htc_l:12.5,htc_r:12.5,length:0.015
# (15478, 48)
# Lowest Niyama:1.02, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:8.964466094067262,htc_r:12.5,length:0.015
# (11814, 48)
# Lowest Niyama:3.76, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:16.035533905932738,htc_r:12.5,length:0.015
# (15478, 48)
# Lowest Niyama:1.05, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:8.964466094067262,length:0.015
# (11814, 48)
# Lowest Niyama:3.68, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:16.035533905932738,length:0.015
# (24549, 48)
# Lowest Niyama:2.57, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.007928932188134523
# (9301, 48)
# Lowest Niyama:6.42, rho_l:2459.995, rho_s:2709.995, k_l:103.995, k_s:96.195, cp_l:1245.295, cp_s:962.995, t_surr:291.5, L_fusion:389000.0, temp_init:913.0,htc_l:12.5,htc_r:12.5,length:0.022071067811865477

# %%
counts = range(1,len(Fractional_Factorial_doe_axial)+1)

plt.scatter(counts,Fractional_Factorial_doe_axial['Lowest_Niyama'], alpha=0.5, color='b')
plt.title('Lowest Niyama')
plt.xlabel('Run Number')
plt.ylabel('Lowest Niyama')
plt.show()

# %%
formula13 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model13 = sm.OLS.from_formula(formula13, data=Fractional_Factorial_doe_axial.iloc[:-1]).fit()
print(model13.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     2.073
# Date:                Wed, 28 Aug 2024   Prob (F-statistic):             0.0289
# Time:                        09:08:43   Log-Likelihood:                -185.84
# No. Observations:                  88   AIC:                             397.7
# Df Residuals:                      75   BIC:                             429.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                         -21.9506     40.609     -0.541      0.590    -102.848      58.947
# rho_l                               0.0067      0.008      0.811      0.420      -0.010       0.023
# rho_s                              -0.0061      0.008     -0.740      0.462      -0.023       0.010
# k_l                                -0.0012      0.010     -0.122      0.903      -0.020       0.018
# k_s                                -0.0218      0.010     -2.272      0.026      -0.041      -0.003
# cp_l                               -0.0001      0.008     -0.018      0.986      -0.015       0.015
# cp_s                               -0.0011      0.008     -0.143      0.886      -0.016       0.014
# Surr_temp                          -0.0140      0.040     -0.346      0.730      -0.094       0.067
# L_fusion                         6.317e-06   1.72e-05      0.367      0.714    -2.8e-05    4.06e-05
# temp_init                           0.0280      0.022      1.280      0.204      -0.016       0.072
# heat_transfer_coefficient_left      0.0598      0.105      0.569      0.571      -0.149       0.269
# heat_transfer_coefficient_right     0.0653      0.105      0.622      0.536      -0.144       0.275
# Length                            212.4619     53.330      3.984      0.000     106.224     318.700
# ==============================================================================
# Omnibus:                       10.608   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                9.857
# Skew:                          -0.746   Prob(JB):                      0.00724
# Kurtosis:                       2.319   Cond. No.                     8.99e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.99e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model13.predict(Fractional_Factorial_doe_axial.iloc[-1])
print(f'Predicted value of the response variable: {y_pred.values[0]}')
error = Fractional_Factorial_doe_axial.iloc[-1]['Lowest_Niyama'] - y_pred.values[0]
print(f'Prediction error: {error}')

# Perform a t-test to determine if the prediction error is significantly different from zero
# Extract the residuals from the model
residuals = model13.resid

# Calculate the mean and standard error of the residuals
mean_residuals = np.mean(residuals)
std_error = np.std(residuals, ddof=1) / np.sqrt(len(residuals))

# Perform t-test on the prediction error
t_statistic = (error - mean_residuals) / std_error
df = len(residuals) - 1  # Degrees of freedom
p_value = 2 * (1 - stats.t.cdf(np.abs(t_statistic), df))

print(f't-statistic: {t_statistic}')
print(f'p-value: {p_value}')

# Interpretation of the t-test result
if p_value < 0.05:
    print("The prediction error is significantly different from zero (reject null hypothesis).")
else:
    print("The prediction error is not significantly different from zero (fail to reject null hypothesis).")
# Out:
# Predicted value of the response variable: 4.738722448802797
# Prediction error: 1.6812775511972031
# t-statistic: 7.842861253051654
# p-value: 1.0311751452718454e-11
# The prediction error is significantly different from zero (reject null hypothesis).

# %%
residual6 = model13.resid
Fractional_Factorial_doe_center_pt['Residuals'] =residual6
print (f"The plots of the residuals vs. fitted values are shown below")
# Plot residuals vs. fitted values
plt.scatter(model13.fittedvalues, residual6)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs. Model Output')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()
# Out:
# The plots of the residuals vs. fitted values are shown below

# %%
from statsmodels.formula.api import ols

formula14 = 'Lowest_Niyama ~ rho_l + rho_s + k_l + k_s + \
           cp_l + cp_s + Surr_temp + L_fusion \
         + temp_init+ heat_transfer_coefficient_left + heat_transfer_coefficient_right+ Length'

model14 = ols(formula14, data=Fractional_Factorial_doe_axial).fit()

anova_results7 = sm.stats.anova_lm(model14, typ=2)

print(anova_results7)
# Out:
#                                      sum_sq    df          F    PR(>F)
# rho_l                              3.083116   1.0   0.660902  0.418781
# rho_s                              2.565551   1.0   0.549956  0.460621
# k_l                                0.069987   1.0   0.015003  0.902838
# k_s                               24.216119   1.0   5.191010  0.025514
# cp_l                               0.001467   1.0   0.000315  0.985897
# cp_s                               0.096323   1.0   0.020648  0.886122
# Surr_temp                          0.562848   1.0   0.120653  0.729287
# L_fusion                           0.632677   1.0   0.135622  0.713697
# temp_init                          7.691719   1.0   1.648810  0.203022
# heat_transfer_coefficient_left     1.519502   1.0   0.325723  0.569872
# heat_transfer_coefficient_right    1.814976   1.0   0.389061  0.534661
# Length                            81.872894   1.0  17.550418  0.000075
# Residual                         354.540840  76.0        NaN       NaN

# %%
formula15 = 'Lowest_Niyama ~   \
            + heat_transfer_coefficient_left*heat_transfer_coefficient_right + \
           np.power(heat_transfer_coefficient_left, 2)'

# %%
model16 = sm.OLS.from_formula(formula15, data=Fractional_Factorial_doe_axial).fit()

# Print the model summary
print(model16.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lowest_Niyama   R-squared:                       0.576
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     28.49
# Date:                Wed, 28 Aug 2024   Prob (F-statistic):           5.80e-15
# Time:                        10:26:38   Log-Likelihood:                -163.00
# No. Observations:                  89   AIC:                             336.0
# Df Residuals:                      84   BIC:                             348.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                         15.5967      9.812      1.590      0.116      -3.915      35.108
# heat_transfer_coefficient_left                                     1.8233      1.445      1.262      0.210      -1.049       4.696
# heat_transfer_coefficient_right                                   -3.7525      0.396     -9.476      0.000      -4.540      -2.965
# heat_transfer_coefficient_left:heat_transfer_coefficient_right     0.3054      0.031      9.821      0.000       0.244       0.367
# np.power(heat_transfer_coefficient_left, 2)                       -0.2233      0.056     -4.018      0.000      -0.334      -0.113
# ==============================================================================
# Omnibus:                       10.194   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.143
# Skew:                           0.769   Prob(JB):                      0.00627
# Kurtosis:                       3.607   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Extracting coefficients (terms) and their p-values
terms = model16.params.index
coefficients = model16.params.values
p_values = model16.pvalues.values

# Combine terms, coefficients, and p-values into a DataFrame
terms_pvalues_df = pd.DataFrame({
    'Term': terms,
    
    'P-Value': p_values
})
p_value_threshold = 0.05
significant_terms = terms_pvalues_df.loc[terms_pvalues_df['P-Value'] > p_value_threshold]
print(significant_terms)
# Out:
#                              Term   P-Value
# 0                       Intercept  0.115674
# 1  heat_transfer_coefficient_left  0.210382
